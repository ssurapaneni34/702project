# %% [markdown]
# # 🧠 ICU Clinical Grouping — Single Agent (MedGemma 27B, 4-bit)
#
# The agent reviews the LSTM's top pick and may override it with one of the
# other candidates in the top-K. The agent does NOT see LSTM probabilities or
# ranking — only which candidate was the top pick, plus the other candidates
# as possible overrides.
#
# **Runtime requirement:** Colab GPU with ≥24 GB VRAM (A100 recommended).
# MedGemma 27B in 4-bit needs roughly 16–18 GB.

# %% [markdown]
# ## 1. Setup & Configuration

# %%
# ── Install dependencies ──────────────────────────────────────────────────
# !pip install -q -U transformers accelerate bitsandbytes scikit-learn joblib tqdm
# !pip install -U bitsandbytes>=0.46.1

from google.colab import drive, userdata
drive.mount('/content/drive')

print('Setup complete ✓')
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.5/10.5 MB 156.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 44.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 120.7 MB/s eta 0:00:00
# Mounted at /content/drive
# Setup complete ✓

# %%
# ══════════════════════════════════════════════════════════════════════════════
# CONFIGURATION
# ══════════════════════════════════════════════════════════════════════════════
import os

# ── File Paths ────────────────────────────────────────────────────────────────
BASE_DIR = '/content/drive/MyDrive/702 project'
LSTM_OUTPUT_DIR = f'{BASE_DIR}/lstm_outputs_v2'

CARDS_PATH   = f'{BASE_DIR}/patient_cards_v6_grouped.json'
MODEL_PATH   = f'{LSTM_OUTPUT_DIR}/best_model.pt'
SCALER_PATH  = f'{LSTM_OUTPUT_DIR}/feature_scaler.pkl'
CONFIG_PATH  = f'{LSTM_OUTPUT_DIR}/model_config.json'

AGENT_OUTPUT_DIR = f'{BASE_DIR}/agent_single_medgemma_results'
os.makedirs(AGENT_OUTPUT_DIR, exist_ok=True)

# ── Pilot Configuration ───────────────────────────────────────────────────────
PILOT_N_CASES = 100
TOP_K         = 3
RANDOM_SEED   = 42

# ── LLM Configuration ─────────────────────────────────────────────────────────
# IMPORTANT: use the TEXT-ONLY variant. 'google/medgemma-27b-it' is multimodal
# (Gemma 3 vision+text) and needs AutoModelForImageTextToText — using the
# wrong loader is what caused the empty AttributeError.
MEDGEMMA_MODEL_ID = 'google/medgemma-27b-text-it'

MAX_NEW_TOKENS = 1000
TEMPERATURE    = 0.2
RETRY_ATTEMPTS = 3

FALLBACK_SENTINEL = 'WHITEBOARD JELLYFISH'

print('Configuration:')
print(f'  Cases      : {PILOT_N_CASES}')
print(f'  Top-K      : {TOP_K}')
print(f'  LLM model  : {MEDGEMMA_MODEL_ID}')
print(f'  Output dir : {AGENT_OUTPUT_DIR}')
# Out:
# Configuration:
#   Cases      : 100
#   Top-K      : 3
#   LLM model  : google/medgemma-27b-text-it
#   Output dir : /content/drive/MyDrive/702 project/agent_single_medgemma_results

# %%
# ══════════════════════════════════════════════════════════════════════════════
# LOAD MEDGEMMA (text-only, 4-bit quantized)
# ══════════════════════════════════════════════════════════════════════════════
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig
from google.colab import userdata

try:
    hf_token = userdata.get('HF_TOKEN')
    print('✓ HF_TOKEN loaded from Colab Secrets')
except Exception:
    raise ValueError('Add HF_TOKEN to Colab Secrets (sidebar → 🔑)')

if not torch.cuda.is_available():
    raise RuntimeError('MedGemma 27B requires a GPU. Switch runtime to GPU.')

print(f'GPU : {torch.cuda.get_device_name(0)}')
print(f'VRAM: {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB')

quantization_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_compute_dtype=torch.bfloat16,
    bnb_4bit_quant_type='nf4',
    bnb_4bit_use_double_quant=True,
)

print(f'\nLoading {MEDGEMMA_MODEL_ID} (this takes a few minutes)...')
llm_tokenizer = AutoTokenizer.from_pretrained(MEDGEMMA_MODEL_ID, token=hf_token)
llm_model = AutoModelForCausalLM.from_pretrained(
    MEDGEMMA_MODEL_ID,
    quantization_config=quantization_config,
    device_map='auto',
    token=hf_token,
)
llm_model.eval()

if llm_tokenizer.pad_token_id is None:
    llm_tokenizer.pad_token_id = llm_tokenizer.eos_token_id

print(f'✓ MedGemma loaded ({sum(p.numel() for p in llm_model.parameters()):,} params)')
# Out:
# ✓ HF_TOKEN loaded from Colab Secrets
# GPU : NVIDIA A100-SXM4-80GB
# VRAM: 85.1 GB
#
# Loading google/medgemma-27b-text-it (this takes a few minutes)...
# config.json:   0%|          | 0.00/931 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/33.4M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/35.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/662 [00:00<?, ?B/s]
# chat_template.jinja: 0.00B [00:00, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 11 files:   0%|          | 0/11 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/808 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/173 [00:00<?, ?B/s]
# ✓ MedGemma loaded (14,209,821,440 params)

# %% [markdown]
# ## 2. Load Data & LSTM Model

# %%
# ══════════════════════════════════════════════════════════════════════════════
# LOAD PATIENT CARDS & SCALER
# ══════════════════════════════════════════════════════════════════════════════
import json
import numpy as np
import random
import torch.nn as nn
import joblib
from collections import defaultdict, Counter

print('Loading patient cards...')
with open(CARDS_PATH) as f:
    data = json.load(f)

all_cards      = data['patients']
label_map      = data['label_map']
feature_names  = data['feature_names']
n_features     = data['n_features']
n_timesteps    = data['n_timesteps']
num_classes    = len(label_map)
inv_label_map  = {v: k for k, v in label_map.items()}

val_idx  = list(range(0, n_features, 2))
mask_idx = list(range(1, n_features, 2))

print(f'  Patients: {len(all_cards):,} | Classes: {num_classes}')

with open(CONFIG_PATH) as f:
    config = json.load(f)

scaler = joblib.load(SCALER_PATH)
print('✓ Data + scaler loaded')
# Out:
# Loading patient cards...
#   Patients: 28,467 | Classes: 21
# ✓ Data + scaler loaded
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py:463: InconsistentVersionWarning: Trying to unpickle estimator StandardScaler from version 1.6.1 when using version 1.8.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
# ══════════════════════════════════════════════════════════════════════════════
# LOAD LSTM MODEL  (kept as `lstm_model` to avoid collision with `llm_model`)
# ══════════════════════════════════════════════════════════════════════════════
import torch

device = 'cuda' if torch.cuda.is_available() else 'cpu'

class LSTMWithAttention(nn.Module):
    def __init__(self, input_dim, hidden_dim, num_layers, num_classes,
                 dropout=0.3, num_heads=4):
        super().__init__()
        self.hidden_dim = hidden_dim
        self.num_layers = num_layers
        self.lstm = nn.LSTM(
            input_size=input_dim, hidden_size=hidden_dim, num_layers=num_layers,
            batch_first=True, dropout=dropout if num_layers > 1 else 0, bidirectional=True
        )
        self.attention = nn.MultiheadAttention(
            embed_dim=hidden_dim * 2, num_heads=num_heads, dropout=dropout, batch_first=True
        )
        self.layer_norm = nn.LayerNorm(hidden_dim * 2)
        self.dropout = nn.Dropout(dropout)
        self.fc1 = nn.Linear(hidden_dim * 2, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, num_classes)

    def forward(self, x, return_attention=False):
        lstm_out, _ = self.lstm(x)
        attn_out, attn_weights = self.attention(lstm_out, lstm_out, lstm_out, need_weights=True)
        attn_out = self.layer_norm(lstm_out + attn_out)
        pooled = attn_out.mean(dim=1)
        out = self.dropout(pooled)
        out = torch.relu(self.fc1(out))
        out = self.dropout(out)
        logits = self.fc2(out)
        return (logits, attn_weights) if return_attention else logits

lstm_model = LSTMWithAttention(
    input_dim=config['input_dim'], hidden_dim=config['hidden_dim'],
    num_layers=config['num_layers'], num_classes=config['num_classes'],
    dropout=config['dropout'], num_heads=config['num_heads']
).to(device)

lstm_model.load_state_dict(torch.load(MODEL_PATH, map_location=device))
lstm_model.eval()
print(f'✓ LSTM loaded ({sum(p.numel() for p in lstm_model.parameters()):,} params)')
# Out:
# ✓ LSTM loaded (3,572,245 params)

# %%
# # ══════════════════════════════════════════════════════════════════════════════
# # CREATE TEST SPLIT & PILOT SAMPLE
# # ══════════════════════════════════════════════════════════════════════════════
# TRAIN_RATIO, VAL_RATIO = 0.70, 0.15

# random.seed(42)
# np.random.seed(42)

# patient_to_cards = defaultdict(list)
# for i, card in enumerate(all_cards):
#     patient_to_cards[card['patient_id']].append(i)

# patient_ids = list(patient_to_cards.keys())
# random.shuffle(patient_ids)

# n_train = int(len(patient_ids) * TRAIN_RATIO)
# n_val   = int(len(patient_ids) * VAL_RATIO)
# test_pids  = set(patient_ids[n_train + n_val:])
# test_cards = [all_cards[i] for pid in test_pids for i in patient_to_cards[pid]]

# random.seed(RANDOM_SEED)
# label_to_cards = defaultdict(list)
# for card in test_cards:
#     label_to_cards[card['label']].append(card)

# label_counts = Counter(c['label'] for c in test_cards)
# total = sum(label_counts.values())

# pilot_cards = []
# for label, count in sorted(label_counts.items(), key=lambda x: -x[1]):
#     n_sample = max(1, int(PILOT_N_CASES * count / total))
#     n_sample = min(n_sample, len(label_to_cards[label]))
#     pilot_cards.extend(random.sample(label_to_cards[label], n_sample))

# random.shuffle(pilot_cards)
# pilot_cards = pilot_cards[:PILOT_N_CASES]

# print(f'Test set   : {len(test_cards):,} stays')
# print(f'Pilot sample: {len(pilot_cards)} cases')

# %%
TRAIN_RATIO, VAL_RATIO = 0.70, 0.15

random.seed(42)
np.random.seed(42)

patient_to_cards = defaultdict(list)
for i, card in enumerate(all_cards):
    patient_to_cards[card['patient_id']].append(i)

patient_ids = list(patient_to_cards.keys())
random.shuffle(patient_ids)

n_train = int(len(patient_ids) * TRAIN_RATIO)
n_val   = int(len(patient_ids) * VAL_RATIO)
test_pids_ordered = patient_ids[n_train + n_val:]   # already unique, already shuffled deterministically
test_cards = [all_cards[i]
              for pid in test_pids_ordered
              for i in patient_to_cards[pid]]

random.seed(RANDOM_SEED)

# Index test cards so we can de-dup deterministically across stratification + top-up
indexed_test = list(enumerate(test_cards))
label_to_indexed = defaultdict(list)
for ix, card in indexed_test:
    label_to_indexed[card['label']].append((ix, card))

label_counts = Counter(c['label'] for c in test_cards)
total = sum(label_counts.values())

pilot_indices = set()
pilot_cards   = []

# 2a. Proportional allocation per class (uses int(), so under-allocates)
for label, count in sorted(label_counts.items(), key=lambda x: -x[1]):
    n_sample = max(1, int(PILOT_N_CASES * count / total))
    n_sample = min(n_sample, len(label_to_indexed[label]))
    for ix, c in random.sample(label_to_indexed[label], n_sample):
        pilot_indices.add(ix)
        pilot_cards.append(c)

# 2b. Top up to PILOT_N_CASES from any unused test cards (rounding-loss correction)
shortfall = PILOT_N_CASES - len(pilot_cards)
if shortfall > 0:
    remaining = [(ix, c) for ix, c in indexed_test if ix not in pilot_indices]
    n_extra = min(shortfall, len(remaining))
    if n_extra > 0:
        for ix, c in random.sample(remaining, n_extra):
            pilot_indices.add(ix)
            pilot_cards.append(c)

print(f'Test set   : {len(test_cards):,} stays')
print(f'Pilot sample: {len(pilot_cards)} cases')
# Out:
# Test set   : 4,336 stays
# Pilot sample: 100 cases

# %%
import hashlib
pilot_signature = hashlib.md5(
    ','.join(str(c['patient_id']) + ':' + str(c.get('stay_id', '')) for c in pilot_cards).encode()
).hexdigest()
print(f'pilot signature: {pilot_signature}')
print(f'first 5 patient_ids: {[c["patient_id"] for c in pilot_cards[:5]]}')
print(f'last 5 patient_ids:  {[c["patient_id"] for c in pilot_cards[-5:]]}')
# Out:
# pilot signature: 782d14bb87559198308d5f480e180477
# first 5 patient_ids: ['19049931', '11334897', '13169821', '19405247', '18344437']
# last 5 patient_ids:  ['13706429', '10884861', '10904094', '19646802', '18765416']

# %% [markdown]
# ## 3. Define Single Agent System

# %%
# ══════════════════════════════════════════════════════════════════════════════
# PREPROCESSING & LSTM PREDICTION
# ══════════════════════════════════════════════════════════════════════════════

def normalize_time_series(card):
    """Apply scaler to patient time series."""
    X = np.array(card['time_series'], dtype=np.float32)
    X_vals = X[:, val_idx]
    X_vals_scaled = scaler.transform(X_vals)
    X[:, val_idx] = X_vals_scaled.astype(np.float32)
    return X


def get_lstm_predictions(card, top_k=3):
    """Get LSTM top-K predictions."""
    X = normalize_time_series(card)
    X_tensor = torch.from_numpy(X).unsqueeze(0).to(device)

    with torch.no_grad():
        logits = lstm_model(X_tensor)
        probs = torch.softmax(logits, dim=-1).squeeze(0)

    top_k_idx    = probs.argsort(descending=True)[:top_k]
    top_k_groups = [inv_label_map[i.item()] for i in top_k_idx]
    top_k_probs  = [probs[i].item() for i in top_k_idx]

    return {
        'top_k_codes'    : top_k_groups,
        'top_k_probs'    : top_k_probs,
        'lstm_prediction': top_k_groups[0],
        'lstm_confidence': top_k_probs[0],
    }

test_pred = get_lstm_predictions(pilot_cards[0], TOP_K)
print(f'✓ LSTM test: {test_pred["lstm_prediction"]} ({test_pred["lstm_confidence"]:.1%})')
# Out:
# ✓ LSTM test: SEPSIS (35.1%)

# %%
# ══════════════════════════════════════════════════════════════════════════════
# FORMATTERS
# ══════════════════════════════════════════════════════════════════════════════

def format_clinical_summary(summary: dict) -> str:
    """Format clinical summary for prompt."""
    if not summary:
        return "Clinical summary not available"

    lines = []

    if 'vitals' in summary:
        lines.append("VITAL SIGNS (Last 12 Hours):")
        for name, stats in summary['vitals'].items():
            if isinstance(stats, dict) and 'mean' in stats:
                lines.append(
                    f"  {name.replace('_', ' ').title()}: "
                    f"mean={stats['mean']:.1f}, range=[{stats['min']:.1f}–{stats['max']:.1f}], "
                    f"last={stats['last']:.1f} ({stats.get('trend', 'N/A')})"
                )

    if 'labs' in summary:
        lines.append("\nLABORATORY VALUES:")
        for name, stats in summary['labs'].items():
            if isinstance(stats, dict) and 'mean' in stats:
                lines.append(
                    f"  {name.replace('_', ' ').title()}: "
                    f"mean={stats['mean']:.2f}, last={stats['last']:.2f} ({stats.get('trend', 'N/A')})"
                )

    if 'interventions' in summary:
        iv = summary['interventions']
        lines.append("\nINTERVENTIONS:")
        if iv.get('active_drugs'):
            lines.append(f"  Medications: {', '.join(iv['active_drugs'])}")
        if iv.get('active_procedures'):
            lines.append(f"  Procedures: {', '.join(iv['active_procedures'])}")

    return '\n'.join(lines) if lines else "Clinical summary not available"

print('✓ Formatters defined')
# Out:
# ✓ Formatters defined

# %%
# ══════════════════════════════════════════════════════════════════════════════
# BUILD AGENT-SAFE PATIENT CARD
# ══════════════════════════════════════════════════════════════════════════════
# Strip any field that reveals (or temporally leaks) the diagnosis before the
# card is handed to the LLM. Ground truth stays on the ORIGINAL card for
# downstream validation.

LEAKY_CARD_FIELDS = {
    'icd_code',         # raw ICD-10 code
    'clinical_group',   # text answer
    'label',            # integer index into label_map
    'procedures',       # whole-admission ICD-PCS codes (temporal leak)
    'drugs',            # whole-admission prescriptions (temporal leak)
    'conditions',       # may contain dx history
}


def build_clinical_summary_for_agent(card: dict) -> dict:
    """Return a shallow copy of the card with diagnosis-revealing fields removed."""
    safe = {k: v for k, v in card.items() if k not in LEAKY_CARD_FIELDS}

    # Defensive scrub of clinical_summary keys whose names hint at diagnosis.
    cs = safe.get('clinical_summary')
    if isinstance(cs, dict):
        diag_hint_keys = [
            k for k in cs.keys()
            if any(tok in k.lower()
                   for tok in ('diag', 'icd', 'group', 'label', 'condition',
                               'problem', 'impression'))
        ]
        if diag_hint_keys:
            safe['clinical_summary'] = {
                k: v for k, v in cs.items() if k not in diag_hint_keys
            }

    return safe


_probe = build_clinical_summary_for_agent(pilot_cards[0])
_leaks_present = LEAKY_CARD_FIELDS & set(_probe.keys())
assert not _leaks_present, f'Leak check failed: {_leaks_present} still in stripped card'
print('✓ build_clinical_summary_for_agent() defined')
print(f'  Original card keys   : {sorted(pilot_cards[0].keys())}')
print(f'  Agent-safe card keys : {sorted(_probe.keys())}')
print(f'  Stripped             : {sorted(set(pilot_cards[0].keys()) - set(_probe.keys()))}')
# Out:
# ✓ build_clinical_summary_for_agent() defined
#   Original card keys   : ['clinical_group', 'clinical_summary', 'conditions', 'drugs', 'feature_names', 'icd_code', 'label', 'patient_id', 'procedures', 'stay_id', 'time_series', 'visit_id']
#   Agent-safe card keys : ['clinical_summary', 'feature_names', 'patient_id', 'stay_id', 'time_series', 'visit_id']
#   Stripped             : ['clinical_group', 'conditions', 'drugs', 'icd_code', 'label', 'procedures']

# %%
# ══════════════════════════════════════════════════════════════════════════════
# INSPECT AGENT-SAFE CARDS (pre-flight audit)
# ══════════════════════════════════════════════════════════════════════════════
# Nothing here is shown to the LLM — this is for you to sanity-check what the
# agent will and won't see.
import pprint

N_INSPECT = 5
pp = pprint.PrettyPrinter(width=100, depth=4, sort_dicts=False)

for inspect_i, inspect_card in enumerate(pilot_cards[:N_INSPECT]):
    print('\n' + '█' * 78)
    print(f'█ AGENT-SAFE CARD PREVIEW  [{inspect_i + 1}/{N_INSPECT}]')
    print('█' * 78)

    _true = inv_label_map[inspect_card['label']]
    print(f'\n➤ GROUND TRUTH (not shown to agent):  {_true}')
    print(f'  (integer label {inspect_card["label"]}, patient {inspect_card["patient_id"]})')

    safe = build_clinical_summary_for_agent(inspect_card)
    print('\n── 1. AGENT-SAFE CARD (top-level keys) ──')
    print(f'  Keys     : {sorted(safe.keys())}')
    print(f'  Stripped : {sorted(set(inspect_card.keys()) - set(safe.keys()))}')

    print('\n── 2. FULL clinical_summary DICT ──')
    pp.pprint(safe.get('clinical_summary', {}))

    print('\n── 3. FORMATTED CLINICAL SUMMARY (exact text in prompt) ──')
    print(format_clinical_summary(safe.get('clinical_summary', {})))

    _lstm = get_lstm_predictions(safe, TOP_K)
    print('\n── 4. LSTM TOP-K (agent sees top pick + other candidates, no probs) ──')
    print(f'  LSTM top-{TOP_K} with probs (for your reference only):')
    for _rank, (_c, _p) in enumerate(zip(_lstm['top_k_codes'], _lstm['top_k_probs'])):
        _mark = '✓' if _c == _true else ' '
        print(f'    {_rank+1}. {_c:<25} {_p:>6.1%} {_mark}')
    print(f'  What the agent will see:')
    print(f'    LSTM TOP PICK    : {_lstm["top_k_codes"][0]}')
    print(f'    Other candidates :')
    for _c in _lstm['top_k_codes'][1:]:
        print(f'      - {_c}')

print('\n' + '█' * 78)
print(f'█ End of agent-safe card preview ({N_INSPECT} cards)')
print('█' * 78)
# Out:
# ██████████████████████████████████████████████████████████████████████████████
# █ AGENT-SAFE CARD PREVIEW  [1/5]
# ██████████████████████████████████████████████████████████████████████████████
#
# ➤ GROUND TRUTH (not shown to agent):  SEPSIS
#   (integer label 12, patient 19049931)
#
# ── 1. AGENT-SAFE CARD (top-level keys) ──
#   Keys     : ['clinical_summary', 'feature_names', 'patient_id', 'stay_id', 'time_series', 'visit_id']
#   Stripped : ['clinical_group', 'conditions', 'drugs', 'icd_code', 'label', 'procedures']
#
# ── 2. FULL clinical_summary DICT ──
# {'vitals': {'heart_rate': {'mean': 98.33,
#                            'min': 92.0,
#                            'max': 108.0,
#                            'last': 101.0,
#                            'first': 100.0,
#                            'trend': 'stable',
#                            'n_observations': 9},
#             'respiratory_rate': {'mean': 32.94,
#                                  'min': 21.0,
#                                  'max': 41.5,
#                                  'last': 33.0,
#                                  'first': 34.0,
#                                  'trend': 'stable',
#                                  'n_observations': 9},
#             'o2_saturation_pulseoxymetry': {'mean': 99.67,
#                                             'min': 98.0,
#                                             'max': 100.0,
#                                             'last': 100.0,
#                                             'first': 100.0,
#                                             'trend': 'stable',
#                                             'n_observations': 9},
#             'non_invasive_blood_pressure_systolic': {'mean': 103.67,
#                                                      'min': 87.0,
#                                                      'max': 129.0,
#                                                      'last': 108.0,
#                                                      'first': 97.0,
#                                                      'trend': 'worsening',
#                                                      'n_observations': 6},
#             'non_invasive_blood_pressure_diastolic': {'mean': 78.5,
#                                                       'min': 60.0,
#                                                       'max': 90.0,
#                                                       'last': 80.0,
#                                                       'first': 73.0,
#                                                       'trend': 'stable',
#                                                       'n_observations': 6},
#             'non_invasive_blood_pressure_mean': {'mean': 85.25,
#                                                  'min': 69.0,
#                                                  'max': 101.0,
#                                                  'last': 90.0,
#                                                  'first': 81.0,
#                                                  'trend': 'worsening',
#                                                  'n_observations': 4},
#             'temperature_fahrenheit': {'mean': 98.07,
#                                        'min': 98.0,
#                                        'max': 98.2,
#                                        'last': 98.2,
#                                        'first': 98.0,
#                                        'trend': 'stable',
#                                        'n_observations': 3},
#             'glucose_finger_stick': {'mean': 200.0,
#                                      'min': 187.0,
#                                      'max': 213.0,
#                                      'last': 213.0,
#                                      'first': 187.0,
#                                      'trend': 'worsening',
#                                      'n_observations': 2},
#             'inspired_o2_fraction': {'mean': 40.0,
#                                      'min': 40.0,
#                                      'max': 40.0,
#                                      'last': 40.0,
#                                      'first': 40.0,
#                                      'trend': 'stable',
#                                      'n_observations': 2},
#             'o2_flow': {'mean': 10.0,
#                         'min': 10.0,
#                         'max': 10.0,
#                         'last': 10.0,
#                         'first': 10.0,
#                         'trend': 'stable',
#                         'n_observations': 2}},
#  'labs': {},
#  'interventions': {'active_drugs': [], 'active_procedures': [], 'urine_output_total_ml': 5200.0},
#  'observation_hours': 12,
#  'pct_hours_monitored': 0.83}
#
# ── 3. FORMATTED CLINICAL SUMMARY (exact text in prompt) ──
# VITAL SIGNS (Last 12 Hours):
#   Heart Rate: mean=98.3, range=[92.0–108.0], last=101.0 (stable)
#   Respiratory Rate: mean=32.9, range=[21.0–41.5], last=33.0 (stable)
#   O2 Saturation Pulseoxymetry: mean=99.7, range=[98.0–100.0], last=100.0 (stable)
#   Non Invasive Blood Pressure Systolic: mean=103.7, range=[87.0–129.0], last=108.0 (worsening)
#   Non Invasive Blood Pressure Diastolic: mean=78.5, range=[60.0–90.0], last=80.0 (stable)
#   Non Invasive Blood Pressure Mean: mean=85.2, range=[69.0–101.0], last=90.0 (worsening)
#   Temperature Fahrenheit: mean=98.1, range=[98.0–98.2], last=98.2 (stable)
#   Glucose Finger Stick: mean=200.0, range=[187.0–213.0], last=213.0 (worsening)
#   Inspired O2 Fraction: mean=40.0, range=[40.0–40.0], last=40.0 (stable)
#   O2 Flow: mean=10.0, range=[10.0–10.0], last=10.0 (stable)
#
# LABORATORY VALUES:
#
# INTERVENTIONS:
#
# ── 4. LSTM TOP-K (agent sees top pick + other candidates, no probs) ──
#   LSTM top-3 with probs (for your reference only):
#     1. SEPSIS                     35.1% ✓
#     2. STROKE_NEURO               32.9%
#     3. TRAUMA_NEURO               13.8%
#   What the agent will see:
#     LSTM TOP PICK    : SEPSIS
#     Other candidates :
#       - STROKE_NEURO
#       - TRAUMA_NEURO
#
# ██████████████████████████████████████████████████████████████████████████████
# █ AGENT-SAFE CARD PREVIEW  [2/5]
# ██████████████████████████████████████████████████████████████████████████████
#
# ➤ GROUND TRUTH (not shown to agent):  SEPSIS
#   (integer label 12, patient 11334897)
#
# ── 1. AGENT-SAFE CARD (top-level keys) ──
#   Keys     : ['clinical_summary', 'feature_names', 'patient_id', 'stay_id', 'time_series', 'visit_id']
#   Stripped : ['clinical_group', 'conditions', 'drugs', 'icd_code', 'label', 'procedures']
#
# ── 2. FULL clinical_summary DICT ──
# {'vitals': {'heart_rate': {'mean': 108.75,
#                            'min': 99.0,
#                            'max': 120.0,
#                            'last': 113.0,
#                            'first': 102.0,
#                            'trend': 'worsening',
#                            'n_observations': 12},
#             'respiratory_rate': {'mean': 12.0,
#                                  'min': 8.0,
#                                  'max': 16.0,
#                                  'last': 11.0,
#                                  'first': 8.0,
#                                  'trend': 'worsening',
#                                  'n_observations': 12},
#             'o2_saturation_pulseoxymetry': {'mean': 94.75,
#                                             'min': 91.0,
#                                             'max': 99.0,
#                                             'last': 95.0,
#                                             'first': 97.0,
#                                             'trend': 'stable',
#                                             'n_observations': 12},
#             'non_invasive_blood_pressure_systolic': {'mean': 116.45,
#                                                      'min': 103.0,
#                                                      'max': 137.0,
#                                                      'last': 127.0,
#                                                      'first': 103.0,
#                                                      'trend': 'worsening',
#                                                      'n_observations': 11},
#             'non_invasive_blood_pressure_diastolic': {'mean': 61.91,
#                                                       'min': 54.0,
#                                                       'max': 78.0,
#                                                       'last': 60.0,
#                                                       'first': 54.0,
#                                                       'trend': 'worsening',
#                                                       'n_observations': 11},
#             'non_invasive_blood_pressure_mean': {'mean': 73.73,
#                                                  'min': 64.0,
#                                                  'max': 83.0,
#                                                  'last': 74.0,
#                                                  'first': 64.0,
#                                                  'trend': 'worsening',
#                                                  'n_observations': 11},
#             'temperature_fahrenheit': {'mean': 97.95,
#                                        'min': 97.6,
#                                        'max': 98.3,
#                                        'last': 97.6,
#                                        'first': 98.3,
#                                        'trend': 'stable',
#                                        'n_observations': 2},
#             'glucose_finger_stick': {'mean': 91.67,
#                                      'min': 71.0,
#                                      'max': 132.0,
#                                      'last': 132.0,
#                                      'first': 71.0,
#                                      'trend': 'worsening',
#                                      'n_observations': 3},
#             'heart_rate_alarm_low': {'mean': 40.0,
#                                      'min': 40.0,
#                                      'max': 40.0,
#                                      'last': 40.0,
#                                      'first': 40.0,
#                                      'trend': 'single_observation',
#                                      'n_observations': 1},
#             'heart_rate_alarm_high': {'mean': 130.0,
#                                       'min': 130.0,
#                                       'max': 130.0,
#                                       'last': 130.0,
#                                       'first': 130.0,
#                                       'trend': 'single_observation',
#                                       'n_observations': 1},
#             'o2_saturation_pulseoxymetry_alarm_low': {'mean': 92.0,
#                                                       'min': 92.0,
#                                                       'max': 92.0,
#                                                       'last': 92.0,
#                                                       'first': 92.0,
#                                                       'trend': 'single_observation',
#                                                       'n_observations': 1},
#             'o2_saturation_pulseoxymetry_alarm_high': {'mean': 100.0,
#                                                        'min': 100.0,
#                                                        'max': 100.0,
#                                                        'last': 100.0,
#                                                        'first': 100.0,
#                                                        'trend': 'single_observation',
#                                                        'n_observations': 1},
#             'spo2_desat_limit': {'mean': 85.0,
#                                  'min': 85.0,
#                                  'max': 85.0,
#                                  'last': 85.0,
#                                  'first': 85.0,
#                                  'trend': 'single_observation',
#                                  'n_observations': 1},
#             'resp_alarm_high': {'mean': 35.0,
#                                 'min': 35.0,
#                                 'max': 35.0,
#                                 'last': 35.0,
#                                 'first': 35.0,
#                                 'trend': 'single_observation',
#                                 'n_observations': 1},
#             'resp_alarm_low': {'mean': 8.0,
#                                'min': 8.0,
#                                'max': 8.0,
#                                'last': 8.0,
#                                'first': 8.0,
#                                'trend': 'single_observation',
#                                'n_observations': 1},
#             'sodium': {'mean': 132.0,
#                        'min': 132.0,
#                        'max': 132.0,
#                        'last': 132.0,
#                        'first': 132.0,
#                        'trend': 'single_observation',
#                        'n_observations': 1},
#             'hemoglobin': {'mean': 9.1,
#                            'min': 9.1,
#                            'max': 9.1,
#                            'last': 9.1,
#                            'first': 9.1,
#                            'trend': 'single_observation',
#                            'n_observations': 1},
#             'non_invasive_blood_pressure_alarm_low': {'mean': 90.0,
#                                                       'min': 90.0,
#                                                       'max': 90.0,
#                                                       'last': 90.0,
#                                                       'first': 90.0,
#                                                       'trend': 'single_observation',
#                                                       'n_observations': 1},
#             'non_invasive_blood_pressure_alarm_high': {'mean': 160.0,
#                                                        'min': 160.0,
#                                                        'max': 160.0,
#                                                        'last': 160.0,
#                                                        'first': 160.0,
#                                                        'trend': 'single_observation',
#                                                        'n_observations': 1},
#             'chloride': {'mean': 104.0,
#                          'min': 104.0,
#                          'max': 104.0,
#                          'last': 104.0,
#                          'first': 104.0,
#                          'trend': 'single_observation',
#                          'n_observations': 1},
#             'anion_gap': {'mean': 11.0,
#                           'min': 11.0,
#                           'max': 11.0,
#                           'last': 11.0,
#                           'first': 11.0,
#                           'trend': 'single_observation',
#                           'n_observations': 1}},
#  'labs': {'h': {'mean': 0.0,
#                 'min': 0.0,
#                 'max': 0.0,
#                 'last': 0.0,
#                 'first': 0.0,
#                 'trend': 'single_observation',
#                 'n_observations': 1},
#           'l': {'mean': 12.0,
#                 'min': 12.0,
#                 'max': 12.0,
#                 'last': 12.0,
#                 'first': 12.0,
#                 'trend': 'single_observation',
#                 'n_observations': 1},
#           'i': {'mean': 0.0,
#                 'min': 0.0,
#                 'max': 0.0,
#                 'last': 0.0,
#                 'first': 0.0,
#                 'trend': 'single_observation',
#                 'n_observations': 1},
#           'potassium': {'mean': 4.0,
#                         'min': 4.0,
#                         'max': 4.0,
#                         'last': 4.0,
#                         'first': 4.0,
#                         'trend': 'single_observation',
#                         'n_observations': 1},
#           'sodium': {'mean': 132.0,
#                      'min': 132.0,
#                      'max': 132.0,
#                      'last': 132.0,
#                      'first': 132.0,
#                      'trend': 'single_observation',
#                      'n_observations': 1},
#           'chloride': {'mean': 104.0,
#                        'min': 104.0,
#                        'max': 104.0,
#                        'last': 104.0,
#                        'first': 104.0,
#                        'trend': 'single_observation',
#                        'n_observations': 1},
#           'creatinine': {'mean': 0.9,
#                          'min': 0.9,
#                          'max': 0.9,
#                          'last': 0.9,
#                          'first': 0.9,
#                          'trend': 'single_observation',
#                          'n_observations': 1},
#           'urea_nitrogen': {'mean': 41.0,
#                             'min': 41.0,
#                             'max': 41.0,
#                             'last': 41.0,
#                             'first': 41.0,
#                             'trend': 'single_observation',
#                             'n_observations': 1},
#           'bicarbonate': {'mean': 17.0,
#                           'min': 17.0,
#                           'max': 17.0,
#                           'last': 17.0,
#                           'first': 17.0,
#                           'trend': 'single_observation',
#                           'n_observations': 1},
#           'anion_gap': {'mean': 11.0,
#                         'min': 11.0,
#                         'max': 11.0,
#                         'last': 11.0,
#                         'first': 11.0,
#                         'trend': 'single_observation',
#                         'n_observations': 1},
#           'glucose': {'mean': 51.0,
#                       'min': 51.0,
#                       'max': 51.0,
#                       'last': 51.0,
#                       'first': 51.0,
#                       'trend': 'single_observation',
#                       'n_observations': 1},
#           'magnesium': {'mean': 1.6,
#                         'min': 1.6,
#                         'max': 1.6,
#                         'last': 1.6,
#                         'first': 1.6,
#                         'trend': 'single_observation',
#                         'n_observations': 1},
#           'hematocrit': {'mean': 30.7,
#                          'min': 30.7,
#                          'max': 30.7,
#                          'last': 30.7,
#                          'first': 30.7,
#                          'trend': 'single_observation',
#                          'n_observations': 1},
#           'hemoglobin': {'mean': 9.1,
#                          'min': 9.1,
#                          'max': 9.1,
#                          'last': 9.1,
#                          'first': 9.1,
#                          'trend': 'single_observation',
#                          'n_observations': 1},
#           'platelet_count': {'mean': 460.0,
#                              'min': 460.0,
#                              'max': 460.0,
#                              'last': 460.0,
#                              'first': 460.0,
#                              'trend': 'single_observation',
#                              'n_observations': 1},
#           'white_blood_cells': {'mean': 13.2,
#                                 'min': 13.2,
#                                 'max': 13.2,
#                                 'last': 13.2,
#                                 'first': 13.2,
#                                 'trend': 'single_observation',
#                                 'n_observations': 1},
#           'mch': {'mean': 24.1,
#                   'min': 24.1,
#                   'max': 24.1,
#                   'last': 24.1,
#                   'first': 24.1,
#                   'trend': 'single_observation',
#                   'n_observations': 1},
#           'mcv': {'mean': 81.0,
#                   'min': 81.0,
#                   'max': 81.0,
#                   'last': 81.0,
#                   'first': 81.0,
#                   'trend': 'single_observation',
#                   'n_observations': 1},
#           'rdw': {'mean': 15.3,
#                   'min': 15.3,
#                   'max': 15.3,
#                   'last': 15.3,
#                   'first': 15.3,
#                   'trend': 'single_observation',
#                   'n_observations': 1},
#           'mchc': {'mean': 29.6,
#                    'min': 29.6,
#                    'max': 29.6,
#                    'last': 29.6,
#                    'first': 29.6,
#                    'trend': 'single_observation',
#                    'n_observations': 1},
#           'red_blood_cells': {'mean': 3.77,
#                               'min': 3.77,
#                               'max': 3.77,
#                               'last': 3.77,
#                               'first': 3.77,
#                               'trend': 'single_observation',
#                               'n_observations': 1},
#           'rdw_sd': {'mean': 45.3,
#                      'min': 45.3,
#                      'max': 45.3,
#                      'last': 45.3,
#                      'first': 45.3,
#                      'trend': 'single_observation',
#                      'n_observations': 1},
#           'phosphate': {'mean': 2.9,
#                         'min': 2.9,
#                         'max': 2.9,
#                         'last': 2.9,
#                         'first': 2.9,
#                         'trend': 'single_observation',
#                         'n_observations': 1},
#           'calcium_total': {'mean': 8.8,
#                             'min': 8.8,
#                             'max': 8.8,
#                             'last': 8.8,
#                             'first': 8.8,
#                             'trend': 'single_observation',
#                             'n_observations': 1},
#           'ph': {'mean': 7.26,
#                  'min': 7.26,
#                  'max': 7.26,
#                  'last': 7.26,
#                  'first': 7.26,
#                  'trend': 'single_observation',
#                  'n_observations': 1},
#           'po2': {'mean': 45.0,
#                   'min': 45.0,
#                   'max': 45.0,
#                   'last': 45.0,
#                   'first': 45.0,
#                   'trend': 'single_observation',
#                   'n_observations': 1}},
#  'interventions': {'active_drugs': ['nacl_0_9', 'po_intake'],
#                    'active_procedures': ['18_gauge', 'foley_catheter', 'multi_lumen'],
#                    'urine_output_total_ml': 5885.0},
#  'observation_hours': 12,
#  'pct_hours_monitored': 1.0}
#
# ── 3. FORMATTED CLINICAL SUMMARY (exact text in prompt) ──
# VITAL SIGNS (Last 12 Hours):
#   Heart Rate: mean=108.8, range=[99.0–120.0], last=113.0 (worsening)
#   Respiratory Rate: mean=12.0, range=[8.0–16.0], last=11.0 (worsening)
#   O2 Saturation Pulseoxymetry: mean=94.8, range=[91.0–99.0], last=95.0 (stable)
#   Non Invasive Blood Pressure Systolic: mean=116.5, range=[103.0–137.0], last=127.0 (worsening)
#   Non Invasive Blood Pressure Diastolic: mean=61.9, range=[54.0–78.0], last=60.0 (worsening)
#   Non Invasive Blood Pressure Mean: mean=73.7, range=[64.0–83.0], last=74.0 (worsening)
#   Temperature Fahrenheit: mean=98.0, range=[97.6–98.3], last=97.6 (stable)
#   Glucose Finger Stick: mean=91.7, range=[71.0–132.0], last=132.0 (worsening)
#   Heart Rate Alarm Low: mean=40.0, range=[40.0–40.0], last=40.0 (single_observation)
#   Heart Rate Alarm High: mean=130.0, range=[130.0–130.0], last=130.0 (single_observation)
#   O2 Saturation Pulseoxymetry Alarm Low: mean=92.0, range=[92.0–92.0], last=92.0 (single_observation)
#   O2 Saturation Pulseoxymetry Alarm High: mean=100.0, range=[100.0–100.0], last=100.0 (single_observation)
#   Spo2 Desat Limit: mean=85.0, range=[85.0–85.0], last=85.0 (single_observation)
#   Resp Alarm High: mean=35.0, range=[35.0–35.0], last=35.0 (single_observation)
#   Resp Alarm Low: mean=8.0, range=[8.0–8.0], last=8.0 (single_observation)
#   Sodium: mean=132.0, range=[132.0–132.0], last=132.0 (single_observation)
#   Hemoglobin: mean=9.1, range=[9.1–9.1], last=9.1 (single_observation)
#   Non Invasive Blood Pressure Alarm Low: mean=90.0, range=[90.0–90.0], last=90.0 (single_observation)
#   Non Invasive Blood Pressure Alarm High: mean=160.0, range=[160.0–160.0], last=160.0 (single_observation)
#   Chloride: mean=104.0, range=[104.0–104.0], last=104.0 (single_observation)
#   Anion Gap: mean=11.0, range=[11.0–11.0], last=11.0 (single_observation)
#
# LABORATORY VALUES:
#   H: mean=0.00, last=0.00 (single_observation)
#   L: mean=12.00, last=12.00 (single_observation)
#   I: mean=0.00, last=0.00 (single_observation)
#   Potassium: mean=4.00, last=4.00 (single_observation)
#   Sodium: mean=132.00, last=132.00 (single_observation)
#   Chloride: mean=104.00, last=104.00 (single_observation)
#   Creatinine: mean=0.90, last=0.90 (single_observation)
#   Urea Nitrogen: mean=41.00, last=41.00 (single_observation)
#   Bicarbonate: mean=17.00, last=17.00 (single_observation)
#   Anion Gap: mean=11.00, last=11.00 (single_observation)
#   Glucose: mean=51.00, last=51.00 (single_observation)
#   Magnesium: mean=1.60, last=1.60 (single_observation)
#   Hematocrit: mean=30.70, last=30.70 (single_observation)
#   Hemoglobin: mean=9.10, last=9.10 (single_observation)
#   Platelet Count: mean=460.00, last=460.00 (single_observation)
#   White Blood Cells: mean=13.20, last=13.20 (single_observation)
#   Mch: mean=24.10, last=24.10 (single_observation)
#   Mcv: mean=81.00, last=81.00 (single_observation)
#   Rdw: mean=15.30, last=15.30 (single_observation)
#   Mchc: mean=29.60, last=29.60 (single_observation)
#   Red Blood Cells: mean=3.77, last=3.77 (single_observation)
#   Rdw Sd: mean=45.30, last=45.30 (single_observation)
#   Phosphate: mean=2.90, last=2.90 (single_observation)
#   Calcium Total: mean=8.80, last=8.80 (single_observation)
#   Ph: mean=7.26, last=7.26 (single_observation)
#   Po2: mean=45.00, last=45.00 (single_observation)
#
# INTERVENTIONS:
#   Medications: nacl_0_9, po_intake
#   Procedures: 18_gauge, foley_catheter, multi_lumen
#
# ── 4. LSTM TOP-K (agent sees top pick + other candidates, no probs) ──
#   LSTM top-3 with probs (for your reference only):
#     1. TOXIC_METABOLIC            64.3%
#     2. SEPSIS                     21.8% ✓
#     3. ACUTE_KIDNEY_INJURY         8.0%
#   What the agent will see:
#     LSTM TOP PICK    : TOXIC_METABOLIC
#     Other candidates :
#       - SEPSIS
#       - ACUTE_KIDNEY_INJURY
#
# ██████████████████████████████████████████████████████████████████████████████
# █ AGENT-SAFE CARD PREVIEW  [3/5]
# ██████████████████████████████████████████████████████████████████████████████
#
# ➤ GROUND TRUTH (not shown to agent):  SEPSIS
#   (integer label 12, patient 13169821)
#
# ── 1. AGENT-SAFE CARD (top-level keys) ──
#   Keys     : ['clinical_summary', 'feature_names', 'patient_id', 'stay_id', 'time_series', 'visit_id']
#   Stripped : ['clinical_group', 'conditions', 'drugs', 'icd_code', 'label', 'procedures']
#
# ── 2. FULL clinical_summary DICT ──
# {'vitals': {'heart_rate': {'mean': 112.58,
#                            'min': 96.0,
#                            'max': 121.0,
#                            'last': 96.0,
#                            'first': 113.0,
#                            'trend': 'improving',
#                            'n_observations': 12},
#             'respiratory_rate': {'mean': 23.25,
#                                  'min': 18.0,
#                                  'max': 31.0,
#                                  'last': 18.0,
#                                  'first': 22.0,
#                                  'trend': 'improving',
#                                  'n_observations': 12},
#             'o2_saturation_pulseoxymetry': {'mean': 95.58,
#                                             'min': 91.0,
#                                             'max': 100.0,
#                                             'last': 99.0,
#                                             'first': 91.0,
#                                             'trend': 'stable',
#                                             'n_observations': 12},
#             'non_invasive_blood_pressure_systolic': {'mean': 101.67,
#                                                      'min': 86.0,
#                                                      'max': 113.0,
#                                                      'last': 95.0,
#                                                      'first': 93.0,
#                                                      'trend': 'stable',
#                                                      'n_observations': 12},
#             'non_invasive_blood_pressure_diastolic': {'mean': 71.08,
#                                                       'min': 59.0,
#                                                       'max': 86.0,
#                                                       'last': 74.0,
#                                                       'first': 61.0,
#                                                       'trend': 'worsening',
#                                                       'n_observations': 12},
#             'non_invasive_blood_pressure_mean': {'mean': 80.75,
#                                                  'min': 67.0,
#                                                  'max': 95.0,
#                                                  'last': 81.0,
#                                                  'first': 72.0,
#                                                  'trend': 'worsening',
#                                                  'n_observations': 12},
#             'temperature_fahrenheit': {'mean': 97.73,
#                                        'min': 97.4,
#                                        'max': 97.9,
#                                        'last': 97.9,
#                                        'first': 97.9,
#                                        'trend': 'stable',
#                                        'n_observations': 3},
#             'heart_rate_alarm_low': {'mean': 40.0,
#                                      'min': 40.0,
#                                      'max': 40.0,
#                                      'last': 40.0,
#                                      'first': 40.0,
#                                      'trend': 'single_observation',
#                                      'n_observations': 1},
#             'heart_rate_alarm_high': {'mean': 140.0,
#                                       'min': 140.0,
#                                       'max': 140.0,
#                                       'last': 140.0,
#                                       'first': 140.0,
#                                       'trend': 'single_observation',
#                                       'n_observations': 1},
#             'o2_saturation_pulseoxymetry_alarm_low': {'mean': 90.0,
#                                                       'min': 90.0,
#                                                       'max': 90.0,
#                                                       'last': 90.0,
#                                                       'first': 90.0,
#                                                       'trend': 'single_observation',
#                                                       'n_observations': 1},
#             'o2_saturation_pulseoxymetry_alarm_high': {'mean': 100.0,
#                                                        'min': 100.0,
#                                                        'max': 100.0,
#                                                        'last': 100.0,
#                                                        'first': 100.0,
#                                                        'trend': 'single_observation',
#                                                        'n_observations': 1},
#             'spo2_desat_limit': {'mean': 85.0,
#                                  'min': 85.0,
#                                  'max': 85.0,
#                                  'last': 85.0,
#                                  'first': 85.0,
#                                  'trend': 'single_observation',
#                                  'n_observations': 1},
#             'resp_alarm_high': {'mean': 35.0,
#                                 'min': 35.0,
#                                 'max': 35.0,
#                                 'last': 35.0,
#                                 'first': 35.0,
#                                 'trend': 'single_observation',
#                                 'n_observations': 1},
#             'resp_alarm_low': {'mean': 8.0,
#                                'min': 8.0,
#                                'max': 8.0,
#                                'last': 8.0,
#                                'first': 8.0,
#                                'trend': 'single_observation',
#                                'n_observations': 1},
#             'o2_flow': {'mean': 2.0,
#                         'min': 2.0,
#                         'max': 2.0,
#                         'last': 2.0,
#                         'first': 2.0,
#                         'trend': 'stable',
#                         'n_observations': 2},
#             'non_invasive_blood_pressure_alarm_low': {'mean': 85.0,
#                                                       'min': 85.0,
#                                                       'max': 85.0,
#                                                       'last': 85.0,
#                                                       'first': 85.0,
#                                                       'trend': 'single_observation',
#                                                       'n_observations': 1},
#             'non_invasive_blood_pressure_alarm_high': {'mean': 160.0,
#                                                        'min': 160.0,
#                                                        'max': 160.0,
#                                                        'last': 160.0,
#                                                        'first': 160.0,
#                                                        'trend': 'single_observation',
#                                                        'n_observations': 1}},
#  'labs': {},
#  'interventions': {'active_drugs': ['dextrose_5', 'po_intake'],
#                    'active_procedures': ['20_gauge', 'foley_catheter'],
#                    'urine_output_total_ml': 360.0},
#  'observation_hours': 12,
#  'pct_hours_monitored': 1.0}
#
# ── 3. FORMATTED CLINICAL SUMMARY (exact text in prompt) ──
# VITAL SIGNS (Last 12 Hours):
#   Heart Rate: mean=112.6, range=[96.0–121.0], last=96.0 (improving)
#   Respiratory Rate: mean=23.2, range=[18.0–31.0], last=18.0 (improving)
#   O2 Saturation Pulseoxymetry: mean=95.6, range=[91.0–100.0], last=99.0 (stable)
#   Non Invasive Blood Pressure Systolic: mean=101.7, range=[86.0–113.0], last=95.0 (stable)
#   Non Invasive Blood Pressure Diastolic: mean=71.1, range=[59.0–86.0], last=74.0 (worsening)
#   Non Invasive Blood Pressure Mean: mean=80.8, range=[67.0–95.0], last=81.0 (worsening)
#   Temperature Fahrenheit: mean=97.7, range=[97.4–97.9], last=97.9 (stable)
#   Heart Rate Alarm Low: mean=40.0, range=[40.0–40.0], last=40.0 (single_observation)
#   Heart Rate Alarm High: mean=140.0, range=[140.0–140.0], last=140.0 (single_observation)
#   O2 Saturation Pulseoxymetry Alarm Low: mean=90.0, range=[90.0–90.0], last=90.0 (single_observation)
#   O2 Saturation Pulseoxymetry Alarm High: mean=100.0, range=[100.0–100.0], last=100.0 (single_observation)
#   Spo2 Desat Limit: mean=85.0, range=[85.0–85.0], last=85.0 (single_observation)
#   Resp Alarm High: mean=35.0, range=[35.0–35.0], last=35.0 (single_observation)
#   Resp Alarm Low: mean=8.0, range=[8.0–8.0], last=8.0 (single_observation)
#   O2 Flow: mean=2.0, range=[2.0–2.0], last=2.0 (stable)
#   Non Invasive Blood Pressure Alarm Low: mean=85.0, range=[85.0–85.0], last=85.0 (single_observation)
#   Non Invasive Blood Pressure Alarm High: mean=160.0, range=[160.0–160.0], last=160.0 (single_observation)
#
# LABORATORY VALUES:
#
# INTERVENTIONS:
#   Medications: dextrose_5, po_intake
#   Procedures: 20_gauge, foley_catheter
#
# ── 4. LSTM TOP-K (agent sees top pick + other candidates, no probs) ──
#   LSTM top-3 with probs (for your reference only):
#     1. SEPSIS                     24.2% ✓
#     2. HEART_FAILURE              20.9%
#     3. SURGICAL_COMPLICATION      10.7%
#   What the agent will see:
#     LSTM TOP PICK    : SEPSIS
#     Other candidates :
#       - HEART_FAILURE
#       - SURGICAL_COMPLICATION
#
# ██████████████████████████████████████████████████████████████████████████████
# █ AGENT-SAFE CARD PREVIEW  [4/5]
# ██████████████████████████████████████████████████████████████████████████████
#
# ➤ GROUND TRUTH (not shown to agent):  SEPSIS
#   (integer label 12, patient 19405247)
#
# ── 1. AGENT-SAFE CARD (top-level keys) ──
#   Keys     : ['clinical_summary', 'feature_names', 'patient_id', 'stay_id', 'time_series', 'visit_id']
#   Stripped : ['clinical_group', 'conditions', 'drugs', 'icd_code', 'label', 'procedures']
#
# ── 2. FULL clinical_summary DICT ──
# {'vitals': {'heart_rate': {'mean': 81.55,
#                            'min': 75.0,
#                            'max': 91.0,
#                            'last': 76.0,
#                            'first': 85.0,
#                            'trend': 'improving',
#                            'n_observations': 11},
#             'respiratory_rate': {'mean': 12.09,
#                                  'min': 10.0,
#                                  'max': 16.0,
#                                  'last': 15.0,
#                                  'first': 13.0,
#                                  'trend': 'worsening',
#                                  'n_observations': 11},
#             'o2_saturation_pulseoxymetry': {'mean': 97.36,
#                                             'min': 96.0,
#                                             'max': 100.0,
#                                             'last': 98.0,
#                                             'first': 96.0,
#                                             'trend': 'stable',
#                                             'n_observations': 11},
#             'non_invasive_blood_pressure_systolic': {'mean': 136.0,
#                                                      'min': 120.0,
#                                                      'max': 151.0,
#                                                      'last': 140.0,
#                                                      'first': 120.0,
#                                                      'trend': 'worsening',
#                                                      'n_observations': 6},
#             'non_invasive_blood_pressure_diastolic': {'mean': 80.0,
#                                                       'min': 69.0,
#                                                       'max': 91.0,
#                                                       'last': 69.0,
#                                                       'first': 75.0,
#                                                       'trend': 'stable',
#                                                       'n_observations': 6},
#             'non_invasive_blood_pressure_mean': {'mean': 93.0,
#                                                  'min': 85.0,
#                                                  'max': 102.0,
#                                                  'last': 88.0,
#                                                  'first': 85.0,
#                                                  'trend': 'stable',
#                                                  'n_observations': 6},
#             'temperature_fahrenheit': {'mean': 97.93,
#                                        'min': 97.4,
#                                        'max': 98.2,
#                                        'last': 97.4,
#                                        'first': 98.2,
#                                        'trend': 'stable',
#                                        'n_observations': 3},
#             'sodium': {'mean': 137.0,
#                        'min': 137.0,
#                        'max': 137.0,
#                        'last': 137.0,
#                        'first': 137.0,
#                        'trend': 'single_observation',
#                        'n_observations': 1},
#             'hemoglobin': {'mean': 11.1,
#                            'min': 11.1,
#                            'max': 11.1,
#                            'last': 11.1,
#                            'first': 11.1,
#                            'trend': 'single_observation',
#                            'n_observations': 1},
#             'chloride': {'mean': 102.0,
#                          'min': 102.0,
#                          'max': 102.0,
#                          'last': 102.0,
#                          'first': 102.0,
#                          'trend': 'single_observation',
#                          'n_observations': 1},
#             'anion_gap': {'mean': 16.0,
#                           'min': 16.0,
#                           'max': 16.0,
#                           'last': 16.0,
#                           'first': 16.0,
#                           'trend': 'single_observation',
#                           'n_observations': 1}},
#  'labs': {'potassium': {'mean': 3.6,
#                         'min': 3.6,
#                         'max': 3.6,
#                         'last': 3.6,
#                         'first': 3.6,
#                         'trend': 'single_observation',
#                         'n_observations': 1},
#           'sodium': {'mean': 137.0,
#                      'min': 137.0,
#                      'max': 137.0,
#                      'last': 137.0,
#                      'first': 137.0,
#                      'trend': 'single_observation',
#                      'n_observations': 1},
#           'chloride': {'mean': 102.0,
#                        'min': 102.0,
#                        'max': 102.0,
#                        'last': 102.0,
#                        'first': 102.0,
#                        'trend': 'single_observation',
#                        'n_observations': 1},
#           'creatinine': {'mean': 0.8,
#                          'min': 0.8,
#                          'max': 0.8,
#                          'last': 0.8,
#                          'first': 0.8,
#                          'trend': 'single_observation',
#                          'n_observations': 1},
#           'urea_nitrogen': {'mean': 8.0,
#                             'min': 8.0,
#                             'max': 8.0,
#                             'last': 8.0,
#                             'first': 8.0,
#                             'trend': 'single_observation',
#                             'n_observations': 1},
#           'bicarbonate': {'mean': 23.0,
#                           'min': 23.0,
#                           'max': 23.0,
#                           'last': 23.0,
#                           'first': 23.0,
#                           'trend': 'single_observation',
#                           'n_observations': 1},
#           'anion_gap': {'mean': 16.0,
#                         'min': 16.0,
#                         'max': 16.0,
#                         'last': 16.0,
#                         'first': 16.0,
#                         'trend': 'single_observation',
#                         'n_observations': 1},
#           'glucose': {'mean': 114.0,
#                       'min': 114.0,
#                       'max': 114.0,
#                       'last': 114.0,
#                       'first': 114.0,
#                       'trend': 'single_observation',
#                       'n_observations': 1},
#           'magnesium': {'mean': 2.0,
#                         'min': 2.0,
#                         'max': 2.0,
#                         'last': 2.0,
#                         'first': 2.0,
#                         'trend': 'single_observation',
#                         'n_observations': 1},
#           'hematocrit': {'mean': 35.3,
#                          'min': 35.3,
#                          'max': 35.3,
#                          'last': 35.3,
#                          'first': 35.3,
#                          'trend': 'single_observation',
#                          'n_observations': 1},
#           'hemoglobin': {'mean': 11.1,
#                          'min': 11.1,
#                          'max': 11.1,
#                          'last': 11.1,
#                          'first': 11.1,
#                          'trend': 'single_observation',
#                          'n_observations': 1},
#           'platelet_count': {'mean': 284.0,
#                              'min': 284.0,
#                              'max': 284.0,
#                              'last': 284.0,
#                              'first': 284.0,
#                              'trend': 'single_observation',
#                              'n_observations': 1},
#           'white_blood_cells': {'mean': 8.2,
#                                 'min': 8.2,
#                                 'max': 8.2,
#                                 'last': 8.2,
#                                 'first': 8.2,
#                                 'trend': 'single_observation',
#                                 'n_observations': 1},
#           'mch': {'mean': 25.8,
#                   'min': 25.8,
#                   'max': 25.8,
#                   'last': 25.8,
#                   'first': 25.8,
#                   'trend': 'single_observation',
#                   'n_observations': 1},
#           'mcv': {'mean': 82.0,
#                   'min': 82.0,
#                   'max': 82.0,
#                   'last': 82.0,
#                   'first': 82.0,
#                   'trend': 'single_observation',
#                   'n_observations': 1},
#           'rdw': {'mean': 14.2,
#                   'min': 14.2,
#                   'max': 14.2,
#                   'last': 14.2,
#                   'first': 14.2,
#                   'trend': 'single_observation',
#                   'n_observations': 1},
#           'mchc': {'mean': 31.4,
#                    'min': 31.4,
#                    'max': 31.4,
#                    'last': 31.4,
#                    'first': 31.4,
#                    'trend': 'single_observation',
#                    'n_observations': 1},
#           'red_blood_cells': {'mean': 4.31,
#                               'min': 4.31,
#                               'max': 4.31,
#                               'last': 4.31,
#                               'first': 4.31,
#                               'trend': 'single_observation',
#                               'n_observations': 1},
#           'rdw_sd': {'mean': 42.1,
#                      'min': 42.1,
#                      'max': 42.1,
#                      'last': 42.1,
#                      'first': 42.1,
#                      'trend': 'single_observation',
#                      'n_observations': 1},
#           'phosphate': {'mean': 3.2,
#                         'min': 3.2,
#                         'max': 3.2,
#                         'last': 3.2,
#                         'first': 3.2,
#                         'trend': 'single_observation',
#                         'n_observations': 1},
#           'calcium_total': {'mean': 8.8,
#                             'min': 8.8,
#                             'max': 8.8,
#                             'last': 8.8,
#                             'first': 8.8,
#                             'trend': 'single_observation',
#                             'n_observations': 1},
#           'ptt': {'mean': 36.5,
#                   'min': 36.5,
#                   'max': 36.5,
#                   'last': 36.5,
#                   'first': 36.5,
#                   'trend': 'single_observation',
#                   'n_observations': 1},
#           'pt': {'mean': 12.3,
#                  'min': 12.3,
#                  'max': 12.3,
#                  'last': 12.3,
#                  'first': 12.3,
#                  'trend': 'single_observation',
#                  'n_observations': 1},
#           'inr': {'mean': 1.1,
#                   'min': 1.1,
#                   'max': 1.1,
#                   'last': 1.1,
#                   'first': 1.1,
#                   'trend': 'single_observation',
#                   'n_observations': 1}},
#  'interventions': {'active_drugs': ['nacl_0_9', 'solution'],
#                    'active_procedures': ['20_gauge', '18_gauge'],
#                    'urine_output_total_ml': 0.0},
#  'observation_hours': 12,
#  'pct_hours_monitored': 0.92}
#
# ── 3. FORMATTED CLINICAL SUMMARY (exact text in prompt) ──
# VITAL SIGNS (Last 12 Hours):
#   Heart Rate: mean=81.5, range=[75.0–91.0], last=76.0 (improving)
#   Respiratory Rate: mean=12.1, range=[10.0–16.0], last=15.0 (worsening)
#   O2 Saturation Pulseoxymetry: mean=97.4, range=[96.0–100.0], last=98.0 (stable)
#   Non Invasive Blood Pressure Systolic: mean=136.0, range=[120.0–151.0], last=140.0 (worsening)
#   Non Invasive Blood Pressure Diastolic: mean=80.0, range=[69.0–91.0], last=69.0 (stable)
#   Non Invasive Blood Pressure Mean: mean=93.0, range=[85.0–102.0], last=88.0 (stable)
#   Temperature Fahrenheit: mean=97.9, range=[97.4–98.2], last=97.4 (stable)
#   Sodium: mean=137.0, range=[137.0–137.0], last=137.0 (single_observation)
#   Hemoglobin: mean=11.1, range=[11.1–11.1], last=11.1 (single_observation)
#   Chloride: mean=102.0, range=[102.0–102.0], last=102.0 (single_observation)
#   Anion Gap: mean=16.0, range=[16.0–16.0], last=16.0 (single_observation)
#
# LABORATORY VALUES:
#   Potassium: mean=3.60, last=3.60 (single_observation)
#   Sodium: mean=137.00, last=137.00 (single_observation)
#   Chloride: mean=102.00, last=102.00 (single_observation)
#   Creatinine: mean=0.80, last=0.80 (single_observation)
#   Urea Nitrogen: mean=8.00, last=8.00 (single_observation)
#   Bicarbonate: mean=23.00, last=23.00 (single_observation)
#   Anion Gap: mean=16.00, last=16.00 (single_observation)
#   Glucose: mean=114.00, last=114.00 (single_observation)
#   Magnesium: mean=2.00, last=2.00 (single_observation)
#   Hematocrit: mean=35.30, last=35.30 (single_observation)
#   Hemoglobin: mean=11.10, last=11.10 (single_observation)
#   Platelet Count: mean=284.00, last=284.00 (single_observation)
#   White Blood Cells: mean=8.20, last=8.20 (single_observation)
#   Mch: mean=25.80, last=25.80 (single_observation)
#   Mcv: mean=82.00, last=82.00 (single_observation)
#   Rdw: mean=14.20, last=14.20 (single_observation)
#   Mchc: mean=31.40, last=31.40 (single_observation)
#   Red Blood Cells: mean=4.31, last=4.31 (single_observation)
#   Rdw Sd: mean=42.10, last=42.10 (single_observation)
#   Phosphate: mean=3.20, last=3.20 (single_observation)
#   Calcium Total: mean=8.80, last=8.80 (single_observation)
#   Ptt: mean=36.50, last=36.50 (single_observation)
#   Pt: mean=12.30, last=12.30 (single_observation)
#   Inr: mean=1.10, last=1.10 (single_observation)
#
# INTERVENTIONS:
#   Medications: nacl_0_9, solution
#   Procedures: 20_gauge, 18_gauge
#
# ── 4. LSTM TOP-K (agent sees top pick + other candidates, no probs) ──
#   LSTM top-3 with probs (for your reference only):
#     1. STROKE_NEURO               53.4%
#     2. TRAUMA_NEURO               32.2%
#     3. SURGICAL_COMPLICATION       4.3%
#   What the agent will see:
#     LSTM TOP PICK    : STROKE_NEURO
#     Other candidates :
#       - TRAUMA_NEURO
#       - SURGICAL_COMPLICATION
#
# ██████████████████████████████████████████████████████████████████████████████
# █ AGENT-SAFE CARD PREVIEW  [5/5]
# ██████████████████████████████████████████████████████████████████████████████
#
# ➤ GROUND TRUTH (not shown to agent):  SEPSIS
#   (integer label 12, patient 18344437)
#
# ── 1. AGENT-SAFE CARD (top-level keys) ──
#   Keys     : ['clinical_summary', 'feature_names', 'patient_id', 'stay_id', 'time_series', 'visit_id']
#   Stripped : ['clinical_group', 'conditions', 'drugs', 'icd_code', 'label', 'procedures']
#
# ── 2. FULL clinical_summary DICT ──
# {'vitals': {'heart_rate': {'mean': 87.42,
#                            'min': 79.0,
#                            'max': 99.0,
#                            'last': 87.0,
#                            'first': 89.0,
#                            'trend': 'stable',
#                            'n_observations': 12},
#             'respiratory_rate': {'mean': 20.58,
#                                  'min': 15.0,
#                                  'max': 39.0,
#                                  'last': 20.0,
#                                  'first': 15.0,
#                                  'trend': 'worsening',
#                                  'n_observations': 12},
#             'o2_saturation_pulseoxymetry': {'mean': 98.92,
#                                             'min': 97.0,
#                                             'max': 100.0,
#                                             'last': 100.0,
#                                             'first': 99.0,
#                                             'trend': 'stable',
#                                             'n_observations': 12},
#             'non_invasive_blood_pressure_systolic': {'mean': 110.5,
#                                                      'min': 107.0,
#                                                      'max': 114.0,
#                                                      'last': 114.0,
#                                                      'first': 107.0,
#                                                      'trend': 'stable',
#                                                      'n_observations': 2},
#             'non_invasive_blood_pressure_diastolic': {'mean': 60.0,
#                                                       'min': 58.0,
#                                                       'max': 62.0,
#                                                       'last': 62.0,
#                                                       'first': 58.0,
#                                                       'trend': 'stable',
#                                                       'n_observations': 2},
#             'non_invasive_blood_pressure_mean': {'mean': 71.0,
#                                                  'min': 69.0,
#                                                  'max': 73.0,
#                                                  'last': 73.0,
#                                                  'first': 69.0,
#                                                  'trend': 'stable',
#                                                  'n_observations': 2},
#             'arterial_blood_pressure_mean': {'mean': 72.6,
#                                              'min': 67.0,
#                                              'max': 80.0,
#                                              'last': 72.0,
#                                              'first': 68.0,
#                                              'trend': 'stable',
#                                              'n_observations': 10},
#             'arterial_blood_pressure_systolic': {'mean': 113.1,
#                                                  'min': 102.0,
#                                                  'max': 124.0,
#                                                  'last': 120.0,
#                                                  'first': 102.0,
#                                                  'trend': 'worsening',
#                                                  'n_observations': 10},
#             'arterial_blood_pressure_diastolic': {'mean': 53.4,
#                                                   'min': 48.0,
#                                                   'max': 61.0,
#                                                   'last': 52.0,
#                                                   'first': 50.0,
#                                                   'trend': 'stable',
#                                                   'n_observations': 10},
#             'temperature_fahrenheit': {'mean': 98.1,
#                                        'min': 97.5,
#                                        'max': 98.4,
#                                        'last': 97.5,
#                                        'first': 98.4,
#                                        'trend': 'stable',
#                                        'n_observations': 3},
#             'glucose_finger_stick': {'mean': 111.5,
#                                      'min': 110.0,
#                                      'max': 113.0,
#                                      'last': 113.0,
#                                      'first': 110.0,
#                                      'trend': 'stable',
#                                      'n_observations': 2},
#             'inspired_o2_fraction': {'mean': 0.0,
#                                      'min': 0.0,
#                                      'max': 0.0,
#                                      'last': 0.0,
#                                      'first': 0.0,
#                                      'trend': 'stable',
#                                      'n_observations': 2},
#             'heart_rate_alarm_low': {'mean': 50.0,
#                                      'min': 50.0,
#                                      'max': 50.0,
#                                      'last': 50.0,
#                                      'first': 50.0,
#                                      'trend': 'single_observation',
#                                      'n_observations': 1},
#             'heart_rate_alarm_high': {'mean': 130.0,
#                                       'min': 130.0,
#                                       'max': 130.0,
#                                       'last': 130.0,
#                                       'first': 130.0,
#                                       'trend': 'single_observation',
#                                       'n_observations': 1},
#             'o2_saturation_pulseoxymetry_alarm_low': {'mean': 92.0,
#                                                       'min': 92.0,
#                                                       'max': 92.0,
#                                                       'last': 92.0,
#                                                       'first': 92.0,
#                                                       'trend': 'single_observation',
#                                                       'n_observations': 1},
#             'o2_saturation_pulseoxymetry_alarm_high': {'mean': 100.0,
#                                                        'min': 100.0,
#                                                        'max': 100.0,
#                                                        'last': 100.0,
#                                                        'first': 100.0,
#                                                        'trend': 'single_observation',
#                                                        'n_observations': 1},
#             'spo2_desat_limit': {'mean': 88.0,
#                                  'min': 88.0,
#                                  'max': 88.0,
#                                  'last': 88.0,
#                                  'first': 88.0,
#                                  'trend': 'single_observation',
#                                  'n_observations': 1},
#             'resp_alarm_high': {'mean': 35.0,
#                                 'min': 35.0,
#                                 'max': 35.0,
#                                 'last': 35.0,
#                                 'first': 35.0,
#                                 'trend': 'single_observation',
#                                 'n_observations': 1},
#             'resp_alarm_low': {'mean': 8.0,
#                                'min': 8.0,
#                                'max': 8.0,
#                                'last': 8.0,
#                                'first': 8.0,
#                                'trend': 'single_observation',
#                                'n_observations': 1},
#             'o2_flow': {'mean': 8.0,
#                         'min': 8.0,
#                         'max': 8.0,
#                         'last': 8.0,
#                         'first': 8.0,
#                         'trend': 'stable',
#                         'n_observations': 2}},
#  'labs': {},
#  'interventions': {'active_drugs': ['nacl_0_9', 'dextrose_5'],
#                    'active_procedures': ['foley_catheter', 'arterial_line', 'multi_lumen'],
#                    'urine_output_total_ml': 3925.0},
#  'observation_hours': 12,
#  'pct_hours_monitored': 1.0}
#
# ── 3. FORMATTED CLINICAL SUMMARY (exact text in prompt) ──
# VITAL SIGNS (Last 12 Hours):
#   Heart Rate: mean=87.4, range=[79.0–99.0], last=87.0 (stable)
#   Respiratory Rate: mean=20.6, range=[15.0–39.0], last=20.0 (worsening)
#   O2 Saturation Pulseoxymetry: mean=98.9, range=[97.0–100.0], last=100.0 (stable)
#   Non Invasive Blood Pressure Systolic: mean=110.5, range=[107.0–114.0], last=114.0 (stable)
#   Non Invasive Blood Pressure Diastolic: mean=60.0, range=[58.0–62.0], last=62.0 (stable)
#   Non Invasive Blood Pressure Mean: mean=71.0, range=[69.0–73.0], last=73.0 (stable)
#   Arterial Blood Pressure Mean: mean=72.6, range=[67.0–80.0], last=72.0 (stable)
#   Arterial Blood Pressure Systolic: mean=113.1, range=[102.0–124.0], last=120.0 (worsening)
#   Arterial Blood Pressure Diastolic: mean=53.4, range=[48.0–61.0], last=52.0 (stable)
#   Temperature Fahrenheit: mean=98.1, range=[97.5–98.4], last=97.5 (stable)
#   Glucose Finger Stick: mean=111.5, range=[110.0–113.0], last=113.0 (stable)
#   Inspired O2 Fraction: mean=0.0, range=[0.0–0.0], last=0.0 (stable)
#   Heart Rate Alarm Low: mean=50.0, range=[50.0–50.0], last=50.0 (single_observation)
#   Heart Rate Alarm High: mean=130.0, range=[130.0–130.0], last=130.0 (single_observation)
#   O2 Saturation Pulseoxymetry Alarm Low: mean=92.0, range=[92.0–92.0], last=92.0 (single_observation)
#   O2 Saturation Pulseoxymetry Alarm High: mean=100.0, range=[100.0–100.0], last=100.0 (single_observation)
#   Spo2 Desat Limit: mean=88.0, range=[88.0–88.0], last=88.0 (single_observation)
#   Resp Alarm High: mean=35.0, range=[35.0–35.0], last=35.0 (single_observation)
#   Resp Alarm Low: mean=8.0, range=[8.0–8.0], last=8.0 (single_observation)
#   O2 Flow: mean=8.0, range=[8.0–8.0], last=8.0 (stable)
#
# LABORATORY VALUES:
#
# INTERVENTIONS:
#   Medications: nacl_0_9, dextrose_5
#   Procedures: foley_catheter, arterial_line, multi_lumen
#
# ── 4. LSTM TOP-K (agent sees top pick + other candidates, no probs) ──
#   LSTM top-3 with probs (for your reference only):
#     1. SEPSIS                     70.2% ✓
#     2. SURGICAL_COMPLICATION      10.8%
#     3. LIVER_FAILURE               3.9%
#   What the agent will see:
#     LSTM TOP PICK    : SEPSIS
#     Other candidates :
#       - SURGICAL_COMPLICATION
#       - LIVER_FAILURE
#
# ██████████████████████████████████████████████████████████████████████████████
# █ End of agent-safe card preview (5 cards)
# ██████████████████████████████████████████████████████████████████████████████

# %%
# ══════════════════════════════════════════════════════════════════════════════
# SINGLE AGENT PROMPT — BLINDED to LSTM ranking
# ══════════════════════════════════════════════════════════════════════════════

SINGLE_AGENT_PROMPT = """
You are an expert ICU physician. You are given patient data and {top_k} possible diagnoses to consider. Your task is to determine which diagnosis best fits the clinical picture.

## PATIENT DATA (Last 12 Hours in ICU)
{clinical_summary}

## CANDIDATE DIAGNOSES
Consider these {top_k} possibilities (listed in no particular order):
{candidates_list}


## YOUR TASK
You are working with INCOMPLETE ICU data. Not all clinically relevant labs will be present. Your goal is to find the diagnosis most consistent with available evidence, explicitly accounting for what is and is not measured. A diagnosis should not be dismissed solely because its defining marker was not collected.


Respond with ONLY valid JSON:
{{
  "chosen_diagnosis": "DIAGNOSIS_NAME",
  "reasoning": "2-3 sentence explanation of why this diagnosis fits best",
  "supporting_evidence": ["key finding 1", "key finding 2", "key finding 3"],
  "ruled_out": [
    {{"diagnosis": "OTHER_DIAGNOSIS_1", "reason": "why ruled out"}},
    {{"diagnosis": "OTHER_DIAGNOSIS_2", "reason": "why ruled out"}}
  ]
}}

Your chosen_diagnosis MUST be one of the {top_k} candidates listed above.
"""

print('✓ Blinded single agent prompt defined (agent does NOT see LSTM ranking)')
# Out:
# ✓ Blinded single agent prompt defined (agent does NOT see LSTM ranking)

# %%
# ══════════════════════════════════════════════════════════════════════════════
# LLM WRAPPER (local MedGemma) — robust error handling + full tracebacks
# ══════════════════════════════════════════════════════════════════════════════
import re
import time
import traceback


def _is_oom(exc: BaseException) -> bool:
    """Detect GPU OOM across PyTorch versions.

    torch.cuda.OutOfMemoryError was only added in PyTorch 2.1; on older
    installs we fall back to sniffing the RuntimeError message.
    """
    oom_cls = getattr(torch.cuda, 'OutOfMemoryError', None)
    if oom_cls is not None and isinstance(exc, oom_cls):
        return True
    return isinstance(exc, RuntimeError) and 'out of memory' in str(exc).lower()


def call_llm(prompt: str) -> dict:
    """Call MedGemma 27B (local, 4-bit) and parse JSON from the response."""

    for attempt in range(RETRY_ATTEMPTS):
        try:
            # 1. Render chat template to a plain string, then tokenize explicitly.
            #    This avoids transformers-version differences in what
            #    apply_chat_template(return_tensors='pt') returns (tensor vs
            #    BatchEncoding) that caused the empty AttributeError.
            chat_text = llm_tokenizer.apply_chat_template(
                [{'role': 'user', 'content': prompt}],
                add_generation_prompt=True,
                tokenize=False,
            )
            inputs = llm_tokenizer(
                chat_text,
                return_tensors='pt',
            ).to(llm_model.device)

            # 2. Generate
            with torch.no_grad():
                outputs = llm_model.generate(
                    **inputs,
                    max_new_tokens=MAX_NEW_TOKENS,
                    do_sample=True,
                    temperature=TEMPERATURE,
                    pad_token_id=llm_tokenizer.pad_token_id,
                )

            # 3. Decode only new tokens
            prompt_len = inputs['input_ids'].shape[-1]
            new_tokens = outputs[0][prompt_len:]
            full_text = llm_tokenizer.decode(new_tokens, skip_special_tokens=True)

            if not full_text.strip():
                raise ValueError('Empty response from model')

            # 4. Extract JSON object from response
            json_match = re.search(r'\{[\s\S]*\}', full_text.strip())
            if not json_match:
                raise ValueError(f'No JSON found. First 200 chars: {full_text[:200]!r}')
            return json.loads(json_match.group(0))

        except Exception as e:
            if _is_oom(e):
                print('    ⚠ GPU OOM: clearing cache and retrying...')
                torch.cuda.empty_cache()
                time.sleep(5)
                continue

            # Show the full traceback — this is what we needed to debug the
            # original empty-AttributeError. Truncated str(e) hid everything.
            print(f'    ⚠ {type(e).__name__} on attempt {attempt+1}/{RETRY_ATTEMPTS}:')
            traceback.print_exc()
            if attempt < RETRY_ATTEMPTS - 1:
                time.sleep(2)

    return {'error': 'Failed after retries', 'chosen_diagnosis': None}

print('✓ MedGemma wrapper ready')
# Out:
# ✓ MedGemma wrapper ready

# %%
# ══════════════════════════════════════════════════════════════════════════════
# SINGLE AGENT DIAGNOSIS FUNCTION — BLINDED mode
# ══════════════════════════════════════════════════════════════════════════════
# The agent sees all K candidates in a SHUFFLED order, with no indication of
# which was the LSTM's top pick. 'accept' / 'override' labels are computed
# post-hoc by comparing the agent's choice to the LSTM top-1 — the agent itself
# is never told what the LSTM ranked first.


def diagnose_single_agent(patient_card: dict, verbose: bool = False) -> dict:
    """Run single-agent diagnosis on one patient, blinded to LSTM ranking."""

    def _log(title, body=None):
        if not verbose:
            return
        print(f'\n── {title} ──')
        if body is not None:
            print(body)

    # Build agent-safe view of the card. Everything the LLM sees comes from here.
    clinical_summary_for_agent = build_clinical_summary_for_agent(patient_card)
    _log('STEP A: agent-safe card (top-level keys)',
         f'  keys: {sorted(clinical_summary_for_agent.keys())}')

    # 1. LSTM top-K (uses stripped card — only needs time_series)
    lstm_output = get_lstm_predictions(clinical_summary_for_agent, TOP_K)
    if verbose:
        print('\n── STEP B: LSTM top-K (probs shown for reference — NOT shown to agent) ──')
        for _rank, (_c, _p) in enumerate(zip(lstm_output['top_k_codes'], lstm_output['top_k_probs'])):
            print(f'  {_rank+1}. {_c:<25} {_p:>6.1%}')

    # 2. Record LSTM top-1 for post-hoc agreement analysis (NOT shown to agent)
    lstm_top_pick = lstm_output['top_k_codes'][0]

    # 3. Shuffle the candidates. Seed per-patient so the order is reproducible
    #    across runs but independent of LSTM rank position.
    patient_id_for_seed = patient_card.get('patient_id') or patient_card.get('stay_id') or 0
    shuffle_rng = random.Random(hash(('shuffle', patient_id_for_seed, RANDOM_SEED)))
    shuffled_candidates = list(lstm_output['top_k_codes'])
    shuffle_rng.shuffle(shuffled_candidates)

    _log('STEP C: shuffled candidate order the agent will see (blinded)',
         '  ' + ' | '.join(shuffled_candidates))

    candidates_list = '\n'.join([f'- {code}' for code in shuffled_candidates])

    # 4. Build the prompt
    formatted_summary = format_clinical_summary(
        clinical_summary_for_agent.get('clinical_summary', {})
    )
    _log('STEP D: formatted clinical summary', formatted_summary)

    prompt = SINGLE_AGENT_PROMPT.format(
        top_k=TOP_K,
        clinical_summary=formatted_summary,
        candidates_list=candidates_list,
    )
    _log('STEP E: FULL PROMPT SENT TO LLM', prompt)

    # 5. Call LLM
    agent_output = call_llm(prompt)
    if verbose:
        print('\n── STEP F: RAW LLM RESPONSE (parsed JSON) ──')
        try:
            print(json.dumps(agent_output, indent=2, ensure_ascii=False))
        except (TypeError, ValueError):
            print(repr(agent_output))

    # 6. Extract prediction; normalize against the candidate set
    raw_pred = agent_output.get('chosen_diagnosis') or ''
    norm     = raw_pred.strip().strip('"\'.,').upper()
    lookup   = {c.strip().upper(): c for c in lstm_output['top_k_codes']}
    agent_pred = lookup.get(norm)

    if agent_pred is None:
        if verbose:
            print(f'\n  ⚠ chosen_diagnosis {raw_pred!r} not in top-K candidates; '
                  f'falling back to sentinel: {FALLBACK_SENTINEL}')
        agent_pred = FALLBACK_SENTINEL

    # 7. Compute post-hoc agreement label (agent itself never reported a decision)
    decision = 'accept' if agent_pred == lstm_top_pick else 'override'

    print(f'{agent_pred}  ({decision})')

    if verbose:
        print('\n── STEP G: AGENT REASONING (parsed fields) ──')
        print(f'  decision (post-hoc): {decision}   [agent was blinded; computed from chosen_diagnosis vs LSTM top-1]')
        print(f'  chosen_diagnosis   : {agent_pred}')
        _reasoning = agent_output.get('reasoning')
        if _reasoning:
            print('  reasoning        :')
            for line in str(_reasoning).splitlines() or [str(_reasoning)]:
                print(f'      {line}')
        _support = agent_output.get('supporting_evidence') or []
        if _support:
            print('  supporting_evidence:')
            for item in _support:
                print(f'      • {item}')
        _ruled = agent_output.get('ruled_out') or []
        if _ruled:
            print('  ruled_out:')
            for item in _ruled:
                if isinstance(item, dict):
                    print(f'      • {item.get("diagnosis", "?")}: {item.get("reason", "")}')
                else:
                    print(f'      • {item}')

    # 8. Ground truth from the ORIGINAL card (never sent to LLM)
    true_label = inv_label_map[patient_card['label']]

    return {
        'patient_id'            : patient_card.get('patient_id'),
        'stay_id'               : patient_card.get('stay_id'),
        'true_label'            : true_label,
        'lstm_output'           : lstm_output,
        'lstm_top_pick'         : lstm_top_pick,
        'candidates_shown_order': shuffled_candidates,  # exact order agent saw
        'agent_output'          : agent_output,
        'agent_prediction'      : agent_pred,
        'agent_decision'        : decision,             # post-hoc label
        'agent_disagrees'       : agent_pred != lstm_top_pick,
        'lstm_correct'          : lstm_top_pick == true_label,
        'agent_correct'         : agent_pred == true_label,
    }

print('✓ Blinded single agent system ready')
# Out:
# ✓ Blinded single agent system ready

# %% [markdown]
# ## 4. Run Pilot

# %%
# ══════════════════════════════════════════════════════════════════════════════
# RUN PILOT  (verbose: full per-case logging)
# ══════════════════════════════════════════════════════════════════════════════
from tqdm.notebook import tqdm
import datetime

print(f'Starting single-agent pilot: {len(pilot_cards)} cases')
print(f'LLM calls: {len(pilot_cards)} (1 per case)')
print(f'Model   : {MEDGEMMA_MODEL_ID}')
print(f'Verbose : True  — every step of every case will be printed in full.')
print('=' * 78)

results = []
start_time = datetime.datetime.now()

for i, card in enumerate(tqdm(pilot_cards, desc='Processing')):
    true_label = inv_label_map[card['label']]

    print('\n' + '═' * 78)
    print(f'CASE [{i+1}/{len(pilot_cards)}]  Patient {card["patient_id"]}  |  True: {true_label}')
    print('═' * 78)

    try:
        result = diagnose_single_agent(card, verbose=True)
        results.append(result)

        lstm_mark    = '✓' if result['lstm_correct']  else '✗'
        agent_mark   = '✓' if result['agent_correct'] else '✗'
        decision_tag = f'  ({result["agent_decision"].upper()})'
        print('\n── OUTCOME ──')
        print(f'  LSTM top pick : {result["lstm_top_pick"]} {lstm_mark}')
        print(f'  Agent pick    : {result["agent_prediction"]} {agent_mark}{decision_tag}')

    except Exception as e:
        print(f'\n  ERROR: {type(e).__name__}: {e}')
        results.append({'patient_id': card.get('patient_id'), 'error': str(e)})

elapsed = datetime.datetime.now() - start_time
print('\n' + '=' * 78)
print(f'Pilot complete — elapsed: {elapsed}')
print(f'Valid: {sum(1 for r in results if "error" not in r)}/{len(results)}')
# Out:
# Starting single-agent pilot: 100 cases
# LLM calls: 100 (1 per case)
# Model   : google/medgemma-27b-text-it
# Verbose : True  — every step of every case will be printed in full.
# ==============================================================================
# Processing:   0%|          | 0/100 [00:00<?, ?it/s]
# Streaming output truncated to the last 5000 lines.
#   Procedures: 18_gauge, multi_lumen
#
# ## CANDIDATE DIAGNOSES
# Consider these 3 possibilities (listed in no particular order):
# - SURGICAL_COMPLICATION
# - GI_BLEED
# - SEPSIS
#
#
# ## YOUR TASK
# You are working with INCOMPLETE ICU data. Not all clinically relevant labs will be present. Your goal is to find the diagnosis most consistent with available evidence, explicitly accounting for what is and is not measured. A diagnosis should not be dismissed solely because its defining marker was not collected.
#
#
# Respond with ONLY valid JSON:
# {
#   "chosen_diagnosis": "DIAGNOSIS_NAME",
#   "reasoning": "2-3 sentence explanation of why this diagnosis fits best",
#   "supporting_evidence": ["key finding 1", "key finding 2", "key finding 3"],
#   "ruled_out": [
#     {"diagnosis": "OTHER_DIAGNOSIS_1", "reason": "why ruled out"},
#     {"diagnosis": "OTHER_DIAGNOSIS_2", "reason": "why ruled out"}
#   ]
# }
#
# Your chosen_diagnosis MUST be one of the 3 candidates listed above.
#
#
# ── STEP F: RAW LLM RESPONSE (parsed JSON) ──
# {
#   "chosen_diagnosis": "GI_BLEED",
#   "reasoning": "The patient exhibits signs of hemodynamic instability with worsening blood pressure despite stable heart rate and respiratory rate, alongside a low hemoglobin level (10.6 g/dL) and low platelet count (76,000/uL), suggesting acute blood loss. The elevated INR (1.6) could indicate underlying coagulopathy or be related to the cause of the bleed. While sepsis is possible, the lack of fever or significant leukocytosis makes GI bleed more likely given the anemia and thrombocytopenia.",
#   "supporting_evidence": [
#     "Worsening systolic, diastolic, and mean blood pressure",
#     "Low Hemoglobin (10.6 g/dL)",
#     "Low Platelet Count (76,000/uL)",
#     "Elevated INR (1.6)"
#   ],
#   "ruled_out": [
#     {
#       "diagnosis": "SEPSIS",
#       "reason": "No fever (stable temperature) or significant leukocytosis (WBC 9.5k) reported, although these are not definitive exclusions."
#     },
#     {
#       "diagnosis": "SURGICAL_COMPLICATION",
#       "reason": "No specific surgical history or findings are provided to suggest a complication related to recent surgery."
#     }
#   ]
# }
# GI_BLEED  (override)
#
# ── STEP G: AGENT REASONING (parsed fields) ──
#   decision (post-hoc): override   [agent was blinded; computed from chosen_diagnosis vs LSTM top-1]
#   chosen_diagnosis   : GI_BLEED
#   reasoning        :
#       The patient exhibits signs of hemodynamic instability with worsening blood pressure despite stable heart rate and respiratory rate, alongside a low hemoglobin level (10.6 g/dL) and low platelet count (76,000/uL), suggesting acute blood loss. The elevated INR (1.6) could indicate underlying coagulopathy or be related to the cause of the bleed. While sepsis is possible, the lack of fever or significant leukocytosis makes GI bleed more likely given the anemia and thrombocytopenia.
#   supporting_evidence:
#       • Worsening systolic, diastolic, and mean blood pressure
#       • Low Hemoglobin (10.6 g/dL)
#       • Low Platelet Count (76,000/uL)
#       • Elevated INR (1.6)
#   ruled_out:
#       • SEPSIS: No fever (stable temperature) or significant leukocytosis (WBC 9.5k) reported, although these are not definitive exclusions.
#       • SURGICAL_COMPLICATION: No specific surgical history or findings are provided to suggest a complication related to recent surgery.
#
# ── OUTCOME ──
#   LSTM top pick : SEPSIS ✗
#   Agent pick    : GI_BLEED ✗  (OVERRIDE)
#
# ══════════════════════════════════════════════════════════════════════════════
# CASE [70/100]  Patient 11699665  |  True: SURGICAL_COMPLICATION
# ══════════════════════════════════════════════════════════════════════════════
#
# ── STEP A: agent-safe card (top-level keys) ──
#   keys: ['clinical_summary', 'feature_names', 'patient_id', 'stay_id', 'time_series', 'visit_id']
#
# ── STEP B: LSTM top-K (probs shown for reference — NOT shown to agent) ──
#   1. STROKE_NEURO               69.0%
#   2. TRAUMA_NEURO               24.1%
#   3. SURGICAL_COMPLICATION       2.3%
#
# ── STEP C: shuffled candidate order the agent will see (blinded) ──
#   STROKE_NEURO | SURGICAL_COMPLICATION | TRAUMA_NEURO
#
# ── STEP D: formatted clinical summary ──
# VITAL SIGNS (Last 12 Hours):
#   Heart Rate: mean=63.9, range=[60.0–75.0], last=68.0 (stable)
#   Respiratory Rate: mean=19.0, range=[11.0–38.0], last=18.0 (improving)
#   O2 Saturation Pulseoxymetry: mean=94.6, range=[90.0–100.0], last=94.0 (stable)
#   Non Invasive Blood Pressure Systolic: mean=99.0, range=[99.0–99.0], last=99.0 (stable)
#   Non Invasive Blood Pressure Diastolic: mean=63.5, range=[63.0–64.0], last=63.0 (stable)
#   Non Invasive Blood Pressure Mean: mean=74.0, range=[73.0–75.0], last=75.0 (stable)
#   Arterial Blood Pressure Mean: mean=76.6, range=[75.0–80.0], last=75.0 (stable)
#   Arterial Blood Pressure Systolic: mean=99.6, range=[93.0–107.0], last=93.0 (stable)
#   Arterial Blood Pressure Diastolic: mean=59.8, range=[57.0–61.0], last=61.0 (stable)
#   Temperature Fahrenheit: mean=98.2, range=[98.0–98.3], last=98.3 (stable)
#   Heart Rate Alarm Low: mean=40.0, range=[40.0–40.0], last=40.0 (stable)
#   Heart Rate Alarm High: mean=130.0, range=[130.0–130.0], last=130.0 (stable)
#   O2 Saturation Pulseoxymetry Alarm Low: mean=92.0, range=[92.0–92.0], last=92.0 (stable)
#   O2 Saturation Pulseoxymetry Alarm High: mean=100.0, range=[100.0–100.0], last=100.0 (stable)
#   Spo2 Desat Limit: mean=85.0, range=[85.0–85.0], last=85.0 (stable)
#   Resp Alarm High: mean=32.0, range=[32.0–32.0], last=32.0 (stable)
#   Resp Alarm Low: mean=8.0, range=[8.0–8.0], last=8.0 (stable)
#   Non Invasive Blood Pressure Alarm Low: mean=60.0, range=[60.0–60.0], last=60.0 (stable)
#   Non Invasive Blood Pressure Alarm High: mean=120.0, range=[120.0–120.0], last=120.0 (stable)
#
# LABORATORY VALUES:
#
# INTERVENTIONS:
#   Medications: po_intake
#   Procedures: arterial_line, 22_gauge
#
# ── STEP E: FULL PROMPT SENT TO LLM ──
#
# You are an expert ICU physician. You are given patient data and 3 possible diagnoses to consider. Your task is to determine which diagnosis best fits the clinical picture.
#
# ## PATIENT DATA (Last 12 Hours in ICU)
# VITAL SIGNS (Last 12 Hours):
#   Heart Rate: mean=63.9, range=[60.0–75.0], last=68.0 (stable)
#   Respiratory Rate: mean=19.0, range=[11.0–38.0], last=18.0 (improving)
#   O2 Saturation Pulseoxymetry: mean=94.6, range=[90.0–100.0], last=94.0 (stable)
#   Non Invasive Blood Pressure Systolic: mean=99.0, range=[99.0–99.0], last=99.0 (stable)
#   Non Invasive Blood Pressure Diastolic: mean=63.5, range=[63.0–64.0], last=63.0 (stable)
#   Non Invasive Blood Pressure Mean: mean=74.0, range=[73.0–75.0], last=75.0 (stable)
#   Arterial Blood Pressure Mean: mean=76.6, range=[75.0–80.0], last=75.0 (stable)
#   Arterial Blood Pressure Systolic: mean=99.6, range=[93.0–107.0], last=93.0 (stable)
#   Arterial Blood Pressure Diastolic: mean=59.8, range=[57.0–61.0], last=61.0 (stable)
#   Temperature Fahrenheit: mean=98.2, range=[98.0–98.3], last=98.3 (stable)
#   Heart Rate Alarm Low: mean=40.0, range=[40.0–40.0], last=40.0 (stable)
#   Heart Rate Alarm High: mean=130.0, range=[130.0–130.0], last=130.0 (stable)
#   O2 Saturation Pulseoxymetry Alarm Low: mean=92.0, range=[92.0–92.0], last=92.0 (stable)
#   O2 Saturation Pulseoxymetry Alarm High: mean=100.0, range=[100.0–100.0], last=100.0 (stable)
#   Spo2 Desat Limit: mean=85.0, range=[85.0–85.0], last=85.0 (stable)
#   Resp Alarm High: mean=32.0, range=[32.0–32.0], last=32.0 (stable)
#   Resp Alarm Low: mean=8.0, range=[8.0–8.0], last=8.0 (stable)
#   Non Invasive Blood Pressure Alarm Low: mean=60.0, range=[60.0–60.0], last=60.0 (stable)
#   Non Invasive Blood Pressure Alarm High: mean=120.0, range=[120.0–120.0], last=120.0 (stable)
#
# LABORATORY VALUES:
#
# INTERVENTIONS:
#   Medications: po_intake
#   Procedures: arterial_line, 22_gauge
#
# ## CANDIDATE DIAGNOSES
# Consider these 3 possibilities (listed in no particular order):
# - STROKE_NEURO
# - SURGICAL_COMPLICATION
# - TRAUMA_NEURO
#
#
# ## YOUR TASK
# You are working with INCOMPLETE ICU data. Not all clinically relevant labs will be present. Your goal is to find the diagnosis most consistent with available evidence, explicitly accounting for what is and is not measured. A diagnosis should not be dismissed solely because its defining marker was not collected.
#
#
# Respond with ONLY valid JSON:
# {
#   "chosen_diagnosis": "DIAGNOSIS_NAME",
#   "reasoning": "2-3 sentence explanation of why this diagnosis fits best",
#   "supporting_evidence": ["key finding 1", "key finding 2", "key finding 3"],
#   "ruled_out": [
#     {"diagnosis": "OTHER_DIAGNOSIS_1", "reason": "why ruled out"},
#     {"diagnosis": "OTHER_DIAGNOSIS_2", "reason": "why ruled out"}
#   ]
# }
#
# Your chosen_diagnosis MUST be one of the 3 candidates listed above.
#
#
# ── STEP F: RAW LLM RESPONSE (parsed JSON) ──
# {
#   "chosen_diagnosis": "STROKE_NEURO",
#   "reasoning": "The patient presents with stable but relatively low vital signs, particularly a mean heart rate of 63.9 and a mean arterial pressure of 76.6, which could be consistent with increased intracranial pressure or autonomic dysfunction seen in stroke. The lack of significant respiratory distress or hemodynamic instability makes surgical complications or trauma less likely as the primary driver of the current clinical picture. While specific neurological findings are missing, the overall stability combined with potential bradycardia points towards a neurological event.",
#   "supporting_evidence": [
#     "Mean Heart Rate 63.9 (potential bradycardia)",
#     "Mean Arterial Pressure 76.6 (relatively low)",
#     "Stable vital signs overall (suggesting no acute surgical or traumatic instability)"
#   ],
#   "ruled_out": [
#     {
#       "diagnosis": "SURGICAL_COMPLICATION",
#       "reason": "Vital signs are stable without significant fluctuations, and there's no mention of recent surgery or specific complications like bleeding or infection."
#     },
#     {
#       "diagnosis": "TRAUMA_NEURO",
#       "reason": "No information suggesting acute trauma (e.g., history, bruising, unstable vitals typical of acute injury) is provided; the stable vitals argue against an acute traumatic event."
#     }
#   ]
# }
# STROKE_NEURO  (accept)
#
# ── STEP G: AGENT REASONING (parsed fields) ──
#   decision (post-hoc): accept   [agent was blinded; computed from chosen_diagnosis vs LSTM top-1]
#   chosen_diagnosis   : STROKE_NEURO
#   reasoning        :
#       The patient presents with stable but relatively low vital signs, particularly a mean heart rate of 63.9 and a mean arterial pressure of 76.6, which could be consistent with increased intracranial pressure or autonomic dysfunction seen in stroke. The lack of significant respiratory distress or hemodynamic instability makes surgical complications or trauma less likely as the primary driver of the current clinical picture. While specific neurological findings are missing, the overall stability combined with potential bradycardia points towards a neurological event.
#   supporting_evidence:
#       • Mean Heart Rate 63.9 (potential bradycardia)
#       • Mean Arterial Pressure 76.6 (relatively low)
#       • Stable vital signs overall (suggesting no acute surgical or traumatic instability)
#   ruled_out:
#       • SURGICAL_COMPLICATION: Vital signs are stable without significant fluctuations, and there's no mention of recent surgery or specific complications like bleeding or infection.
#       • TRAUMA_NEURO: No information suggesting acute trauma (e.g., history, bruising, unstable vitals typical of acute injury) is provided; the stable vitals argue against an acute traumatic event.
#
# ── OUTCOME ──
#   LSTM top pick : STROKE_NEURO ✗
#   Agent pick    : STROKE_NEURO ✗  (ACCEPT)
#
# ══════════════════════════════════════════════════════════════════════════════
# CASE [71/100]  Patient 15470366  |  True: SURGICAL_COMPLICATION
# ══════════════════════════════════════════════════════════════════════════════
#
# ── STEP A: agent-safe card (top-level keys) ──
#   keys: ['clinical_summary', 'feature_names', 'patient_id', 'stay_id', 'time_series', 'visit_id']
#
# ── STEP B: LSTM top-K (probs shown for reference — NOT shown to agent) ──
#   1. HEART_FAILURE              17.7%
#   2. SEPSIS                     16.9%
#   3. COPD_ASTHMA                16.3%
#
# ── STEP C: shuffled candidate order the agent will see (blinded) ──
#   COPD_ASTHMA | HEART_FAILURE | SEPSIS
#
# ── STEP D: formatted clinical summary ──
# VITAL SIGNS (Last 12 Hours):
#   Heart Rate: mean=77.9, range=[68.0–83.0], last=71.0 (improving)
#   Respiratory Rate: mean=27.1, range=[21.0–34.0], last=24.0 (improving)
#   O2 Saturation Pulseoxymetry: mean=95.0, range=[87.0–100.0], last=87.0 (stable)
#   Non Invasive Blood Pressure Systolic: mean=118.3, range=[110.0–138.0], last=119.0 (stable)
#   Non Invasive Blood Pressure Diastolic: mean=67.9, range=[42.0–102.0], last=102.0 (worsening)
#   Non Invasive Blood Pressure Mean: mean=78.4, range=[59.0–106.0], last=106.0 (worsening)
#   Temperature Fahrenheit: mean=98.4, range=[98.1–98.6], last=98.6 (stable)
#   Glucose Finger Stick: mean=139.0, range=[139.0–139.0], last=139.0 (stable)
#   Heart Rate Alarm Low: mean=40.0, range=[40.0–40.0], last=40.0 (single_observation)
#   Heart Rate Alarm High: mean=130.0, range=[130.0–130.0], last=130.0 (single_observation)
#   O2 Saturation Pulseoxymetry Alarm Low: mean=89.0, range=[89.0–89.0], last=89.0 (single_observation)
#   O2 Saturation Pulseoxymetry Alarm High: mean=100.0, range=[100.0–100.0], last=100.0 (single_observation)
#   Spo2 Desat Limit: mean=85.0, range=[85.0–85.0], last=85.0 (single_observation)
#   Resp Alarm High: mean=40.0, range=[40.0–40.0], last=40.0 (single_observation)
#   Resp Alarm Low: mean=8.0, range=[8.0–8.0], last=8.0 (single_observation)
#   O2 Flow: mean=2.0, range=[2.0–2.0], last=2.0 (stable)
#   Sodium: mean=138.0, range=[138.0–138.0], last=138.0 (single_observation)
#   Hemoglobin: mean=9.4, range=[9.4–9.4], last=9.4 (single_observation)
#   Non Invasive Blood Pressure Alarm Low: mean=90.0, range=[90.0–90.0], last=90.0 (single_observation)
#   Non Invasive Blood Pressure Alarm High: mean=125.0, range=[125.0–125.0], last=125.0 (single_observation)
#   Chloride: mean=101.0, range=[101.0–101.0], last=101.0 (single_observation)
#   Anion Gap: mean=11.0, range=[11.0–11.0], last=11.0 (single_observation)
#
# LABORATORY VALUES:
#   H: mean=7.00, last=7.00 (single_observation)
#   L: mean=6.00, last=6.00 (single_observation)
#   I: mean=0.00, last=0.00 (single_observation)
#   Potassium: mean=4.30, last=4.30 (single_observation)
#   Sodium: mean=138.00, last=138.00 (single_observation)
#   Chloride: mean=101.00, last=101.00 (single_observation)
#   Creatinine: mean=1.30, last=1.30 (single_observation)
#   Urea Nitrogen: mean=18.00, last=18.00 (single_observation)
#   Bicarbonate: mean=26.00, last=26.00 (single_observation)
#   Anion Gap: mean=11.00, last=11.00 (single_observation)
#   Glucose: mean=116.00, last=116.00 (single_observation)
#   Magnesium: mean=2.20, last=2.20 (single_observation)
#   Hematocrit: mean=31.10, last=31.10 (single_observation)
#   Hemoglobin: mean=9.40, last=9.40 (single_observation)
#   Platelet Count: mean=312.00, last=312.00 (single_observation)
#   White Blood Cells: mean=9.80, last=9.80 (single_observation)
#   Mch: mean=31.20, last=31.20 (single_observation)
#   Mcv: mean=103.00, last=103.00 (single_observation)
#   Rdw: mean=13.80, last=13.80 (single_observation)
#   Mchc: mean=30.20, last=30.20 (single_observation)
#   Red Blood Cells: mean=3.01, last=3.01 (single_observation)
#   Rdw Sd: mean=52.50, last=52.50 (single_observation)
#   Phosphate: mean=3.70, last=3.70 (single_observation)
#   Calcium Total: mean=8.50, last=8.50 (single_observation)
#
# INTERVENTIONS:
#   Medications: dextrose_5, po_intake
#   Procedures: 18_gauge, 22_gauge
#
# ── STEP E: FULL PROMPT SENT TO LLM ──
#
# You are an expert ICU physician. You are given patient data and 3 possible diagnoses to consider. Your task is to determine which diagnosis best fits the clinical picture.
#
# ## PATIENT DATA (Last 12 Hours in ICU)
# VITAL SIGNS (Last 12 Hours):
#   Heart Rate: mean=77.9, range=[68.0–83.0], last=71.0 (improving)
#   Respiratory Rate: mean=27.1, range=[21.0–34.0], last=24.0 (improving)
#   O2 Saturation Pulseoxymetry: mean=95.0, range=[87.0–100.0], last=87.0 (stable)
#   Non Invasive Blood Pressure Systolic: mean=118.3, range=[110.0–138.0], last=119.0 (stable)
#   Non Invasive Blood Pressure Diastolic: mean=67.9, range=[42.0–102.0], last=102.0 (worsening)
#   Non Invasive Blood Pressure Mean: mean=78.4, range=[59.0–106.0], last=106.0 (worsening)
#   Temperature Fahrenheit: mean=98.4, range=[98.1–98.6], last=98.6 (stable)
#   Glucose Finger Stick: mean=139.0, range=[139.0–139.0], last=139.0 (stable)
#   Heart Rate Alarm Low: mean=40.0, range=[40.0–40.0], last=40.0 (single_observation)
#   Heart Rate Alarm High: mean=130.0, range=[130.0–130.0], last=130.0 (single_observation)
#   O2 Saturation Pulseoxymetry Alarm Low: mean=89.0, range=[89.0–89.0], last=89.0 (single_observation)
#   O2 Saturation Pulseoxymetry Alarm High: mean=100.0, range=[100.0–100.0], last=100.0 (single_observation)
#   Spo2 Desat Limit: mean=85.0, range=[85.0–85.0], last=85.0 (single_observation)
#   Resp Alarm High: mean=40.0, range=[40.0–40.0], last=40.0 (single_observation)
#   Resp Alarm Low: mean=8.0, range=[8.0–8.0], last=8.0 (single_observation)
#   O2 Flow: mean=2.0, range=[2.0–2.0], last=2.0 (stable)
#   Sodium: mean=138.0, range=[138.0–138.0], last=138.0 (single_observation)
#   Hemoglobin: mean=9.4, range=[9.4–9.4], last=9.4 (single_observation)
#   Non Invasive Blood Pressure Alarm Low: mean=90.0, range=[90.0–90.0], last=90.0 (single_observation)
#   Non Invasive Blood Pressure Alarm High: mean=125.0, range=[125.0–125.0], last=125.0 (single_observation)
#   Chloride: mean=101.0, range=[101.0–101.0], last=101.0 (single_observation)
#   Anion Gap: mean=11.0, range=[11.0–11.0], last=11.0 (single_observation)
#
# LABORATORY VALUES:
#   H: mean=7.00, last=7.00 (single_observation)
#   L: mean=6.00, last=6.00 (single_observation)
#   I: mean=0.00, last=0.00 (single_observation)
#   Potassium: mean=4.30, last=4.30 (single_observation)
#   Sodium: mean=138.00, last=138.00 (single_observation)
#   Chloride: mean=101.00, last=101.00 (single_observation)
#   Creatinine: mean=1.30, last=1.30 (single_observation)
#   Urea Nitrogen: mean=18.00, last=18.00 (single_observation)
#   Bicarbonate: mean=26.00, last=26.00 (single_observation)
#   Anion Gap: mean=11.00, last=11.00 (single_observation)
#   Glucose: mean=116.00, last=116.00 (single_observation)
#   Magnesium: mean=2.20, last=2.20 (single_observation)
#   Hematocrit: mean=31.10, last=31.10 (single_observation)
#   Hemoglobin: mean=9.40, last=9.40 (single_observation)
#   Platelet Count: mean=312.00, last=312.00 (single_observation)
#   White Blood Cells: mean=9.80, last=9.80 (single_observation)
#   Mch: mean=31.20, last=31.20 (single_observation)
#   Mcv: mean=103.00, last=103.00 (single_observation)
#   Rdw: mean=13.80, last=13.80 (single_observation)
#   Mchc: mean=30.20, last=30.20 (single_observation)
#   Red Blood Cells: mean=3.01, last=3.01 (single_observation)
#   Rdw Sd: mean=52.50, last=52.50 (single_observation)
#   Phosphate: mean=3.70, last=3.70 (single_observation)
#   Calcium Total: mean=8.50, last=8.50 (single_observation)
#
# INTERVENTIONS:
#   Medications: dextrose_5, po_intake
#   Procedures: 18_gauge, 22_gauge
#
# ## CANDIDATE DIAGNOSES
# Consider these 3 possibilities (listed in no particular order):
# - COPD_ASTHMA
# - HEART_FAILURE
# - SEPSIS
#
#
# ## YOUR TASK
# You are working with INCOMPLETE ICU data. Not all clinically relevant labs will be present. Your goal is to find the diagnosis most consistent with available evidence, explicitly accounting for what is and is not measured. A diagnosis should not be dismissed solely because its defining marker was not collected.
#
#
# Respond with ONLY valid JSON:
# {
#   "chosen_diagnosis": "DIAGNOSIS_NAME",
#   "reasoning": "2-3 sentence explanation of why this diagnosis fits best",
#   "supporting_evidence": ["key finding 1", "key finding 2", "key finding 3"],
#   "ruled_out": [
#     {"diagnosis": "OTHER_DIAGNOSIS_1", "reason": "why ruled out"},
#     {"diagnosis": "OTHER_DIAGNOSIS_2", "reason": "why ruled out"}
#   ]
# }
#
# Your chosen_diagnosis MUST be one of the 3 candidates listed above.
#
#
# ── STEP F: RAW LLM RESPONSE (parsed JSON) ──
# {
#   "chosen_diagnosis": "SEPSIS",
#   "reasoning": "The patient presents with signs suggestive of systemic inflammation and potential organ dysfunction, including tachycardia (mean 77.9, with high alarm at 130), tachypnea (mean 27.1, with high alarm at 40), and worsening diastolic blood pressure/mean arterial pressure (last diastolic 102, last MAP 106). While definitive markers like lactate or WBC count are not provided, the overall picture points towards sepsis as the most likely underlying process requiring further investigation.",
#   "supporting_evidence": [
#     "Tachypnea (mean RR 27.1)",
#     "Tachycardia (mean HR 77.9)",
#     "Worsening diastolic BP and MAP"
#   ],
#   "ruled_out": [
#     {
#       "diagnosis": "COPD_ASTHMA",
#       "reason": "No specific history or findings like wheezing or significant hypoxemia (mean SpO2 95.0) are mentioned to strongly suggest an acute exacerbation."
#     },
#     {
#       "diagnosis": "HEART_FAILURE",
#       "reason": "While diastolic BP is worsening, other typical signs like significant hypoxemia, specific ECG changes, or elevated BNP (not provided) are absent. The current data doesn't strongly point towards acute decompensated heart failure."
#     }
#   ]
# }
# SEPSIS  (override)
#
# ── STEP G: AGENT REASONING (parsed fields) ──
#   decision (post-hoc): override   [agent was blinded; computed from chosen_diagnosis vs LSTM top-1]
#   chosen_diagnosis   : SEPSIS
#   reasoning        :
#       The patient presents with signs suggestive of systemic inflammation and potential organ dysfunction, including tachycardia (mean 77.9, with high alarm at 130), tachypnea (mean 27.1, with high alarm at 40), and worsening diastolic blood pressure/mean arterial pressure (last diastolic 102, last MAP 106). While definitive markers like lactate or WBC count are not provided, the overall picture points towards sepsis as the most likely underlying process requiring further investigation.
#   supporting_evidence:
#       • Tachypnea (mean RR 27.1)
#       • Tachycardia (mean HR 77.9)
#       • Worsening diastolic BP and MAP
#   ruled_out:
#       • COPD_ASTHMA: No specific history or findings like wheezing or significant hypoxemia (mean SpO2 95.0) are mentioned to strongly suggest an acute exacerbation.
#       • HEART_FAILURE: While diastolic BP is worsening, other typical signs like significant hypoxemia, specific ECG changes, or elevated BNP (not provided) are absent. The current data doesn't strongly point towards acute decompensated heart failure.
#
# ── OUTCOME ──
#   LSTM top pick : HEART_FAILURE ✗
#   Agent pick    : SEPSIS ✗  (OVERRIDE)
#
# ══════════════════════════════════════════════════════════════════════════════
# CASE [72/100]  Patient 11814148  |  True: SURGICAL_COMPLICATION
# ══════════════════════════════════════════════════════════════════════════════
#
# ── STEP A: agent-safe card (top-level keys) ──
#   keys: ['clinical_summary', 'feature_names', 'patient_id', 'stay_id', 'time_series', 'visit_id']
#
# ── STEP B: LSTM top-K (probs shown for reference — NOT shown to agent) ──
#   1. SEPSIS                     33.3%
#   2. TOXIC_METABOLIC            14.2%
#   3. SURGICAL_COMPLICATION      11.0%
#
# ── STEP C: shuffled candidate order the agent will see (blinded) ──
#   SURGICAL_COMPLICATION | SEPSIS | TOXIC_METABOLIC
#
# ── STEP D: formatted clinical summary ──
# VITAL SIGNS (Last 12 Hours):
#   Heart Rate: mean=88.6, range=[78.0–96.0], last=89.0 (stable)
#   Respiratory Rate: mean=16.4, range=[9.0–31.5], last=16.0 (improving)
#   O2 Saturation Pulseoxymetry: mean=96.5, range=[94.0–99.0], last=95.0 (stable)
#   Non Invasive Blood Pressure Systolic: mean=111.0, range=[94.0–125.0], last=111.0 (worsening)
#   Non Invasive Blood Pressure Diastolic: mean=80.7, range=[75.0–92.0], last=82.0 (stable)
#   Non Invasive Blood Pressure Mean: mean=88.1, range=[80.0–97.0], last=89.0 (worsening)
#   Temperature Fahrenheit: mean=97.5, range=[97.4–97.6], last=97.6 (stable)
#   Heart Rate Alarm Low: mean=60.0, range=[60.0–60.0], last=60.0 (single_observation)
#   Heart Rate Alarm High: mean=130.0, range=[130.0–130.0], last=130.0 (single_observation)
#   O2 Saturation Pulseoxymetry Alarm Low: mean=92.0, range=[92.0–92.0], last=92.0 (single_observation)
#   O2 Saturation Pulseoxymetry Alarm High: mean=100.0, range=[100.0–100.0], last=100.0 (single_observation)
#   Resp Alarm High: mean=35.0, range=[35.0–35.0], last=35.0 (single_observation)
#   Resp Alarm Low: mean=8.0, range=[8.0–8.0], last=8.0 (single_observation)
#   Non Invasive Blood Pressure Alarm Low: mean=90.0, range=[90.0–90.0], last=90.0 (single_observation)
#   Non Invasive Blood Pressure Alarm High: mean=160.0, range=[160.0–160.0], last=160.0 (single_observation)
#
# LABORATORY VALUES:
#
# INTERVENTIONS:
#   Medications: nacl_0_9, solution
#   Procedures: foley_catheter
#
# ── STEP E: FULL PROMPT SENT TO LLM ──
#
# You are an expert ICU physician. You are given patient data and 3 possible diagnoses to consider. Your task is to determine which diagnosis best fits the clinical picture.
#
# ## PATIENT DATA (Last 12 Hours in ICU)
# VITAL SIGNS (Last 12 Hours):
#   Heart Rate: mean=88.6, range=[78.0–96.0], last=89.0 (stable)
#   Respiratory Rate: mean=16.4, range=[9.0–31.5], last=16.0 (improving)
#   O2 Saturation Pulseoxymetry: mean=96.5, range=[94.0–99.0], last=95.0 (stable)
#   Non Invasive Blood Pressure Systolic: mean=111.0, range=[94.0–125.0], last=111.0 (worsening)
#   Non Invasive Blood Pressure Diastolic: mean=80.7, range=[75.0–92.0], last=82.0 (stable)
#   Non Invasive Blood Pressure Mean: mean=88.1, range=[80.0–97.0], last=89.0 (worsening)
#   Temperature Fahrenheit: mean=97.5, range=[97.4–97.6], last=97.6 (stable)
#   Heart Rate Alarm Low: mean=60.0, range=[60.0–60.0], last=60.0 (single_observation)
#   Heart Rate Alarm High: mean=130.0, range=[130.0–130.0], last=130.0 (single_observation)
#   O2 Saturation Pulseoxymetry Alarm Low: mean=92.0, range=[92.0–92.0], last=92.0 (single_observation)
#   O2 Saturation Pulseoxymetry Alarm High: mean=100.0, range=[100.0–100.0], last=100.0 (single_observation)
#   Resp Alarm High: mean=35.0, range=[35.0–35.0], last=35.0 (single_observation)
#   Resp Alarm Low: mean=8.0, range=[8.0–8.0], last=8.0 (single_observation)
#   Non Invasive Blood Pressure Alarm Low: mean=90.0, range=[90.0–90.0], last=90.0 (single_observation)
#   Non Invasive Blood Pressure Alarm High: mean=160.0, range=[160.0–160.0], last=160.0 (single_observation)
#
# LABORATORY VALUES:
#
# INTERVENTIONS:
#   Medications: nacl_0_9, solution
#   Procedures: foley_catheter
#
# ## CANDIDATE DIAGNOSES
# Consider these 3 possibilities (listed in no particular order):
# - SURGICAL_COMPLICATION
# - SEPSIS
# - TOXIC_METABOLIC
#
#
# ## YOUR TASK
# You are working with INCOMPLETE ICU data. Not all clinically relevant labs will be present. Your goal is to find the diagnosis most consistent with available evidence, explicitly accounting for what is and is not measured. A diagnosis should not be dismissed solely because its defining marker was not collected.
#
#
# Respond with ONLY valid JSON:
# {
#   "chosen_diagnosis": "DIAGNOSIS_NAME",
#   "reasoning": "2-3 sentence explanation of why this diagnosis fits best",
#   "supporting_evidence": ["key finding 1", "key finding 2", "key finding 3"],
#   "ruled_out": [
#     {"diagnosis": "OTHER_DIAGNOSIS_1", "reason": "why ruled out"},
#     {"diagnosis": "OTHER_DIAGNOSIS_2", "reason": "why ruled out"}
#   ]
# }
#
# Your chosen_diagnosis MUST be one of the 3 candidates listed above.
#
#
# ── STEP F: RAW LLM RESPONSE (parsed JSON) ──
# {
#   "chosen_diagnosis": "SEPSIS",
#   "reasoning": "The patient exhibits worsening hemodynamics (decreasing mean arterial pressure) despite relatively stable heart rate and respiratory rate, which is concerning for distributive shock. While definitive sepsis markers like lactate or white blood cell count are missing, the overall clinical picture warrants high suspicion for sepsis, especially given the potential for occult infection in an ICU setting. The single high heart rate and low respiratory rate alarms also hint at potential instability.",
#   "supporting_evidence": [
#     "Worsening mean arterial pressure (MAP)",
#     "Single high heart rate alarm",
#     "Single low respiratory rate alarm"
#   ],
#   "ruled_out": [
#     {
#       "diagnosis": "SURGICAL_COMPLICATION",
#       "reason": "No information regarding recent surgery or specific surgical site issues is provided."
#     },
#     {
#       "diagnosis": "TOXIC_METABOLIC",
#       "reason": "No specific toxic ingestion or metabolic derangement (e.g., electrolyte abnormalities, acidosis) is documented."
#     }
#   ]
# }
# SEPSIS  (accept)
#
# ── STEP G: AGENT REASONING (parsed fields) ──
#   decision (post-hoc): accept   [agent was blinded; computed from chosen_diagnosis vs LSTM top-1]
#   chosen_diagnosis   : SEPSIS
#   reasoning        :
#       The patient exhibits worsening hemodynamics (decreasing mean arterial pressure) despite relatively stable heart rate and respiratory rate, which is concerning for distributive shock. While definitive sepsis markers like lactate or white blood cell count are missing, the overall clinical picture warrants high suspicion for sepsis, especially given the potential for occult infection in an ICU setting. The single high heart rate and low respiratory rate alarms also hint at potential instability.
#   supporting_evidence:
#       • Worsening mean arterial pressure (MAP)
#       • Single high heart rate alarm
#       • Single low respiratory rate alarm
#   ruled_out:
#       • SURGICAL_COMPLICATION: No information regarding recent surgery or specific surgical site issues is provided.
#       • TOXIC_METABOLIC: No specific toxic ingestion or metabolic derangement (e.g., electrolyte abnormalities, acidosis) is documented.
#
# ── OUTCOME ──
#   LSTM top pick : SEPSIS ✗
#   Agent pick    : SEPSIS ✗  (ACCEPT)
#
# ══════════════════════════════════════════════════════════════════════════════
# CASE [73/100]  Patient 18075452  |  True: SURGICAL_COMPLICATION
# ══════════════════════════════════════════════════════════════════════════════
#
# ── STEP A: agent-safe card (top-level keys) ──
#   keys: ['clinical_summary', 'feature_names', 'patient_id', 'stay_id', 'time_series', 'visit_id']
#
# ── STEP B: LSTM top-K (probs shown for reference — NOT shown to agent) ──
#   1. SEPSIS                     68.7%
#   2. SURGICAL_COMPLICATION      10.9%
#   3. TOXIC_METABOLIC             4.0%
#
# ── STEP C: shuffled candidate order the agent will see (blinded) ──
#   TOXIC_METABOLIC | SURGICAL_COMPLICATION | SEPSIS
#
# ── STEP D: formatted clinical summary ──
# VITAL SIGNS (Last 12 Hours):
#   Heart Rate: mean=90.1, range=[90.0–91.0], last=90.0 (stable)
#   Respiratory Rate: mean=27.1, range=[19.0–34.0], last=32.0 (stable)
#   O2 Saturation Pulseoxymetry: mean=96.8, range=[86.0–100.0], last=96.0 (stable)
#   Non Invasive Blood Pressure Systolic: mean=87.3, range=[71.0–95.0], last=95.0 (stable)
#   Non Invasive Blood Pressure Diastolic: mean=58.7, range=[53.0–67.0], last=60.0 (stable)
#   Non Invasive Blood Pressure Mean: mean=68.3, range=[61.0–76.0], last=71.0 (stable)
#   Temperature Fahrenheit: mean=98.3, range=[98.0–98.5], last=98.5 (stable)
#   Heart Rate Alarm Low: mean=50.0, range=[50.0–50.0], last=50.0 (single_observation)
#   Heart Rate Alarm High: mean=130.0, range=[130.0–130.0], last=130.0 (single_observation)
#   O2 Saturation Pulseoxymetry Alarm Low: mean=92.0, range=[92.0–92.0], last=92.0 (single_observation)
#   O2 Saturation Pulseoxymetry Alarm High: mean=100.0, range=[100.0–100.0], last=100.0 (single_observation)
#   Spo2 Desat Limit: mean=88.0, range=[88.0–88.0], last=88.0 (single_observation)
#   Resp Alarm High: mean=35.0, range=[35.0–35.0], last=35.0 (single_observation)
#   Resp Alarm Low: mean=8.0, range=[8.0–8.0], last=8.0 (single_observation)
#   Sodium: mean=133.0, range=[133.0–133.0], last=133.0 (single_observation)
#   Non Invasive Blood Pressure Alarm Low: mean=60.0, range=[60.0–60.0], last=60.0 (single_observation)
#   Non Invasive Blood Pressure Alarm High: mean=110.0, range=[110.0–110.0], last=110.0 (single_observation)
#
# LABORATORY VALUES:
#   H: mean=20.00, last=20.00 (single_observation)
#   L: mean=30.00, last=30.00 (single_observation)
#   I: mean=1.00, last=1.00 (single_observation)
#   Sodium: mean=133.00, last=133.00 (single_observation)
#
# INTERVENTIONS:
#   Medications: nacl_0_9, dextrose_5, po_intake
#   Procedures: 20_gauge, multi_lumen
#
# ── STEP E: FULL PROMPT SENT TO LLM ──
#
# You are an expert ICU physician. You are given patient data and 3 possible diagnoses to consider. Your task is to determine which diagnosis best fits the clinical picture.
#
# ## PATIENT DATA (Last 12 Hours in ICU)
# VITAL SIGNS (Last 12 Hours):
#   Heart Rate: mean=90.1, range=[90.0–91.0], last=90.0 (stable)
#   Respiratory Rate: mean=27.1, range=[19.0–34.0], last=32.0 (stable)
#   O2 Saturation Pulseoxymetry: mean=96.8, range=[86.0–100.0], last=96.0 (stable)
#   Non Invasive Blood Pressure Systolic: mean=87.3, range=[71.0–95.0], last=95.0 (stable)
#   Non Invasive Blood Pressure Diastolic: mean=58.7, range=[53.0–67.0], last=60.0 (stable)
#   Non Invasive Blood Pressure Mean: mean=68.3, range=[61.0–76.0], last=71.0 (stable)
#   Temperature Fahrenheit: mean=98.3, range=[98.0–98.5], last=98.5 (stable)
#   Heart Rate Alarm Low: mean=50.0, range=[50.0–50.0], last=50.0 (single_observation)
#   Heart Rate Alarm High: mean=130.0, range=[130.0–130.0], last=130.0 (single_observation)
#   O2 Saturation Pulseoxymetry Alarm Low: mean=92.0, range=[92.0–92.0], last=92.0 (single_observation)
#   O2 Saturation Pulseoxymetry Alarm High: mean=100.0, range=[100.0–100.0], last=100.0 (single_observation)
#   Spo2 Desat Limit: mean=88.0, range=[88.0–88.0], last=88.0 (single_observation)
#   Resp Alarm High: mean=35.0, range=[35.0–35.0], last=35.0 (single_observation)
#   Resp Alarm Low: mean=8.0, range=[8.0–8.0], last=8.0 (single_observation)
#   Sodium: mean=133.0, range=[133.0–133.0], last=133.0 (single_observation)
#   Non Invasive Blood Pressure Alarm Low: mean=60.0, range=[60.0–60.0], last=60.0 (single_observation)
#   Non Invasive Blood Pressure Alarm High: mean=110.0, range=[110.0–110.0], last=110.0 (single_observation)
#
# LABORATORY VALUES:
#   H: mean=20.00, last=20.00 (single_observation)
#   L: mean=30.00, last=30.00 (single_observation)
#   I: mean=1.00, last=1.00 (single_observation)
#   Sodium: mean=133.00, last=133.00 (single_observation)
#
# INTERVENTIONS:
#   Medications: nacl_0_9, dextrose_5, po_intake
#   Procedures: 20_gauge, multi_lumen
#
# ## CANDIDATE DIAGNOSES
# Consider these 3 possibilities (listed in no particular order):
# - TOXIC_METABOLIC
# - SURGICAL_COMPLICATION
# - SEPSIS
#
#
# ## YOUR TASK
# You are working with INCOMPLETE ICU data. Not all clinically relevant labs will be present. Your goal is to find the diagnosis most consistent with available evidence, explicitly accounting for what is and is not measured. A diagnosis should not be dismissed solely because its defining marker was not collected.
#
#
# Respond with ONLY valid JSON:
# {
#   "chosen_diagnosis": "DIAGNOSIS_NAME",
#   "reasoning": "2-3 sentence explanation of why this diagnosis fits best",
#   "supporting_evidence": ["key finding 1", "key finding 2", "key finding 3"],
#   "ruled_out": [
#     {"diagnosis": "OTHER_DIAGNOSIS_1", "reason": "why ruled out"},
#     {"diagnosis": "OTHER_DIAGNOSIS_2", "reason": "why ruled out"}
#   ]
# }
#
# Your chosen_diagnosis MUST be one of the 3 candidates listed above.
#
#
# ── STEP F: RAW LLM RESPONSE (parsed JSON) ──
# {
#   "chosen_diagnosis": "TOXIC_METABOLIC",
#   "reasoning": "The patient presents with stable but concerning vital signs, including borderline low blood pressure (mean 68.3) and tachypnea (mean 27.1), alongside a low sodium level (133.0). While sepsis is possible, the lack of fever or significant hemodynamic instability makes it less likely. A toxic or metabolic cause, potentially related to an unmeasured substance or electrolyte imbalance, could explain the overall clinical picture.",
#   "supporting_evidence": [
#     "Low Sodium (133.0)",
#     "Tachypnea (mean RR 27.1)",
#     "Borderline Hypotension (mean MAP 68.3)"
#   ],
#   "ruled_out": [
#     {
#       "diagnosis": "SEPSIS",
#       "reason": "No fever reported, and vital signs are relatively stable despite concerning trends, making overt sepsis less likely without further data."
#     },
#     {
#       "diagnosis": "SURGICAL_COMPLICATION",
#       "reason": "No specific surgical history or findings (e.g., bleeding, wound issues) are mentioned in the provided data to support this diagnosis."
#     }
#   ]
# }
# TOXIC_METABOLIC  (override)
#
# ── STEP G: AGENT REASONING (parsed fields) ──
#   decision (post-hoc): override   [agent was blinded; computed from chosen_diagnosis vs LSTM top-1]
#   chosen_diagnosis   : TOXIC_METABOLIC
#   reasoning        :
#       The patient presents with stable but concerning vital signs, including borderline low blood pressure (mean 68.3) and tachypnea (mean 27.1), alongside a low sodium level (133.0). While sepsis is possible, the lack of fever or significant hemodynamic instability makes it less likely. A toxic or metabolic cause, potentially related to an unmeasured substance or electrolyte imbalance, could explain the overall clinical picture.
#   supporting_evidence:
#       • Low Sodium (133.0)
#       • Tachypnea (mean RR 27.1)
#       • Borderline Hypotension (mean MAP 68.3)
#   ruled_out:
#       • SEPSIS: No fever reported, and vital signs are relatively stable despite concerning trends, making overt sepsis less likely without further data.
#       • SURGICAL_COMPLICATION: No specific surgical history or findings (e.g., bleeding, wound issues) are mentioned in the provided data to support this diagnosis.
#
# ── OUTCOME ──
#   LSTM top pick : SEPSIS ✗
#   Agent pick    : TOXIC_METABOLIC ✗  (OVERRIDE)
#
# ══════════════════════════════════════════════════════════════════════════════
# CASE [74/100]  Patient 12755559  |  True: VALVE_DISEASE
# ══════════════════════════════════════════════════════════════════════════════
#
# ── STEP A: agent-safe card (top-level keys) ──
#   keys: ['clinical_summary', 'feature_names', 'patient_id', 'stay_id', 'time_series', 'visit_id']
#
# ── STEP B: LSTM top-K (probs shown for reference — NOT shown to agent) ──
#   1. SEPSIS                     41.4%
#   2. HEART_FAILURE              32.8%
#   3. SURGICAL_COMPLICATION       5.8%
#
# ── STEP C: shuffled candidate order the agent will see (blinded) ──
#   HEART_FAILURE | SEPSIS | SURGICAL_COMPLICATION
#
# ── STEP D: formatted clinical summary ──
# VITAL SIGNS (Last 12 Hours):
#   Heart Rate: mean=81.1, range=[68.0–94.0], last=81.0 (improving)
#   Respiratory Rate: mean=18.4, range=[16.0–22.0], last=17.0 (stable)
#   O2 Saturation Pulseoxymetry: mean=95.2, range=[93.0–97.0], last=96.0 (stable)
#   Non Invasive Blood Pressure Systolic: mean=89.1, range=[75.0–109.0], last=95.0 (improving)
#   Non Invasive Blood Pressure Diastolic: mean=64.7, range=[44.0–83.0], last=68.0 (stable)
#   Non Invasive Blood Pressure Mean: mean=73.6, range=[55.0–91.0], last=79.0 (stable)
#   Temperature Fahrenheit: mean=98.0, range=[98.0–98.1], last=98.1 (stable)
#   Central Venous Pressure: mean=301.0, range=[301.0–301.0], last=301.0 (single_observation)
#   Sodium: mean=134.0, range=[134.0–134.0], last=134.0 (single_observation)
#   Hemoglobin: mean=8.5, range=[8.5–8.5], last=8.5 (single_observation)
#   Chloride: mean=96.0, range=[96.0–96.0], last=96.0 (single_observation)
#   Anion Gap: mean=11.0, range=[11.0–11.0], last=11.0 (single_observation)
#
# LABORATORY VALUES:
#   H: mean=0.00, last=0.00 (single_observation)
#   L: mean=14.00, last=14.00 (single_observation)
#   I: mean=1.00, last=1.00 (single_observation)
#   Potassium: mean=3.90, last=3.90 (single_observation)
#   Sodium: mean=134.00, last=134.00 (single_observation)
#   Chloride: mean=96.00, last=96.00 (single_observation)
#   Creatinine: mean=1.10, last=1.10 (single_observation)
#   Urea Nitrogen: mean=28.00, last=28.00 (single_observation)
#   Bicarbonate: mean=27.00, last=27.00 (single_observation)
#   Anion Gap: mean=11.00, last=11.00 (single_observation)
#   Glucose: mean=108.00, last=108.00 (single_observation)
#   Magnesium: mean=2.50, last=2.50 (single_observation)
#   Hematocrit: mean=27.70, last=27.70 (single_observation)
#   Hemoglobin: mean=8.50, last=8.50 (single_observation)
#   Platelet Count: mean=161.00, last=161.00 (single_observation)
#   White Blood Cells: mean=6.80, last=6.80 (single_observation)
#   Mch: mean=24.60, last=24.60 (single_observation)
#   Mcv: mean=80.00, last=80.00 (single_observation)
#   Rdw: mean=25.10, last=25.10 (single_observation)
#   Mchc: mean=30.70, last=30.70 (single_observation)
#   Red Blood Cells: mean=3.45, last=3.45 (single_observation)
#   Rdw Sd: mean=73.00, last=73.00 (single_observation)
#   Phosphate: mean=3.30, last=3.30 (single_observation)
#   Calcium Total: mean=8.80, last=8.80 (single_observation)
#   Ptt: mean=68.00, last=68.00 (single_observation)
#   Pt: mean=13.80, last=13.80 (single_observation)
#   Inr: mean=1.30, last=1.30 (single_observation)
#
# INTERVENTIONS:
#
# ── STEP E: FULL PROMPT SENT TO LLM ──
#
# You are an expert ICU physician. You are given patient data and 3 possible diagnoses to consider. Your task is to determine which diagnosis best fits the clinical picture.
#
# ## PATIENT DATA (Last 12 Hours in ICU)
# VITAL SIGNS (Last 12 Hours):
#   Heart Rate: mean=81.1, range=[68.0–94.0], last=81.0 (improving)
#   Respiratory Rate: mean=18.4, range=[16.0–22.0], last=17.0 (stable)
#   O2 Saturation Pulseoxymetry: mean=95.2, range=[93.0–97.0], last=96.0 (stable)
#   Non Invasive Blood Pressure Systolic: mean=89.1, range=[75.0–109.0], last=95.0 (improving)
#   Non Invasive Blood Pressure Diastolic: mean=64.7, range=[44.0–83.0], last=68.0 (stable)
#   Non Invasive Blood Pressure Mean: mean=73.6, range=[55.0–91.0], last=79.0 (stable)
#   Temperature Fahrenheit: mean=98.0, range=[98.0–98.1], last=98.1 (stable)
#   Central Venous Pressure: mean=301.0, range=[301.0–301.0], last=301.0 (single_observation)
#   Sodium: mean=134.0, range=[134.0–134.0], last=134.0 (single_observation)
#   Hemoglobin: mean=8.5, range=[8.5–8.5], last=8.5 (single_observation)
#   Chloride: mean=96.0, range=[96.0–96.0], last=96.0 (single_observation)
#   Anion Gap: mean=11.0, range=[11.0–11.0], last=11.0 (single_observation)
#
# LABORATORY VALUES:
#   H: mean=0.00, last=0.00 (single_observation)
#   L: mean=14.00, last=14.00 (single_observation)
#   I: mean=1.00, last=1.00 (single_observation)
#   Potassium: mean=3.90, last=3.90 (single_observation)
#   Sodium: mean=134.00, last=134.00 (single_observation)
#   Chloride: mean=96.00, last=96.00 (single_observation)
#   Creatinine: mean=1.10, last=1.10 (single_observation)
#   Urea Nitrogen: mean=28.00, last=28.00 (single_observation)
#   Bicarbonate: mean=27.00, last=27.00 (single_observation)
#   Anion Gap: mean=11.00, last=11.00 (single_observation)
#   Glucose: mean=108.00, last=108.00 (single_observation)
#   Magnesium: mean=2.50, last=2.50 (single_observation)
#   Hematocrit: mean=27.70, last=27.70 (single_observation)
#   Hemoglobin: mean=8.50, last=8.50 (single_observation)
#   Platelet Count: mean=161.00, last=161.00 (single_observation)
#   White Blood Cells: mean=6.80, last=6.80 (single_observation)
#   Mch: mean=24.60, last=24.60 (single_observation)
#   Mcv: mean=80.00, last=80.00 (single_observation)
#   Rdw: mean=25.10, last=25.10 (single_observation)
#   Mchc: mean=30.70, last=30.70 (single_observation)
#   Red Blood Cells: mean=3.45, last=3.45 (single_observation)
#   Rdw Sd: mean=73.00, last=73.00 (single_observation)
#   Phosphate: mean=3.30, last=3.30 (single_observation)
#   Calcium Total: mean=8.80, last=8.80 (single_observation)
#   Ptt: mean=68.00, last=68.00 (single_observation)
#   Pt: mean=13.80, last=13.80 (single_observation)
#   Inr: mean=1.30, last=1.30 (single_observation)
#
# INTERVENTIONS:
#
# ## CANDIDATE DIAGNOSES
# Consider these 3 possibilities (listed in no particular order):
# - HEART_FAILURE
# - SEPSIS
# - SURGICAL_COMPLICATION
#
#
# ## YOUR TASK
# You are working with INCOMPLETE ICU data. Not all clinically relevant labs will be present. Your goal is to find the diagnosis most consistent with available evidence, explicitly accounting for what is and is not measured. A diagnosis should not be dismissed solely because its defining marker was not collected.
#
#
# Respond with ONLY valid JSON:
# {
#   "chosen_diagnosis": "DIAGNOSIS_NAME",
#   "reasoning": "2-3 sentence explanation of why this diagnosis fits best",
#   "supporting_evidence": ["key finding 1", "key finding 2", "key finding 3"],
#   "ruled_out": [
#     {"diagnosis": "OTHER_DIAGNOSIS_1", "reason": "why ruled out"},
#     {"diagnosis": "OTHER_DIAGNOSIS_2", "reason": "why ruled out"}
#   ]
# }
#
# Your chosen_diagnosis MUST be one of the 3 candidates listed above.
#
#
# ── STEP F: RAW LLM RESPONSE (parsed JSON) ──
# {
#   "chosen_diagnosis": "HEART_FAILURE",
#   "reasoning": "The patient presents with low blood pressure (mean 73.6 mmHg, systolic 89.1 mmHg) and a single elevated CVP reading (301.0 mmHg, which is likely a typo and should be interpreted as 30.1 cm H2O, indicating high right atrial pressure). These findings, along with the stable respiratory rate and oxygen saturation, are suggestive of cardiogenic shock or decompensated heart failure, rather than sepsis or a primary surgical complication.",
#   "supporting_evidence": [
#     "Low mean arterial pressure (MAP) of 73.6 mmHg",
#     "Low systolic blood pressure (SBP) of 89.1 mmHg",
#     "Elevated Central Venous Pressure (CVP) of 301.0 (interpreted as 30.1 cm H2O)"
#   ],
#   "ruled_out": [
#     {
#       "diagnosis": "SEPSIS",
#       "reason": "While hypotension can occur in sepsis, the patient lacks fever (temperature is stable at 98.0 F), significant tachycardia (mean HR 81.1), or leukocytosis (WBC 6.8). The stable respiratory rate and oxygen saturation also make severe sepsis less likely, although it cannot be definitively excluded without more data."
#     },
#     {
#       "diagnosis": "SURGICAL_COMPLICATION",
#       "reason": "There is no information provided regarding recent surgery or specific signs of a surgical complication (e.g., bleeding, infection at a surgical site, specific organ dysfunction related to surgery). The current presentation is more consistent with a primary cardiac issue."
#     }
#   ]
# }
# HEART_FAILURE  (override)
#
# ── STEP G: AGENT REASONING (parsed fields) ──
#   decision (post-hoc): override   [agent was blinded; computed from chosen_diagnosis vs LSTM top-1]
#   chosen_diagnosis   : HEART_FAILURE
#   reasoning        :
#       The patient presents with low blood pressure (mean 73.6 mmHg, systolic 89.1 mmHg) and a single elevated CVP reading (301.0 mmHg, which is likely a typo and should be interpreted as 30.1 cm H2O, indicating high right atrial pressure). These findings, along with the stable respiratory rate and oxygen saturation, are suggestive of cardiogenic shock or decompensated heart failure, rather than sepsis or a primary surgical complication.
#   supporting_evidence:
#       • Low mean arterial pressure (MAP) of 73.6 mmHg
#       • Low systolic blood pressure (SBP) of 89.1 mmHg
#       • Elevated Central Venous Pressure (CVP) of 301.0 (interpreted as 30.1 cm H2O)
#   ruled_out:
#       • SEPSIS: While hypotension can occur in sepsis, the patient lacks fever (temperature is stable at 98.0 F), significant tachycardia (mean HR 81.1), or leukocytosis (WBC 6.8). The stable respiratory rate and oxygen saturation also make severe sepsis less likely, although it cannot be definitively excluded without more data.
#       • SURGICAL_COMPLICATION: There is no information provided regarding recent surgery or specific signs of a surgical complication (e.g., bleeding, infection at a surgical site, specific organ dysfunction related to surgery). The current presentation is more consistent with a primary cardiac issue.
#
# ── OUTCOME ──
#   LSTM top pick : SEPSIS ✗
#   Agent pick    : HEART_FAILURE ✗  (OVERRIDE)
#
# ══════════════════════════════════════════════════════════════════════════════
# CASE [75/100]  Patient 13490135  |  True: VALVE_DISEASE
# ...
#   supporting_evidence:
#       • Hypotension (mean BP 50)
#       • Hypoxemia (O2 sat 72% on 100% FiO2)
#       • Leukocytosis (WBC 21.6)
#   ruled_out:
#       • ACUTE_MI: No cardiac enzymes (Troponin, CK-MB) or ECG data are provided, making it impossible to confirm or rule out MI based on the available data. While hypotension and hypoxemia can occur in MI, the lack of specific cardiac markers makes sepsis a more likely explanation for the overall clinical picture.
#       • SURGICAL_COMPLICATION: There is no information regarding recent surgery or specific surgical site findings. While sepsis can be a complication of surgery, the data doesn't specifically point towards a surgical source over other potential causes of sepsis.
#
# ── OUTCOME ──
#   LSTM top pick : SURGICAL_COMPLICATION ✗
#   Agent pick    : SEPSIS ✓  (OVERRIDE)
#
# ══════════════════════════════════════════════════════════════════════════════
# CASE [99/100]  Patient 19646802  |  True: TRAUMA_NEURO
# ══════════════════════════════════════════════════════════════════════════════
#
# ── STEP A: agent-safe card (top-level keys) ──
#   keys: ['clinical_summary', 'feature_names', 'patient_id', 'stay_id', 'time_series', 'visit_id']
#
# ── STEP B: LSTM top-K (probs shown for reference — NOT shown to agent) ──
#   1. STROKE_NEURO               34.5%
#   2. SURGICAL_COMPLICATION      28.1%
#   3. TRAUMA_NEURO               20.5%
#
# ── STEP C: shuffled candidate order the agent will see (blinded) ──
#   SURGICAL_COMPLICATION | TRAUMA_NEURO | STROKE_NEURO
#
# ── STEP D: formatted clinical summary ──
# VITAL SIGNS (Last 12 Hours):
#   Heart Rate: mean=79.5, range=[69.0–100.0], last=100.0 (worsening)
#   Respiratory Rate: mean=22.0, range=[14.0–37.0], last=23.0 (worsening)
#   O2 Saturation Pulseoxymetry: mean=94.8, range=[91.0–100.0], last=92.0 (stable)
#   Non Invasive Blood Pressure Systolic: mean=104.0, range=[84.0–124.0], last=110.0 (stable)
#   Non Invasive Blood Pressure Diastolic: mean=60.9, range=[42.0–87.0], last=58.0 (worsening)
#   Non Invasive Blood Pressure Mean: mean=71.1, range=[56.0–97.0], last=71.0 (worsening)
#   Temperature Fahrenheit: mean=98.7, range=[97.4–99.9], last=99.9 (stable)
#   Glucose Finger Stick: mean=120.0, range=[120.0–120.0], last=120.0 (single_observation)
#   Heart Rate Alarm Low: mean=50.0, range=[50.0–50.0], last=50.0 (single_observation)
#   Heart Rate Alarm High: mean=120.0, range=[120.0–120.0], last=120.0 (single_observation)
#   O2 Saturation Pulseoxymetry Alarm Low: mean=92.0, range=[92.0–92.0], last=92.0 (single_observation)
#   O2 Saturation Pulseoxymetry Alarm High: mean=100.0, range=[100.0–100.0], last=100.0 (single_observation)
#   Spo2 Desat Limit: mean=85.0, range=[85.0–85.0], last=85.0 (single_observation)
#   Resp Alarm High: mean=35.0, range=[35.0–35.0], last=35.0 (single_observation)
#   Resp Alarm Low: mean=8.0, range=[8.0–8.0], last=8.0 (single_observation)
#   O2 Flow: mean=2.5, range=[2.0–3.0], last=2.0 (improving)
#   Non Invasive Blood Pressure Alarm Low: mean=90.0, range=[90.0–90.0], last=90.0 (single_observation)
#   Non Invasive Blood Pressure Alarm High: mean=160.0, range=[160.0–160.0], last=160.0 (single_observation)
#
# LABORATORY VALUES:
#
# INTERVENTIONS:
#   Medications: nacl_0_9, solution, po_intake
#   Procedures: 20_gauge, foley_catheter
#
# ── STEP E: FULL PROMPT SENT TO LLM ──
#
# You are an expert ICU physician. You are given patient data and 3 possible diagnoses to consider. Your task is to determine which diagnosis best fits the clinical picture.
#
# ## PATIENT DATA (Last 12 Hours in ICU)
# VITAL SIGNS (Last 12 Hours):
#   Heart Rate: mean=79.5, range=[69.0–100.0], last=100.0 (worsening)
#   Respiratory Rate: mean=22.0, range=[14.0–37.0], last=23.0 (worsening)
#   O2 Saturation Pulseoxymetry: mean=94.8, range=[91.0–100.0], last=92.0 (stable)
#   Non Invasive Blood Pressure Systolic: mean=104.0, range=[84.0–124.0], last=110.0 (stable)
#   Non Invasive Blood Pressure Diastolic: mean=60.9, range=[42.0–87.0], last=58.0 (worsening)
#   Non Invasive Blood Pressure Mean: mean=71.1, range=[56.0–97.0], last=71.0 (worsening)
#   Temperature Fahrenheit: mean=98.7, range=[97.4–99.9], last=99.9 (stable)
#   Glucose Finger Stick: mean=120.0, range=[120.0–120.0], last=120.0 (single_observation)
#   Heart Rate Alarm Low: mean=50.0, range=[50.0–50.0], last=50.0 (single_observation)
#   Heart Rate Alarm High: mean=120.0, range=[120.0–120.0], last=120.0 (single_observation)
#   O2 Saturation Pulseoxymetry Alarm Low: mean=92.0, range=[92.0–92.0], last=92.0 (single_observation)
#   O2 Saturation Pulseoxymetry Alarm High: mean=100.0, range=[100.0–100.0], last=100.0 (single_observation)
#   Spo2 Desat Limit: mean=85.0, range=[85.0–85.0], last=85.0 (single_observation)
#   Resp Alarm High: mean=35.0, range=[35.0–35.0], last=35.0 (single_observation)
#   Resp Alarm Low: mean=8.0, range=[8.0–8.0], last=8.0 (single_observation)
#   O2 Flow: mean=2.5, range=[2.0–3.0], last=2.0 (improving)
#   Non Invasive Blood Pressure Alarm Low: mean=90.0, range=[90.0–90.0], last=90.0 (single_observation)
#   Non Invasive Blood Pressure Alarm High: mean=160.0, range=[160.0–160.0], last=160.0 (single_observation)
#
# LABORATORY VALUES:
#
# INTERVENTIONS:
#   Medications: nacl_0_9, solution, po_intake
#   Procedures: 20_gauge, foley_catheter
#
# ## CANDIDATE DIAGNOSES
# Consider these 3 possibilities (listed in no particular order):
# - SURGICAL_COMPLICATION
# - TRAUMA_NEURO
# - STROKE_NEURO
#
#
# ## YOUR TASK
# You are working with INCOMPLETE ICU data. Not all clinically relevant labs will be present. Your goal is to find the diagnosis most consistent with available evidence, explicitly accounting for what is and is not measured. A diagnosis should not be dismissed solely because its defining marker was not collected.
#
#
# Respond with ONLY valid JSON:
# {
#   "chosen_diagnosis": "DIAGNOSIS_NAME",
#   "reasoning": "2-3 sentence explanation of why this diagnosis fits best",
#   "supporting_evidence": ["key finding 1", "key finding 2", "key finding 3"],
#   "ruled_out": [
#     {"diagnosis": "OTHER_DIAGNOSIS_1", "reason": "why ruled out"},
#     {"diagnosis": "OTHER_DIAGNOSIS_2", "reason": "why ruled out"}
#   ]
# }
#
# Your chosen_diagnosis MUST be one of the 3 candidates listed above.
#
#
# ── STEP F: RAW LLM RESPONSE (parsed JSON) ──
# {
#   "chosen_diagnosis": "STROKE_NEURO",
#   "reasoning": "The patient presents with worsening vital signs, particularly a widening pulse pressure (diastolic worsening more than systolic) and increasing heart rate, which can be indicative of increased intracranial pressure or autonomic dysfunction often seen in stroke. While specific neurological labs or imaging are missing, the overall clinical picture points towards a neurological event like stroke.",
#   "supporting_evidence": [
#     "Worsening diastolic blood pressure",
#     "Worsening mean arterial pressure",
#     "Worsening heart rate"
#   ],
#   "ruled_out": [
#     {
#       "diagnosis": "SURGICAL_COMPLICATION",
#       "reason": "No information regarding recent surgery or typical post-operative complications like bleeding or infection is provided."
#     },
#     {
#       "diagnosis": "TRAUMA_NEURO",
#       "reason": "No history or signs of trauma are mentioned in the provided data."
#     }
#   ]
# }
# STROKE_NEURO  (accept)
#
# ── STEP G: AGENT REASONING (parsed fields) ──
#   decision (post-hoc): accept   [agent was blinded; computed from chosen_diagnosis vs LSTM top-1]
#   chosen_diagnosis   : STROKE_NEURO
#   reasoning        :
#       The patient presents with worsening vital signs, particularly a widening pulse pressure (diastolic worsening more than systolic) and increasing heart rate, which can be indicative of increased intracranial pressure or autonomic dysfunction often seen in stroke. While specific neurological labs or imaging are missing, the overall clinical picture points towards a neurological event like stroke.
#   supporting_evidence:
#       • Worsening diastolic blood pressure
#       • Worsening mean arterial pressure
#       • Worsening heart rate
#   ruled_out:
#       • SURGICAL_COMPLICATION: No information regarding recent surgery or typical post-operative complications like bleeding or infection is provided.
#       • TRAUMA_NEURO: No history or signs of trauma are mentioned in the provided data.
#
# ── OUTCOME ──
#   LSTM top pick : STROKE_NEURO ✗
#   Agent pick    : STROKE_NEURO ✗  (ACCEPT)
#
# ══════════════════════════════════════════════════════════════════════════════
# CASE [100/100]  Patient 18765416  |  True: TOXIC_METABOLIC
# ══════════════════════════════════════════════════════════════════════════════
#
# ── STEP A: agent-safe card (top-level keys) ──
#   keys: ['clinical_summary', 'feature_names', 'patient_id', 'stay_id', 'time_series', 'visit_id']
#
# ── STEP B: LSTM top-K (probs shown for reference — NOT shown to agent) ──
#   1. PNEUMONIA                  22.2%
#   2. SEPSIS                     22.0%
#   3. HEART_FAILURE               9.4%
#
# ── STEP C: shuffled candidate order the agent will see (blinded) ──
#   PNEUMONIA | SEPSIS | HEART_FAILURE
#
# ── STEP D: formatted clinical summary ──
# VITAL SIGNS (Last 12 Hours):
#   Heart Rate: mean=89.6, range=[76.0–103.0], last=87.0 (stable)
#   Respiratory Rate: mean=17.4, range=[12.0–31.0], last=31.0 (worsening)
#   O2 Saturation Pulseoxymetry: mean=94.4, range=[92.0–96.0], last=94.0 (stable)
#   Non Invasive Blood Pressure Systolic: mean=124.4, range=[112.0–140.0], last=117.0 (stable)
#   Non Invasive Blood Pressure Diastolic: mean=81.4, range=[70.0–95.0], last=95.0 (worsening)
#   Non Invasive Blood Pressure Mean: mean=89.1, range=[81.0–106.0], last=84.0 (stable)
#   Temperature Fahrenheit: mean=98.3, range=[98.1–98.6], last=98.2 (stable)
#   Heart Rate Alarm Low: mean=55.0, range=[55.0–55.0], last=55.0 (single_observation)
#   Heart Rate Alarm High: mean=130.0, range=[130.0–130.0], last=130.0 (single_observation)
#   O2 Saturation Pulseoxymetry Alarm Low: mean=92.0, range=[92.0–92.0], last=92.0 (single_observation)
#   O2 Saturation Pulseoxymetry Alarm High: mean=100.0, range=[100.0–100.0], last=100.0 (single_observation)
#   Spo2 Desat Limit: mean=89.0, range=[89.0–89.0], last=89.0 (single_observation)
#   Resp Alarm High: mean=35.0, range=[35.0–35.0], last=35.0 (single_observation)
#   Resp Alarm Low: mean=8.0, range=[8.0–8.0], last=8.0 (single_observation)
#   O2 Flow: mean=3.0, range=[2.0–4.0], last=2.0 (improving)
#   Non Invasive Blood Pressure Alarm Low: mean=90.0, range=[90.0–90.0], last=90.0 (single_observation)
#   Non Invasive Blood Pressure Alarm High: mean=160.0, range=[160.0–160.0], last=160.0 (single_observation)
#
# LABORATORY VALUES:
#
# INTERVENTIONS:
#
# ── STEP E: FULL PROMPT SENT TO LLM ──
#
# You are an expert ICU physician. You are given patient data and 3 possible diagnoses to consider. Your task is to determine which diagnosis best fits the clinical picture.
#
# ## PATIENT DATA (Last 12 Hours in ICU)
# VITAL SIGNS (Last 12 Hours):
#   Heart Rate: mean=89.6, range=[76.0–103.0], last=87.0 (stable)
#   Respiratory Rate: mean=17.4, range=[12.0–31.0], last=31.0 (worsening)
#   O2 Saturation Pulseoxymetry: mean=94.4, range=[92.0–96.0], last=94.0 (stable)
#   Non Invasive Blood Pressure Systolic: mean=124.4, range=[112.0–140.0], last=117.0 (stable)
#   Non Invasive Blood Pressure Diastolic: mean=81.4, range=[70.0–95.0], last=95.0 (worsening)
#   Non Invasive Blood Pressure Mean: mean=89.1, range=[81.0–106.0], last=84.0 (stable)
#   Temperature Fahrenheit: mean=98.3, range=[98.1–98.6], last=98.2 (stable)
#   Heart Rate Alarm Low: mean=55.0, range=[55.0–55.0], last=55.0 (single_observation)
#   Heart Rate Alarm High: mean=130.0, range=[130.0–130.0], last=130.0 (single_observation)
#   O2 Saturation Pulseoxymetry Alarm Low: mean=92.0, range=[92.0–92.0], last=92.0 (single_observation)
#   O2 Saturation Pulseoxymetry Alarm High: mean=100.0, range=[100.0–100.0], last=100.0 (single_observation)
#   Spo2 Desat Limit: mean=89.0, range=[89.0–89.0], last=89.0 (single_observation)
#   Resp Alarm High: mean=35.0, range=[35.0–35.0], last=35.0 (single_observation)
#   Resp Alarm Low: mean=8.0, range=[8.0–8.0], last=8.0 (single_observation)
#   O2 Flow: mean=3.0, range=[2.0–4.0], last=2.0 (improving)
#   Non Invasive Blood Pressure Alarm Low: mean=90.0, range=[90.0–90.0], last=90.0 (single_observation)
#   Non Invasive Blood Pressure Alarm High: mean=160.0, range=[160.0–160.0], last=160.0 (single_observation)
#
# LABORATORY VALUES:
#
# INTERVENTIONS:
#
# ## CANDIDATE DIAGNOSES
# Consider these 3 possibilities (listed in no particular order):
# - PNEUMONIA
# - SEPSIS
# - HEART_FAILURE
#
#
# ## YOUR TASK
# You are working with INCOMPLETE ICU data. Not all clinically relevant labs will be present. Your goal is to find the diagnosis most consistent with available evidence, explicitly accounting for what is and is not measured. A diagnosis should not be dismissed solely because its defining marker was not collected.
#
#
# Respond with ONLY valid JSON:
# {
#   "chosen_diagnosis": "DIAGNOSIS_NAME",
#   "reasoning": "2-3 sentence explanation of why this diagnosis fits best",
#   "supporting_evidence": ["key finding 1", "key finding 2", "key finding 3"],
#   "ruled_out": [
#     {"diagnosis": "OTHER_DIAGNOSIS_1", "reason": "why ruled out"},
#     {"diagnosis": "OTHER_DIAGNOSIS_2", "reason": "why ruled out"}
#   ]
# }
#
# Your chosen_diagnosis MUST be one of the 3 candidates listed above.
#
#
# ── STEP F: RAW LLM RESPONSE (parsed JSON) ──
# {
#   "chosen_diagnosis": "PNEUMONIA",
#   "reasoning": "The patient presents with a worsening respiratory rate (mean 17.4, range 12-31, last 31) and a single observation of a high respiratory alarm (35), suggesting respiratory distress. While oxygen saturation is relatively stable, the overall trend points towards a pulmonary process. Without labs like WBC or inflammatory markers, pneumonia remains a strong possibility given the respiratory findings.",
#   "supporting_evidence": [
#     "Worsening respiratory rate (last=31)",
#     "High respiratory alarm (35)",
#     "Stable O2 saturation despite increased respiratory effort"
#   ],
#   "ruled_out": [
#     {
#       "diagnosis": "SEPSIS",
#       "reason": "No clear signs of systemic inflammation or hemodynamic instability (stable BP, HR) are present, although sepsis cannot be definitively ruled out without labs like lactate or WBC."
#     },
#     {
#       "diagnosis": "HEART_FAILURE",
#       "reason": "While diastolic BP is worsening, the overall BP is stable, and there are no specific signs like JVD, edema, or significant tachycardia/bradycardia strongly suggestive of acute heart failure exacerbation."
#     }
#   ]
# }
# PNEUMONIA  (accept)
#
# ── STEP G: AGENT REASONING (parsed fields) ──
#   decision (post-hoc): accept   [agent was blinded; computed from chosen_diagnosis vs LSTM top-1]
#   chosen_diagnosis   : PNEUMONIA
#   reasoning        :
#       The patient presents with a worsening respiratory rate (mean 17.4, range 12-31, last 31) and a single observation of a high respiratory alarm (35), suggesting respiratory distress. While oxygen saturation is relatively stable, the overall trend points towards a pulmonary process. Without labs like WBC or inflammatory markers, pneumonia remains a strong possibility given the respiratory findings.
#   supporting_evidence:
#       • Worsening respiratory rate (last=31)
#       • High respiratory alarm (35)
#       • Stable O2 saturation despite increased respiratory effort
#   ruled_out:
#       • SEPSIS: No clear signs of systemic inflammation or hemodynamic instability (stable BP, HR) are present, although sepsis cannot be definitively ruled out without labs like lactate or WBC.
#       • HEART_FAILURE: While diastolic BP is worsening, the overall BP is stable, and there are no specific signs like JVD, edema, or significant tachycardia/bradycardia strongly suggestive of acute heart failure exacerbation.
#
# ── OUTCOME ──
#   LSTM top pick : PNEUMONIA ✗
#   Agent pick    : PNEUMONIA ✗  (ACCEPT)
#
# ==============================================================================
# Pilot complete — elapsed: 1:34:42.140892
# Valid: 100/100

# %%
# ══════════════════════════════════════════════════════════════════════════════
# COMPUTE METRICS
# ══════════════════════════════════════════════════════════════════════════════

valid_results = [r for r in results if 'error' not in r]
print(f'Valid results: {len(valid_results)}/{len(results)}')

disagree_cases = []
if valid_results:
    n = len(valid_results)

    lstm_correct  = sum(r['lstm_correct']  for r in valid_results)
    agent_correct = sum(r['agent_correct'] for r in valid_results)

    both_correct   = sum(r['lstm_correct']     and r['agent_correct']     for r in valid_results)
    agent_improved = sum(not r['lstm_correct'] and r['agent_correct']     for r in valid_results)
    agent_hurt     = sum(r['lstm_correct']     and not r['agent_correct'] for r in valid_results)
    both_wrong     = sum(not r['lstm_correct'] and not r['agent_correct'] for r in valid_results)

    disagreements = sum(r['agent_disagrees'] for r in valid_results)
    true_in_topk  = sum(r['true_label'] in r['lstm_output']['top_k_codes'] for r in valid_results)

    print(f'\n{"═" * 60}')
    print(f'SINGLE AGENT RESULTS ({n} cases, top-{TOP_K})')
    print(f'{"═" * 60}')
    print(f'\nAccuracy:')
    print(f'  LSTM Top-1  : {lstm_correct}/{n} ({lstm_correct/n*100:.1f}%)')
    print(f'  Agent       : {agent_correct}/{n} ({agent_correct/n*100:.1f}%)')
    print(f'  Improvement : {(agent_correct - lstm_correct)/n*100:+.1f}%')
    print(f'\nTrue in top-{TOP_K}: {true_in_topk}/{n} ({true_in_topk/n*100:.1f}%)')
    print(f'Agent disagreed: {disagreements}/{n} ({disagreements/n*100:.1f}%)')
    print(f'\nCase Breakdown:')
    print(f'  Both correct    : {both_correct} ({both_correct/n*100:.1f}%)')
    print(f'  Agent improved  : {agent_improved} ({agent_improved/n*100:.1f}%) 🎉')
    print(f'  Agent hurt      : {agent_hurt} ({agent_hurt/n*100:.1f}%) ⚠️')
    print(f'  Both wrong      : {both_wrong} ({both_wrong/n*100:.1f}%)')
    print(f'\nNet: {agent_improved - agent_hurt:+d} cases')

    disagree_cases = [r for r in valid_results if r['agent_disagrees']]
# Out:
# Valid results: 100/100
#
# ════════════════════════════════════════════════════════════
# SINGLE AGENT RESULTS (100 cases, top-3)
# ════════════════════════════════════════════════════════════
#
# Accuracy:
#   LSTM Top-1  : 40/100 (40.0%)
#   Agent       : 36/100 (36.0%)
#   Improvement : -4.0%
#
# True in top-3: 80/100 (80.0%)
# Agent disagreed: 48/100 (48.0%)
#
# Case Breakdown:
#   Both correct    : 26 (26.0%)
#   Agent improved  : 10 (10.0%) 🎉
#   Agent hurt      : 14 (14.0%) ⚠️
#   Both wrong      : 50 (50.0%)
#
# Net: -4 cases

# %%
import pandas as pd

# Ensure valid_results is defined, in case the previous cell was not executed
valid_results = [r for r in results if 'error' not in r]

table_data = []
for r in valid_results:
    lstm_top_pick = r['lstm_top_pick']
    true_label = r['true_label']
    lstm_confidence = f"{r['lstm_output']['top_k_probs'][0]:.1%}"
    agent_pick = r['agent_prediction']

    # Map agent_decision to 'Accept' or 'Reject'
    decision_text = 'Accept' if r['agent_decision'] == 'accept' else 'Reject'

    # Map agent_correct to 'Correct' or 'Wrong'
    agent_result_text = 'Correct' if r['agent_correct'] else 'Wrong'

    table_data.append({
        'True Label': true_label,
        'LSTM Top-1': lstm_top_pick,
        'LSTM Confidence (%)': lstm_confidence,
        'Agent Pick': agent_pick,
        'Decision (Accept/Reject)': decision_text,
        'Result (Correct/Wrong)': agent_result_text
    })

df_results = pd.DataFrame(table_data)

print("\nSummary of all 100 cases:")
df_results
# Out:
# Summary of all 100 cases:
#          True Label             LSTM Top-1 LSTM Confidence (%)  \
# 0            SEPSIS                 SEPSIS               35.1%
# 1            SEPSIS        TOXIC_METABOLIC               64.3%
# 2            SEPSIS                 SEPSIS               24.2%
# 3            SEPSIS           STROKE_NEURO               53.4%
# 4            SEPSIS                 SEPSIS               70.2%
# ..              ...                    ...                 ...
# 95          SYNCOPE          HEART_FAILURE               19.4%
# 96    UTI_INFECTION               ACUTE_MI               28.9%
# 97           SEPSIS  SURGICAL_COMPLICATION               29.9%
# 98     TRAUMA_NEURO           STROKE_NEURO               34.5%
# 99  TOXIC_METABOLIC              PNEUMONIA               22.2%
#
#                Agent Pick Decision (Accept/Reject) Result (Correct/Wrong)
# 0                  SEPSIS                   Accept                Correct
# 1                  SEPSIS                   Reject                Correct
# 2                  SEPSIS                   Accept                Correct
# 3   SURGICAL_COMPLICATION                   Reject                  Wrong
# 4                  SEPSIS                   Accept                Correct
# ..                    ...                      ...                    ...
# 95        TOXIC_METABOLIC                   Reject                  Wrong
# 96     CORONARY_ARTERY_DZ                   Reject                  Wrong
# 97                 SEPSIS                   Reject                Correct
# 98           STROKE_NEURO                   Accept                  Wrong
# 99              PNEUMONIA                   Accept                  Wrong
#
# [100 rows x 6 columns]

# %%
# ══════════════════════════════════════════════════════════════════════════════
# INSPECT A CASE
# ══════════════════════════════════════════════════════════════════════════════

def inspect_case(result):
    print('═' * 70)
    print(f"PATIENT: {result['patient_id']}")
    print('═' * 70)
    print(f"\n🎯 TRUE: {result['true_label']}")

    print(f"\n📊 LSTM TOP-{TOP_K} (probs not shown to agent):")
    for i, (code, prob) in enumerate(zip(
        result['lstm_output']['top_k_codes'],
        result['lstm_output']['top_k_probs']
    )):
        mark = '✓' if code == result['true_label'] else ' '
        tag  = '  ← LSTM top pick' if i == 0 else ''
        print(f"   {i+1}. {code:<25} {prob:>6.1%} {mark}{tag}")

    print(f"\n   What the agent saw (no probs):")
    print(f"     LSTM top pick   : {result.get('lstm_top_pick')}")
    for c in result.get('other_candidates_shown', []):
        print(f"     other candidate : {c}")

    print(f"\n🤖 AGENT DECISION:")
    print(f"   Decision: {result.get('agent_decision', '?').upper()}")
    print(f"   Chose   : {result['agent_prediction']}")

    ao = result['agent_output']
    if 'lstm_top_pick_assessment' in ao:
        print(f"\n   LSTM top-pick assessment: {ao['lstm_top_pick_assessment']}")
    if 'reasoning' in ao:
        print(f"\n   Reasoning: {ao['reasoning']}")
    if 'supporting_evidence' in ao:
        print(f"\n   Supporting evidence:")
        for ev in ao['supporting_evidence'][:3]:
            print(f"     • {ev}")
    if 'ruled_out' in ao:
        print(f"\n   Ruled out:")
        for ro in ao['ruled_out']:
            print(f"     • {ro.get('diagnosis', '?')}: {ro.get('reason', 'N/A')}")

    print(f"\n{'─' * 70}")
    if result['lstm_correct'] and result['agent_correct']:
        print('✅ BOTH CORRECT')
    elif not result['lstm_correct'] and result['agent_correct']:
        print('🎉 AGENT IMPROVED (override was right)' if result['agent_decision'] == 'override'
              else '🎉 AGENT CORRECT (accepted correct LSTM pick)')
    elif result['lstm_correct'] and not result['agent_correct']:
        print('⚠️ AGENT HURT (overrode a correct LSTM pick)')
    else:
        print('❌ BOTH WRONG')

if valid_results:
    inspect_case(valid_results[0])
# Out:
# ══════════════════════════════════════════════════════════════════════
# PATIENT: 19049931
# ══════════════════════════════════════════════════════════════════════
#
# 🎯 TRUE: SEPSIS
#
# 📊 LSTM TOP-3 (probs not shown to agent):
#    1. SEPSIS                     35.1% ✓  ← LSTM top pick
#    2. STROKE_NEURO               32.9%
#    3. TRAUMA_NEURO               13.8%
#
#    What the agent saw (no probs):
#      LSTM top pick   : SEPSIS
#
# 🤖 AGENT DECISION:
#    Decision: ACCEPT
#    Chose   : SEPSIS
#
#    Reasoning: The patient presents with tachycardia (HR 98.3), tachypnea (RR 32.9), and worsening hypotension (MAP 85.2, last 90.0) despite stable oxygenation, which are classic signs of sepsis. The hyperglycemia (Glucose 200.0) is also commonly associated with sepsis. While neurological deficits are not explicitly mentioned, the overall picture strongly suggests a systemic inflammatory response.
#
#    Supporting evidence:
#      • Tachycardia (mean HR 98.3)
#      • Tachypnea (mean RR 32.9)
#      • Worsening hypotension (mean MAP 85.2, last 90.0)
#
#    Ruled out:
#      • STROKE_NEURO: No focal neurological deficits or specific stroke symptoms are reported in the provided data. While altered mental status can occur in sepsis, the primary findings point away from a primary neurological event.
#      • TRAUMA_NEURO: There is no mention of trauma history, physical exam findings suggestive of injury, or relevant imaging results. The vital sign pattern is more consistent with a systemic process than isolated head trauma.
#
# ──────────────────────────────────────────────────────────────────────
# ✅ BOTH CORRECT

# %%
# ══════════════════════════════════════════════════════════════════════════════
# DISAGREEMENTS WHERE TRUE IS IN LSTM TOP-K
# ══════════════════════════════════════════════════════════════════════════════
print('\n' + '═' * 60)
print('DISAGREEMENTS WHERE TRUE IS IN LSTM TOP-K')
print('═' * 60)

true_in_topk_disagreements = [
    r for r in disagree_cases
    if r['true_label'] in r['lstm_output']['top_k_codes']
]

if true_in_topk_disagreements:
    for r in true_in_topk_disagreements:
        print(f'\n  Patient {r["patient_id"]}')
        print(f'    True: {r["true_label"]}')
        print(f'    LSTM Top-{TOP_K}: {r["lstm_output"]["top_k_codes"]}')
        print(f'    Agent: {r["agent_prediction"]}')
    for result_item in true_in_topk_disagreements:
        inspect_case(result_item)
else:
    print('  No cases where agent disagreed and true label was in LSTM top-K.')
# Out:
# ════════════════════════════════════════════════════════════
# DISAGREEMENTS WHERE TRUE IS IN LSTM TOP-K
# ════════════════════════════════════════════════════════════
#
#   Patient 11334897
#     True: SEPSIS
#     LSTM Top-3: ['TOXIC_METABOLIC', 'SEPSIS', 'ACUTE_KIDNEY_INJURY']
#     Agent: SEPSIS
#
#   Patient 18299579
#     True: SEPSIS
#     LSTM Top-3: ['TOXIC_METABOLIC', 'SEPSIS', 'TRAUMA_NEURO']
#     Agent: SEPSIS
#
#   Patient 16800280
#     True: SEPSIS
#     LSTM Top-3: ['LIVER_FAILURE', 'SEPSIS', 'GI_BLEED']
#     Agent: GI_BLEED
#
#   Patient 15724651
#     True: SEPSIS
#     LSTM Top-3: ['SEPSIS', 'GI_BLEED', 'SURGICAL_COMPLICATION']
#     Agent: GI_BLEED
#
#   Patient 14530906
#     True: SEPSIS
#     LSTM Top-3: ['SURGICAL_COMPLICATION', 'SEPSIS', 'STROKE_NEURO']
#     Agent: SEPSIS
#
#   Patient 12369624
#     True: SEPSIS
#     LSTM Top-3: ['LIVER_FAILURE', 'SEPSIS', 'GI_BLEED']
#     Agent: GI_BLEED
#
#   Patient 17978664
#     True: SEPSIS
#     LSTM Top-3: ['SEPSIS', 'SURGICAL_COMPLICATION', 'LIVER_FAILURE']
#     Agent: SURGICAL_COMPLICATION
#
#   Patient 15152799
#     True: STROKE_NEURO
#     LSTM Top-3: ['TOXIC_METABOLIC', 'STROKE_NEURO', 'AFIB_ARRHYTHMIA']
#     Agent: AFIB_ARRHYTHMIA
#
#   Patient 15781092
#     True: STROKE_NEURO
#     LSTM Top-3: ['STROKE_NEURO', 'TRAUMA_NEURO', 'SURGICAL_COMPLICATION']
#     Agent: SURGICAL_COMPLICATION
#
#   Patient 14139649
#     True: STROKE_NEURO
#     LSTM Top-3: ['TRAUMA_NEURO', 'STROKE_NEURO', 'SEPSIS']
#     Agent: SEPSIS
#
#   Patient 16388960
#     True: STROKE_NEURO
#     LSTM Top-3: ['STROKE_NEURO', 'TRAUMA_NEURO', 'SURGICAL_COMPLICATION']
#     Agent: SURGICAL_COMPLICATION
#
#   Patient 15642021
#     True: STROKE_NEURO
#     LSTM Top-3: ['STROKE_NEURO', 'TRAUMA_NEURO', 'SEPSIS']
#     Agent: SEPSIS
#
#   Patient 10655850
#     True: STROKE_NEURO
#     LSTM Top-3: ['STROKE_NEURO', 'TRAUMA_NEURO', 'SURGICAL_COMPLICATION']
#     Agent: SURGICAL_COMPLICATION
#
#   Patient 15511885
#     True: ACUTE_MI
#     LSTM Top-3: ['ACUTE_MI', 'HEART_FAILURE', 'SURGICAL_COMPLICATION']
#     Agent: HEART_FAILURE
#
#   Patient 15831913
#     True: ACUTE_MI
#     LSTM Top-3: ['VALVE_DISEASE', 'CORONARY_ARTERY_DZ', 'ACUTE_MI']
#     Agent: CORONARY_ARTERY_DZ
#
#   Patient 18570090
#     True: ACUTE_MI
#     LSTM Top-3: ['ACUTE_MI', 'SURGICAL_COMPLICATION', 'CORONARY_ARTERY_DZ']
#     Agent: SURGICAL_COMPLICATION
#
#   Patient 12388358
#     True: ACUTE_MI
#     LSTM Top-3: ['HEART_FAILURE', 'AFIB_ARRHYTHMIA', 'ACUTE_MI']
#     Agent: AFIB_ARRHYTHMIA
#
#   Patient 19347575
#     True: CORONARY_ARTERY_DZ
#     LSTM Top-3: ['VALVE_DISEASE', 'CORONARY_ARTERY_DZ', 'ACUTE_MI']
#     Agent: CORONARY_ARTERY_DZ
#
#   Patient 10896397
#     True: CORONARY_ARTERY_DZ
#     LSTM Top-3: ['VALVE_DISEASE', 'CORONARY_ARTERY_DZ', 'ACUTE_MI']
#     Agent: CORONARY_ARTERY_DZ
#
#   Patient 17815215
#     True: CORONARY_ARTERY_DZ
#     LSTM Top-3: ['VALVE_DISEASE', 'CORONARY_ARTERY_DZ', 'ACUTE_MI']
#     Agent: CORONARY_ARTERY_DZ
#
#   Patient 15746911
#     True: HEART_FAILURE
#     LSTM Top-3: ['COPD_ASTHMA', 'HEART_FAILURE', 'PNEUMONIA']
#     Agent: HEART_FAILURE
#
#   Patient 17043686
#     True: HEART_FAILURE
#     LSTM Top-3: ['ACUTE_MI', 'AFIB_ARRHYTHMIA', 'HEART_FAILURE']
#     Agent: AFIB_ARRHYTHMIA
#
#   Patient 13971180
#     True: TOXIC_METABOLIC
#     LSTM Top-3: ['TOXIC_METABOLIC', 'SEPSIS', 'ACUTE_KIDNEY_INJURY']
#     Agent: ACUTE_KIDNEY_INJURY
#
#   Patient 16946732
#     True: TRAUMA_NEURO
#     LSTM Top-3: ['STROKE_NEURO', 'SEPSIS', 'TRAUMA_NEURO']
#     Agent: SEPSIS
#
#   Patient 17907863
#     True: TRAUMA_NEURO
#     LSTM Top-3: ['TRAUMA_NEURO', 'STROKE_NEURO', 'SURGICAL_COMPLICATION']
#     Agent: STROKE_NEURO
#
#   Patient 10563695
#     True: TRAUMA_NEURO
#     LSTM Top-3: ['SEPSIS', 'TRAUMA_NEURO', 'TOXIC_METABOLIC']
#     Agent: TOXIC_METABOLIC
#
#   Patient 19687015
#     True: SURGICAL_COMPLICATION
#     LSTM Top-3: ['SEPSIS', 'SURGICAL_COMPLICATION', 'GI_BLEED']
#     Agent: GI_BLEED
#
#   Patient 18075452
#     True: SURGICAL_COMPLICATION
#     LSTM Top-3: ['SEPSIS', 'SURGICAL_COMPLICATION', 'TOXIC_METABOLIC']
#     Agent: TOXIC_METABOLIC
#
#   Patient 13770725
#     True: VALVE_DISEASE
#     LSTM Top-3: ['VALVE_DISEASE', 'CORONARY_ARTERY_DZ', 'ACUTE_MI']
#     Agent: CORONARY_ARTERY_DZ
#
#   Patient 10117812
#     True: LIVER_FAILURE
#     LSTM Top-3: ['LIVER_FAILURE', 'SEPSIS', 'TOXIC_METABOLIC']
#     Agent: TOXIC_METABOLIC
#
#   Patient 14478167
#     True: LIVER_FAILURE
#     LSTM Top-3: ['LIVER_FAILURE', 'SEPSIS', 'GI_BLEED']
#     Agent: SEPSIS
#
#   Patient 17325614
#     True: AFIB_ARRHYTHMIA
#     LSTM Top-3: ['SEPSIS', 'HEART_FAILURE', 'AFIB_ARRHYTHMIA']
#     Agent: AFIB_ARRHYTHMIA
#
#   Patient 12375699
#     True: AFIB_ARRHYTHMIA
#     LSTM Top-3: ['AFIB_ARRHYTHMIA', 'ACUTE_MI', 'HEART_FAILURE']
#     Agent: HEART_FAILURE
#
#   Patient 15101852
#     True: GI_BLEED
#     LSTM Top-3: ['SEPSIS', 'SURGICAL_COMPLICATION', 'GI_BLEED']
#     Agent: GI_BLEED
#
#   Patient 10904094
#     True: SEPSIS
#     LSTM Top-3: ['SURGICAL_COMPLICATION', 'SEPSIS', 'ACUTE_MI']
#     Agent: SEPSIS
# ══════════════════════════════════════════════════════════════════════
# PATIENT: 11334897
# ══════════════════════════════════════════════════════════════════════
#
# 🎯 TRUE: SEPSIS
#
# 📊 LSTM TOP-3 (probs not shown to agent):
#    1. TOXIC_METABOLIC            64.3%    ← LSTM top pick
#    2. SEPSIS                     21.8% ✓
#    3. ACUTE_KIDNEY_INJURY         8.0%
#
#    What the agent saw (no probs):
#      LSTM top pick   : TOXIC_METABOLIC
#
# 🤖 AGENT DECISION:
#    Decision: OVERRIDE
#    Chose   : SEPSIS
#
#    Reasoning: The patient presents with worsening tachycardia (HR mean 108.8), worsening hypotension (MAP mean 73.7), and worsening hyperglycemia (Glucose last 132.0), alongside leukocytosis (WBC 13.2) and metabolic acidosis (pH 7.26, Bicarbonate 17.0). These findings strongly suggest a systemic inflammatory response consistent with sepsis, even without a definitive source identified yet.
#
#    Supporting evidence:
#      • Worsening tachycardia (HR mean 108.8)
#      • Worsening hypotension (MAP mean 73.7)
#      • Leukocytosis (WBC 13.2)
#
#    Ruled out:
#      • TOXIC_METABOLIC: While hyperglycemia is present, there is no specific toxic ingestion history or characteristic toxidrome described. The overall picture with hypotension, tachycardia, and acidosis is more suggestive of sepsis.
#      • ACUTE_KIDNEY_INJURY: Creatinine is 0.90, which is not significantly elevated, and BUN is 41.0, which could be pre-renal due to dehydration or sepsis rather than intrinsic AKI. While AKI could be developing, the primary driver appears to be systemic inflammation.
#
# ──────────────────────────────────────────────────────────────────────
# 🎉 AGENT IMPROVED (override was right)
# ══════════════════════════════════════════════════════════════════════
# PATIENT: 18299579
# ══════════════════════════════════════════════════════════════════════
#
# 🎯 TRUE: SEPSIS
#
# 📊 LSTM TOP-3 (probs not shown to agent):
#    1. TOXIC_METABOLIC            36.7%    ← LSTM top pick
#    2. SEPSIS                     16.4% ✓
#    3. TRAUMA_NEURO               12.5%
#
#    What the agent saw (no probs):
#      LSTM top pick   : TOXIC_METABOLIC
#
# 🤖 AGENT DECISION:
#    Decision: OVERRIDE
#    Chose   : SEPSIS
#
#    Reasoning: The patient exhibits tachycardia (mean HR 103.2) and a worsening respiratory rate (mean 19.1, last 25.0), which are common signs of systemic inflammation. While specific infection markers are missing, the overall clinical picture is most suggestive of sepsis, especially given the potential for hemodynamic instability indicated by the wide range of blood pressures.
#
#    Supporting evidence:
#      • Tachycardia (mean HR 103.2)
#      • Worsening respiratory rate (last 25.0)
#      • Wide range of blood pressure readings (systolic 95.0-134.0)
#
#    Ruled out:
#      • TRAUMA_NEURO: No specific neurological findings or history of trauma are provided in the data.
#      • TOXIC_METABOLIC: While labs are limited, there are no overt signs of specific toxic ingestions or severe metabolic derangements like significant electrolyte abnormalities or acidosis.
#
# ──────────────────────────────────────────────────────────────────────
# 🎉 AGENT IMPROVED (override was right)
# ══════════════════════════════════════════════════════════════════════
# PATIENT: 16800280
# ══════════════════════════════════════════════════════════════════════
#
# 🎯 TRUE: SEPSIS
#
# 📊 LSTM TOP-3 (probs not shown to agent):
#    1. LIVER_FAILURE              32.5%    ← LSTM top pick
#    2. SEPSIS                     32.4% ✓
#    3. GI_BLEED                    9.4%
#
#    What the agent saw (no probs):
#      LSTM top pick   : LIVER_FAILURE
#
# 🤖 AGENT DECISION:
#    Decision: OVERRIDE
#    Chose   : GI_BLEED
#
#    Reasoning: The patient presents with significant anemia (Hgb 8.2, Hct 24.9) and thrombocytopenia (Platelets 88k), which are highly suggestive of acute blood loss, likely from a gastrointestinal source given the ICU setting. While sepsis can cause anemia and thrombocytopenia, the lack of fever, stable hemodynamics (despite borderline low Hgb), and absence of typical sepsis markers make GI bleed more likely.
#
#    Supporting evidence:
#      • Hemoglobin 8.2
#      • Hematocrit 24.9
#      • Platelet Count 88.0
#
#    Ruled out:
#      • SEPSIS: No fever, stable hemodynamics, and lack of other typical sepsis indicators (e.g., elevated WBC, lactate, inflammatory markers - though WBC is low, which could be sepsis, it's less specific than the anemia/thrombocytopenia for GI bleed).
#      • LIVER_FAILURE: No data provided on liver function tests (e.g., bilirubin, ALT, AST, INR, albumin) which are essential for diagnosing liver failure. While thrombocytopenia can occur, the profound anemia is less typical.
#
# ──────────────────────────────────────────────────────────────────────
# ❌ BOTH WRONG
# ══════════════════════════════════════════════════════════════════════
# PATIENT: 15724651
# ══════════════════════════════════════════════════════════════════════
#
# 🎯 TRUE: SEPSIS
#
# 📊 LSTM TOP-3 (probs not shown to agent):
#    1. SEPSIS                     41.8% ✓  ← LSTM top pick
#    2. GI_BLEED                   20.0%
#    3. SURGICAL_COMPLICATION      14.2%
#
#    What the agent saw (no probs):
#      LSTM top pick   : SEPSIS
#
# 🤖 AGENT DECISION:
#    Decision: OVERRIDE
#    Chose   : GI_BLEED
#
#    Reasoning: The patient presents with significant anemia (Hgb 8.2) and a relatively normal white blood cell count, which is more suggestive of blood loss than infection or a typical surgical complication. While sepsis can cause anemia, the lack of fever or significant leukocytosis makes GI bleed a more likely primary cause for the low hemoglobin.
#
#    Supporting evidence:
#      • Hemoglobin: 8.2
#      • Hematocrit: 25.5
#      • White Blood Cells: 9.5
#
#    Ruled out:
#      • SEPSIS: No fever (Temperature stable at 98.6F) and normal white blood cell count (9.5) are not typical for sepsis, although sepsis cannot be entirely ruled out without more data.
#      • SURGICAL_COMPLICATION: No information about recent surgery is provided, and the clinical picture doesn't strongly suggest a specific post-operative issue like infection or anastomotic leak. The primary finding is anemia.
#
# ──────────────────────────────────────────────────────────────────────
# ⚠️ AGENT HURT (overrode a correct LSTM pick)
# ══════════════════════════════════════════════════════════════════════
# PATIENT: 14530906
# ══════════════════════════════════════════════════════════════════════
#
# 🎯 TRUE: SEPSIS
#
# 📊 LSTM TOP-3 (probs not shown to agent):
#    1. SURGICAL_COMPLICATION      34.6%    ← LSTM top pick
#    2. SEPSIS                     32.1% ✓
#    3. STROKE_NEURO               12.1%
#
#    What the agent saw (no probs):
#      LSTM top pick   : SURGICAL_COMPLICATION
#
# 🤖 AGENT DECISION:
#    Decision: OVERRIDE
#    Chose   : SEPSIS
#
#    Reasoning: The patient exhibits worsening hemodynamics, specifically a decreasing mean arterial pressure (MAP) and increasing systolic blood pressure (SBP), suggesting distributive shock. While the respiratory rate is relatively stable, the overall picture points towards a systemic inflammatory response. The lack of specific labs like lactate or white blood cell count doesn't rule out sepsis, as it can present with these hemodynamic changes.
#
#    Supporting evidence:
#      • Worsening Mean Arterial Pressure (MAP)
#      • Worsening Systolic Blood Pressure (SBP)
#      • Worsening Respiratory Rate
#
#    Ruled out:
#      • STROKE_NEURO: No focal neurological deficits or specific stroke-related vital sign changes are mentioned; the hemodynamic instability is more suggestive of a systemic process.
#      • SURGICAL_COMPLICATION: No information about recent surgery or specific surgical complications (e.g., bleeding, infection at site) is provided; the current data doesn't strongly point towards a post-operative issue.
#
# ──────────────────────────────────────────────────────────────────────
# 🎉 AGENT IMPROVED (override was right)
# ══════════════════════════════════════════════════════════════════════
# PATIENT: 12369624
# ══════════════════════════════════════════════════════════════════════
#
# 🎯 TRUE: SEPSIS
#
# 📊 LSTM TOP-3 (probs not shown to agent):
#    1. LIVER_FAILURE              35.1%    ← LSTM top pick
#    2. SEPSIS                     27.5% ✓
#    3. GI_BLEED                    8.7%
#
#    What the agent saw (no probs):
#      LSTM top pick   : LIVER_FAILURE
#
# 🤖 AGENT DECISION:
#    Decision: OVERRIDE
#    Chose   : GI_BLEED
#
#    Reasoning: The patient presents with significant anemia (Hct 31.6, Hgb 10.4) and thrombocytopenia (Platelets 107k), suggesting blood loss. While the specific source isn't identified, the low hemoglobin and hematocrit are highly concerning for a GI bleed, especially in an ICU setting where occult bleeding can occur.
#
#    Supporting evidence:
#      • Hemoglobin 10.4
#      • Hematocrit 31.6
#      • Platelet Count 107.0
#
#    Ruled out:
#      • LIVER_FAILURE: No specific labs like bilirubin, albumin, or INR are provided to assess liver function.
#      • SEPSIS: While WBC is mildly elevated (11.3), there are no clear signs of infection like fever (temp stable at 98.6), significant tachycardia (mean HR 60.2), or hypotension (mean BP 71.2). The provided data lacks key sepsis markers like lactate or procalcitonin.
#
# ──────────────────────────────────────────────────────────────────────
# ❌ BOTH WRONG
# ══════════════════════════════════════════════════════════════════════
# PATIENT: 17978664
# ══════════════════════════════════════════════════════════════════════
#
# 🎯 TRUE: SEPSIS
#
# 📊 LSTM TOP-3 (probs not shown to agent):
#    1. SEPSIS                     62.5% ✓  ← LSTM top pick
#    2. SURGICAL_COMPLICATION      14.7%
#    3. LIVER_FAILURE               5.3%
#
#    What the agent saw (no probs):
#      LSTM top pick   : SEPSIS
#
# 🤖 AGENT DECISION:
#    Decision: OVERRIDE
#    Chose   : SURGICAL_COMPLICATION
#
#    Reasoning: The patient's vital signs show relative stability with improving heart rate and respiratory rate, which is less typical for active sepsis. The presence of a Foley catheter and multi-lumen line suggests a recent surgical procedure, and the low hemoglobin (7.6) could indicate post-operative bleeding, a common surgical complication. While sepsis cannot be entirely ruled out without more data, the current picture leans towards a complication related to a recent surgery.
#
#    Supporting evidence:
#      • Low Hemoglobin (7.6)
#      • Presence of Foley catheter and multi-lumen line (suggesting recent surgery)
#      • Relatively stable vital signs with improvement
#
#    Ruled out:
#      • SEPSIS: Vital signs are improving and relatively stable, lacking the typical sustained tachycardia, tachypnea, or hypotension often seen in sepsis. No fever is documented, although absence doesn't rule it out.
#      • LIVER_FAILURE: No specific labs are provided to assess liver function (e.g., bilirubin, albumin, INR, ammonia). While the INR is elevated (3.6), this could be due to anticoagulation or other causes, and is not specific to liver failure without other supporting data.
#
# ──────────────────────────────────────────────────────────────────────
# ⚠️ AGENT HURT (overrode a correct LSTM pick)
# ══════════════════════════════════════════════════════════════════════
# PATIENT: 15152799
# ══════════════════════════════════════════════════════════════════════
#
# 🎯 TRUE: STROKE_NEURO
#
# 📊 LSTM TOP-3 (probs not shown to agent):
#    1. TOXIC_METABOLIC            21.9%    ← LSTM top pick
#    2. STROKE_NEURO               18.8% ✓
#    3. AFIB_ARRHYTHMIA            17.5%
#
#    What the agent saw (no probs):
#      LSTM top pick   : TOXIC_METABOLIC
#
# 🤖 AGENT DECISION:
#    Decision: OVERRIDE
#    Chose   : AFIB_ARRHYTHMIA
#
#    Reasoning: The patient exhibits a significant heart rate variability, including bradycardia (HR 50) and tachycardia (HR 130) alarms, suggesting an underlying arrhythmia. While the mean heart rate is stable, these extreme values point towards an irregular rhythm like atrial fibrillation. The other diagnoses lack specific supporting evidence in the provided data.
#
#    Supporting evidence:
#      • Heart Rate Alarm Low: mean=50.0
#      • Heart Rate Alarm High: mean=130.0
#      • Mean heart rate is relatively stable (82.9) despite alarms, suggesting intermittent episodes
#
#    Ruled out:
#      • STROKE_NEURO: No neurological assessment or specific stroke indicators (e.g., focal deficits, altered mental status beyond potential arrhythmia effects) are provided.
#      • TOXIC_METABOLIC: No relevant laboratory values (e.g., electrolytes, glucose, lactate, toxicology screen) are available to support a toxic or metabolic encephalopathy.
#
# ──────────────────────────────────────────────────────────────────────
# ❌ BOTH WRONG
# ══════════════════════════════════════════════════════════════════════
# PATIENT: 15781092
# ══════════════════════════════════════════════════════════════════════
#
# 🎯 TRUE: STROKE_NEURO
#
# 📊 LSTM TOP-3 (probs not shown to agent):
#    1. STROKE_NEURO               62.7% ✓  ← LSTM top pick
#    2. TRAUMA_NEURO               29.9%
#    3. SURGICAL_COMPLICATION       3.3%
#
#    What the agent saw (no probs):
#      LSTM top pick   : STROKE_NEURO
#
# 🤖 AGENT DECISION:
#    Decision: OVERRIDE
#    Chose   : SURGICAL_COMPLICATION
#
#    Reasoning: The patient's vital signs show a significant drop in diastolic blood pressure and a worsening trend in heart rate, suggesting potential hypovolemia or hemodynamic instability, common after surgery. The elevated glucose, while potentially related to stress response, could also indicate a complication like infection or impaired glucose metabolism post-operatively. The lack of specific neurological findings makes stroke or trauma less likely.
#
#    Supporting evidence:
#      • Worsening heart rate trend (mean 88.4, last 82.0)
#      • Low diastolic blood pressure (mean 60.4, range [36.0-80.0])
#      • Elevated glucose (last 141.0)
#
#    Ruled out:
#      • STROKE_NEURO: No focal neurological deficits or specific signs of stroke (e.g., altered mental status, cranial nerve palsies) are documented in the provided data.
#      • TRAUMA_NEURO: There is no mention of trauma history or specific signs of head injury (e.g., GCS score, pupillary changes, scalp lacerations) in the data.
#
# ──────────────────────────────────────────────────────────────────────
# ⚠️ AGENT HURT (overrode a correct LSTM pick)
# ══════════════════════════════════════════════════════════════════════
# PATIENT: 14139649
# ══════════════════════════════════════════════════════════════════════
#
# 🎯 TRUE: STROKE_NEURO
#
# 📊 LSTM TOP-3 (probs not shown to agent):
#    1. TRAUMA_NEURO               26.4%    ← LSTM top pick
#    2. STROKE_NEURO               21.0% ✓
#    3. SEPSIS                     19.4%
#
#    What the agent saw (no probs):
#      LSTM top pick   : TRAUMA_NEURO
#
# 🤖 AGENT DECISION:
#    Decision: OVERRIDE
#    Chose   : SEPSIS
#
#    Reasoning: The patient presents with stable but slightly elevated vital signs (HR 78.7, RR 15.2, BP 124.1/66.8, Temp 99.0) and a slightly elevated glucose (129.5), which are non-specific but can be seen in early sepsis. The lack of significant hemodynamic instability or specific neurological findings makes trauma or stroke less likely, while sepsis remains a plausible explanation for the overall clinical picture, especially given the commonality of sepsis in ICU settings.
#
#    Supporting evidence:
#      • Slightly elevated temperature (99.0 F)
#      • Slightly elevated glucose (129.5)
#      • Stable but potentially concerning vital signs in an ICU setting
#
#    Ruled out:
#      • TRAUMA_NEURO: No specific evidence of trauma or acute neurological injury is presented; vital signs are relatively stable.
#      • STROKE_NEURO: No focal neurological deficits or significant changes in vital signs suggestive of an acute stroke are documented.
#
# ──────────────────────────────────────────────────────────────────────
# ❌ BOTH WRONG
# ══════════════════════════════════════════════════════════════════════
# PATIENT: 16388960
# ══════════════════════════════════════════════════════════════════════
#
# 🎯 TRUE: STROKE_NEURO
#
# 📊 LSTM TOP-3 (probs not shown to agent):
#    1. STROKE_NEURO               64.1% ✓  ← LSTM top pick
#    2. TRAUMA_NEURO               31.0%
#    3. SURGICAL_COMPLICATION       2.5%
#
#    What the agent saw (no probs):
#      LSTM top pick   : STROKE_NEURO
#
# 🤖 AGENT DECISION:
#    Decision: OVERRIDE
#    Chose   : SURGICAL_COMPLICATION
#
#    Reasoning: The patient's vital signs are relatively stable, with only mild tachycardia, but the presence of an 18-gauge procedure suggests a recent intervention. While neurological events are possible, the lack of specific neurological findings or significant vital sign instability makes a primary neurological event less likely than a complication related to a procedure.
#
#    Supporting evidence:
#      • 18_gauge procedure
#      • Stable vital signs
#      • Mild tachycardia (HR mean 101.3)
#
#    Ruled out:
#      • TRAUMA_NEURO: No specific trauma history or signs of significant head injury are mentioned.
#      • STROKE_NEURO: No focal neurological deficits or significant hemodynamic instability typically associated with acute stroke are documented.
#
# ──────────────────────────────────────────────────────────────────────
# ⚠️ AGENT HURT (overrode a correct LSTM pick)
# ══════════════════════════════════════════════════════════════════════
# PATIENT: 15642021
# ══════════════════════════════════════════════════════════════════════
#
# 🎯 TRUE: STROKE_NEURO
#
# 📊 LSTM TOP-3 (probs not shown to agent):
#    1. STROKE_NEURO               49.6% ✓  ← LSTM top pick
#    2. TRAUMA_NEURO               22.6%
#    3. SEPSIS                     17.2%
#
#    What the agent saw (no probs):
#      LSTM top pick   : STROKE_NEURO
#
# 🤖 AGENT DECISION:
#    Decision: OVERRIDE
#    Chose   : SEPSIS
#
#    Reasoning: The patient presents with tachycardia (mean HR 123.4), tachypnea (mean RR 28.5), and hypoxemia (mean O2 Sat 85.0), which are common signs of systemic inflammation. Although specific infection markers are missing, the overall clinical picture strongly suggests sepsis, especially given the worsening trend in heart rate and mean arterial pressure despite some improvement in respiratory rate and oxygen saturation.
#
#    Supporting evidence:
#      • Tachycardia (mean HR 123.4)
#      • Tachypnea (mean RR 28.5)
#      • Hypoxemia (mean O2 Sat 85.0)
#
#    Ruled out:
#      • TRAUMA_NEURO: No specific trauma history or neurological findings are mentioned in the provided data. While tachycardia and hypertension can occur with trauma, the lack of other supporting evidence makes this less likely.
#      • STROKE_NEURO: There are no focal neurological deficits or specific stroke risk factors mentioned. The vital sign abnormalities are more consistent with a systemic process like sepsis than a primary neurological event.
#
# ──────────────────────────────────────────────────────────────────────
# ⚠️ AGENT HURT (overrode a correct LSTM pick)
# ══════════════════════════════════════════════════════════════════════
# PATIENT: 10655850
# ══════════════════════════════════════════════════════════════════════
#
# 🎯 TRUE: STROKE_NEURO
#
# 📊 LSTM TOP-3 (probs not shown to agent):
#    1. STROKE_NEURO               60.5% ✓  ← LSTM top pick
#    2. TRAUMA_NEURO               21.5%
#    3. SURGICAL_COMPLICATION      12.5%
#
#    What the agent saw (no probs):
#      LSTM top pick   : STROKE_NEURO
#
# 🤖 AGENT DECISION:
#    Decision: OVERRIDE
#    Chose   : SURGICAL_COMPLICATION
#
#    Reasoning: The patient has received intravenous access via 18 and 20 gauge catheters, suggesting a recent or ongoing procedure. While vital signs are currently stable, the lack of specific neurological findings or trauma indicators makes a surgical complication the most plausible explanation for ICU admission given the interventions.
#
#    Supporting evidence:
#      • 18_gauge
#      • 20_gauge
#
#    Ruled out:
#      • TRAUMA_NEURO: No specific neurological deficits or signs of trauma are documented in the provided data.
#      • STROKE_NEURO: No specific neurological deficits or signs of stroke are documented in the provided data.
#
# ──────────────────────────────────────────────────────────────────────
# ⚠️ AGENT HURT (overrode a correct LSTM pick)
# ══════════════════════════════════════════════════════════════════════
# PATIENT: 15511885
# ══════════════════════════════════════════════════════════════════════
#
# 🎯 TRUE: ACUTE_MI
#
# 📊 LSTM TOP-3 (probs not shown to agent):
#    1. ACUTE_MI                   31.5% ✓  ← LSTM top pick
#    2. HEART_FAILURE              17.3%
#    3. SURGICAL_COMPLICATION      16.8%
#
#    What the agent saw (no probs):
#      LSTM top pick   : ACUTE_MI
#
# 🤖 AGENT DECISION:
#    Decision: OVERRIDE
#    Chose   : HEART_FAILURE
#
#    Reasoning: The patient presents with tachycardia, worsening respiratory rate, and stable but low-normal oxygen saturation, suggesting respiratory distress potentially secondary to fluid overload or cardiac dysfunction. While specific cardiac biomarkers or imaging are missing, the overall clinical picture is most consistent with decompensated heart failure, especially given the lack of clear evidence for acute MI or a recent surgical event.
#
#    Supporting evidence:
#      • Tachycardia (mean HR 123.7)
#      • Worsening respiratory rate (mean 19.7, last 22.0)
#      • Stable but low-normal O2 saturation (mean 95.7, last 95.0)
#
#    Ruled out:
#      • ACUTE_MI: No troponin or EKG data is provided to support acute myocardial infarction, although tachycardia could be present.
#      • SURGICAL_COMPLICATION: There is no mention of recent surgery or specific complications like bleeding (stable hemoglobin) or infection (stable temperature, WBC).
#
# ──────────────────────────────────────────────────────────────────────
# ⚠️ AGENT HURT (overrode a correct LSTM pick)
# ══════════════════════════════════════════════════════════════════════
# PATIENT: 15831913
# ══════════════════════════════════════════════════════════════════════
#
# 🎯 TRUE: ACUTE_MI
#
# 📊 LSTM TOP-3 (probs not shown to agent):
#    1. VALVE_DISEASE              36.0%    ← LSTM top pick
#    2. CORONARY_ARTERY_DZ         31.0%
#    3. ACUTE_MI                   24.3% ✓
#
#    What the agent saw (no probs):
#      LSTM top pick   : VALVE_DISEASE
#
# 🤖 AGENT DECISION:
#    Decision: OVERRIDE
#    Chose   : CORONARY_ARTERY_DZ
#
#    Reasoning: The patient presents with worsening respiratory rate and hyperglycemia, which can be associated with cardiac ischemia or stress response. While vital signs are relatively stable overall, the single high heart rate alarm suggests potential intermittent cardiac events. Without specific cardiac markers or EKG data, coronary artery disease remains a strong possibility given the potential for ischemia.
#
#    Supporting evidence:
#      • Worsening respiratory rate (mean=22.5, last=28.0)
#      • Worsening glucose (mean=126.5, last=151.0)
#      • Single high heart rate alarm (120.0)
#
#    Ruled out:
#      • VALVE_DISEASE: No specific signs of acute valvular dysfunction (e.g., new murmur, significant hemodynamic instability beyond the initial low BP which is improving) are present in the provided data.
#      • ACUTE_MI: While possible, the data lacks definitive evidence like EKG changes or elevated cardiac enzymes (troponin) which are crucial for diagnosing an acute myocardial infarction. The current data is more suggestive of underlying coronary artery disease rather than an acute event.
#
# ──────────────────────────────────────────────────────────────────────
# ❌ BOTH WRONG
# ══════════════════════════════════════════════════════════════════════
# PATIENT: 18570090
# ══════════════════════════════════════════════════════════════════════
#
# 🎯 TRUE: ACUTE_MI
#
# 📊 LSTM TOP-3 (probs not shown to agent):
#    1. ACUTE_MI                   73.7% ✓  ← LSTM top pick
#    2. SURGICAL_COMPLICATION       9.3%
#    3. CORONARY_ARTERY_DZ          8.9%
#
#    What the agent saw (no probs):
#      LSTM top pick   : ACUTE_MI
#
# 🤖 AGENT DECISION:
#    Decision: OVERRIDE
#    Chose   : SURGICAL_COMPLICATION
#
#    Reasoning: The patient presents with worsening vital signs including tachycardia, tachypnea, and hypotension, suggestive of systemic instability. The presence of a Foley catheter and IV lines (18 and 20 gauge) indicates a recent or ongoing surgical procedure, making a complication the most likely explanation for the acute deterioration. While cardiac causes are possible, the lack of specific cardiac markers or EKG data makes a surgical complication more probable given the context.
#
#    Supporting evidence:
#      • Worsening respiratory rate (tachypnea)
#      • Worsening systolic and diastolic blood pressure (hypotension)
#      • Presence of Foley catheter and IV lines (suggestive of recent surgery)
#
#    Ruled out:
#      • ACUTE_MI: No troponin or EKG data is available to support or refute an acute myocardial infarction. While tachycardia is present, it is non-specific.
#      • CORONARY_ARTERY_DZ: Similar to ACUTE_MI, there is no specific evidence like EKG changes or cardiac enzyme elevation to confirm underlying coronary artery disease as the primary acute issue. The current presentation is more suggestive of an acute systemic process.
#
# ──────────────────────────────────────────────────────────────────────
# ⚠️ AGENT HURT (overrode a correct LSTM pick)
# ══════════════════════════════════════════════════════════════════════
# PATIENT: 12388358
# ══════════════════════════════════════════════════════════════════════
#
# 🎯 TRUE: ACUTE_MI
#
# 📊 LSTM TOP-3 (probs not shown to agent):
#    1. HEART_FAILURE              33.2%    ← LSTM top pick
#    2. AFIB_ARRHYTHMIA            22.9%
#    3. ACUTE_MI                   21.8% ✓
#
#    What the agent saw (no probs):
#      LSTM top pick   : HEART_FAILURE
#
# 🤖 AGENT DECISION:
#    Decision: OVERRIDE
#    Chose   : AFIB_ARRHYTHMIA
#
#    Reasoning: The patient exhibits significant heart rate variability, including bradycardia (HR 50) and tachycardia (HR 130) alarms, which are highly suggestive of an arrhythmia like Atrial Fibrillation. While other vital signs are relatively stable, the fluctuating heart rate is the most striking abnormality pointing towards an arrhythmic process.
#
#    Supporting evidence:
#      • Heart Rate Alarm Low: mean=50.0
#      • Heart Rate Alarm High: mean=130.0
#      • Mean Heart Rate: 82.1 (with a range of 81.0–84.0, suggesting some variability)
#
#    Ruled out:
#      • HEART_FAILURE: No clear signs of volume overload (e.g., respiratory distress, significant edema, specific lab markers like BNP) are present in the provided data. Vital signs are relatively stable, which is less typical for acute decompensated heart failure.
#      • ACUTE_MI: While tachycardia can occur in MI, the data lacks specific markers like troponin or ECG findings. The primary abnormality is the heart rate fluctuation, not ischemic indicators.
#
# ──────────────────────────────────────────────────────────────────────
# ❌ BOTH WRONG
# ══════════════════════════════════════════════════════════════════════
# PATIENT: 19347575
# ══════════════════════════════════════════════════════════════════════
#
# 🎯 TRUE: CORONARY_ARTERY_DZ
#
# 📊 LSTM TOP-3 (probs not shown to agent):
#    1. VALVE_DISEASE              40.3%    ← LSTM top pick
#    2. CORONARY_ARTERY_DZ         32.6% ✓
#    3. ACUTE_MI                   22.2%
#
#    What the agent saw (no probs):
#      LSTM top pick   : VALVE_DISEASE
#
# 🤖 AGENT DECISION:
#    Decision: OVERRIDE
#    Chose   : CORONARY_ARTERY_DZ
#
#    Reasoning: The patient presents with stable hemodynamics but a worsening respiratory rate, which could indicate developing heart failure secondary to underlying coronary artery disease. While specific cardiac markers are missing, the overall picture is most suggestive of a cardiac etiology, potentially an acute coronary syndrome or exacerbation of chronic ischemic heart disease, rather than primary valve disease or a non-cardiac cause.
#
#    Supporting evidence:
#      • Worsening respiratory rate (20.0 mean -> 24.0 last)
#      • Stable hemodynamics (BP, HR) despite potential underlying pathology
#      • Absence of clear signs pointing towards primary valve disease or other specific diagnoses
#
#    Ruled out:
#      • VALVE_DISEASE: No specific findings like murmurs, echocardiogram data, or signs of endocarditis are present to strongly support primary valve disease.
#      • ACUTE_MI: While possible, the stable heart rate and lack of specific ECG or troponin data make it less definitive than the broader category of Coronary Artery Disease, which encompasses various presentations including unstable angina or non-ST elevation MI.
#
# ──────────────────────────────────────────────────────────────────────
# 🎉 AGENT IMPROVED (override was right)
# ══════════════════════════════════════════════════════════════════════
# PATIENT: 10896397
# ══════════════════════════════════════════════════════════════════════
#
# 🎯 TRUE: CORONARY_ARTERY_DZ
#
# 📊 LSTM TOP-3 (probs not shown to agent):
#    1. VALVE_DISEASE              44.1%    ← LSTM top pick
#    2. CORONARY_ARTERY_DZ         26.2% ✓
#    3. ACUTE_MI                   19.8%
#
#    What the agent saw (no probs):
#      LSTM top pick   : VALVE_DISEASE
#
# 🤖 AGENT DECISION:
#    Decision: OVERRIDE
#    Chose   : CORONARY_ARTERY_DZ
#
#    Reasoning: The patient exhibits worsening vital signs, particularly diastolic and mean blood pressure, along with a slightly increasing heart rate, suggesting potential hemodynamic instability. While specific cardiac markers are missing, these trends are concerning for an underlying cardiac issue like coronary artery disease, which can present with subtle changes before overt myocardial infarction. The stable oxygen saturation despite increased respiratory rate might indicate compensatory mechanisms or early cardiac dysfunction.
#
#    Supporting evidence:
#      • Worsening diastolic blood pressure
#      • Worsening mean arterial pressure
#      • Increasing heart rate
#
#    Ruled out:
#      • ACUTE_MI: Lack of specific ECG changes or elevated cardiac biomarkers (e.g., troponin) to confirm acute myocardial infarction.
#      • VALVE_DISEASE: No specific auscultatory findings (murmurs) or echocardiographic data are provided to support a primary valvular pathology.
#
# ──────────────────────────────────────────────────────────────────────
# 🎉 AGENT IMPROVED (override was right)
# ══════════════════════════════════════════════════════════════════════
# PATIENT: 17815215
# ══════════════════════════════════════════════════════════════════════
#
# 🎯 TRUE: CORONARY_ARTERY_DZ
#
# 📊 LSTM TOP-3 (probs not shown to agent):
#    1. VALVE_DISEASE              53.4%    ← LSTM top pick
#    2. CORONARY_ARTERY_DZ         24.0% ✓
#    3. ACUTE_MI                   16.9%
#
#    What the agent saw (no probs):
#      LSTM top pick   : VALVE_DISEASE
#
# 🤖 AGENT DECISION:
#    Decision: OVERRIDE
#    Chose   : CORONARY_ARTERY_DZ
#
#    Reasoning: The patient presents with worsening tachycardia and tachypnea, suggestive of cardiac stress or ischemia. While specific cardiac biomarkers (like troponin) are missing, the overall clinical picture points towards a cardiac etiology, potentially related to coronary artery disease, which can manifest as acute coronary syndrome or worsening chronic ischemia.
#
#    Supporting evidence:
#      • Worsening heart rate (mean 100.5, last 108.0)
#      • Worsening respiratory rate (mean 16.7, last 26.0)
#      • Worsening systolic blood pressure (mean 101.8, last 99.0)
#
#    Ruled out:
#      • VALVE_DISEASE: No specific signs or symptoms suggestive of acute valvular dysfunction (e.g., new murmur, signs of acute heart failure) are present in the provided data.
#      • ACUTE_MI: While possible, the data lacks definitive evidence like ECG changes or elevated cardiac biomarkers (e.g., troponin), making it less certain than the broader category of Coronary Artery Disease which encompasses various ischemic presentations.
#
# ──────────────────────────────────────────────────────────────────────
# 🎉 AGENT IMPROVED (override was right)
# ══════════════════════════════════════════════════════════════════════
# PATIENT: 15746911
# ══════════════════════════════════════════════════════════════════════
#
# 🎯 TRUE: HEART_FAILURE
#
# 📊 LSTM TOP-3 (probs not shown to agent):
#    1. COPD_ASTHMA                22.0%    ← LSTM top pick
#    2. HEART_FAILURE              15.1% ✓
#    3. PNEUMONIA                  14.8%
#
#    What the agent saw (no probs):
#      LSTM top pick   : COPD_ASTHMA
#
# 🤖 AGENT DECISION:
#    Decision: OVERRIDE
#    Chose   : HEART_FAILURE
#
#    Reasoning: The patient presents with tachycardia (mean HR 101.8), a widening pulse pressure (Systolic mean 139.3, Diastolic mean 64.2), and a relatively stable respiratory rate and oxygen saturation despite the tachycardia. These findings, particularly the pulse pressure widening and tachycardia without significant hypoxia, are suggestive of cardiac dysfunction, potentially decompensated heart failure. The lack of fever or significant respiratory distress makes pneumonia or COPD/Asthma less likely.
#
#    Supporting evidence:
#      • Tachycardia (mean HR 101.8)
#      • Widening pulse pressure (Systolic mean 139.3, Diastolic mean 64.2)
#      • Stable O2 saturation (mean 98.2) despite tachycardia
#
#    Ruled out:
#      • PNEUMONIA: No fever is documented, and oxygen saturation is relatively stable, making acute pneumonia less likely as the primary driver.
#      • COPD_ASTHMA: Respiratory rate is only mildly elevated (mean 20.4) and oxygen saturation is stable, without clear signs of significant bronchospasm or respiratory distress typical of an acute exacerbation.
#
# ──────────────────────────────────────────────────────────────────────
# 🎉 AGENT IMPROVED (override was right)
# ══════════════════════════════════════════════════════════════════════
# PATIENT: 17043686
# ══════════════════════════════════════════════════════════════════════
#
# 🎯 TRUE: HEART_FAILURE
#
# 📊 LSTM TOP-3 (probs not shown to agent):
#    1. ACUTE_MI                   46.8%    ← LSTM top pick
#    2. AFIB_ARRHYTHMIA            19.3%
#    3. HEART_FAILURE              13.0% ✓
#
#    What the agent saw (no probs):
#      LSTM top pick   : ACUTE_MI
#
# 🤖 AGENT DECISION:
#    Decision: OVERRIDE
#    Chose   : AFIB_ARRHYTHMIA
#
#    Reasoning: The patient's heart rate shows significant variability (range 73-97 bpm) and includes single observations of both bradycardia (50 bpm) and tachycardia (130 bpm), which is highly suggestive of atrial fibrillation. While other diagnoses are possible, the lack of specific markers for MI (like troponin) or heart failure (like BNP or chest x-ray) makes AFIB the most likely diagnosis given the available data.
#
#    Supporting evidence:
#      • Heart Rate range of 73-97 bpm
#      • Single observation of Heart Rate 50 bpm
#      • Single observation of Heart Rate 130 bpm
#
#    Ruled out:
#      • ACUTE_MI: No specific cardiac enzymes (e.g., Troponin) or EKG data are provided to confirm myocardial infarction.
#      • HEART_FAILURE: No specific markers for heart failure (e.g., BNP, chest x-ray, echocardiogram) are available, and vital signs are relatively stable apart from the heart rate variability.
#
# ──────────────────────────────────────────────────────────────────────
# ❌ BOTH WRONG
# ══════════════════════════════════════════════════════════════════════
# PATIENT: 13971180
# ══════════════════════════════════════════════════════════════════════
#
# 🎯 TRUE: TOXIC_METABOLIC
#
# 📊 LSTM TOP-3 (probs not shown to agent):
#    1. TOXIC_METABOLIC            63.4% ✓  ← LSTM top pick
#    2. SEPSIS                     23.0%
#    3. ACUTE_KIDNEY_INJURY         8.4%
#
#    What the agent saw (no probs):
#      LSTM top pick   : TOXIC_METABOLIC
#
# 🤖 AGENT DECISION:
#    Decision: OVERRIDE
#    Chose   : ACUTE_KIDNEY_INJURY
#
#    Reasoning: The patient presents with significant laboratory abnormalities indicative of acute kidney injury, including a markedly elevated creatinine (5.10) and BUN (75.00), along with metabolic acidosis (pH 7.26, Bicarbonate 13.00). While sepsis and toxic metabolic causes are possible, the profound renal dysfunction is the most striking feature currently documented.
#
#    Supporting evidence:
#      • Creatinine: 5.10
#      • Urea Nitrogen: 75.00
#      • pH: 7.26
#
#    Ruled out:
#      • SEPSIS: While possible, there is no direct evidence of infection (e.g., WBC count is only mildly elevated at 9.70, no fever documented) or specific signs of systemic inflammatory response syndrome beyond the acidosis which could be attributed to AKI.
#      • TOXIC_METABOLIC: No specific toxic ingestion or metabolic derangement (like DKA) is clearly indicated by the available labs, although hyperglycemia is present. The primary driver appears to be renal failure.
#
# ──────────────────────────────────────────────────────────────────────
# ⚠️ AGENT HURT (overrode a correct LSTM pick)
# ══════════════════════════════════════════════════════════════════════
# PATIENT: 16946732
# ══════════════════════════════════════════════════════════════════════
#
# 🎯 TRUE: TRAUMA_NEURO
#
# 📊 LSTM TOP-3 (probs not shown to agent):
#    1. STROKE_NEURO               45.1%    ← LSTM top pick
#    2. SEPSIS                     20.4%
#    3. TRAUMA_NEURO               17.5% ✓
#
#    What the agent saw (no probs):
#      LSTM top pick   : STROKE_NEURO
#
# 🤖 AGENT DECISION:
#    Decision: OVERRIDE
#    Chose   : SEPSIS
#
#    Reasoning: The patient presents with a persistent fever (100.9°F) and tachycardia (mean HR 98.8), which are common signs of a systemic inflammatory response. While respiratory rate is improving and O2 saturation is stable, the lack of other data prevents ruling out sepsis, which often presents with subtle or evolving signs.
#
#    Supporting evidence:
#      • Temperature 100.9°F
#      • Heart Rate mean 98.8
#      • Stable but low-normal O2 Saturation (92.0%)
#
#    Ruled out:
#      • TRAUMA_NEURO: No mention of trauma history, neurological deficits, or relevant imaging/labs to suggest head injury.
#      • STROKE_NEURO: No mention of focal neurological deficits, sudden onset of symptoms, or relevant imaging/labs to suggest stroke.
#
# ──────────────────────────────────────────────────────────────────────
# ❌ BOTH WRONG
# ══════════════════════════════════════════════════════════════════════
# PATIENT: 17907863
# ══════════════════════════════════════════════════════════════════════
#
# 🎯 TRUE: TRAUMA_NEURO
#
# 📊 LSTM TOP-3 (probs not shown to agent):
#    1. TRAUMA_NEURO               42.5% ✓  ← LSTM top pick
#    2. STROKE_NEURO               21.9%
#    3. SURGICAL_COMPLICATION      11.9%
#
#    What the agent saw (no probs):
#      LSTM top pick   : TRAUMA_NEURO
#
# 🤖 AGENT DECISION:
#    Decision: OVERRIDE
#    Chose   : STROKE_NEURO
#
#    Reasoning: The patient presents with bradycardia (mean HR 48) and a worsening respiratory rate (mean 12.3, last 15.0), which can be associated with increased intracranial pressure or brainstem involvement from a stroke. While vital signs are somewhat stable, the combination of bradycardia and respiratory changes warrants consideration for a neurological event like stroke, especially given the lack of clear signs pointing towards trauma or recent surgery.
#
#    Supporting evidence:
#      • Bradycardia (mean HR 48)
#      • Worsening respiratory rate (mean 12.3, last 15.0)
#      • Lack of specific trauma or surgical indicators
#
#    Ruled out:
#      • TRAUMA_NEURO: No specific indicators of trauma (e.g., history, physical exam findings, specific labs like troponin or lactate suggestive of shock) are present in the provided data.
#      • SURGICAL_COMPLICATION: No information regarding recent surgery or typical post-operative complications (e.g., fever, specific electrolyte abnormalities, signs of infection) is available.
#
# ──────────────────────────────────────────────────────────────────────
# ⚠️ AGENT HURT (overrode a correct LSTM pick)
# ══════════════════════════════════════════════════════════════════════
# PATIENT: 10563695
# ══════════════════════════════════════════════════════════════════════
#
# 🎯 TRUE: TRAUMA_NEURO
#
# 📊 LSTM TOP-3 (probs not shown to agent):
#    1. SEPSIS                     27.5%    ← LSTM top pick
#    2. TRAUMA_NEURO               17.4% ✓
#    3. TOXIC_METABOLIC            11.1%
#
#    What the agent saw (no probs):
#      LSTM top pick   : SEPSIS
#
# 🤖 AGENT DECISION:
#    Decision: OVERRIDE
#    Chose   : TOXIC_METABOLIC
#
#    Reasoning: The patient exhibits hyperglycemia (glucose mean 125.0, last 138.0) which is a common finding in toxic/metabolic encephalopathy. While vital signs are relatively stable, the worsening glucose trend without other clear signs of sepsis or trauma points towards a metabolic derangement. The lack of specific labs to confirm sepsis or trauma further supports focusing on the available metabolic data.
#
#    Supporting evidence:
#      • Worsening glucose (last 138.0)
#      • Stable vital signs overall
#      • No specific labs provided for sepsis or trauma
#
#    Ruled out:
#      • SEPSIS: Vital signs are stable, and there are no specific inflammatory markers (like WBC, lactate, CRP) or source of infection mentioned to strongly suggest sepsis.
#      • TRAUMA_NEURO: There is no mention of trauma history, neurological exam findings, or imaging results to support a primary neurotraumatic cause.
#
# ──────────────────────────────────────────────────────────────────────
# ❌ BOTH WRONG
# ══════════════════════════════════════════════════════════════════════
# PATIENT: 19687015
# ══════════════════════════════════════════════════════════════════════
#
# 🎯 TRUE: SURGICAL_COMPLICATION
#
# 📊 LSTM TOP-3 (probs not shown to agent):
#    1. SEPSIS                     65.8%    ← LSTM top pick
#    2. SURGICAL_COMPLICATION      16.1% ✓
#    3. GI_BLEED                    5.7%
#
#    What the agent saw (no probs):
#      LSTM top pick   : SEPSIS
#
# 🤖 AGENT DECISION:
#    Decision: OVERRIDE
#    Chose   : GI_BLEED
#
#    Reasoning: The patient exhibits signs of hemodynamic instability with worsening blood pressure despite stable heart rate and respiratory rate, alongside a low hemoglobin level (10.6 g/dL) and low platelet count (76,000/uL), suggesting acute blood loss. The elevated INR (1.6) could indicate underlying coagulopathy or be related to the cause of the bleed. While sepsis is possible, the lack of fever or significant leukocytosis makes GI bleed more likely given the anemia and thrombocytopenia.
#
#    Supporting evidence:
#      • Worsening systolic, diastolic, and mean blood pressure
#      • Low Hemoglobin (10.6 g/dL)
#      • Low Platelet Count (76,000/uL)
#
#    Ruled out:
#      • SEPSIS: No fever (stable temperature) or significant leukocytosis (WBC 9.5k) reported, although these are not definitive exclusions.
#      • SURGICAL_COMPLICATION: No specific surgical history or findings are provided to suggest a complication related to recent surgery.
#
# ──────────────────────────────────────────────────────────────────────
# ❌ BOTH WRONG
# ══════════════════════════════════════════════════════════════════════
# PATIENT: 18075452
# ══════════════════════════════════════════════════════════════════════
#
# 🎯 TRUE: SURGICAL_COMPLICATION
#
# 📊 LSTM TOP-3 (probs not shown to agent):
#    1. SEPSIS                     68.7%    ← LSTM top pick
#    2. SURGICAL_COMPLICATION      10.9% ✓
#    3. TOXIC_METABOLIC             4.0%
#
#    What the agent saw (no probs):
#      LSTM top pick   : SEPSIS
#
# 🤖 AGENT DECISION:
#    Decision: OVERRIDE
#    Chose   : TOXIC_METABOLIC
#
#    Reasoning: The patient presents with stable but concerning vital signs, including borderline low blood pressure (mean 68.3) and tachypnea (mean 27.1), alongside a low sodium level (133.0). While sepsis is possible, the lack of fever or significant hemodynamic instability makes it less likely. A toxic or metabolic cause, potentially related to an unmeasured substance or electrolyte imbalance, could explain the overall clinical picture.
#
#    Supporting evidence:
#      • Low Sodium (133.0)
#      • Tachypnea (mean RR 27.1)
#      • Borderline Hypotension (mean MAP 68.3)
#
#    Ruled out:
#      • SEPSIS: No fever reported, and vital signs are relatively stable despite concerning trends, making overt sepsis less likely without further data.
#      • SURGICAL_COMPLICATION: No specific surgical history or findings (e.g., bleeding, wound issues) are mentioned in the provided data to support this diagnosis.
#
# ──────────────────────────────────────────────────────────────────────
# ❌ BOTH WRONG
# ══════════════════════════════════════════════════════════════════════
# PATIENT: 13770725
# ══════════════════════════════════════════════════════════════════════
#
# 🎯 TRUE: VALVE_DISEASE
#
# 📊 LSTM TOP-3 (probs not shown to agent):
#    1. VALVE_DISEASE              34.4% ✓  ← LSTM top pick
#    2. CORONARY_ARTERY_DZ         31.3%
#    3. ACUTE_MI                   26.4%
#
#    What the agent saw (no probs):
#      LSTM top pick   : VALVE_DISEASE
#
# 🤖 AGENT DECISION:
#    Decision: OVERRIDE
#    Chose   : CORONARY_ARTERY_DZ
#
#    Reasoning: The patient presents with bradycardia (mean HR 57) and stable hemodynamics (mean BP 67), but also shows a worsening respiratory rate (mean 16, range 10-25, last 14). While labs are limited, the overall picture suggests a cardiac etiology potentially related to ischemia or infarction, which falls under coronary artery disease. The lack of specific cardiac enzyme or EKG data prevents definitive diagnosis but makes CAD the most plausible underlying cause given the available information.
#
#    Supporting evidence:
#      • Bradycardia (mean HR 57)
#      • Worsening respiratory rate (mean 16, range 10-25)
#      • Stable hemodynamics (mean BP 67)
#
#    Ruled out:
#      • ACUTE_MI: Lack of specific cardiac markers (troponin, CK-MB) or EKG data to confirm acute myocardial infarction.
#      • VALVE_DISEASE: No clinical signs or data suggestive of valvular dysfunction (e.g., murmurs, echocardiogram results).
#
# ──────────────────────────────────────────────────────────────────────
# ⚠️ AGENT HURT (overrode a correct LSTM pick)
# ══════════════════════════════════════════════════════════════════════
# PATIENT: 10117812
# ══════════════════════════════════════════════════════════════════════
#
# 🎯 TRUE: LIVER_FAILURE
#
# 📊 LSTM TOP-3 (probs not shown to agent):
#    1. LIVER_FAILURE              56.2% ✓  ← LSTM top pick
#    2. SEPSIS                     31.6%
#    3. TOXIC_METABOLIC             4.2%
#
#    What the agent saw (no probs):
#      LSTM top pick   : LIVER_FAILURE
#
# 🤖 AGENT DECISION:
#    Decision: OVERRIDE
#    Chose   : TOXIC_METABOLIC
#
#    Reasoning: The patient presents with hyponatremia (Na 130), a low anion gap (8), and a low bicarbonate (20), suggesting a metabolic acidosis potentially related to a toxic ingestion or metabolic derangement. While sepsis is possible, the lack of fever, significant leukocytosis (not provided), or clear source of infection makes it less likely than a toxic/metabolic cause given the specific lab abnormalities.
#
#    Supporting evidence:
#      • Hyponatremia (Na 130)
#      • Low anion gap (8)
#      • Low bicarbonate (20)
#
#    Ruled out:
#      • SEPSIS: No fever, no clear source of infection identified, and labs don't strongly support sepsis without further information (e.g., WBC count, lactate).
#      • LIVER_FAILURE: No data provided on liver function tests (AST, ALT, bilirubin, INR) to support liver failure.
#
# ──────────────────────────────────────────────────────────────────────
# ⚠️ AGENT HURT (overrode a correct LSTM pick)
# ══════════════════════════════════════════════════════════════════════
# PATIENT: 14478167
# ══════════════════════════════════════════════════════════════════════
#
# 🎯 TRUE: LIVER_FAILURE
#
# 📊 LSTM TOP-3 (probs not shown to agent):
#    1. LIVER_FAILURE              62.5% ✓  ← LSTM top pick
#    2. SEPSIS                     29.8%
#    3. GI_BLEED                    2.5%
#
#    What the agent saw (no probs):
#      LSTM top pick   : LIVER_FAILURE
#
# 🤖 AGENT DECISION:
#    Decision: OVERRIDE
#    Chose   : SEPSIS
#
#    Reasoning: The patient exhibits worsening vital signs including bradycardia (relative to worsening BP), hypertension, and increasing CVP, alongside leukocytosis and worsening renal function (creatinine). These findings, particularly the hemodynamic instability and inflammatory response markers, are highly suggestive of sepsis, even without a definitive source identified yet.
#
#    Supporting evidence:
#      • Worsening hemodynamics (increasing BP, CVP, worsening HR trend)
#      • Leukocytosis (WBC 19.15)
#      • Worsening renal function (Creatinine 2.00)
#
#    Ruled out:
#      • GI_BLEED: While the patient has anemia (Hgb 10.15), there is no explicit mention of melena, hematemesis, or a significant drop in hemoglobin suggesting acute bleeding. Platelet count is decreasing, but not drastically.
#      • LIVER_FAILURE: Key markers of liver failure like bilirubin, albumin, and INR are not provided or are stable (INR 1.10), making this diagnosis less likely based on the available data.
#
# ──────────────────────────────────────────────────────────────────────
# ⚠️ AGENT HURT (overrode a correct LSTM pick)
# ══════════════════════════════════════════════════════════════════════
# PATIENT: 17325614
# ══════════════════════════════════════════════════════════════════════
#
# 🎯 TRUE: AFIB_ARRHYTHMIA
#
# 📊 LSTM TOP-3 (probs not shown to agent):
#    1. SEPSIS                     32.7%    ← LSTM top pick
#    2. HEART_FAILURE              20.0%
#    3. AFIB_ARRHYTHMIA            10.3% ✓
#
#    What the agent saw (no probs):
#      LSTM top pick   : SEPSIS
#
# 🤖 AGENT DECISION:
#    Decision: OVERRIDE
#    Chose   : AFIB_ARRHYTHMIA
#
#    Reasoning: The patient presents with persistent tachycardia (mean HR 120.2) despite improving hemodynamics (BP, RR, O2 sat). While sepsis can cause tachycardia, the lack of fever or significant respiratory distress makes it less likely. Heart failure could cause tachycardia, but the improving BP and stable oxygenation argue against acute decompensation.
#
#    Supporting evidence:
#      • Persistent tachycardia (mean HR 120.2)
#      • Stable oxygen saturation (mean 96.3%)
#      • Improving hemodynamics (BP, RR)
#
#    Ruled out:
#      • SEPSIS: No fever reported, stable oxygenation, and improving hemodynamics make sepsis less likely as the primary driver, although it cannot be entirely excluded without more data.
#      • HEART_FAILURE: Improving blood pressure and stable oxygen saturation are not typical for acute heart failure decompensation, although underlying heart failure could be present.
#
# ──────────────────────────────────────────────────────────────────────
# 🎉 AGENT IMPROVED (override was right)
# ══════════════════════════════════════════════════════════════════════
# PATIENT: 12375699
# ══════════════════════════════════════════════════════════════════════
#
# 🎯 TRUE: AFIB_ARRHYTHMIA
#
# 📊 LSTM TOP-3 (probs not shown to agent):
#    1. AFIB_ARRHYTHMIA            39.6% ✓  ← LSTM top pick
#    2. ACUTE_MI                   22.9%
#    3. HEART_FAILURE              10.0%
#
#    What the agent saw (no probs):
#      LSTM top pick   : AFIB_ARRHYTHMIA
#
# 🤖 AGENT DECISION:
#    Decision: OVERRIDE
#    Chose   : HEART_FAILURE
#
#    Reasoning: The patient presents with stable hemodynamics but a worsening respiratory rate, suggesting respiratory distress potentially secondary to fluid overload or pulmonary congestion. The elevated anion gap and BUN could indicate renal hypoperfusion or metabolic acidosis, common in heart failure exacerbations. While cardiac markers are missing, the overall picture is more suggestive of heart failure than an acute MI or arrhythmia.
#
#    Supporting evidence:
#      • Worsening respiratory rate (19.2 mean, range 15-28, last 21.0)
#      • Elevated BUN (34.00)
#      • Elevated Anion Gap (20.00)
#
#    Ruled out:
#      • ACUTE_MI: No specific cardiac biomarkers (e.g., Troponin, CK-MB) are provided to confirm myocardial injury, and vital signs are relatively stable without significant tachycardia or hypotension typically seen in acute MI.
#      • AFIB_ARRHYTHMIA: Heart rate is stable with a mean of 73.0, and no ECG data is available to confirm atrial fibrillation. While brief bradycardia (HR 50) and tachycardia (HR 130) alarms occurred, they were single observations and the overall trend is stable.
#
# ──────────────────────────────────────────────────────────────────────
# ⚠️ AGENT HURT (overrode a correct LSTM pick)
# ══════════════════════════════════════════════════════════════════════
# PATIENT: 15101852
# ══════════════════════════════════════════════════════════════════════
#
# 🎯 TRUE: GI_BLEED
#
# 📊 LSTM TOP-3 (probs not shown to agent):
#    1. SEPSIS                     53.6%    ← LSTM top pick
#    2. SURGICAL_COMPLICATION      15.2%
#    3. GI_BLEED                   12.4% ✓
#
#    What the agent saw (no probs):
#      LSTM top pick   : SEPSIS
#
# 🤖 AGENT DECISION:
#    Decision: OVERRIDE
#    Chose   : GI_BLEED
#
#    Reasoning: The patient presents with significant anemia (Hgb 8.4, Hct 25.4) and a worsening anion gap, suggesting metabolic acidosis potentially from hypoperfusion or lactic acidosis secondary to blood loss. While sepsis is possible, the lack of fever or significant leukocytosis makes GI bleed a more likely explanation for the anemia and potential hemodynamic instability.
#
#    Supporting evidence:
#      • Hemoglobin 8.4 g/dL
#      • Hematocrit 25.4%
#      • Worsening Anion Gap (9.0)
#
#    Ruled out:
#      • SEPSIS: No fever reported, WBC count is elevated but not dramatically so (24.9k), and other typical sepsis markers are absent.
#      • SURGICAL_COMPLICATION: While possible, there's no specific information about recent surgery or complications like infection or anastomotic leak. The primary finding is severe anemia.
#
# ──────────────────────────────────────────────────────────────────────
# 🎉 AGENT IMPROVED (override was right)
# ══════════════════════════════════════════════════════════════════════
# PATIENT: 10904094
# ══════════════════════════════════════════════════════════════════════
#
# 🎯 TRUE: SEPSIS
#
# 📊 LSTM TOP-3 (probs not shown to agent):
#    1. SURGICAL_COMPLICATION      29.9%    ← LSTM top pick
#    2. SEPSIS                     28.1% ✓
#    3. ACUTE_MI                   16.2%
#
#    What the agent saw (no probs):
#      LSTM top pick   : SURGICAL_COMPLICATION
#
# 🤖 AGENT DECISION:
#    Decision: OVERRIDE
#    Chose   : SEPSIS
#
#    Reasoning: The patient presents with significant physiological instability including hypotension (mean BP 50), hypoxemia (O2 sat 72% on 100% FiO2), and tachycardia (mean HR 79.5, but with a wide range including bradycardia), suggestive of a systemic inflammatory response. The elevated white blood cell count (21.6) further supports an infectious or inflammatory process. While cardiac markers are missing, the overall picture is most consistent with sepsis.
#
#    Supporting evidence:
#      • Hypotension (mean BP 50)
#      • Hypoxemia (O2 sat 72% on 100% FiO2)
#      • Leukocytosis (WBC 21.6)
#
#    Ruled out:
#      • ACUTE_MI: No cardiac enzymes (Troponin, CK-MB) or ECG data are provided, making it impossible to confirm or rule out MI based on the available data. While hypotension and hypoxemia can occur in MI, the lack of specific cardiac markers makes sepsis a more likely explanation for the overall clinical picture.
#      • SURGICAL_COMPLICATION: There is no information regarding recent surgery or specific surgical site findings. While sepsis can be a complication of surgery, the data doesn't specifically point towards a surgical source over other potential causes of sepsis.
#
# ──────────────────────────────────────────────────────────────────────
# 🎉 AGENT IMPROVED (override was right)
