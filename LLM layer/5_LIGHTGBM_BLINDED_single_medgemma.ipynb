# %% [markdown]
# # 🌳🧠 ICU Clinical Grouping — TOP-5 LightGBM + MedGemma Single Agent (Blinded)
#
# LightGBM tabular baseline (5-class) followed by a blinded MedGemma 27B reasoning layer.
#
# The LightGBM model is trained on per-channel summary statistics from the 12-hour ICU window.
# The agent receives the LightGBM top-3 candidates in shuffled order (blinded to confidence/rank)
# and selects the single most appropriate diagnosis using clinical reasoning.

# %% [markdown]
# ## 1. Setup & Configuration

# %%
# !pip install -q lightgbm scikit-learn joblib pandas
# !pip install -q -U transformers accelerate bitsandbytes tqdm huggingface_hub

from google.colab import drive, userdata
drive.mount('/content/drive')
print('Setup complete ✓')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Setup complete ✓

# %%
import os

# ── Paths ─────────────────────────────────────────────────────────────────────
CARDS_PATH = '/content/drive/MyDrive/702 project/patient_cards_v6_grouped.json'
OUTPUT_DIR = '/content/drive/MyDrive/702 project/TOP5_lightgbm_outputs'
AGENT_OUTPUT_DIR = '/content/drive/MyDrive/702 project/TOP5_lgb_agent_blinded_results'

os.makedirs(OUTPUT_DIR, exist_ok=True)
os.makedirs(AGENT_OUTPUT_DIR, exist_ok=True)

# ── Split (MUST match LSTM notebook for fair comparison) ──────────────────────
TRAIN_RATIO = 0.70
VAL_RATIO   = 0.15
SPLIT_SEED  = 42

# ── LightGBM hyperparameters ──────────────────────────────────────────────────
LGB_PARAMS = {
    'objective'        : 'multiclass',
    'metric'           : 'multi_logloss',
    'num_leaves'       : 63,
    'learning_rate'    : 0.05,
    'feature_fraction' : 0.8,
    'bagging_fraction' : 0.8,
    'bagging_freq'     : 5,
    'min_data_in_leaf' : 20,
    'lambda_l2'        : 1.0,
    'verbose'          : -1,
    'num_threads'      : -1,
    'seed'             : 42,
}
NUM_BOOST_ROUND       = 2000
EARLY_STOPPING_ROUNDS = 50

# ── Agent / Pilot Configuration ───────────────────────────────────────────────
TOP_K_DEBATE  = 3
PILOT_N_CASES = 100
RANDOM_SEED   = 42

# ── LLM Configuration ─────────────────────────────────────────────────────────
MEDGEMMA_MODEL_ID = 'google/medgemma-27b-text-it'
MAX_NEW_TOKENS    = 1000
TEMPERATURE       = 0.2
RETRY_ATTEMPTS    = 3
FALLBACK_SENTINEL = 'WHITEBOARD JELLYFISH'

print(f'Output dir       : {OUTPUT_DIR}')
print(f'Agent output dir : {AGENT_OUTPUT_DIR}')
print(f'Split seed       : {SPLIT_SEED}  (must match LSTM)')
print(f'LLM model        : {MEDGEMMA_MODEL_ID}')
# Out:
# Output dir       : /content/drive/MyDrive/702 project/TOP5_lightgbm_outputs
# Agent output dir : /content/drive/MyDrive/702 project/TOP5_lgb_agent_blinded_results
# Split seed       : 42  (must match LSTM)
# LLM model        : google/medgemma-27b-text-it

# %% [markdown]
# ## 2. Load Patient Cards

# %%
import json
import numpy as np

print(f'Loading {CARDS_PATH} …')
with open(CARDS_PATH) as f:
    data = json.load(f)

cards         = data['patients']
label_map     = data['label_map']
feature_names = data['feature_names']
n_features    = data['n_features']
n_timesteps   = data['n_timesteps']
num_classes   = len(label_map)
inv_label_map = {v: k for k, v in label_map.items()}

# Feature columns are interleaved [val_0, mask_0, val_1, mask_1, ...]
val_idx  = list(range(0, n_features, 2))
mask_idx = list(range(1, n_features, 2))

# Raw variable names (strip the '_val' suffix from value columns)
raw_var_names = [feature_names[i].replace('_val', '') for i in val_idx]

# ── Disambiguate duplicates ───────────────────────────────────────────────────
# MIMIC sometimes records the same physiologic measurement under multiple
# itemids (e.g., sodium from chemistry vs. blood-gas panels). Those land as
# separate columns with the same display name. We keep all the data and just
# uniquify the names with __1 / __2 suffixes.
from collections import defaultdict, Counter

seen_count   = defaultdict(int)
var_names    = []
rename_log   = []

for raw in raw_var_names:
    seen_count[raw] += 1
    if seen_count[raw] == 1:
        # First occurrence — leave as-is for now (might rename in pass 2 if it dups)
        var_names.append(raw)
    else:
        suffixed = f'{raw}__{seen_count[raw]}'
        var_names.append(suffixed)
        rename_log.append((raw, suffixed))

# Pass 2: any name that ended up duplicated (was seen 2+ times) — also suffix
# its FIRST occurrence to make ordering consistent (foo, foo__2, foo__3 → foo__1, foo__2, foo__3).
final_counts = Counter(raw_var_names)
needs_first_rename = {name for name, c in final_counts.items() if c > 1}
if needs_first_rename:
    first_seen_at = {}
    for i, name in enumerate(raw_var_names):
        if name in needs_first_rename and name not in first_seen_at:
            first_seen_at[name] = i
            var_names[i] = f'{name}__1'
            rename_log.append((name, f'{name}__1'))

# Final sanity: every name unique
assert len(set(var_names)) == len(var_names), \
    f'Still duplicated: {[n for n, c in Counter(var_names).items() if c > 1]}'

n_vars = len(var_names)

if rename_log:
    print(f'\nDisambiguated {len({orig for orig, _ in rename_log})} duplicate names:')
    by_orig = defaultdict(list)
    for orig, new in rename_log:
        by_orig[orig].append(new)
    for orig, news in sorted(by_orig.items()):
        print(f'  {orig!r:<30} → {sorted(set(news))}')
else:
    print('\nNo duplicates in feature names — nothing to rename.')

# Sanity check on data shape (unchanged from before)
c0  = cards[0]
ts0 = np.array(c0['time_series'])
assert ts0.shape == (n_timesteps, n_features), f'Shape mismatch: {ts0.shape}'
assert isinstance(c0['label'], int)
assert np.isfinite(ts0).all(), 'NaN/Inf in time_series'

print(f'\nCards     : {len(cards):,}')
print(f'Classes   : {num_classes}')
print(f'Tensor    : ({n_timesteps}, {n_features}) per patient')
print(f'Variables : {n_vars} (each with value + mask channel)')

TOP_5_CLASSES = ['SEPSIS', 'STROKE_NEURO', 'ACUTE_MI',
                 'CORONARY_ARTERY_DZ', 'HEART_FAILURE']

# Filter
keep_label_ids = {label_map[c] for c in TOP_5_CLASSES}
cards = [c for c in cards if c['label'] in keep_label_ids]

# Remap labels to 0..4
old_to_new = {old: new for new, old in enumerate(sorted(keep_label_ids))}
new_label_map = {inv_label_map[old]: new for old, new in old_to_new.items()}
new_inv_label_map = {v: k for k, v in new_label_map.items()}

for c in cards:
    c['label'] = old_to_new[c['label']]

num_classes = 5
label_map = new_label_map
inv_label_map = new_inv_label_map
# Out:
# Loading /content/drive/MyDrive/702 project/patient_cards_v6_grouped.json …
#
# Disambiguated 4 duplicate names:
#   'anion_gap'                    → ['anion_gap__1', 'anion_gap__2']
#   'chloride'                     → ['chloride__1', 'chloride__2']
#   'hemoglobin'                   → ['hemoglobin__1', 'hemoglobin__2']
#   'sodium'                       → ['sodium__1', 'sodium__2']
#
# Cards     : 28,467
# Classes   : 21
# Tensor    : (12, 136) per patient
# Variables : 68 (each with value + mask channel)

# %%
from collections import Counter

# ── Step 1: compute class frequencies ─────────────────────────────────────────
label_counts = Counter(c['label'] for c in cards)

# Top-5 most common label IDs
top5_label_ids = [label for label, _ in label_counts.most_common(5)]

# Convert to label names (for readability)
top5_label_names = [inv_label_map[l] for l in top5_label_ids]

print("\nTop 5 classes by frequency:")
for i, (lid, count) in enumerate(label_counts.most_common(5)):
    print(f"  {i}: {inv_label_map[lid]} (id={lid}) → {count:,} cards")

# ── Step 2: filter cards ──────────────────────────────────────────────────────
cards = [c for c in cards if c['label'] in top5_label_ids]

# ── Step 3: remap labels to 0..4 (preserve frequency order) ───────────────────
old_to_new = {old: new for new, old in enumerate(top5_label_ids)}

new_label_map = {inv_label_map[old]: new for old, new in old_to_new.items()}
new_inv_label_map = {v: k for k, v in new_label_map.items()}

for c in cards:
    c['label'] = old_to_new[c['label']]

num_classes = 5
label_map = new_label_map
inv_label_map = new_inv_label_map

# ── Step 4: print counts AFTER filtering/remapping ────────────────────────────
new_counts = Counter(c['label'] for c in cards)

print("\nCounts after filtering + remapping:")
for new_id in range(5):
    print(f"  {new_id}: {inv_label_map[new_id]} → {new_counts[new_id]:,} cards")
# Out:
# Top 5 classes by frequency:
#   0: SEPSIS (id=3) → 5,524 cards
#   1: STROKE_NEURO (id=4) → 4,740 cards
#   2: ACUTE_MI (id=0) → 2,361 cards
#   3: CORONARY_ARTERY_DZ (id=1) → 2,335 cards
#   4: HEART_FAILURE (id=2) → 1,794 cards
#
# Counts after filtering + remapping:
#   0: SEPSIS → 5,524 cards
#   1: STROKE_NEURO → 4,740 cards
#   2: ACUTE_MI → 2,361 cards
#   3: CORONARY_ARTERY_DZ → 2,335 cards
#   4: HEART_FAILURE → 1,794 cards

# %% [markdown]
# ## 3. Patient-Level Split (identical to LSTM notebook)

# %%
import random
from collections import defaultdict, Counter

random.seed(SPLIT_SEED)
np.random.seed(SPLIT_SEED)

# Group by patient_id so the same patient never spans train/val/test
patient_to_cards = defaultdict(list)
cards = sorted(cards, key=lambda x: x['patient_id'])

for i, card in enumerate(cards):
    patient_to_cards[card['patient_id']].append(i)

patient_ids = list(patient_to_cards.keys())
random.shuffle(patient_ids)

n_train = int(len(patient_ids) * TRAIN_RATIO)
n_val   = int(len(patient_ids) * VAL_RATIO)

# IMPORTANT: keep these as ordered lists, not sets. set iteration order is
# nondeterministic across Python sessions because of PYTHONHASHSEED, which
# bit us before. Use sets only for membership testing if needed.
train_pids = patient_ids[:n_train]
val_pids   = patient_ids[n_train:n_train + n_val]
test_pids  = patient_ids[n_train + n_val:]

train_cards = [cards[i] for pid in train_pids for i in patient_to_cards[pid]]
val_cards   = [cards[i] for pid in val_pids   for i in patient_to_cards[pid]]
test_cards  = [cards[i] for pid in test_pids  for i in patient_to_cards[pid]]

print(f'Patients — train: {len(train_pids):,}  val: {len(val_pids):,}  test: {len(test_pids):,}')
print(f'Stays    — train: {len(train_cards):,}  val: {len(val_cards):,}  test: {len(test_cards):,}')

# Sanity: print a hash of the test cohort so we can verify it matches the LSTM
import hashlib
test_signature = hashlib.md5(
    ','.join(str(c['patient_id']) + ':' + str(c.get('stay_id', '')) for c in test_cards).encode()
).hexdigest()
print(f'\nTest cohort signature: {test_signature}')
print('  (should match between LSTM and LightGBM runs to validate fair comparison)')
# Out:
# Patients — train: 9,624  val: 2,062  test: 2,063
# Stays    — train: 11,716  val: 2,554  test: 2,484
#
# Test cohort signature: cecc29fd0d5283d8b86fb5be8fc250c5
#   (should match between LSTM and LightGBM runs to validate fair comparison)

# %% [markdown]
# ## 4. Feature Engineering — Time Series → Tabular
#
# For each of the 68 variables, compute summary statistics across the 12-hour
# window. These are the same statistics the agent's prompt formatter shows the
# LLM, so this baseline is asking: *can a tree ensemble do as well as the LSTM
# using only what the agent already sees?*
#
# Per-variable features (6 total):
# - **mean** (over observed timesteps)
# - **min** (over observed timesteps)
# - **max** (over observed timesteps)
# - **last** (most recent observed value)
# - **slope** (linear trend across observed timesteps)
# - **missing_rate** (fraction of timesteps with no observation)
#
# Total feature count: `n_vars × 6`. With 68 variables that's ~408 features.

# %%
def extract_features(time_series_array):
    """
    Convert (N, T, F) raw time series to (N, n_vars * 6) tabular feature matrix.

    The mask channel tells us which timesteps are real observations vs. zeros
    from imputation. We compute statistics over OBSERVED timesteps only — when
    no timesteps are observed, we emit NaN and let LightGBM handle missingness
    natively (it splits NaN as a third branch).
    """
    X = np.asarray(time_series_array, dtype=np.float32)
    N, T, F = X.shape

    vals  = X[:, :, val_idx]   # (N, T, n_vars)  raw values
    masks = X[:, :, mask_idx]  # (N, T, n_vars)  1 = observed, 0 = missing

    # 1. Stats over observed timesteps
    obs_count = masks.sum(axis=1)                                   # (N, n_vars)
    has_obs   = obs_count > 0

    # Mean of observed
    sum_vals = (vals * masks).sum(axis=1)                           # (N, n_vars)
    with np.errstate(invalid='ignore', divide='ignore'):
        mean_obs = np.where(has_obs, sum_vals / obs_count, np.nan)

    # Min/max of observed (mask out unobserved with +/- inf, then take min/max)
    vals_for_min = np.where(masks > 0, vals,  np.inf)
    vals_for_max = np.where(masks > 0, vals, -np.inf)
    min_obs = vals_for_min.min(axis=1)
    max_obs = vals_for_max.max(axis=1)
    min_obs = np.where(has_obs, min_obs, np.nan)
    max_obs = np.where(has_obs, max_obs, np.nan)

    # 2. Last observed value (walk timesteps backward, find most recent observation)
    last_obs = np.full((N, len(val_idx)), np.nan, dtype=np.float32)
    for t in range(T - 1, -1, -1):
        # For each (sample, var) where we haven't filled in last_obs yet AND mask is set, fill it.
        unfilled = np.isnan(last_obs)
        observed = masks[:, t, :] > 0
        fill_now = unfilled & observed
        last_obs[fill_now] = vals[:, t, :][fill_now]

    # 3. Slope: simple least-squares fit of value vs. timestep over observed points.
    # When fewer than 2 points are observed, slope = 0 (no trend information).
    t_arr = np.arange(T, dtype=np.float32)
    slope = np.zeros((N, len(val_idx)), dtype=np.float32)

    # Sums needed for closed-form slope (weighted by mask):
    sum_w   = masks.sum(axis=1)                          # (N, n_vars)  = obs_count
    sum_t   = (masks * t_arr[None, :, None]).sum(axis=1)
    sum_v   = (masks * vals).sum(axis=1)
    sum_tv  = (masks * vals * t_arr[None, :, None]).sum(axis=1)
    sum_tt  = (masks * (t_arr ** 2)[None, :, None]).sum(axis=1)

    denom = sum_w * sum_tt - sum_t ** 2
    enough_pts = sum_w >= 2
    valid = enough_pts & (denom != 0)

    with np.errstate(invalid='ignore', divide='ignore'):
        slope_calc = (sum_w * sum_tv - sum_t * sum_v) / denom
    slope = np.where(valid, slope_calc, 0.0)

    # 4. Missingness rate
    missing_rate = 1.0 - (obs_count / T)

    # Stack all 6 stats per variable: (N, 6, n_vars) → (N, n_vars * 6)
    stacked = np.stack([mean_obs, min_obs, max_obs, last_obs, slope, missing_rate], axis=1)
    flat = stacked.reshape(N, -1)
    return flat


# Build feature names in the same order: var0_mean, var0_min, ..., var0_missing, var1_mean, ...
STAT_NAMES = ['mean', 'min', 'max', 'last', 'slope', 'missing']
tabular_feature_names = []
for stat in STAT_NAMES:
    for v in var_names:
        tabular_feature_names.append(f'{v}__{stat}')
# Order matches the np.stack above (stat-major), so reshape gives this order
n_tab_features = len(tabular_feature_names)
print(f'Tabular features per stay: {n_tab_features}  ({n_vars} vars × {len(STAT_NAMES)} stats)')
# Out:
# Tabular features per stay: 408  (68 vars × 6 stats)

# %%
# Materialize feature matrices.
# Loading all time_series at once may use ~1-2 GB depending on dataset size — fine on Colab.
print('Building feature matrices...')

def cards_to_array(cards_list):
    return np.array([c['time_series'] for c in cards_list], dtype=np.float32)

X_train_raw = cards_to_array(train_cards)
X_val_raw   = cards_to_array(val_cards)
X_test_raw  = cards_to_array(test_cards)

X_train = extract_features(X_train_raw)
X_val   = extract_features(X_val_raw)
X_test  = extract_features(X_test_raw)

y_train = np.array([c['label'] for c in train_cards], dtype=np.int64)
y_val   = np.array([c['label'] for c in val_cards],   dtype=np.int64)
y_test  = np.array([c['label'] for c in test_cards],  dtype=np.int64)

print(f'X_train: {X_train.shape}  y_train: {y_train.shape}')
print(f'X_val  : {X_val.shape}    y_val  : {y_val.shape}')
print(f'X_test : {X_test.shape}   y_test : {y_test.shape}')

# Free raw arrays — we don't need them past this point
del X_train_raw, X_val_raw, X_test_raw
import gc; gc.collect()

# Quick sanity: NaN rate per column should be reasonable (mostly = missing rate)
nan_rate = np.isnan(X_train).mean(axis=0)
print(f'\nNaN rate per feature — mean: {nan_rate.mean():.2%}  max: {nan_rate.max():.2%}')
print('(High NaN rates expected for sparse vitals/labs — LightGBM handles natively)')
# Out:
# Building feature matrices...
# X_train: (11716, 408)  y_train: (11716,)
# X_val  : (2554, 408)    y_val  : (2554,)
# X_test : (2484, 408)   y_test : (2484,)
#
# NaN rate per feature — mean: 34.12%  max: 91.03%
# (High NaN rates expected for sparse vitals/labs — LightGBM handles natively)

# %%
# # Quick check on the existing var_names so you know what's getting renamed.
# from collections import Counter

# dup_counter = Counter(var_names)
# duplicates  = {name: count for name, count in dup_counter.items() if count > 1}

# if duplicates:
#     print(f'Found {len(duplicates)} duplicated variable names:')
#     for name, count in sorted(duplicates.items(), key=lambda x: -x[1]):
#         # Find every column index where this name occurs in the original feature_names
#         positions = [i for i, fn in enumerate(feature_names)
#                      if fn.replace('_val', '') == name and i % 2 == 0]
#         print(f'  {name!r:<30} appears {count}× at val-column indices {positions}')
# else:
#     print('No duplicates found — the error must be elsewhere.')

# %% [markdown]
# ## 5. Train LightGBM

# %%
import lightgbm as lgb
import time

print(f'Training LightGBM on {len(y_train):,} stays, {num_classes} classes, {n_tab_features} features...')

train_set = lgb.Dataset(X_train, label=y_train, feature_name=tabular_feature_names)
val_set   = lgb.Dataset(X_val,   label=y_val,   feature_name=tabular_feature_names,
                        reference=train_set)

params = {**LGB_PARAMS, 'num_class': num_classes}

start = time.time()
booster = lgb.train(
    params,
    train_set,
    num_boost_round=NUM_BOOST_ROUND,
    valid_sets=[train_set, val_set],
    valid_names=['train', 'val'],
    callbacks=[
        lgb.early_stopping(stopping_rounds=EARLY_STOPPING_ROUNDS, verbose=True),
        lgb.log_evaluation(period=50),
    ],
)
elapsed = time.time() - start
print(f'\n✓ Training complete — {elapsed:.1f}s, best iter: {booster.best_iteration}')
# Out:
# Training LightGBM on 11,716 stays, 5 classes, 408 features...
# Training until validation scores don't improve for 50 rounds
# [50]	train's multi_logloss: 0.425538	val's multi_logloss: 0.755818
# [100]	train's multi_logloss: 0.211405	val's multi_logloss: 0.706163
# [150]	train's multi_logloss: 0.114019	val's multi_logloss: 0.707862
# Early stopping, best iteration is:
# [116]	train's multi_logloss: 0.172013	val's multi_logloss: 0.70343
#
# ✓ Training complete — 25.1s, best iter: 116

# %% [markdown]
# ## 6. Evaluate on Test Set

# %%
from sklearn.metrics import accuracy_score, f1_score, classification_report

# Predict probabilities on test set
test_probs = booster.predict(X_test, num_iteration=booster.best_iteration)  # (N, num_classes)
test_preds = test_probs.argmax(axis=1)

# Headline metrics
top1_acc    = accuracy_score(y_test, test_preds)
f1_macro    = f1_score(y_test, test_preds, average='macro',    zero_division=0)
f1_weighted = f1_score(y_test, test_preds, average='weighted', zero_division=0)

# Top-K accuracy
topk_acc = {}
for k in [3, 5]:
    topk_preds  = np.argsort(test_probs, axis=1)[:, -k:]
    topk_acc[k] = np.mean([y_test[i] in topk_preds[i] for i in range(len(y_test))])

print('═' * 50)
print('LIGHTGBM TEST SET RESULTS')
print('═' * 50)
print(f'  Top-1 accuracy : {top1_acc*100:6.2f}%')
print(f'  Top-3 accuracy : {topk_acc[3]*100:6.2f}%')
print(f'  F1 macro       : {f1_macro*100:6.2f}%')
print(f'  F1 weighted    : {f1_weighted*100:6.2f}%')
print(f'  Test samples   : {len(y_test):,}')
# Out:
# ══════════════════════════════════════════════════
# LIGHTGBM TEST SET RESULTS
# ══════════════════════════════════════════════════
#   Top-1 accuracy :  73.87%
#   Top-3 accuracy :  96.01%
#   F1 macro       :  66.17%
#   F1 weighted    :  72.63%
#   Test samples   : 2,484

# %%
# Per-class report — useful for the per-class analysis
target_names = [inv_label_map[i] for i in range(num_classes)]
print(classification_report(
    y_test, test_preds,
    target_names=target_names,
    digits=3,
    zero_division=0,
))
# Out:
#                     precision    recall  f1-score   support
#
#             SEPSIS      0.742     0.875     0.803       824
#       STROKE_NEURO      0.895     0.876     0.885       724
#           ACUTE_MI      0.554     0.335     0.418       367
# CORONARY_ARTERY_DZ      0.627     0.756     0.686       320
#      HEART_FAILURE      0.587     0.462     0.517       249
#
#           accuracy                          0.739      2484
#          macro avg      0.681     0.661     0.662      2484
#       weighted avg      0.729     0.739     0.726      2484

# %%
from collections import Counter

# Majority-class baseline: always predict the most common class in training
most_common_label = Counter([c['label'] for c in train_cards]).most_common(1)[0][0]
majority_acc = (y_test == most_common_label).mean()
print(f'Majority-class baseline    : {majority_acc*100:5.2f}%')

# Stratified-random baseline: sample predictions from the training prior
from collections import Counter
prior = np.array([Counter([c['label'] for c in train_cards]).get(i, 0) for i in range(num_classes)])
prior = prior / prior.sum()
np.random.seed(0)
random_preds = np.random.choice(num_classes, size=len(y_test), p=prior)
random_acc = (y_test == random_preds).mean()
print(f'Stratified-random baseline : {random_acc*100:5.2f}%')

# True top-3 ceiling under random: what a random classifier achieves at top-3
# (the prob mass of the 3 most common classes)
top3_classes = np.argsort(prior)[-3:]
random_top3_acc = sum((y_test == c).mean() for c in top3_classes)
print(f'Random top-3 (3 majority)  : {random_top3_acc*100:5.2f}%')
# Out:
# Majority-class baseline    : 33.17%
# Stratified-random baseline : 24.68%
# Random top-3 (3 majority)  : 75.20%

# %% [markdown]
# ## 7. Feature Importance
#
# LightGBM gives you free interpretability. The 'gain' importance shows which
# summary statistics contribute most to splits — this is also a good sanity
# check (heart rate stats and lactate stats should rank high, not e.g. alarm
# limit settings).

# %%
import pandas as pd

# Feature importance by gain (impact on loss reduction)
imp = pd.DataFrame({
    'feature'   : tabular_feature_names,
    'gain'      : booster.feature_importance(importance_type='gain'),
    'split_count': booster.feature_importance(importance_type='split'),
}).sort_values('gain', ascending=False)

print('TOP 30 FEATURES BY GAIN:')
print(imp.head(30).to_string(index=False))

# Save full ranking for the writeup
imp_path = os.path.join(OUTPUT_DIR, 'feature_importance.csv')
imp.to_csv(imp_path, index=False)
print(f'\nFull importance ranking saved → {imp_path}')
# Out:
# TOP 30 FEATURES BY GAIN:
#                                     feature         gain  split_count
#                        resp_alarm_high__min 12620.507314           78
#                       urine_output__missing 12567.682269          328
#                             dextrose_5__min  8743.131615          333
#                        resp_alarm_high__max  8318.748941           64
#                       resp_alarm_high__mean  6387.963472          104
#                      spo2_desat_limit__mean  5194.118828          222
#                            dextrose_5__mean  4587.289867          348
#  non_invasive_blood_pressure_systolic__mean  4536.813757          544
#                       resp_alarm_high__last  4276.921107           32
#                      spo2_desat_limit__last  4136.962256           90
#                              nacl_0_9__mean  3706.441196          424
#                       spo2_desat_limit__max  3644.648319          135
#                           nacl_0_9__missing  3596.435473          244
#                               nacl_0_9__max  3525.261421          333
#                  glucose_finger_stick__mean  3182.516650          393
#                             po_intake__mean  3176.628187          274
#                   glucose_finger_stick__max  3146.086189          417
#                            heart_rate__mean  3078.192676          491
#                central_venous_pressure__min  3068.659102          100
#                               nacl_0_9__min  3047.346283          339
#                temperature_fahrenheit__mean  2930.151436          516
#                      respiratory_rate__mean  2749.644927          587
#                   glucose_finger_stick__min  2602.366665          389
#                        multi_lumen__missing  2598.635408          243
#                             dextrose_5__max  2466.029891          324
#           o2_saturation_pulseoxymetry__mean  2445.635063          557
#                              nacl_0_9__last  2411.274346          288
#   non_invasive_blood_pressure_systolic__min  2392.886604          405
# non_invasive_blood_pressure_alarm_high__max  2195.712685          158
#                  glucose_finger_stick__last  2113.875415          375
#
# Full importance ranking saved → /content/drive/MyDrive/702 project/TOP5_lightgbm_outputs/feature_importance.csv

# %% [markdown]
# ## 8. Build `debate_inputs.json` (same schema as LSTM notebook)

# %%
# Build the per-test-case structure the agent notebook consumes.
# Schema MUST match the LSTM notebook exactly so swapping classifier requires
# only changing the input path on the agent side.

debate_inputs       = []
lstm_correct_count  = 0   # variable named 'lstm_*' for schema compatibility
true_in_topk_count  = 0

# Re-run prediction one card at a time (slower but matches LSTM notebook structure)
print(f'Building debate inputs for {len(test_cards):,} test cases...')

# Vectorized version — extract_features already gave us X_test, test_probs
top_k_idx_all = np.argsort(test_probs, axis=1)[:, -TOP_K_DEBATE:][:, ::-1]  # descending

for i, card in enumerate(test_cards):
    top_k_idx   = top_k_idx_all[i]
    top_k_codes = [inv_label_map[int(j)] for j in top_k_idx]
    top_k_probs = [float(test_probs[i, int(j)]) for j in top_k_idx]

    true_label = card['label']
    true_code  = inv_label_map[true_label]

    pred_code     = top_k_codes[0]
    is_correct    = (pred_code == true_code)
    is_in_topk    = (true_code in top_k_codes)

    lstm_correct_count += is_correct
    true_in_topk_count += is_in_topk

    debate_inputs.append({
        'patient_id'      : card['patient_id'],
        'visit_id'        : card.get('visit_id', card.get('hadm_id')),
        'stay_id'         : card['stay_id'],
        'true_label'      : true_label,
        'true_icd_code'   : true_code,
        'top_k_codes'     : top_k_codes,
        'top_k_probs'     : top_k_probs,
        'lstm_prediction' : pred_code,        # name kept for agent-side compatibility
        'lstm_confidence' : top_k_probs[0],   # ditto
        'lstm_correct'    : is_correct,       # ditto
        'true_in_topk'    : is_in_topk,
        'clinical_summary': card.get('clinical_summary', {}),
    })

lstm_top1 = lstm_correct_count / len(test_cards)
in_topk   = true_in_topk_count / len(test_cards)

print(f'\nLightGBM Top-1   : {lstm_top1*100:.2f}%')
print(f'True in Top-{TOP_K_DEBATE}     : {in_topk*100:.2f}%  ← agent ceiling')
# Out:
# Building debate inputs for 2,484 test cases...
#
# LightGBM Top-1   : 73.87%
# True in Top-3     : 96.01%  ← agent ceiling

# %% [markdown]
# ## 9. Save Outputs

# %%
import joblib
import pandas as pd

def to_python(obj):
    """Recursively convert numpy types to plain Python for JSON."""
    if isinstance(obj, (np.integer,)):  return int(obj)
    if isinstance(obj, (np.floating,)): return float(obj)
    if isinstance(obj, (np.bool_,)):    return bool(obj)
    if isinstance(obj, np.ndarray):     return obj.tolist()
    if isinstance(obj, dict):  return {k: to_python(v) for k, v in obj.items()}
    if isinstance(obj, list):  return [to_python(v) for v in obj]
    return obj

# 1. LightGBM booster (the model itself)
model_path = os.path.join(OUTPUT_DIR, 'best_model.txt')   # .txt is LGB native format
booster.save_model(model_path, num_iteration=booster.best_iteration)

# 2. debate_inputs.json — same schema as LSTM notebook
debate_path = os.path.join(OUTPUT_DIR, 'debate_inputs.json')
with open(debate_path, 'w') as f:
    json.dump({
        'classifier_type'  : 'lightgbm',
        'label_map'        : label_map,
        'inv_label_map'    : {str(k): v for k, v in inv_label_map.items()},
        'top_k'            : TOP_K_DEBATE,
        'n_test'           : len(debate_inputs),
        'lstm_top1_acc'    : round(float(lstm_top1), 4),  # name kept for compat
        'true_in_topk_rate': round(float(in_topk),   4),
        'patients'         : to_python(debate_inputs),
    }, f, indent=2)

# 3. test_predictions.csv — flat per-case table for analysis
csv_path = os.path.join(OUTPUT_DIR, 'test_predictions.csv')
pd.DataFrame([{
    'visit_id'    : d['visit_id'],
    'stay_id'     : d['stay_id'],
    'true_icd'    : d['true_icd_code'],
    'pred_icd'    : d['lstm_prediction'],
    'confidence'  : d['lstm_confidence'],
    'correct'     : d['lstm_correct'],
    'true_in_topk': d['true_in_topk'],
    'top_k_codes' : ' | '.join(d['top_k_codes']),
    'top_k_probs' : ' | '.join(f'{p:.3f}' for p in d['top_k_probs']),
} for d in debate_inputs]).to_csv(csv_path, index=False)

# 4. model_config.json
config_path = os.path.join(OUTPUT_DIR, 'model_config.json')
with open(config_path, 'w') as f:
    json.dump({
        'model_type'     : 'LightGBM',
        'lgb_params'     : LGB_PARAMS,
        'num_class'      : num_classes,
        'best_iteration' : int(booster.best_iteration),
        'n_tab_features' : n_tab_features,
        'stat_names'     : STAT_NAMES,
        'var_names'      : var_names,
        'feature_names'  : tabular_feature_names,
        'n_timesteps'    : n_timesteps,
        'label_map'      : label_map,
        'split_seed'     : SPLIT_SEED,
        'train_ratio'    : TRAIN_RATIO,
        'val_ratio'      : VAL_RATIO,
        'split_signature': test_signature,
    }, f, indent=2)

# 5. Persist the test cohort patient_ids (so agent runs can lock to it)
cohort_path = os.path.join(OUTPUT_DIR, 'test_cohort.json')
with open(cohort_path, 'w') as f:
    json.dump({
        'patient_ids' : [c['patient_id'] for c in test_cards],
        'stay_ids'    : [c.get('stay_id') for c in test_cards],
        'signature'   : test_signature,
        'split_seed'  : SPLIT_SEED,
    }, f)

print('Saved outputs:')
for path in [model_path, debate_path, csv_path, config_path, cohort_path,
             os.path.join(OUTPUT_DIR, 'feature_importance.csv')]:
    if os.path.exists(path):
        mb = os.path.getsize(path) / 1e6
        print(f'  {os.path.basename(path):<28} {mb:7.2f} MB')

print(f'\n{"═" * 50}')
print(f'LIGHTGBM BASELINE SUMMARY')
print(f'{"═" * 50}')
print(f'  Top-1 accuracy   : {top1_acc*100:6.2f}%')
print(f'  Top-3 accuracy   : {topk_acc[3]*100:6.2f}%')
print(f'  Agent ceiling    : {in_topk*100:6.2f}%  (true in top-{TOP_K_DEBATE})')
print(f'  Best iteration   : {booster.best_iteration}')
# Out:
# Saved outputs:
#   best_model.txt                  4.01 MB
#   debate_inputs.json             20.00 MB
#   test_predictions.csv            0.32 MB
#   model_config.json               0.01 MB
#   test_cohort.json                0.06 MB
#   feature_importance.csv          0.02 MB
#
# ══════════════════════════════════════════════════
# LIGHTGBM BASELINE SUMMARY
# ══════════════════════════════════════════════════
#   Top-1 accuracy   :  73.87%
#   Top-3 accuracy   :  96.01%
#   Agent ceiling    :  96.01%  (true in top-3)
#   Best iteration   : 116

# %% [markdown]
# ## 10. Side-by-Side Comparison with LSTM (optional)
#
# If you've already trained the LSTM, this cell loads its `debate_inputs.json`
# and compares per-case agreement to the LightGBM. Useful for the writeup.

# %%
# Set this to the LSTM output dir; if not present, this cell is a no-op
LSTM_OUTPUT_DIR = '/content/drive/MyDrive/702 project/TOP5_lstm_outputs'
lstm_debate = os.path.join(LSTM_OUTPUT_DIR, 'debate_inputs.json')

if not os.path.exists(lstm_debate):
    print(f'(skipped — no LSTM debate_inputs.json at {lstm_debate})')
else:
    with open(lstm_debate) as f:
        lstm_data = json.load(f)

    # Index by stay_id for join
    lstm_by_stay = {p['stay_id']: p for p in lstm_data['patients']}
    lgb_by_stay  = {p['stay_id']: p for p in debate_inputs}

    common_stays = sorted(set(lstm_by_stay) & set(lgb_by_stay))
    print(f'Test stays in both runs: {len(common_stays):,}')
    if len(common_stays) != len(lstm_by_stay) or len(common_stays) != len(lgb_by_stay):
        print(f'  ⚠ LSTM-only stays: {len(set(lstm_by_stay) - set(lgb_by_stay))}')
        print(f'  ⚠ LGB-only  stays: {len(set(lgb_by_stay) - set(lstm_by_stay))}')
        print(f'  → split is not aligned; check seed and cards file')

    # Joint accuracy table
    both_correct  = 0
    only_lstm     = 0
    only_lgb      = 0
    both_wrong    = 0
    same_top1     = 0
    in_topk_lstm  = 0
    in_topk_lgb   = 0
    in_topk_both  = 0

    for sid in common_stays:
        a = lstm_by_stay[sid]
        b = lgb_by_stay[sid]
        if a['lstm_correct'] and b['lstm_correct']:        both_correct += 1
        elif a['lstm_correct'] and not b['lstm_correct']:  only_lstm    += 1
        elif not a['lstm_correct'] and b['lstm_correct']:  only_lgb     += 1
        else:                                              both_wrong   += 1

        if a['lstm_prediction'] == b['lstm_prediction']:   same_top1    += 1
        if a['true_in_topk']:   in_topk_lstm += 1
        if b['true_in_topk']:   in_topk_lgb  += 1
        if a['true_in_topk'] and b['true_in_topk']: in_topk_both += 1

    n = len(common_stays)
    print(f'\nTop-1 accuracy:')
    print(f'  LSTM     : {(both_correct + only_lstm)/n*100:6.2f}%')
    print(f'  LightGBM : {(both_correct + only_lgb)/n*100:6.2f}%')
    print(f'\nAgreement on top-1: {same_top1}/{n} ({same_top1/n*100:.1f}%)')
    print(f'\nCase breakdown (top-1):')
    print(f'  Both correct       : {both_correct} ({both_correct/n*100:.1f}%)')
    print(f'  LSTM only correct  : {only_lstm} ({only_lstm/n*100:.1f}%)')
    print(f'  LGB only correct   : {only_lgb} ({only_lgb/n*100:.1f}%)')
    print(f'  Both wrong         : {both_wrong} ({both_wrong/n*100:.1f}%)')
    print(f'\nTrue in top-{TOP_K_DEBATE} (agent ceiling):')
    print(f'  LSTM     : {in_topk_lstm/n*100:6.2f}%')
    print(f'  LightGBM : {in_topk_lgb/n*100:6.2f}%')
    print(f'  Either   : {(in_topk_lstm + in_topk_lgb - in_topk_both)/n*100:6.2f}%  ← ensemble ceiling')
# Out:
# Test stays in both runs: 2,484
#
# Top-1 accuracy:
#   LSTM     :  67.15%
#   LightGBM :  73.87%
#
# Agreement on top-1: 1910/2484 (76.9%)
#
# Case breakdown (top-1):
#   Both correct       : 1524 (61.4%)
#   LSTM only correct  : 144 (5.8%)
#   LGB only correct   : 311 (12.5%)
#   Both wrong         : 505 (20.3%)
#
# True in top-3 (agent ceiling):
#   LSTM     :  93.88%
#   LightGBM :  96.01%
#   Either   :  97.67%  ← ensemble ceiling

# %% [markdown]
# ## 11. Load MedGemma 27B (4-bit quantized)

# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig
from google.colab import userdata # Added import statement

MEDGEMMA_MODEL_ID = 'google/medgemma-27b-text-it'

try:
    hf_token = userdata.get('HF_TOKEN')
    print('✓ HF_TOKEN loaded from Colab Secrets')
except Exception:
    raise ValueError('Add HF_TOKEN to Colab Secrets (sidebar → 🔑)')

if not torch.cuda.is_available():
    raise RuntimeError('MedGemma 27B requires a GPU. Switch runtime to GPU.')

print(f'GPU : {torch.cuda.get_device_name(0)}')
print(f'VRAM: {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB')

quantization_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_compute_dtype=torch.bfloat16,
    bnb_4bit_quant_type='nf4',
    bnb_4bit_use_double_quant=True,
)

print(f'\nLoading {MEDGEMMA_MODEL_ID} (this takes a few minutes)...')
llm_tokenizer = AutoTokenizer.from_pretrained(MEDGEMMA_MODEL_ID, token=hf_token)
llm_model = AutoModelForCausalLM.from_pretrained(
    MEDGEMMA_MODEL_ID,
    quantization_config=quantization_config,
    device_map='auto',
    token=hf_token,
)
llm_model.eval()

if llm_tokenizer.pad_token_id is None:
    llm_tokenizer.pad_token_id = llm_tokenizer.eos_token_id

print(f'✓ MedGemma loaded ({sum(p.numel() for p in llm_model.parameters()):,} params)')
# Out:
# ✓ HF_TOKEN loaded from Colab Secrets
# GPU : NVIDIA A100-SXM4-40GB
# VRAM: 42.4 GB
#
# Loading google/medgemma-27b-text-it (this takes a few minutes)...
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 11 files:   0%|          | 0/11 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/808 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/173 [00:00<?, ?B/s]
# ✓ MedGemma loaded (14,209,821,440 params)

# %% [markdown]
# ## 12. Stratified Pilot Sample from Test Set

# %%
import random
from collections import defaultdict, Counter
import hashlib

random.seed(RANDOM_SEED)

# Index test cards for stratified sampling
indexed_test = list(enumerate(test_cards))
label_to_indexed = defaultdict(list)
for ix, card in indexed_test:
    label_to_indexed[card['label']].append((ix, card))

label_counts = Counter(c['label'] for c in test_cards)
total = sum(label_counts.values())

pilot_indices = set()
pilot_cards   = []

# Proportional allocation per class
for label, count in sorted(label_counts.items(), key=lambda x: -x[1]):
    n_sample = max(1, int(PILOT_N_CASES * count / total))
    n_sample = min(n_sample, len(label_to_indexed[label]))
    for ix, c in random.sample(label_to_indexed[label], n_sample):
        pilot_indices.add(ix)
        pilot_cards.append(c)

# Top up to PILOT_N_CASES
shortfall = PILOT_N_CASES - len(pilot_cards)
if shortfall > 0:
    remaining = [(ix, c) for ix, c in indexed_test if ix not in pilot_indices]
    n_extra = min(shortfall, len(remaining))
    if n_extra > 0:
        for ix, c in random.sample(remaining, n_extra):
            pilot_indices.add(ix)
            pilot_cards.append(c)

pilot_signature = hashlib.md5(
    ','.join(str(c['patient_id']) + ':' + str(c.get('stay_id', '')) for c in pilot_cards).encode()
).hexdigest()

print(f'Test set    : {len(test_cards):,} stays')
print(f'Pilot sample: {len(pilot_cards)} cases')
print(f'Pilot signature: {pilot_signature}')
print(f'First 5 patient_ids: {[c["patient_id"] for c in pilot_cards[:5]]}')
# Out:
# Test set    : 2,484 stays
# Pilot sample: 100 cases
# Pilot signature: 1b4d427efffdd0666a53dd265877243b
# First 5 patient_ids: ['17829884', '19833452', '11693201', '18958916', '13789582']

# %% [markdown]
# ## 13. LightGBM Prediction Function

# %%
def get_lgb_predictions(card, top_k=3):
    """Get LightGBM top-K predictions for a single patient card."""
    X = np.array([card['time_series']], dtype=np.float32)
    X_flat = extract_features(X)  # (1, n_tab_features)
    probs = booster.predict(X_flat, num_iteration=booster.best_iteration)[0]  # (num_classes,)

    top_k_idx    = np.argsort(probs)[::-1][:top_k]
    top_k_groups = [inv_label_map[int(i)] for i in top_k_idx]
    top_k_probs  = [float(probs[i]) for i in top_k_idx]

    return {
        'top_k_codes'    : top_k_groups,
        'top_k_probs'    : top_k_probs,
        'lstm_prediction': top_k_groups[0],   # named lstm_* for schema compatibility
        'lstm_confidence': top_k_probs[0],
    }

# Sanity check
test_pred = get_lgb_predictions(pilot_cards[0], TOP_K_DEBATE)
print(f'✓ LightGBM test: {test_pred["lstm_prediction"]} ({test_pred["lstm_confidence"]:.1%})')
# Out:
# ✓ LightGBM test: SEPSIS (72.1%)

# %% [markdown]
# ## 14. Clinical Summary Formatter & Leak Stripper

# %%
def format_clinical_summary(summary: dict) -> str:
    """Format clinical summary for prompt."""
    if not summary:
        return "Clinical summary not available"

    lines = []

    if 'vitals' in summary:
        lines.append("VITAL SIGNS (Last 12 Hours):")
        for name, stats in summary['vitals'].items():
            if isinstance(stats, dict) and 'mean' in stats:
                lines.append(
                    f"  {name.replace('_', ' ').title()}: "
                    f"mean={stats['mean']:.1f}, range=[{stats['min']:.1f}\u2013{stats['max']:.1f}], "
                    f"last={stats['last']:.1f} ({stats.get('trend', 'N/A')})"
                )

    if 'labs' in summary:
        lines.append("\nLABORATORY VALUES:")
        for name, stats in summary['labs'].items():
            if isinstance(stats, dict) and 'mean' in stats:
                lines.append(
                    f"  {name.replace('_', ' ').title()}: "
                    f"mean={stats['mean']:.2f}, last={stats['last']:.2f} ({stats.get('trend', 'N/A')})"
                )

    if 'interventions' in summary:
        iv = summary['interventions']
        lines.append("\nINTERVENTIONS:")
        if iv.get('active_drugs'):
            lines.append(f"  Medications: {', '.join(iv['active_drugs'])}")
        if iv.get('active_procedures'):
            lines.append(f"  Procedures: {', '.join(iv['active_procedures'])}")

    return '\n'.join(lines) if lines else "Clinical summary not available"


LEAKY_CARD_FIELDS = {
    'icd_code', 'clinical_group', 'label',
    'procedures', 'drugs', 'conditions',
}

def build_clinical_summary_for_agent(card: dict) -> dict:
    """Return a shallow copy of the card with diagnosis-revealing fields removed."""
    safe = {k: v for k, v in card.items() if k not in LEAKY_CARD_FIELDS}
    cs = safe.get('clinical_summary')
    if isinstance(cs, dict):
        diag_hint_keys = [
            k for k in cs.keys()
            if any(tok in k.lower()
                   for tok in ('diag', 'icd', 'group', 'label', 'condition',
                               'problem', 'impression'))
        ]
        if diag_hint_keys:
            safe['clinical_summary'] = {
                k: v for k, v in cs.items() if k not in diag_hint_keys
            }
    return safe

_probe = build_clinical_summary_for_agent(pilot_cards[0])
_leaks_present = LEAKY_CARD_FIELDS & set(_probe.keys())
assert not _leaks_present, f'Leak check failed: {_leaks_present} still in stripped card'
print('✓ Formatters and leak stripper defined')
# Out:
# ✓ Formatters and leak stripper defined

# %% [markdown]
# ## 15. Single Agent Prompt (Blinded)

# %%
SINGLE_AGENT_PROMPT = """
You are an expert ICU physician. You are given patient data and {top_k} possible diagnoses to consider. Your task is to determine which diagnosis best fits the clinical picture.

## PATIENT DATA (Last 12 Hours in ICU)
{clinical_summary}

## CANDIDATE DIAGNOSES
Consider these {top_k} possibilities (listed in no particular order):
{candidates_list}


## YOUR TASK
You are working with INCOMPLETE ICU data. Not all clinically relevant labs will be present. Your goal is to find the diagnosis most consistent with available evidence, explicitly accounting for what is and is not measured. A diagnosis should not be dismissed solely because its defining marker was not collected.


Respond with ONLY valid JSON:
{{
  "chosen_diagnosis": "DIAGNOSIS_NAME",
  "reasoning": "2-3 sentence explanation of why this diagnosis fits best",
  "supporting_evidence": ["key finding 1", "key finding 2", "key finding 3"],
  "ruled_out": [
    {{"diagnosis": "OTHER_DIAGNOSIS_1", "reason": "why ruled out"}},
    {{"diagnosis": "OTHER_DIAGNOSIS_2", "reason": "why ruled out"}}
  ]
}}

Your chosen_diagnosis MUST be one of the {top_k} candidates listed above.
"""

print('✓ Blinded single agent prompt defined (agent does NOT see LightGBM ranking or probabilities)')
# Out:
# ✓ Blinded single agent prompt defined (agent does NOT see LightGBM ranking or probabilities)

# %% [markdown]
# ## 16. LLM Wrapper

# %%
import re
import time
import traceback


def _is_oom(exc: BaseException) -> bool:
    oom_cls = getattr(torch.cuda, 'OutOfMemoryError', None)
    if oom_cls is not None and isinstance(exc, oom_cls):
        return True
    return isinstance(exc, RuntimeError) and 'out of memory' in str(exc).lower()


def call_llm(prompt: str) -> dict:
    """Call MedGemma 27B (local, 4-bit) and parse JSON from the response."""
    for attempt in range(RETRY_ATTEMPTS):
        try:
            chat_text = llm_tokenizer.apply_chat_template(
                [{'role': 'user', 'content': prompt}],
                add_generation_prompt=True,
                tokenize=False,
            )
            inputs = llm_tokenizer(chat_text, return_tensors='pt').to(llm_model.device)

            with torch.no_grad():
                outputs = llm_model.generate(
                    **inputs,
                    max_new_tokens=MAX_NEW_TOKENS,
                    do_sample=True,
                    temperature=TEMPERATURE,
                    pad_token_id=llm_tokenizer.pad_token_id,
                )

            prompt_len = inputs['input_ids'].shape[-1]
            new_tokens = outputs[0][prompt_len:]
            full_text = llm_tokenizer.decode(new_tokens, skip_special_tokens=True)

            if not full_text.strip():
                raise ValueError('Empty response from model')

            json_match = re.search(r'\{[\s\S]*\}', full_text.strip())
            if not json_match:
                raise ValueError(f'No JSON found. First 200 chars: {full_text[:200]!r}')
            return json.loads(json_match.group(0))

        except Exception as e:
            if _is_oom(e):
                print('    \u26a0 GPU OOM: clearing cache and retrying...')
                torch.cuda.empty_cache()
                time.sleep(5)
                continue
            print(f'    \u26a0 {type(e).__name__} on attempt {attempt+1}/{RETRY_ATTEMPTS}:')
            traceback.print_exc()
            if attempt < RETRY_ATTEMPTS - 1:
                time.sleep(2)

    return {'error': 'Failed after retries', 'chosen_diagnosis': None}

print('✓ MedGemma wrapper ready')
# Out:
# ✓ MedGemma wrapper ready

# %% [markdown]
# ## 17. Single Agent Diagnosis Function (Blinded)

# %%
def diagnose_single_agent(patient_card: dict, verbose: bool = False) -> dict:
    """Run single-agent diagnosis on one patient, blinded to LightGBM ranking."""

    def _log(title, body=None):
        if not verbose:
            return
        print(f'\n\u2500\u2500 {title} \u2500\u2500')
        if body is not None:
            print(body)

    # Build agent-safe view of the card
    clinical_summary_for_agent = build_clinical_summary_for_agent(patient_card)
    _log('STEP A: agent-safe card (top-level keys)',
         f'  keys: {sorted(clinical_summary_for_agent.keys())}')

    # 1. LightGBM top-K
    lgb_output = get_lgb_predictions(clinical_summary_for_agent, TOP_K_DEBATE)
    if verbose:
        print('\n\u2500\u2500 STEP B: LightGBM top-K (probs shown for reference \u2014 NOT shown to agent) \u2500\u2500')
        for _rank, (_c, _p) in enumerate(zip(lgb_output['top_k_codes'], lgb_output['top_k_probs'])):
            print(f'  {_rank+1}. {_c:<25} {_p:>6.1%}')

    # 2. Record top-1 for post-hoc agreement analysis
    lgb_top_pick = lgb_output['top_k_codes'][0]

    # 3. Shuffle candidates — agent sees no ranking
    patient_id_for_seed = patient_card.get('patient_id') or patient_card.get('stay_id') or 0
    shuffle_rng = random.Random(hash(('shuffle', patient_id_for_seed, RANDOM_SEED)))
    shuffled_candidates = list(lgb_output['top_k_codes'])
    shuffle_rng.shuffle(shuffled_candidates)

    _log('STEP C: shuffled candidate order shown to agent (blinded)',
         '  ' + ' | '.join(shuffled_candidates))

    candidates_list = '\n'.join([f'- {code}' for code in shuffled_candidates])

    # 4. Build prompt
    formatted_summary = format_clinical_summary(
        clinical_summary_for_agent.get('clinical_summary', {})
    )
    _log('STEP D: formatted clinical summary', formatted_summary)

    prompt = SINGLE_AGENT_PROMPT.format(
        top_k=TOP_K_DEBATE,
        clinical_summary=formatted_summary,
        candidates_list=candidates_list,
    )
    _log('STEP E: FULL PROMPT SENT TO LLM', prompt)

    # 5. Call LLM
    agent_output = call_llm(prompt)
    if verbose:
        print('\n\u2500\u2500 STEP F: RAW LLM RESPONSE (parsed JSON) \u2500\u2500')
        try:
            print(json.dumps(agent_output, indent=2, ensure_ascii=False))
        except (TypeError, ValueError):
            print(repr(agent_output))

    # 6. Extract and normalize prediction
    raw_pred = agent_output.get('chosen_diagnosis') or ''
    norm     = raw_pred.strip().strip('"\'.,.').upper()
    candidates_upper = {c.upper(): c for c in lgb_output['top_k_codes']}

    if norm in candidates_upper:
        agent_prediction = candidates_upper[norm]
    else:
        # Fuzzy match
        agent_prediction = FALLBACK_SENTINEL
        for c_upper, c_orig in candidates_upper.items():
            if norm in c_upper or c_upper in norm:
                agent_prediction = c_orig
                break

    true_label    = inv_label_map[patient_card['label']]
    lstm_correct  = (lgb_top_pick == true_label)
    agent_correct = (agent_prediction == true_label)
    agent_disagrees = (agent_prediction != lgb_top_pick)
    agent_decision  = 'override' if agent_disagrees else 'accept'

    return {
        'patient_id'            : patient_card.get('patient_id'),
        'true_label'            : true_label,
        'lstm_top_pick'         : lgb_top_pick,
        'lstm_output'           : lgb_output,
        'agent_prediction'      : agent_prediction,
        'agent_output'          : agent_output,
        'lstm_correct'          : lstm_correct,
        'agent_correct'         : agent_correct,
        'agent_disagrees'       : agent_disagrees,
        'agent_decision'        : agent_decision,
        'candidates_shown_order': shuffled_candidates,
    }

print('\u2713 diagnose_single_agent() defined')
# Out:
# ✓ diagnose_single_agent() defined

# %% [markdown]
# ## 18. Run Pilot

# %%
from tqdm.notebook import tqdm
import datetime

print(f'Starting blinded single-agent pilot: {len(pilot_cards)} cases')
print(f'LLM calls: {len(pilot_cards)} (1 per case)')
print(f'Model   : {MEDGEMMA_MODEL_ID}')
print('=' * 78)

results    = []
start_time = datetime.datetime.now()

for i, card in enumerate(tqdm(pilot_cards, desc='Processing')):
    true_label = inv_label_map[card['label']]

    print('\n' + '\u2550' * 78)
    print(f'CASE [{i+1}/{len(pilot_cards)}]  Patient {card["patient_id"]}  |  True: {true_label}')
    print('\u2550' * 78)

    try:
        result = diagnose_single_agent(card, verbose=True)
        results.append(result)

        lgb_mark     = '\u2713' if result['lstm_correct']  else '\u2717'
        agent_mark   = '\u2713' if result['agent_correct'] else '\u2717'
        decision_tag = f'  ({result["agent_decision"].upper()})'
        print('\n\u2500\u2500 OUTCOME \u2500\u2500')
        print(f'  LightGBM top pick : {result["lstm_top_pick"]} {lgb_mark}')
        print(f'  Agent pick        : {result["agent_prediction"]} {agent_mark}{decision_tag}')

    except Exception as e:
        print(f'\n  ERROR: {type(e).__name__}: {e}')
        results.append({'patient_id': card.get('patient_id'), 'error': str(e)})

elapsed = datetime.datetime.now() - start_time
print('\n' + '=' * 78)
print(f'Pilot complete \u2014 elapsed: {elapsed}')
print(f'Valid: {sum(1 for r in results if "error" not in r)}/{len(results)}')
# Out:
# Starting blinded single-agent pilot: 100 cases
# LLM calls: 100 (1 per case)
# Model   : google/medgemma-27b-text-it
# ==============================================================================
# Processing:   0%|          | 0/100 [00:00<?, ?it/s]
# Streaming output truncated to the last 5000 lines.
#   O2 Saturation Pulseoxymetry: mean=97.2, range=[96.0–98.0], last=97.0 (stable)
#   Non Invasive Blood Pressure Systolic: mean=121.6, range=[105.0–133.0], last=105.0 (improving)
#   Non Invasive Blood Pressure Diastolic: mean=65.8, range=[52.0–88.0], last=88.0 (worsening)
#   Non Invasive Blood Pressure Mean: mean=82.5, range=[76.0–96.0], last=95.0 (worsening)
#   Temperature Fahrenheit: mean=98.7, range=[98.4–99.0], last=99.0 (stable)
#   Glucose Finger Stick: mean=90.0, range=[87.0–93.0], last=87.0 (stable)
#   Heart Rate Alarm Low: mean=40.0, range=[40.0–40.0], last=40.0 (single_observation)
#   Heart Rate Alarm High: mean=130.0, range=[130.0–130.0], last=130.0 (single_observation)
#   O2 Saturation Pulseoxymetry Alarm Low: mean=90.0, range=[90.0–90.0], last=90.0 (single_observation)
#   O2 Saturation Pulseoxymetry Alarm High: mean=100.0, range=[100.0–100.0], last=100.0 (single_observation)
#   Spo2 Desat Limit: mean=85.0, range=[85.0–85.0], last=85.0 (single_observation)
#   Resp Alarm High: mean=40.0, range=[40.0–40.0], last=40.0 (single_observation)
#   Resp Alarm Low: mean=8.0, range=[8.0–8.0], last=8.0 (single_observation)
#   Central Venous Pressure: mean=3.6, range=[3.0–5.0], last=3.0 (improving)
#   Sodium: mean=138.0, range=[138.0–138.0], last=138.0 (single_observation)
#   Non Invasive Blood Pressure Alarm Low: mean=55.0, range=[55.0–55.0], last=55.0 (single_observation)
#   Non Invasive Blood Pressure Alarm High: mean=120.0, range=[120.0–120.0], last=120.0 (single_observation)
#   Chloride: mean=107.0, range=[107.0–107.0], last=107.0 (single_observation)
#   Anion Gap: mean=16.0, range=[16.0–16.0], last=16.0 (single_observation)
#
# LABORATORY VALUES:
#   H: mean=5.00, last=5.00 (single_observation)
#   L: mean=13.00, last=13.00 (single_observation)
#   I: mean=1.00, last=1.00 (single_observation)
#   Potassium: mean=4.10, last=4.10 (single_observation)
#   Sodium: mean=138.00, last=138.00 (single_observation)
#   Chloride: mean=107.00, last=107.00 (single_observation)
#   Creatinine: mean=0.60, last=0.60 (single_observation)
#   Urea Nitrogen: mean=21.00, last=21.00 (single_observation)
#   Bicarbonate: mean=15.00, last=15.00 (single_observation)
#   Anion Gap: mean=16.00, last=16.00 (single_observation)
#   Glucose: mean=76.00, last=76.00 (single_observation)
#   Magnesium: mean=1.90, last=1.90 (single_observation)
#   Phosphate: mean=2.40, last=2.40 (single_observation)
#   Calcium Total: mean=7.20, last=7.20 (single_observation)
#   Ptt: mean=51.90, last=51.90 (single_observation)
#
# INTERVENTIONS:
#
# ── STEP E: FULL PROMPT SENT TO LLM ──
#
# You are an expert ICU physician. You are given patient data and 3 possible diagnoses to consider. Your task is to determine which diagnosis best fits the clinical picture.
#
# ## PATIENT DATA (Last 12 Hours in ICU)
# VITAL SIGNS (Last 12 Hours):
#   Heart Rate: mean=85.2, range=[78.0–94.0], last=78.0 (stable)
#   Respiratory Rate: mean=23.8, range=[21.0–35.0], last=22.0 (stable)
#   O2 Saturation Pulseoxymetry: mean=97.2, range=[96.0–98.0], last=97.0 (stable)
#   Non Invasive Blood Pressure Systolic: mean=121.6, range=[105.0–133.0], last=105.0 (improving)
#   Non Invasive Blood Pressure Diastolic: mean=65.8, range=[52.0–88.0], last=88.0 (worsening)
#   Non Invasive Blood Pressure Mean: mean=82.5, range=[76.0–96.0], last=95.0 (worsening)
#   Temperature Fahrenheit: mean=98.7, range=[98.4–99.0], last=99.0 (stable)
#   Glucose Finger Stick: mean=90.0, range=[87.0–93.0], last=87.0 (stable)
#   Heart Rate Alarm Low: mean=40.0, range=[40.0–40.0], last=40.0 (single_observation)
#   Heart Rate Alarm High: mean=130.0, range=[130.0–130.0], last=130.0 (single_observation)
#   O2 Saturation Pulseoxymetry Alarm Low: mean=90.0, range=[90.0–90.0], last=90.0 (single_observation)
#   O2 Saturation Pulseoxymetry Alarm High: mean=100.0, range=[100.0–100.0], last=100.0 (single_observation)
#   Spo2 Desat Limit: mean=85.0, range=[85.0–85.0], last=85.0 (single_observation)
#   Resp Alarm High: mean=40.0, range=[40.0–40.0], last=40.0 (single_observation)
#   Resp Alarm Low: mean=8.0, range=[8.0–8.0], last=8.0 (single_observation)
#   Central Venous Pressure: mean=3.6, range=[3.0–5.0], last=3.0 (improving)
#   Sodium: mean=138.0, range=[138.0–138.0], last=138.0 (single_observation)
#   Non Invasive Blood Pressure Alarm Low: mean=55.0, range=[55.0–55.0], last=55.0 (single_observation)
#   Non Invasive Blood Pressure Alarm High: mean=120.0, range=[120.0–120.0], last=120.0 (single_observation)
#   Chloride: mean=107.0, range=[107.0–107.0], last=107.0 (single_observation)
#   Anion Gap: mean=16.0, range=[16.0–16.0], last=16.0 (single_observation)
#
# LABORATORY VALUES:
#   H: mean=5.00, last=5.00 (single_observation)
#   L: mean=13.00, last=13.00 (single_observation)
#   I: mean=1.00, last=1.00 (single_observation)
#   Potassium: mean=4.10, last=4.10 (single_observation)
#   Sodium: mean=138.00, last=138.00 (single_observation)
#   Chloride: mean=107.00, last=107.00 (single_observation)
#   Creatinine: mean=0.60, last=0.60 (single_observation)
#   Urea Nitrogen: mean=21.00, last=21.00 (single_observation)
#   Bicarbonate: mean=15.00, last=15.00 (single_observation)
#   Anion Gap: mean=16.00, last=16.00 (single_observation)
#   Glucose: mean=76.00, last=76.00 (single_observation)
#   Magnesium: mean=1.90, last=1.90 (single_observation)
#   Phosphate: mean=2.40, last=2.40 (single_observation)
#   Calcium Total: mean=7.20, last=7.20 (single_observation)
#   Ptt: mean=51.90, last=51.90 (single_observation)
#
# INTERVENTIONS:
#
# ## CANDIDATE DIAGNOSES
# Consider these 3 possibilities (listed in no particular order):
# - CORONARY_ARTERY_DZ
# - SEPSIS
# - ACUTE_MI
#
#
# ## YOUR TASK
# You are working with INCOMPLETE ICU data. Not all clinically relevant labs will be present. Your goal is to find the diagnosis most consistent with available evidence, explicitly accounting for what is and is not measured. A diagnosis should not be dismissed solely because its defining marker was not collected.
#
#
# Respond with ONLY valid JSON:
# {
#   "chosen_diagnosis": "DIAGNOSIS_NAME",
#   "reasoning": "2-3 sentence explanation of why this diagnosis fits best",
#   "supporting_evidence": ["key finding 1", "key finding 2", "key finding 3"],
#   "ruled_out": [
#     {"diagnosis": "OTHER_DIAGNOSIS_1", "reason": "why ruled out"},
#     {"diagnosis": "OTHER_DIAGNOSIS_2", "reason": "why ruled out"}
#   ]
# }
#
# Your chosen_diagnosis MUST be one of the 3 candidates listed above.
#
#
# ── STEP F: RAW LLM RESPONSE (parsed JSON) ──
# {
#   "chosen_diagnosis": "SEPSIS",
#   "reasoning": "The patient exhibits signs suggestive of sepsis, including a worsening diastolic blood pressure and mean arterial pressure despite a relatively stable heart rate and oxygen saturation. The low bicarbonate level (15.00) indicates metabolic acidosis, a common finding in sepsis. While specific infection markers are missing, the overall hemodynamic instability and metabolic derangement point towards sepsis as the most likely diagnosis among the choices.",
#   "supporting_evidence": [
#     "Worsening diastolic blood pressure (last=88.0)",
#     "Worsening mean arterial pressure (last=95.0)",
#     "Low bicarbonate (15.00)"
#   ],
#   "ruled_out": [
#     {
#       "diagnosis": "CORONARY_ARTERY_DZ",
#       "reason": "No specific cardiac enzyme data (like Troponin) or EKG findings are provided to support acute coronary syndrome."
#     },
#     {
#       "diagnosis": "ACUTE_MI",
#       "reason": "Similar to CAD, there is a lack of definitive evidence for acute myocardial infarction, such as elevated cardiac biomarkers or characteristic EKG changes."
#     }
#   ]
# }
#
# ── OUTCOME ──
#   LightGBM top pick : ACUTE_MI ✓
#   Agent pick        : SEPSIS ✗  (OVERRIDE)
#
# ══════════════════════════════════════════════════════════════════════════════
# CASE [68/100]  Patient 13773609  |  True: ACUTE_MI
# ══════════════════════════════════════════════════════════════════════════════
#
# ── STEP A: agent-safe card (top-level keys) ──
#   keys: ['clinical_summary', 'feature_names', 'patient_id', 'stay_id', 'time_series', 'visit_id']
#
# ── STEP B: LightGBM top-K (probs shown for reference — NOT shown to agent) ──
#   1. CORONARY_ARTERY_DZ         48.6%
#   2. ACUTE_MI                   47.0%
#   3. HEART_FAILURE               2.8%
#
# ── STEP C: shuffled candidate order shown to agent (blinded) ──
#   CORONARY_ARTERY_DZ | ACUTE_MI | HEART_FAILURE
#
# ── STEP D: formatted clinical summary ──
# VITAL SIGNS (Last 12 Hours):
#   Heart Rate: mean=79.6, range=[78.0–83.0], last=83.0 (stable)
#   Respiratory Rate: mean=24.6, range=[20.0–45.0], last=45.0 (worsening)
#   O2 Saturation Pulseoxymetry: mean=95.6, range=[94.0–97.0], last=97.0 (stable)
#   Non Invasive Blood Pressure Systolic: mean=127.0, range=[92.0–141.5], last=107.0 (worsening)
#   Non Invasive Blood Pressure Diastolic: mean=60.8, range=[42.0–73.0], last=42.0 (improving)
#   Non Invasive Blood Pressure Mean: mean=76.7, range=[57.0–86.0], last=57.0 (improving)
#   Temperature Fahrenheit: mean=98.4, range=[97.9–98.7], last=97.9 (stable)
#   Glucose Finger Stick: mean=141.0, range=[139.0–143.0], last=139.0 (stable)
#   Heart Rate Alarm Low: mean=50.0, range=[50.0–50.0], last=50.0 (single_observation)
#   Heart Rate Alarm High: mean=110.0, range=[110.0–110.0], last=110.0 (single_observation)
#   O2 Saturation Pulseoxymetry Alarm Low: mean=90.0, range=[90.0–90.0], last=90.0 (single_observation)
#   O2 Saturation Pulseoxymetry Alarm High: mean=100.0, range=[100.0–100.0], last=100.0 (single_observation)
#   Spo2 Desat Limit: mean=85.0, range=[85.0–85.0], last=85.0 (single_observation)
#   Resp Alarm High: mean=35.0, range=[35.0–35.0], last=35.0 (single_observation)
#   Resp Alarm Low: mean=8.0, range=[8.0–8.0], last=8.0 (single_observation)
#   O2 Flow: mean=2.0, range=[2.0–2.0], last=2.0 (stable)
#   Sodium: mean=139.0, range=[139.0–139.0], last=139.0 (single_observation)
#   Hemoglobin: mean=8.1, range=[8.1–8.1], last=8.1 (single_observation)
#   Non Invasive Blood Pressure Alarm Low: mean=90.0, range=[90.0–90.0], last=90.0 (single_observation)
#   Non Invasive Blood Pressure Alarm High: mean=140.0, range=[140.0–140.0], last=140.0 (single_observation)
#   Chloride: mean=101.0, range=[101.0–101.0], last=101.0 (single_observation)
#   Anion Gap: mean=15.0, range=[15.0–15.0], last=15.0 (single_observation)
#
# LABORATORY VALUES:
#   Potassium: mean=4.20, last=4.20 (single_observation)
#   Sodium: mean=139.00, last=139.00 (single_observation)
#   Chloride: mean=101.00, last=101.00 (single_observation)
#   Creatinine: mean=1.40, last=1.40 (single_observation)
#   Urea Nitrogen: mean=31.00, last=31.00 (single_observation)
#   Bicarbonate: mean=27.00, last=27.00 (single_observation)
#   Anion Gap: mean=15.00, last=15.00 (single_observation)
#   Glucose: mean=124.00, last=124.00 (single_observation)
#   Magnesium: mean=2.50, last=2.50 (single_observation)
#   Hematocrit: mean=25.00, last=25.00 (single_observation)
#   Hemoglobin: mean=8.10, last=8.10 (single_observation)
#   Platelet Count: mean=157.00, last=157.00 (single_observation)
#   White Blood Cells: mean=11.30, last=11.30 (single_observation)
#   Mch: mean=30.90, last=30.90 (single_observation)
#   Mcv: mean=95.00, last=95.00 (single_observation)
#   Rdw: mean=14.10, last=14.10 (single_observation)
#   Mchc: mean=32.40, last=32.40 (single_observation)
#   Red Blood Cells: mean=2.62, last=2.62 (single_observation)
#   Rdw Sd: mean=48.80, last=48.80 (single_observation)
#   Phosphate: mean=2.50, last=2.50 (single_observation)
#   Calcium Total: mean=9.00, last=9.00 (single_observation)
#   Ptt: mean=34.80, last=34.80 (single_observation)
#   Pt: mean=13.40, last=13.40 (single_observation)
#   Inr: mean=1.20, last=1.20 (single_observation)
#
# INTERVENTIONS:
#   Medications: dextrose_5, po_intake
#   Procedures: 20_gauge, foley_catheter
#
# ── STEP E: FULL PROMPT SENT TO LLM ──
#
# You are an expert ICU physician. You are given patient data and 3 possible diagnoses to consider. Your task is to determine which diagnosis best fits the clinical picture.
#
# ## PATIENT DATA (Last 12 Hours in ICU)
# VITAL SIGNS (Last 12 Hours):
#   Heart Rate: mean=79.6, range=[78.0–83.0], last=83.0 (stable)
#   Respiratory Rate: mean=24.6, range=[20.0–45.0], last=45.0 (worsening)
#   O2 Saturation Pulseoxymetry: mean=95.6, range=[94.0–97.0], last=97.0 (stable)
#   Non Invasive Blood Pressure Systolic: mean=127.0, range=[92.0–141.5], last=107.0 (worsening)
#   Non Invasive Blood Pressure Diastolic: mean=60.8, range=[42.0–73.0], last=42.0 (improving)
#   Non Invasive Blood Pressure Mean: mean=76.7, range=[57.0–86.0], last=57.0 (improving)
#   Temperature Fahrenheit: mean=98.4, range=[97.9–98.7], last=97.9 (stable)
#   Glucose Finger Stick: mean=141.0, range=[139.0–143.0], last=139.0 (stable)
#   Heart Rate Alarm Low: mean=50.0, range=[50.0–50.0], last=50.0 (single_observation)
#   Heart Rate Alarm High: mean=110.0, range=[110.0–110.0], last=110.0 (single_observation)
#   O2 Saturation Pulseoxymetry Alarm Low: mean=90.0, range=[90.0–90.0], last=90.0 (single_observation)
#   O2 Saturation Pulseoxymetry Alarm High: mean=100.0, range=[100.0–100.0], last=100.0 (single_observation)
#   Spo2 Desat Limit: mean=85.0, range=[85.0–85.0], last=85.0 (single_observation)
#   Resp Alarm High: mean=35.0, range=[35.0–35.0], last=35.0 (single_observation)
#   Resp Alarm Low: mean=8.0, range=[8.0–8.0], last=8.0 (single_observation)
#   O2 Flow: mean=2.0, range=[2.0–2.0], last=2.0 (stable)
#   Sodium: mean=139.0, range=[139.0–139.0], last=139.0 (single_observation)
#   Hemoglobin: mean=8.1, range=[8.1–8.1], last=8.1 (single_observation)
#   Non Invasive Blood Pressure Alarm Low: mean=90.0, range=[90.0–90.0], last=90.0 (single_observation)
#   Non Invasive Blood Pressure Alarm High: mean=140.0, range=[140.0–140.0], last=140.0 (single_observation)
#   Chloride: mean=101.0, range=[101.0–101.0], last=101.0 (single_observation)
#   Anion Gap: mean=15.0, range=[15.0–15.0], last=15.0 (single_observation)
#
# LABORATORY VALUES:
#   Potassium: mean=4.20, last=4.20 (single_observation)
#   Sodium: mean=139.00, last=139.00 (single_observation)
#   Chloride: mean=101.00, last=101.00 (single_observation)
#   Creatinine: mean=1.40, last=1.40 (single_observation)
#   Urea Nitrogen: mean=31.00, last=31.00 (single_observation)
#   Bicarbonate: mean=27.00, last=27.00 (single_observation)
#   Anion Gap: mean=15.00, last=15.00 (single_observation)
#   Glucose: mean=124.00, last=124.00 (single_observation)
#   Magnesium: mean=2.50, last=2.50 (single_observation)
#   Hematocrit: mean=25.00, last=25.00 (single_observation)
#   Hemoglobin: mean=8.10, last=8.10 (single_observation)
#   Platelet Count: mean=157.00, last=157.00 (single_observation)
#   White Blood Cells: mean=11.30, last=11.30 (single_observation)
#   Mch: mean=30.90, last=30.90 (single_observation)
#   Mcv: mean=95.00, last=95.00 (single_observation)
#   Rdw: mean=14.10, last=14.10 (single_observation)
#   Mchc: mean=32.40, last=32.40 (single_observation)
#   Red Blood Cells: mean=2.62, last=2.62 (single_observation)
#   Rdw Sd: mean=48.80, last=48.80 (single_observation)
#   Phosphate: mean=2.50, last=2.50 (single_observation)
#   Calcium Total: mean=9.00, last=9.00 (single_observation)
#   Ptt: mean=34.80, last=34.80 (single_observation)
#   Pt: mean=13.40, last=13.40 (single_observation)
#   Inr: mean=1.20, last=1.20 (single_observation)
#
# INTERVENTIONS:
#   Medications: dextrose_5, po_intake
#   Procedures: 20_gauge, foley_catheter
#
# ## CANDIDATE DIAGNOSES
# Consider these 3 possibilities (listed in no particular order):
# - CORONARY_ARTERY_DZ
# - ACUTE_MI
# - HEART_FAILURE
#
#
# ## YOUR TASK
# You are working with INCOMPLETE ICU data. Not all clinically relevant labs will be present. Your goal is to find the diagnosis most consistent with available evidence, explicitly accounting for what is and is not measured. A diagnosis should not be dismissed solely because its defining marker was not collected.
#
#
# Respond with ONLY valid JSON:
# {
#   "chosen_diagnosis": "DIAGNOSIS_NAME",
#   "reasoning": "2-3 sentence explanation of why this diagnosis fits best",
#   "supporting_evidence": ["key finding 1", "key finding 2", "key finding 3"],
#   "ruled_out": [
#     {"diagnosis": "OTHER_DIAGNOSIS_1", "reason": "why ruled out"},
#     {"diagnosis": "OTHER_DIAGNOSIS_2", "reason": "why ruled out"}
#   ]
# }
#
# Your chosen_diagnosis MUST be one of the 3 candidates listed above.
#
#
# ── STEP F: RAW LLM RESPONSE (parsed JSON) ──
# {
#   "chosen_diagnosis": "ACUTE_MI",
#   "reasoning": "The patient presents with worsening respiratory rate and systolic blood pressure, potentially indicating hemodynamic instability or compensatory mechanisms. While classic ECG or troponin data is missing, the overall picture suggests an acute cardiac event like MI, which can manifest with these signs, especially in the context of potential underlying coronary artery disease. The stable oxygen saturation despite tachypnea might suggest a non-pulmonary cause for the respiratory distress.",
#   "supporting_evidence": [
#     "Worsening respiratory rate (mean=24.6, range=[20.0–45.0], last=45.0)",
#     "Worsening systolic blood pressure (mean=127.0, range=[92.0–141.5], last=107.0)",
#     "Stable oxygen saturation (mean=95.6, range=[94.0–97.0], last=97.0)"
#   ],
#   "ruled_out": [
#     {
#       "diagnosis": "CORONARY_ARTERY_DZ",
#       "reason": "This is a chronic condition, not an acute event explaining the recent worsening. While likely present, it doesn't fully explain the acute presentation."
#     },
#     {
#       "diagnosis": "HEART_FAILURE",
#       "reason": "While possible, the stable oxygen saturation and lack of clear signs of fluid overload (e.g., edema, specific lung sounds - not provided) make acute MI a more likely primary driver of the current instability."
#     }
#   ]
# }
#
# ── OUTCOME ──
#   LightGBM top pick : CORONARY_ARTERY_DZ ✗
#   Agent pick        : ACUTE_MI ✓  (OVERRIDE)
#
# ══════════════════════════════════════════════════════════════════════════════
# CASE [69/100]  Patient 12236042  |  True: ACUTE_MI
# ══════════════════════════════════════════════════════════════════════════════
#
# ── STEP A: agent-safe card (top-level keys) ──
#   keys: ['clinical_summary', 'feature_names', 'patient_id', 'stay_id', 'time_series', 'visit_id']
#
# ── STEP B: LightGBM top-K (probs shown for reference — NOT shown to agent) ──
#   1. CORONARY_ARTERY_DZ         46.8%
#   2. ACUTE_MI                   42.6%
#   3. STROKE_NEURO                5.3%
#
# ── STEP C: shuffled candidate order shown to agent (blinded) ──
#   ACUTE_MI | CORONARY_ARTERY_DZ | STROKE_NEURO
#
# ── STEP D: formatted clinical summary ──
# VITAL SIGNS (Last 12 Hours):
#   Heart Rate: mean=91.1, range=[78.0–98.0], last=78.0 (improving)
#   Respiratory Rate: mean=19.7, range=[16.0–26.0], last=26.0 (worsening)
#   O2 Saturation Pulseoxymetry: mean=97.3, range=[95.0–99.0], last=96.0 (stable)
#   Non Invasive Blood Pressure Systolic: mean=113.0, range=[103.0–141.0], last=141.0 (worsening)
#   Non Invasive Blood Pressure Diastolic: mean=64.9, range=[56.0–89.0], last=89.0 (worsening)
#   Non Invasive Blood Pressure Mean: mean=79.2, range=[72.0–105.0], last=105.0 (worsening)
#   Temperature Fahrenheit: mean=98.2, range=[98.0–98.4], last=98.1 (stable)
#   Heart Rate Alarm Low: mean=60.0, range=[60.0–60.0], last=60.0 (single_observation)
#   Heart Rate Alarm High: mean=120.0, range=[120.0–120.0], last=120.0 (single_observation)
#   O2 Saturation Pulseoxymetry Alarm Low: mean=92.0, range=[92.0–92.0], last=92.0 (single_observation)
#   O2 Saturation Pulseoxymetry Alarm High: mean=100.0, range=[100.0–100.0], last=100.0 (single_observation)
#   Spo2 Desat Limit: mean=85.0, range=[85.0–85.0], last=85.0 (single_observation)
#   Resp Alarm High: mean=35.0, range=[35.0–35.0], last=35.0 (single_observation)
#   Resp Alarm Low: mean=8.0, range=[8.0–8.0], last=8.0 (single_observation)
#   O2 Flow: mean=2.0, range=[2.0–2.0], last=2.0 (stable)
#   Sodium: mean=129.0, range=[129.0–129.0], last=129.0 (single_observation)
#   Hemoglobin: mean=9.0, range=[9.0–9.0], last=9.0 (single_observation)
#   Non Invasive Blood Pressure Alarm Low: mean=100.0, range=[100.0–100.0], last=100.0 (single_observation)
#   Non Invasive Blood Pressure Alarm High: mean=140.0, range=[140.0–140.0], last=140.0 (single_observation)
#   Chloride: mean=93.0, range=[93.0–93.0], last=93.0 (single_observation)
#   Anion Gap: mean=10.0, range=[10.0–10.0], last=10.0 (single_observation)
#
# LABORATORY VALUES:
#   H: mean=3.00, last=3.00 (single_observation)
#   L: mean=9.00, last=9.00 (single_observation)
#   I: mean=1.00, last=1.00 (single_observation)
#   Potassium: mean=4.20, last=4.20 (single_observation)
#   Sodium: mean=129.00, last=129.00 (single_observation)
#   Chloride: mean=93.00, last=93.00 (single_observation)
#   Creatinine: mean=0.80, last=0.80 (single_observation)
#   Urea Nitrogen: mean=18.00, last=18.00 (single_observation)
#   Bicarbonate: mean=30.00, last=30.00 (single_observation)
#   Anion Gap: mean=10.00, last=10.00 (single_observation)
#   Glucose: mean=125.00, last=125.00 (single_observation)
#   Magnesium: mean=2.30, last=2.30 (single_observation)
#   Hematocrit: mean=27.20, last=27.20 (single_observation)
#   Hemoglobin: mean=9.00, last=9.00 (single_observation)
#   Platelet Count: mean=190.00, last=190.00 (single_observation)
#   White Blood Cells: mean=10.30, last=10.30 (single_observation)
#   Mch: mean=28.90, last=28.90 (single_observation)
#   Mcv: mean=88.00, last=88.00 (single_observation)
#   Rdw: mean=13.80, last=13.80 (single_observation)
#   Mchc: mean=33.10, last=33.10 (single_observation)
#   Red Blood Cells: mean=3.11, last=3.11 (single_observation)
#   Rdw Sd: mean=44.40, last=44.40 (single_observation)
#   Phosphate: mean=3.00, last=3.00 (single_observation)
#   Calcium Total: mean=8.00, last=8.00 (single_observation)
#
# INTERVENTIONS:
#   Medications: dextrose_5, po_intake
#   Procedures: multi_lumen
#
# ── STEP E: FULL PROMPT SENT TO LLM ──
#
# You are an expert ICU physician. You are given patient data and 3 possible diagnoses to consider. Your task is to determine which diagnosis best fits the clinical picture.
#
# ## PATIENT DATA (Last 12 Hours in ICU)
# VITAL SIGNS (Last 12 Hours):
#   Heart Rate: mean=91.1, range=[78.0–98.0], last=78.0 (improving)
#   Respiratory Rate: mean=19.7, range=[16.0–26.0], last=26.0 (worsening)
#   O2 Saturation Pulseoxymetry: mean=97.3, range=[95.0–99.0], last=96.0 (stable)
#   Non Invasive Blood Pressure Systolic: mean=113.0, range=[103.0–141.0], last=141.0 (worsening)
#   Non Invasive Blood Pressure Diastolic: mean=64.9, range=[56.0–89.0], last=89.0 (worsening)
#   Non Invasive Blood Pressure Mean: mean=79.2, range=[72.0–105.0], last=105.0 (worsening)
#   Temperature Fahrenheit: mean=98.2, range=[98.0–98.4], last=98.1 (stable)
#   Heart Rate Alarm Low: mean=60.0, range=[60.0–60.0], last=60.0 (single_observation)
#   Heart Rate Alarm High: mean=120.0, range=[120.0–120.0], last=120.0 (single_observation)
#   O2 Saturation Pulseoxymetry Alarm Low: mean=92.0, range=[92.0–92.0], last=92.0 (single_observation)
#   O2 Saturation Pulseoxymetry Alarm High: mean=100.0, range=[100.0–100.0], last=100.0 (single_observation)
#   Spo2 Desat Limit: mean=85.0, range=[85.0–85.0], last=85.0 (single_observation)
#   Resp Alarm High: mean=35.0, range=[35.0–35.0], last=35.0 (single_observation)
#   Resp Alarm Low: mean=8.0, range=[8.0–8.0], last=8.0 (single_observation)
#   O2 Flow: mean=2.0, range=[2.0–2.0], last=2.0 (stable)
#   Sodium: mean=129.0, range=[129.0–129.0], last=129.0 (single_observation)
#   Hemoglobin: mean=9.0, range=[9.0–9.0], last=9.0 (single_observation)
#   Non Invasive Blood Pressure Alarm Low: mean=100.0, range=[100.0–100.0], last=100.0 (single_observation)
#   Non Invasive Blood Pressure Alarm High: mean=140.0, range=[140.0–140.0], last=140.0 (single_observation)
#   Chloride: mean=93.0, range=[93.0–93.0], last=93.0 (single_observation)
#   Anion Gap: mean=10.0, range=[10.0–10.0], last=10.0 (single_observation)
#
# LABORATORY VALUES:
#   H: mean=3.00, last=3.00 (single_observation)
#   L: mean=9.00, last=9.00 (single_observation)
#   I: mean=1.00, last=1.00 (single_observation)
#   Potassium: mean=4.20, last=4.20 (single_observation)
#   Sodium: mean=129.00, last=129.00 (single_observation)
#   Chloride: mean=93.00, last=93.00 (single_observation)
#   Creatinine: mean=0.80, last=0.80 (single_observation)
#   Urea Nitrogen: mean=18.00, last=18.00 (single_observation)
#   Bicarbonate: mean=30.00, last=30.00 (single_observation)
#   Anion Gap: mean=10.00, last=10.00 (single_observation)
#   Glucose: mean=125.00, last=125.00 (single_observation)
#   Magnesium: mean=2.30, last=2.30 (single_observation)
#   Hematocrit: mean=27.20, last=27.20 (single_observation)
#   Hemoglobin: mean=9.00, last=9.00 (single_observation)
#   Platelet Count: mean=190.00, last=190.00 (single_observation)
#   White Blood Cells: mean=10.30, last=10.30 (single_observation)
#   Mch: mean=28.90, last=28.90 (single_observation)
#   Mcv: mean=88.00, last=88.00 (single_observation)
#   Rdw: mean=13.80, last=13.80 (single_observation)
#   Mchc: mean=33.10, last=33.10 (single_observation)
#   Red Blood Cells: mean=3.11, last=3.11 (single_observation)
#   Rdw Sd: mean=44.40, last=44.40 (single_observation)
#   Phosphate: mean=3.00, last=3.00 (single_observation)
#   Calcium Total: mean=8.00, last=8.00 (single_observation)
#
# INTERVENTIONS:
#   Medications: dextrose_5, po_intake
#   Procedures: multi_lumen
#
# ## CANDIDATE DIAGNOSES
# Consider these 3 possibilities (listed in no particular order):
# - ACUTE_MI
# - CORONARY_ARTERY_DZ
# - STROKE_NEURO
#
#
# ## YOUR TASK
# You are working with INCOMPLETE ICU data. Not all clinically relevant labs will be present. Your goal is to find the diagnosis most consistent with available evidence, explicitly accounting for what is and is not measured. A diagnosis should not be dismissed solely because its defining marker was not collected.
#
#
# Respond with ONLY valid JSON:
# {
#   "chosen_diagnosis": "DIAGNOSIS_NAME",
#   "reasoning": "2-3 sentence explanation of why this diagnosis fits best",
#   "supporting_evidence": ["key finding 1", "key finding 2", "key finding 3"],
#   "ruled_out": [
#     {"diagnosis": "OTHER_DIAGNOSIS_1", "reason": "why ruled out"},
#     {"diagnosis": "OTHER_DIAGNOSIS_2", "reason": "why ruled out"}
#   ]
# }
#
# Your chosen_diagnosis MUST be one of the 3 candidates listed above.
#
#
# ── STEP F: RAW LLM RESPONSE (parsed JSON) ──
# {
#   "chosen_diagnosis": "STROKE_NEURO",
#   "reasoning": "The patient presents with worsening vital signs, particularly a significant increase in blood pressure (mean BP rising to 105 mmHg, systolic to 141 mmHg, diastolic to 89 mmHg) and respiratory rate (mean 19.7, last 26.0), alongside a stable heart rate (mean 91.1, last 78.0) and oxygen saturation. While cardiac causes are possible, the lack of specific cardiac markers (like troponin) and the prominent hypertensive response alongside tachypnea are more suggestive of a neurological event like a stroke, which can cause autonomic dysregulation leading to hypertension and respiratory changes. The hyponatremia (Na 129) could also be associated with certain types of stroke (e.g., SIADH).",
#   "supporting_evidence": [
#     "Worsening hypertension (Systolic, Diastolic, Mean BP)",
#     "Worsening respiratory rate",
#     "Stable heart rate and oxygen saturation despite worsening BP/RR",
#     "Hyponatremia (Sodium 129)"
#   ],
#   "ruled_out": [
#     {
#       "diagnosis": "ACUTE_MI",
#       "reason": "No specific cardiac markers (e.g., Troponin) are provided, and while heart rate is slightly elevated on average, the last reading is improving and stable oxygen saturation doesn't strongly support acute myocardial ischemia."
#     },
#     {
#       "diagnosis": "CORONARY_ARTERY_DZ",
#       "reason": "This is a chronic condition, not an acute diagnosis explaining the current deterioration. While the patient might have underlying CAD, the acute presentation is not typical for stable CAD and lacks specific evidence for an acute coronary syndrome."
#     }
#   ]
# }
#
# ── OUTCOME ──
#   LightGBM top pick : CORONARY_ARTERY_DZ ✗
#   Agent pick        : STROKE_NEURO ✗  (OVERRIDE)
#
# ══════════════════════════════════════════════════════════════════════════════
# CASE [70/100]  Patient 17864819  |  True: ACUTE_MI
# ══════════════════════════════════════════════════════════════════════════════
#
# ── STEP A: agent-safe card (top-level keys) ──
#   keys: ['clinical_summary', 'feature_names', 'patient_id', 'stay_id', 'time_series', 'visit_id']
#
# ── STEP B: LightGBM top-K (probs shown for reference — NOT shown to agent) ──
#   1. SEPSIS                     59.2%
#   2. ACUTE_MI                   28.0%
#   3. STROKE_NEURO                5.3%
#
# ── STEP C: shuffled candidate order shown to agent (blinded) ──
#   SEPSIS | STROKE_NEURO | ACUTE_MI
#
# ── STEP D: formatted clinical summary ──
# VITAL SIGNS (Last 12 Hours):
#   Heart Rate: mean=103.1, range=[94.0–112.0], last=106.0 (stable)
#   Respiratory Rate: mean=26.7, range=[20.0–30.0], last=28.0 (worsening)
#   O2 Saturation Pulseoxymetry: mean=97.2, range=[95.0–99.0], last=97.0 (stable)
#   Non Invasive Blood Pressure Systolic: mean=127.2, range=[104.0–141.0], last=119.0 (improving)
#   Non Invasive Blood Pressure Diastolic: mean=74.2, range=[64.0–81.0], last=70.0 (improving)
#   Non Invasive Blood Pressure Mean: mean=90.6, range=[81.0–99.0], last=86.0 (improving)
#   Temperature Fahrenheit: mean=99.1, range=[98.6–99.7], last=98.8 (stable)
#   Glucose Finger Stick: mean=246.0, range=[241.0–251.0], last=241.0 (stable)
#   Heart Rate Alarm Low: mean=50.0, range=[50.0–50.0], last=50.0 (single_observation)
#   Heart Rate Alarm High: mean=130.0, range=[130.0–130.0], last=130.0 (single_observation)
#   O2 Saturation Pulseoxymetry Alarm Low: mean=92.0, range=[92.0–92.0], last=92.0 (single_observation)
#   O2 Saturation Pulseoxymetry Alarm High: mean=100.0, range=[100.0–100.0], last=100.0 (single_observation)
#   Spo2 Desat Limit: mean=85.0, range=[85.0–85.0], last=85.0 (single_observation)
#   Resp Alarm High: mean=35.0, range=[35.0–35.0], last=35.0 (single_observation)
#   Resp Alarm Low: mean=8.0, range=[8.0–8.0], last=8.0 (single_observation)
#   Non Invasive Blood Pressure Alarm Low: mean=90.0, range=[90.0–90.0], last=90.0 (single_observation)
#   Non Invasive Blood Pressure Alarm High: mean=160.0, range=[160.0–160.0], last=160.0 (single_observation)
#
# LABORATORY VALUES:
#   Ptt: mean=95.80, last=95.80 (single_observation)
#
# INTERVENTIONS:
#   Medications: dextrose_5, heparin_sodium
#   Procedures: 20_gauge, foley_catheter
#
# ── STEP E: FULL PROMPT SENT TO LLM ──
#
# You are an expert ICU physician. You are given patient data and 3 possible diagnoses to consider. Your task is to determine which diagnosis best fits the clinical picture.
#
# ## PATIENT DATA (Last 12 Hours in ICU)
# VITAL SIGNS (Last 12 Hours):
#   Heart Rate: mean=103.1, range=[94.0–112.0], last=106.0 (stable)
#   Respiratory Rate: mean=26.7, range=[20.0–30.0], last=28.0 (worsening)
#   O2 Saturation Pulseoxymetry: mean=97.2, range=[95.0–99.0], last=97.0 (stable)
#   Non Invasive Blood Pressure Systolic: mean=127.2, range=[104.0–141.0], last=119.0 (improving)
#   Non Invasive Blood Pressure Diastolic: mean=74.2, range=[64.0–81.0], last=70.0 (improving)
#   Non Invasive Blood Pressure Mean: mean=90.6, range=[81.0–99.0], last=86.0 (improving)
#   Temperature Fahrenheit: mean=99.1, range=[98.6–99.7], last=98.8 (stable)
#   Glucose Finger Stick: mean=246.0, range=[241.0–251.0], last=241.0 (stable)
#   Heart Rate Alarm Low: mean=50.0, range=[50.0–50.0], last=50.0 (single_observation)
#   Heart Rate Alarm High: mean=130.0, range=[130.0–130.0], last=130.0 (single_observation)
#   O2 Saturation Pulseoxymetry Alarm Low: mean=92.0, range=[92.0–92.0], last=92.0 (single_observation)
#   O2 Saturation Pulseoxymetry Alarm High: mean=100.0, range=[100.0–100.0], last=100.0 (single_observation)
#   Spo2 Desat Limit: mean=85.0, range=[85.0–85.0], last=85.0 (single_observation)
#   Resp Alarm High: mean=35.0, range=[35.0–35.0], last=35.0 (single_observation)
#   Resp Alarm Low: mean=8.0, range=[8.0–8.0], last=8.0 (single_observation)
#   Non Invasive Blood Pressure Alarm Low: mean=90.0, range=[90.0–90.0], last=90.0 (single_observation)
#   Non Invasive Blood Pressure Alarm High: mean=160.0, range=[160.0–160.0], last=160.0 (single_observation)
#
# LABORATORY VALUES:
#   Ptt: mean=95.80, last=95.80 (single_observation)
#
# INTERVENTIONS:
#   Medications: dextrose_5, heparin_sodium
#   Procedures: 20_gauge, foley_catheter
#
# ## CANDIDATE DIAGNOSES
# Consider these 3 possibilities (listed in no particular order):
# - SEPSIS
# - STROKE_NEURO
# - ACUTE_MI
#
#
# ## YOUR TASK
# You are working with INCOMPLETE ICU data. Not all clinically relevant labs will be present. Your goal is to find the diagnosis most consistent with available evidence, explicitly accounting for what is and is not measured. A diagnosis should not be dismissed solely because its defining marker was not collected.
#
#
# Respond with ONLY valid JSON:
# {
#   "chosen_diagnosis": "DIAGNOSIS_NAME",
#   "reasoning": "2-3 sentence explanation of why this diagnosis fits best",
#   "supporting_evidence": ["key finding 1", "key finding 2", "key finding 3"],
#   "ruled_out": [
#     {"diagnosis": "OTHER_DIAGNOSIS_1", "reason": "why ruled out"},
#     {"diagnosis": "OTHER_DIAGNOSIS_2", "reason": "why ruled out"}
#   ]
# }
#
# Your chosen_diagnosis MUST be one of the 3 candidates listed above.
#
#
# ── STEP F: RAW LLM RESPONSE (parsed JSON) ──
# {
#   "chosen_diagnosis": "SEPSIS",
#   "reasoning": "The patient presents with tachycardia (mean HR 103.1), tachypnea (mean RR 26.7, worsening), and hyperglycemia (mean glucose 246.0), which are common signs of a systemic inflammatory response. While definitive markers like lactate or WBC count are missing, the combination of vital sign abnormalities points towards sepsis as the most likely underlying process.",
#   "supporting_evidence": [
#     "Tachycardia (mean HR 103.1)",
#     "Tachypnea (mean RR 26.7, worsening)",
#     "Hyperglycemia (mean glucose 246.0)"
#   ],
#   "ruled_out": [
#     {
#       "diagnosis": "STROKE_NEURO",
#       "reason": "No focal neurological deficits or specific stroke-related findings are mentioned in the provided data."
#     },
#     {
#       "diagnosis": "ACUTE_MI",
#       "reason": "While tachycardia is present, there are no specific ECG findings, cardiac enzyme levels, or chest pain reported to strongly suggest an acute myocardial infarction."
#     }
#   ]
# }
#
# ── OUTCOME ──
#   LightGBM top pick : SEPSIS ✗
#   Agent pick        : SEPSIS ✗  (ACCEPT)
#
# ══════════════════════════════════════════════════════════════════════════════
# CASE [71/100]  Patient 18255949  |  True: ACUTE_MI
# ══════════════════════════════════════════════════════════════════════════════
#
# ── STEP A: agent-safe card (top-level keys) ──
#   keys: ['clinical_summary', 'feature_names', 'patient_id', 'stay_id', 'time_series', 'visit_id']
#
# ── STEP B: LightGBM top-K (probs shown for reference — NOT shown to agent) ──
#   1. ACUTE_MI                   45.8%
#   2. HEART_FAILURE              34.9%
#   3. SEPSIS                     15.7%
#
# ── STEP C: shuffled candidate order shown to agent (blinded) ──
#   ACUTE_MI | SEPSIS | HEART_FAILURE
#
# ── STEP D: formatted clinical summary ──
# VITAL SIGNS (Last 12 Hours):
#   Heart Rate: mean=88.4, range=[83.0–96.0], last=96.0 (worsening)
#   Respiratory Rate: mean=17.4, range=[13.0–21.0], last=16.0 (worsening)
#   O2 Saturation Pulseoxymetry: mean=96.0, range=[92.0–100.0], last=96.0 (stable)
#   Non Invasive Blood Pressure Systolic: mean=105.5, range=[98.0–109.0], last=109.0 (stable)
#   Non Invasive Blood Pressure Diastolic: mean=69.9, range=[66.0–77.0], last=66.0 (improving)
#   Non Invasive Blood Pressure Mean: mean=80.8, range=[77.0–85.0], last=80.0 (stable)
#   Temperature Fahrenheit: mean=98.4, range=[98.0–99.4], last=99.4 (stable)
#   Heart Rate Alarm Low: mean=50.0, range=[50.0–50.0], last=50.0 (single_observation)
#   Heart Rate Alarm High: mean=130.0, range=[130.0–130.0], last=130.0 (single_observation)
#   O2 Saturation Pulseoxymetry Alarm Low: mean=90.0, range=[90.0–90.0], last=90.0 (single_observation)
#   O2 Saturation Pulseoxymetry Alarm High: mean=100.0, range=[100.0–100.0], last=100.0 (single_observation)
#   Spo2 Desat Limit: mean=85.0, range=[85.0–85.0], last=85.0 (single_observation)
#   Resp Alarm High: mean=35.0, range=[35.0–35.0], last=35.0 (single_observation)
#   Resp Alarm Low: mean=8.0, range=[8.0–8.0], last=8.0 (single_observation)
#   O2 Flow: mean=2.7, range=[2.0–4.0], last=2.0 (improving)
#   Non Invasive Blood Pressure Alarm Low: mean=90.0, range=[90.0–90.0], last=90.0 (single_observation)
#   Non Invasive Blood Pressure Alarm High: mean=160.0, range=[160.0–160.0], last=160.0 (single_observation)
#
# LABORATORY VALUES:
#   Ptt: mean=45.60, last=45.60 (single_observation)
#
# INTERVENTIONS:
#   Medications: dextrose_5, po_intake, heparin_sodium
#   Procedures: 20_gauge, 18_gauge
#
# ── STEP E: FULL PROMPT SENT TO LLM ──
#
# You are an expert ICU physician. You are given patient data and 3 possible diagnoses to consider. Your task is to determine which diagnosis best fits the clinical picture.
#
# ## PATIENT DATA (Last 12 Hours in ICU)
# VITAL SIGNS (Last 12 Hours):
#   Heart Rate: mean=88.4, range=[83.0–96.0], last=96.0 (worsening)
#   Respiratory Rate: mean=17.4, range=[13.0–21.0], last=16.0 (worsening)
#   O2 Saturation Pulseoxymetry: mean=96.0, range=[92.0–100.0], last=96.0 (stable)
#   Non Invasive Blood Pressure Systolic: mean=105.5, range=[98.0–109.0], last=109.0 (stable)
#   Non Invasive Blood Pressure Diastolic: mean=69.9, range=[66.0–77.0], last=66.0 (improving)
#   Non Invasive Blood Pressure Mean: mean=80.8, range=[77.0–85.0], last=80.0 (stable)
#   Temperature Fahrenheit: mean=98.4, range=[98.0–99.4], last=99.4 (stable)
#   Heart Rate Alarm Low: mean=50.0, range=[50.0–50.0], last=50.0 (single_observation)
#   Heart Rate Alarm High: mean=130.0, range=[130.0–130.0], last=130.0 (single_observation)
#   O2 Saturation Pulseoxymetry Alarm Low: mean=90.0, range=[90.0–90.0], last=90.0 (single_observation)
#   O2 Saturation Pulseoxymetry Alarm High: mean=100.0, range=[100.0–100.0], last=100.0 (single_observation)
#   Spo2 Desat Limit: mean=85.0, range=[85.0–85.0], last=85.0 (single_observation)
#   Resp Alarm High: mean=35.0, range=[35.0–35.0], last=35.0 (single_observation)
#   Resp Alarm Low: mean=8.0, range=[8.0–8.0], last=8.0 (single_observation)
#   O2 Flow: mean=2.7, range=[2.0–4.0], last=2.0 (improving)
#   Non Invasive Blood Pressure Alarm Low: mean=90.0, range=[90.0–90.0], last=90.0 (single_observation)
#   Non Invasive Blood Pressure Alarm High: mean=160.0, range=[160.0–160.0], last=160.0 (single_observation)
#
# LABORATORY VALUES:
#   Ptt: mean=45.60, last=45.60 (single_observation)
#
# INTERVENTIONS:
#   Medications: dextrose_5, po_intake, heparin_sodium
#   Procedures: 20_gauge, 18_gauge
#
# ## CANDIDATE DIAGNOSES
# Consider these 3 possibilities (listed in no particular order):
# - ACUTE_MI
# - SEPSIS
# - HEART_FAILURE
#
#
# ## YOUR TASK
# You are working with INCOMPLETE ICU data. Not all clinically relevant labs will be present. Your goal is to find the diagnosis most consistent with available evidence, explicitly accounting for what is and is not measured. A diagnosis should not be dismissed solely because its defining marker was not collected.
#
#
# Respond with ONLY valid JSON:
# {
#   "chosen_diagnosis": "DIAGNOSIS_NAME",
#   "reasoning": "2-3 sentence explanation of why this diagnosis fits best",
#   "supporting_evidence": ["key finding 1", "key finding 2", "key finding 3"],
#   "ruled_out": [
#     {"diagnosis": "OTHER_DIAGNOSIS_1", "reason": "why ruled out"},
#     {"diagnosis": "OTHER_DIAGNOSIS_2", "reason": "why ruled out"}
#   ]
# }
#
# Your chosen_diagnosis MUST be one of the 3 candidates listed above.
#
#
# ── STEP F: RAW LLM RESPONSE (parsed JSON) ──
# {
#   "chosen_diagnosis": "SEPSIS",
#   "reasoning": "The patient exhibits worsening vital signs, specifically increasing heart rate and respiratory rate, despite relatively stable oxygen saturation and blood pressure. While specific inflammatory markers or lactate are missing, the overall trend suggests a systemic process like sepsis, which can present with subtle hemodynamic changes initially. The presence of heparin suggests a potential underlying condition like DVT/PE, which can also trigger sepsis.",
#   "supporting_evidence": [
#     "Worsening heart rate (mean 88.4 -> last 96.0)",
#     "Worsening respiratory rate (mean 17.4 -> last 16.0)",
#     "Heparin administration (suggests potential source/risk factor)"
#   ],
#   "ruled_out": [
#     {
#       "diagnosis": "ACUTE_MI",
#       "reason": "No specific ECG changes, troponin levels, or chest pain reported; vital sign changes are non-specific."
#     },
#     {
#       "diagnosis": "HEART_FAILURE",
#       "reason": "Blood pressure is relatively stable, and there's no mention of JVD, edema, or specific cardiac enzyme elevation; worsening RR/HR could be due to other causes."
#     }
#   ]
# }
#
# ── OUTCOME ──
#   LightGBM top pick : ACUTE_MI ✓
#   Agent pick        : SEPSIS ✗  (OVERRIDE)
#
# ══════════════════════════════════════════════════════════════════════════════
# CASE [72/100]  Patient 14947978  |  True: ACUTE_MI
# ══════════════════════════════════════════════════════════════════════════════
#
# ── STEP A: agent-safe card (top-level keys) ──
#   keys: ['clinical_summary', 'feature_names', 'patient_id', 'stay_id', 'time_series', 'visit_id']
#
# ── STEP B: LightGBM top-K (probs shown for reference — NOT shown to agent) ──
#   1. ACUTE_MI                   50.0%
#   2. CORONARY_ARTERY_DZ         33.7%
#   3. SEPSIS                      7.5%
#
# ── STEP C: shuffled candidate order shown to agent (blinded) ──
#   ACUTE_MI | CORONARY_ARTERY_DZ | SEPSIS
#
# ── STEP D: formatted clinical summary ──
# VITAL SIGNS (Last 12 Hours):
#   Heart Rate: mean=84.4, range=[71.0–97.0], last=75.0 (improving)
#   Respiratory Rate: mean=17.0, range=[12.0–21.0], last=17.0 (worsening)
#   O2 Saturation Pulseoxymetry: mean=95.5, range=[92.0–99.0], last=92.0 (stable)
#   Non Invasive Blood Pressure Systolic: mean=107.8, range=[93.0–128.0], last=93.0 (improving)
#   Non Invasive Blood Pressure Diastolic: mean=59.2, range=[54.0–63.0], last=60.0 (stable)
#   Non Invasive Blood Pressure Mean: mean=73.9, range=[67.0–80.0], last=71.0 (improving)
#   Temperature Fahrenheit: mean=99.4, range=[98.9–99.6], last=98.9 (stable)
#   Glucose Finger Stick: mean=90.3, range=[90.0–91.0], last=90.0 (stable)
#   Heart Rate Alarm Low: mean=60.0, range=[60.0–60.0], last=60.0 (single_observation)
#   Heart Rate Alarm High: mean=120.0, range=[120.0–120.0], last=120.0 (single_observation)
#   O2 Saturation Pulseoxymetry Alarm Low: mean=90.0, range=[90.0–90.0], last=90.0 (single_observation)
#   O2 Saturation Pulseoxymetry Alarm High: mean=100.0, range=[100.0–100.0], last=100.0 (single_observation)
#   Spo2 Desat Limit: mean=85.0, range=[85.0–85.0], last=85.0 (single_observation)
#   Resp Alarm High: mean=35.0, range=[35.0–35.0], last=35.0 (single_observation)
#   Resp Alarm Low: mean=8.0, range=[8.0–8.0], last=8.0 (single_observation)
#   O2 Flow: mean=2.0, range=[2.0–2.0], last=2.0 (single_observation)
#   Non Invasive Blood Pressure Alarm Low: mean=90.0, range=[90.0–90.0], last=90.0 (single_observation)
#   Non Invasive Blood Pressure Alarm High: mean=150.0, range=[150.0–150.0], last=150.0 (single_observation)
#
# LABORATORY VALUES:
#
# INTERVENTIONS:
#   Medications: po_intake
#   Procedures: 18_gauge
#
# ── STEP E: FULL PROMPT SENT TO LLM ──
#
# You are an expert ICU physician. You are given patient data and 3 possible diagnoses to consider. Your task is to determine which diagnosis best fits the clinical picture.
#
# ## PATIENT DATA (Last 12 Hours in ICU)
# VITAL SIGNS (Last 12 Hours):
#   Heart Rate: mean=84.4, range=[71.0–97.0], last=75.0 (improving)
#   Respiratory Rate: mean=17.0, range=[12.0–21.0], last=17.0 (worsening)
#   O2 Saturation Pulseoxymetry: mean=95.5, range=[92.0–99.0], last=92.0 (stable)
#   Non Invasive Blood Pressure Systolic: mean=107.8, range=[93.0–128.0], last=93.0 (improving)
#   Non Invasive Blood Pressure Diastolic: mean=59.2, range=[54.0–63.0], last=60.0 (stable)
#   Non Invasive Blood Pressure Mean: mean=73.9, range=[67.0–80.0], last=71.0 (improving)
#   Temperature Fahrenheit: mean=99.4, range=[98.9–99.6], last=98.9 (stable)
#   Glucose Finger Stick: mean=90.3, range=[90.0–91.0], last=90.0 (stable)
#   Heart Rate Alarm Low: mean=60.0, range=[60.0–60.0], last=60.0 (single_observation)
#   Heart Rate Alarm High: mean=120.0, range=[120.0–120.0], last=120.0 (single_observation)
#   O2 Saturation Pulseoxymetry Alarm Low: mean=90.0, range=[90.0–90.0], last=90.0 (single_observation)
#   O2 Saturation Pulseoxymetry Alarm High: mean=100.0, range=[100.0–100.0], last=100.0 (single_observation)
#   Spo2 Desat Limit: mean=85.0, range=[85.0–85.0], last=85.0 (single_observation)
#   Resp Alarm High: mean=35.0, range=[35.0–35.0], last=35.0 (single_observation)
#   Resp Alarm Low: mean=8.0, range=[8.0–8.0], last=8.0 (single_observation)
#   O2 Flow: mean=2.0, range=[2.0–2.0], last=2.0 (single_observation)
#   Non Invasive Blood Pressure Alarm Low: mean=90.0, range=[90.0–90.0], last=90.0 (single_observation)
#   Non Invasive Blood Pressure Alarm High: mean=150.0, range=[150.0–150.0], last=150.0 (single_observation)
#
# LABORATORY VALUES:
#
# INTERVENTIONS:
#   Medications: po_intake
#   Procedures: 18_gauge
#
# ## CANDIDATE DIAGNOSES
# Consider these 3 possibilities (listed in no particular order):
# - ACUTE_MI
# - CORONARY_ARTERY_DZ
# - SEPSIS
#
#
# ## YOUR TASK
# You are working with INCOMPLETE ICU data. Not all clinically relevant labs will be present. Your goal is to find the diagnosis most consistent with available evidence, explicitly accounting for what is and is not measured. A diagnosis should not be dismissed solely because its defining marker was not collected.
#
#
# Respond with ONLY valid JSON:
# {
#   "chosen_diagnosis": "DIAGNOSIS_NAME",
#   "reasoning": "2-3 sentence explanation of why this diagnosis fits best",
#   "supporting_evidence": ["key finding 1", "key finding 2", "key finding 3"],
#   "ruled_out": [
#     {"diagnosis": "OTHER_DIAGNOSIS_1", "reason": "why ruled out"},
#     {"diagnosis": "OTHER_DIAGNOSIS_2", "reason": "why ruled out"}
#   ]
# }
#
# Your chosen_diagnosis MUST be one of the 3 candidates listed above.
#
#
# ── STEP F: RAW LLM RESPONSE (parsed JSON) ──
# {
#   "chosen_diagnosis": "SEPSIS",
#   "reasoning": "The patient presents with a worsening respiratory rate despite relatively stable oxygen saturation and improving hemodynamics, which can be an early sign of sepsis. While definitive markers like lactate or white blood cell count are missing, the overall picture is most suggestive of sepsis among the choices, as acute MI and coronary artery disease typically present with more pronounced hemodynamic instability or chest pain (not mentioned).",
#   "supporting_evidence": [
#     "Worsening respiratory rate (mean 17.0, last 17.0)",
#     "Stable oxygen saturation (mean 95.5, last 92.0)",
#     "Improving hemodynamics (mean BP improving, HR improving)"
#   ],
#   "ruled_out": [
#     {
#       "diagnosis": "ACUTE_MI",
#       "reason": "No mention of chest pain, ECG changes, or significant hemodynamic instability typically associated with acute MI."
#     },
#     {
#       "diagnosis": "CORONARY_ARTERY_DZ",
#       "reason": "This is a chronic condition, not an acute presentation. While the patient might have underlying CAD, the current clinical picture doesn't specifically point to it as the primary acute diagnosis."
#     }
#   ]
# }
#
# ── OUTCOME ──
#   LightGBM top pick : ACUTE_MI ✓
#   Agent pick        : SEPSIS ✗  (OVERRIDE)
#
# ══════════════════════════════════════════════════════════════════════════════
# CASE [73/100]  Patient 19341048  |  True: ACUTE_MI
# ══════════════════════════════════════════════════════════════════════════════
#
# ── STEP A: agent-safe card (top-level keys) ──
#   keys: ['clinical_summary', 'feature_names', 'patient_id', 'stay_id', 'time_series', 'visit_id']
#
# ── STEP B: LightGBM top-K (probs shown for reference — NOT shown to agent) ──
#   1. SEPSIS                     66.5%
#   2. CORONARY_ARTERY_DZ         12.4%
#   3. ACUTE_MI                   12.1%
#
# ── STEP C: shuffled candidate order shown to agent (blinded) ──
#   ACUTE_MI | CORONARY_ARTERY_DZ | SEPSIS
#
# ── STEP D: formatted clinical summary ──
# VITAL SIGNS (Last 12 Hours):
#   Heart Rate: mean=115.4, range=[102.0–139.0], last=109.0 (improving)
#   Respiratory Rate: mean=13.2, range=[10.0–19.0], last=13.0 (stable)
#   O2 Saturation Pulseoxymetry: mean=95.5, range=[93.0–98.0], last=96.0 (stable)
# ...
#   "supporting_evidence": [
#     "Worsening diastolic blood pressure (mean 58.1, last 66.0)",
#     "Elevated Creatinine (1.70) and Urea Nitrogen (45.00)",
#     "Stable but low-normal mean arterial pressure (mean 71.9)"
#   ],
#   "ruled_out": [
#     {
#       "diagnosis": "ACUTE_MI",
#       "reason": "No specific ECG changes, troponin levels, or chest pain reported; vital signs are relatively stable without significant tachycardia or hypertension typically seen in acute MI."
#     },
#     {
#       "diagnosis": "CORONARY_ARTERY_DZ",
#       "reason": "This is a chronic condition, and while potentially underlying, the acute presentation doesn't strongly point to it over heart failure without more specific evidence like angina or ECG changes."
#     }
#   ]
# }
#
# ── OUTCOME ──
#   LightGBM top pick : HEART_FAILURE ✓
#   Agent pick        : HEART_FAILURE ✓  (ACCEPT)
#
# ══════════════════════════════════════════════════════════════════════════════
# CASE [99/100]  Patient 13859166  |  True: STROKE_NEURO
# ══════════════════════════════════════════════════════════════════════════════
#
# ── STEP A: agent-safe card (top-level keys) ──
#   keys: ['clinical_summary', 'feature_names', 'patient_id', 'stay_id', 'time_series', 'visit_id']
#
# ── STEP B: LightGBM top-K (probs shown for reference — NOT shown to agent) ──
#   1. STROKE_NEURO               98.9%
#   2. SEPSIS                      0.4%
#   3. HEART_FAILURE               0.4%
#
# ── STEP C: shuffled candidate order shown to agent (blinded) ──
#   SEPSIS | STROKE_NEURO | HEART_FAILURE
#
# ── STEP D: formatted clinical summary ──
# VITAL SIGNS (Last 12 Hours):
#   Heart Rate: mean=79.3, range=[68.0–93.0], last=85.0 (stable)
#   O2 Saturation Pulseoxymetry: mean=92.9, range=[91.0–94.0], last=94.0 (stable)
#   Non Invasive Blood Pressure Systolic: mean=158.2, range=[154.0–163.0], last=163.0 (stable)
#   Non Invasive Blood Pressure Diastolic: mean=95.1, range=[78.0–111.0], last=105.0 (worsening)
#   Non Invasive Blood Pressure Mean: mean=112.3, range=[104.0–125.0], last=114.0 (stable)
#   Temperature Fahrenheit: mean=98.0, range=[97.9–98.2], last=97.9 (stable)
#   Glucose Finger Stick: mean=89.0, range=[84.0–94.0], last=84.0 (improving)
#   Heart Rate Alarm Low: mean=40.0, range=[40.0–40.0], last=40.0 (stable)
#   Heart Rate Alarm High: mean=130.0, range=[130.0–130.0], last=130.0 (stable)
#   O2 Saturation Pulseoxymetry Alarm Low: mean=88.0, range=[88.0–88.0], last=88.0 (stable)
#   O2 Saturation Pulseoxymetry Alarm High: mean=100.0, range=[100.0–100.0], last=100.0 (stable)
#   Spo2 Desat Limit: mean=87.0, range=[87.0–87.0], last=87.0 (stable)
#   Resp Alarm High: mean=22.0, range=[22.0–22.0], last=22.0 (stable)
#   Resp Alarm Low: mean=7.0, range=[7.0–7.0], last=7.0 (stable)
#   Non Invasive Blood Pressure Alarm Low: mean=100.0, range=[100.0–100.0], last=100.0 (stable)
#   Non Invasive Blood Pressure Alarm High: mean=220.0, range=[220.0–220.0], last=220.0 (stable)
#
# LABORATORY VALUES:
#
# INTERVENTIONS:
#   Medications: po_intake
#   Procedures: 20_gauge
#
# ── STEP E: FULL PROMPT SENT TO LLM ──
#
# You are an expert ICU physician. You are given patient data and 3 possible diagnoses to consider. Your task is to determine which diagnosis best fits the clinical picture.
#
# ## PATIENT DATA (Last 12 Hours in ICU)
# VITAL SIGNS (Last 12 Hours):
#   Heart Rate: mean=79.3, range=[68.0–93.0], last=85.0 (stable)
#   O2 Saturation Pulseoxymetry: mean=92.9, range=[91.0–94.0], last=94.0 (stable)
#   Non Invasive Blood Pressure Systolic: mean=158.2, range=[154.0–163.0], last=163.0 (stable)
#   Non Invasive Blood Pressure Diastolic: mean=95.1, range=[78.0–111.0], last=105.0 (worsening)
#   Non Invasive Blood Pressure Mean: mean=112.3, range=[104.0–125.0], last=114.0 (stable)
#   Temperature Fahrenheit: mean=98.0, range=[97.9–98.2], last=97.9 (stable)
#   Glucose Finger Stick: mean=89.0, range=[84.0–94.0], last=84.0 (improving)
#   Heart Rate Alarm Low: mean=40.0, range=[40.0–40.0], last=40.0 (stable)
#   Heart Rate Alarm High: mean=130.0, range=[130.0–130.0], last=130.0 (stable)
#   O2 Saturation Pulseoxymetry Alarm Low: mean=88.0, range=[88.0–88.0], last=88.0 (stable)
#   O2 Saturation Pulseoxymetry Alarm High: mean=100.0, range=[100.0–100.0], last=100.0 (stable)
#   Spo2 Desat Limit: mean=87.0, range=[87.0–87.0], last=87.0 (stable)
#   Resp Alarm High: mean=22.0, range=[22.0–22.0], last=22.0 (stable)
#   Resp Alarm Low: mean=7.0, range=[7.0–7.0], last=7.0 (stable)
#   Non Invasive Blood Pressure Alarm Low: mean=100.0, range=[100.0–100.0], last=100.0 (stable)
#   Non Invasive Blood Pressure Alarm High: mean=220.0, range=[220.0–220.0], last=220.0 (stable)
#
# LABORATORY VALUES:
#
# INTERVENTIONS:
#   Medications: po_intake
#   Procedures: 20_gauge
#
# ## CANDIDATE DIAGNOSES
# Consider these 3 possibilities (listed in no particular order):
# - SEPSIS
# - STROKE_NEURO
# - HEART_FAILURE
#
#
# ## YOUR TASK
# You are working with INCOMPLETE ICU data. Not all clinically relevant labs will be present. Your goal is to find the diagnosis most consistent with available evidence, explicitly accounting for what is and is not measured. A diagnosis should not be dismissed solely because its defining marker was not collected.
#
#
# Respond with ONLY valid JSON:
# {
#   "chosen_diagnosis": "DIAGNOSIS_NAME",
#   "reasoning": "2-3 sentence explanation of why this diagnosis fits best",
#   "supporting_evidence": ["key finding 1", "key finding 2", "key finding 3"],
#   "ruled_out": [
#     {"diagnosis": "OTHER_DIAGNOSIS_1", "reason": "why ruled out"},
#     {"diagnosis": "OTHER_DIAGNOSIS_2", "reason": "why ruled out"}
#   ]
# }
#
# Your chosen_diagnosis MUST be one of the 3 candidates listed above.
#
#
# ── STEP F: RAW LLM RESPONSE (parsed JSON) ──
# {
#   "chosen_diagnosis": "STROKE_NEURO",
#   "reasoning": "The patient presents with significantly elevated systolic blood pressure (mean 158.2, last 163.0) and diastolic blood pressure (mean 95.1, last 105.0), suggesting hypertensive urgency or emergency, a common finding in acute stroke. While other vital signs are relatively stable, the marked hypertension without clear signs of sepsis (stable temperature, relatively stable HR/O2 sat) or heart failure (no mention of edema, JVD, or respiratory distress beyond baseline) points towards a neurological event like stroke.",
#   "supporting_evidence": [
#     "Elevated Systolic Blood Pressure (mean 158.2, last 163.0)",
#     "Elevated Diastolic Blood Pressure (mean 95.1, last 105.0)",
#     "Relatively stable heart rate and oxygen saturation"
#   ],
#   "ruled_out": [
#     {
#       "diagnosis": "SEPSIS",
#       "reason": "Lack of fever (temperature stable at 98.0F), stable heart rate, and stable oxygen saturation make sepsis less likely, although it cannot be definitively ruled out without more labs (e.g., WBC, lactate, cultures)."
#     },
#     {
#       "diagnosis": "HEART_FAILURE",
#       "reason": "No specific signs of heart failure are present in the provided data (e.g., respiratory distress, edema, JVD). While hypertension can be associated with heart failure, the overall picture is more suggestive of a primary neurological event."
#     }
#   ]
# }
#
# ── OUTCOME ──
#   LightGBM top pick : STROKE_NEURO ✓
#   Agent pick        : STROKE_NEURO ✓  (ACCEPT)
#
# ══════════════════════════════════════════════════════════════════════════════
# CASE [100/100]  Patient 15277035  |  True: CORONARY_ARTERY_DZ
# ══════════════════════════════════════════════════════════════════════════════
#
# ── STEP A: agent-safe card (top-level keys) ──
#   keys: ['clinical_summary', 'feature_names', 'patient_id', 'stay_id', 'time_series', 'visit_id']
#
# ── STEP B: LightGBM top-K (probs shown for reference — NOT shown to agent) ──
#   1. ACUTE_MI                   52.4%
#   2. CORONARY_ARTERY_DZ         31.7%
#   3. STROKE_NEURO                8.2%
#
# ── STEP C: shuffled candidate order shown to agent (blinded) ──
#   CORONARY_ARTERY_DZ | STROKE_NEURO | ACUTE_MI
#
# ── STEP D: formatted clinical summary ──
# VITAL SIGNS (Last 12 Hours):
#   Heart Rate: mean=78.9, range=[75.0–83.0], last=81.0 (stable)
#   Respiratory Rate: mean=20.8, range=[17.0–28.0], last=17.0 (improving)
#   O2 Saturation Pulseoxymetry: mean=99.5, range=[98.0–100.0], last=98.0 (stable)
#   Non Invasive Blood Pressure Systolic: mean=132.0, range=[118.0–153.0], last=129.0 (stable)
#   Non Invasive Blood Pressure Diastolic: mean=65.7, range=[56.5–77.0], last=67.0 (worsening)
#   Non Invasive Blood Pressure Mean: mean=82.0, range=[70.0–93.0], last=83.0 (worsening)
#   Arterial Blood Pressure Mean: mean=84.0, range=[83.0–85.0], last=85.0 (stable)
#   Arterial Blood Pressure Systolic: mean=138.0, range=[137.0–139.0], last=139.0 (stable)
#   Arterial Blood Pressure Diastolic: mean=58.0, range=[57.0–59.0], last=59.0 (stable)
#   Temperature Fahrenheit: mean=98.5, range=[98.4–98.7], last=98.7 (stable)
#   Heart Rate Alarm Low: mean=60.0, range=[60.0–60.0], last=60.0 (single_observation)
#   Heart Rate Alarm High: mean=120.0, range=[120.0–120.0], last=120.0 (single_observation)
#   O2 Saturation Pulseoxymetry Alarm Low: mean=92.0, range=[92.0–92.0], last=92.0 (single_observation)
#   O2 Saturation Pulseoxymetry Alarm High: mean=100.0, range=[100.0–100.0], last=100.0 (single_observation)
#   Spo2 Desat Limit: mean=85.0, range=[85.0–85.0], last=85.0 (single_observation)
#   Resp Alarm High: mean=35.0, range=[35.0–35.0], last=35.0 (single_observation)
#   Resp Alarm Low: mean=8.0, range=[8.0–8.0], last=8.0 (single_observation)
#   Sodium: mean=131.7, range=[129.0–134.0], last=132.0 (stable)
#   Non Invasive Blood Pressure Alarm Low: mean=90.0, range=[90.0–90.0], last=90.0 (single_observation)
#   Non Invasive Blood Pressure Alarm High: mean=160.0, range=[160.0–160.0], last=160.0 (single_observation)
#   Chloride: mean=101.0, range=[99.0–104.0], last=100.0 (stable)
#   Anion Gap: mean=12.0, range=[12.0–12.0], last=12.0 (single_observation)
#
# LABORATORY VALUES:
#   Potassium: mean=5.53, last=4.90 (stable)
#   Sodium: mean=131.67, last=132.00 (stable)
#   Chloride: mean=101.00, last=100.00 (stable)
#   Creatinine: mean=0.83, last=0.80 (stable)
#   Urea Nitrogen: mean=15.75, last=16.00 (stable)
#   Bicarbonate: mean=25.00, last=25.00 (single_observation)
#   Anion Gap: mean=12.00, last=12.00 (single_observation)
#   Glucose: mean=171.50, last=189.00 (worsening)
#   Magnesium: mean=2.00, last=1.90 (stable)
#   Hematocrit: mean=28.50, last=28.10 (stable)
#   Phosphate: mean=4.60, last=4.60 (single_observation)
#   Calcium Total: mean=8.50, last=8.50 (single_observation)
#
# INTERVENTIONS:
#   Medications: dextrose_5, po_intake
#   Procedures: 20_gauge, 18_gauge, foley_catheter, arterial_line, multi_lumen
#
# ── STEP E: FULL PROMPT SENT TO LLM ──
#
# You are an expert ICU physician. You are given patient data and 3 possible diagnoses to consider. Your task is to determine which diagnosis best fits the clinical picture.
#
# ## PATIENT DATA (Last 12 Hours in ICU)
# VITAL SIGNS (Last 12 Hours):
#   Heart Rate: mean=78.9, range=[75.0–83.0], last=81.0 (stable)
#   Respiratory Rate: mean=20.8, range=[17.0–28.0], last=17.0 (improving)
#   O2 Saturation Pulseoxymetry: mean=99.5, range=[98.0–100.0], last=98.0 (stable)
#   Non Invasive Blood Pressure Systolic: mean=132.0, range=[118.0–153.0], last=129.0 (stable)
#   Non Invasive Blood Pressure Diastolic: mean=65.7, range=[56.5–77.0], last=67.0 (worsening)
#   Non Invasive Blood Pressure Mean: mean=82.0, range=[70.0–93.0], last=83.0 (worsening)
#   Arterial Blood Pressure Mean: mean=84.0, range=[83.0–85.0], last=85.0 (stable)
#   Arterial Blood Pressure Systolic: mean=138.0, range=[137.0–139.0], last=139.0 (stable)
#   Arterial Blood Pressure Diastolic: mean=58.0, range=[57.0–59.0], last=59.0 (stable)
#   Temperature Fahrenheit: mean=98.5, range=[98.4–98.7], last=98.7 (stable)
#   Heart Rate Alarm Low: mean=60.0, range=[60.0–60.0], last=60.0 (single_observation)
#   Heart Rate Alarm High: mean=120.0, range=[120.0–120.0], last=120.0 (single_observation)
#   O2 Saturation Pulseoxymetry Alarm Low: mean=92.0, range=[92.0–92.0], last=92.0 (single_observation)
#   O2 Saturation Pulseoxymetry Alarm High: mean=100.0, range=[100.0–100.0], last=100.0 (single_observation)
#   Spo2 Desat Limit: mean=85.0, range=[85.0–85.0], last=85.0 (single_observation)
#   Resp Alarm High: mean=35.0, range=[35.0–35.0], last=35.0 (single_observation)
#   Resp Alarm Low: mean=8.0, range=[8.0–8.0], last=8.0 (single_observation)
#   Sodium: mean=131.7, range=[129.0–134.0], last=132.0 (stable)
#   Non Invasive Blood Pressure Alarm Low: mean=90.0, range=[90.0–90.0], last=90.0 (single_observation)
#   Non Invasive Blood Pressure Alarm High: mean=160.0, range=[160.0–160.0], last=160.0 (single_observation)
#   Chloride: mean=101.0, range=[99.0–104.0], last=100.0 (stable)
#   Anion Gap: mean=12.0, range=[12.0–12.0], last=12.0 (single_observation)
#
# LABORATORY VALUES:
#   Potassium: mean=5.53, last=4.90 (stable)
#   Sodium: mean=131.67, last=132.00 (stable)
#   Chloride: mean=101.00, last=100.00 (stable)
#   Creatinine: mean=0.83, last=0.80 (stable)
#   Urea Nitrogen: mean=15.75, last=16.00 (stable)
#   Bicarbonate: mean=25.00, last=25.00 (single_observation)
#   Anion Gap: mean=12.00, last=12.00 (single_observation)
#   Glucose: mean=171.50, last=189.00 (worsening)
#   Magnesium: mean=2.00, last=1.90 (stable)
#   Hematocrit: mean=28.50, last=28.10 (stable)
#   Phosphate: mean=4.60, last=4.60 (single_observation)
#   Calcium Total: mean=8.50, last=8.50 (single_observation)
#
# INTERVENTIONS:
#   Medications: dextrose_5, po_intake
#   Procedures: 20_gauge, 18_gauge, foley_catheter, arterial_line, multi_lumen
#
# ## CANDIDATE DIAGNOSES
# Consider these 3 possibilities (listed in no particular order):
# - CORONARY_ARTERY_DZ
# - STROKE_NEURO
# - ACUTE_MI
#
#
# ## YOUR TASK
# You are working with INCOMPLETE ICU data. Not all clinically relevant labs will be present. Your goal is to find the diagnosis most consistent with available evidence, explicitly accounting for what is and is not measured. A diagnosis should not be dismissed solely because its defining marker was not collected.
#
#
# Respond with ONLY valid JSON:
# {
#   "chosen_diagnosis": "DIAGNOSIS_NAME",
#   "reasoning": "2-3 sentence explanation of why this diagnosis fits best",
#   "supporting_evidence": ["key finding 1", "key finding 2", "key finding 3"],
#   "ruled_out": [
#     {"diagnosis": "OTHER_DIAGNOSIS_1", "reason": "why ruled out"},
#     {"diagnosis": "OTHER_DIAGNOSIS_2", "reason": "why ruled out"}
#   ]
# }
#
# Your chosen_diagnosis MUST be one of the 3 candidates listed above.
#
#
# ── STEP F: RAW LLM RESPONSE (parsed JSON) ──
# {
#   "chosen_diagnosis": "CORONARY_ARTERY_DZ",
#   "reasoning": "The patient presents with worsening hyperglycemia (glucose 189.00) and stable but slightly elevated potassium (5.53), which can be associated with stress response or underlying cardiac issues. While vital signs are relatively stable, the overall picture lacks specific evidence for stroke or acute MI, making coronary artery disease a more plausible underlying condition contributing to the current state.",
#   "supporting_evidence": [
#     "Worsening hyperglycemia (glucose 189.00)",
#     "Slightly elevated potassium (5.53)",
#     "Presence of arterial line and foley catheter suggests critical illness potentially related to cardiovascular compromise"
#   ],
#   "ruled_out": [
#     {
#       "diagnosis": "STROKE_NEURO",
#       "reason": "No focal neurological deficits or specific stroke-related labs (e.g., D-dimer, imaging) are mentioned."
#     },
#     {
#       "diagnosis": "ACUTE_MI",
#       "reason": "No specific cardiac markers (e.g., troponin) or ECG findings are provided, and vital signs are relatively stable without clear signs of acute myocardial infarction."
#     }
#   ]
# }
#
# ── OUTCOME ──
#   LightGBM top pick : ACUTE_MI ✗
#   Agent pick        : CORONARY_ARTERY_DZ ✓  (OVERRIDE)
#
# ==============================================================================
# Pilot complete — elapsed: 1:34:43.584487
# Valid: 100/100

# %% [markdown]
# ## 19. Compute Metrics

# %%
import pandas as pd

valid_results = [r for r in results if 'error' not in r]
print(f'Valid results: {len(valid_results)}/{len(results)}')

disagree_cases = []
if valid_results:
    n = len(valid_results)

    lgb_correct   = sum(r['lstm_correct']  for r in valid_results)
    agent_correct = sum(r['agent_correct'] for r in valid_results)

    both_correct   = sum(r['lstm_correct']     and r['agent_correct']     for r in valid_results)
    agent_improved = sum(not r['lstm_correct'] and r['agent_correct']     for r in valid_results)
    agent_hurt     = sum(r['lstm_correct']     and not r['agent_correct'] for r in valid_results)
    both_wrong     = sum(not r['lstm_correct'] and not r['agent_correct'] for r in valid_results)

    disagreements = sum(r['agent_disagrees'] for r in valid_results)
    true_in_topk  = sum(r['true_label'] in r['lstm_output']['top_k_codes'] for r in valid_results)

    print(f'\n{"\u2550" * 60}')
    print(f'TOP-5 LIGHTGBM + BLINDED AGENT RESULTS ({n} cases, top-{TOP_K_DEBATE})')
    print(f'{"\u2550" * 60}')
    print(f'\nAccuracy:')
    print(f'  LightGBM Top-1 : {lgb_correct}/{n} ({lgb_correct/n*100:.1f}%)')
    print(f'  Agent          : {agent_correct}/{n} ({agent_correct/n*100:.1f}%)')
    print(f'  Improvement    : {(agent_correct - lgb_correct)/n*100:+.1f}%')
    print(f'\nTrue in top-{TOP_K_DEBATE}: {true_in_topk}/{n} ({true_in_topk/n*100:.1f}%)')
    print(f'Agent disagreed: {disagreements}/{n} ({disagreements/n*100:.1f}%)')
    print(f'\nCase Breakdown:')
    print(f'  Both correct    : {both_correct} ({both_correct/n*100:.1f}%)')
    print(f'  Agent improved  : {agent_improved} ({agent_improved/n*100:.1f}%) \U0001f389')
    print(f'  Agent hurt      : {agent_hurt} ({agent_hurt/n*100:.1f}%) \u26a0\ufe0f')
    print(f'  Both wrong      : {both_wrong} ({both_wrong/n*100:.1f}%)')
    print(f'\nNet: {agent_improved - agent_hurt:+d} cases')

    disagree_cases = [r for r in valid_results if r['agent_disagrees']]

    # Results table
    table_data = []
    for r in valid_results:
        table_data.append({
            'Patient ID'      : r['patient_id'],
            'True Label'      : r['true_label'],
            'LightGBM Top-1'  : r['lstm_top_pick'],
            'LGB Confidence'  : f"{r['lstm_output']['top_k_probs'][0]:.1%}",
            'Agent Pick'      : r['agent_prediction'],
            'Decision'        : r['agent_decision'].upper(),
            'Agent Result'    : 'CORRECT' if r['agent_correct'] else 'INCORRECT',
        })
    df_results = pd.DataFrame(table_data)
    print('\nResults table:')
    display(df_results)
# Out:
# Valid results: 100/100
#
# ════════════════════════════════════════════════════════════
# TOP-5 LIGHTGBM + BLINDED AGENT RESULTS (100 cases, top-3)
# ════════════════════════════════════════════════════════════
#
# Accuracy:
#   LightGBM Top-1 : 72/100 (72.0%)
#   Agent          : 41/100 (41.0%)
#   Improvement    : -31.0%
#
# True in top-3: 98/100 (98.0%)
# Agent disagreed: 63/100 (63.0%)
#
# Case Breakdown:
#   Both correct    : 30 (30.0%)
#   Agent improved  : 11 (11.0%) 🎉
#   Agent hurt      : 42 (42.0%) ⚠️
#   Both wrong      : 17 (17.0%)
#
# Net: -31 cases
#
# Results table:
#    Patient ID          True Label LightGBM Top-1 LGB Confidence  \
# 0    17829884              SEPSIS         SEPSIS          72.1%
# 1    19833452              SEPSIS         SEPSIS          81.7%
# 2    11693201              SEPSIS         SEPSIS          74.3%
# 3    18958916              SEPSIS         SEPSIS          93.7%
# 4    13789582              SEPSIS         SEPSIS          89.3%
# ..        ...                 ...            ...            ...
# 95   19339132       HEART_FAILURE       ACUTE_MI          37.0%
# 96   13177098       HEART_FAILURE  HEART_FAILURE          93.5%
# 97   14428310       HEART_FAILURE  HEART_FAILURE          49.9%
# 98   13859166        STROKE_NEURO   STROKE_NEURO          98.9%
# 99   15277035  CORONARY_ARTERY_DZ       ACUTE_MI          52.4%
#
#             Agent Pick  Decision Agent Result
# 0               SEPSIS    ACCEPT      CORRECT
# 1               SEPSIS    ACCEPT      CORRECT
# 2               SEPSIS    ACCEPT      CORRECT
# 3               SEPSIS    ACCEPT      CORRECT
# 4               SEPSIS    ACCEPT      CORRECT
# ..                 ...       ...          ...
# 95              SEPSIS  OVERRIDE    INCORRECT
# 96              SEPSIS  OVERRIDE    INCORRECT
# 97       HEART_FAILURE    ACCEPT      CORRECT
# 98        STROKE_NEURO    ACCEPT      CORRECT
# 99  CORONARY_ARTERY_DZ  OVERRIDE      CORRECT
#
# [100 rows x 7 columns]

# %% [markdown]
# ## 20. Save Agent Results

# %%
import json as _json

def to_python(obj):
    if isinstance(obj, (bool,)):         return bool(obj)
    if hasattr(obj, 'item'):             return obj.item()
    if isinstance(obj, dict):            return {k: to_python(v) for k, v in obj.items()}
    if isinstance(obj, (list, tuple)):   return [to_python(v) for v in obj]
    return obj

agent_results_path = f'{AGENT_OUTPUT_DIR}/agent_results.json'
with open(agent_results_path, 'w') as f:
    _json.dump({
        'model'           : MEDGEMMA_MODEL_ID,
        'condition'       : 'blinded',
        'classifier'      : 'LightGBM-TOP5',
        'n_cases'         : len(valid_results),
        'lgb_top1_acc'    : lgb_correct / n if valid_results else None,
        'agent_top1_acc'  : agent_correct / n if valid_results else None,
        'results'         : to_python(valid_results),
    }, f, indent=2)

df_results.to_csv(f'{AGENT_OUTPUT_DIR}/agent_results.csv', index=False)
print(f'\u2713 Agent results saved to {AGENT_OUTPUT_DIR}')
# Out:
# ✓ Agent results saved to /content/drive/MyDrive/702 project/TOP5_lgb_agent_blinded_results
