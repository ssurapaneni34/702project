# %% [markdown]
# <a href="https://colab.research.google.com/github/ssurapaneni34/702project/blob/main/preprocessing_702.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Data documentation: https://mimic.mit.edu/docs/iv/modules/icu/

# %%
import os
import pandas as pd

mimic_path = '/content/drive/MyDrive/702 project/mimic_data'

print("Files in directory:", os.listdir(mimic_path))
# Out:
# Files in directory: ['icu', 'hosp']

# %%
# Load a specific table
# Note: MIMIC files are often compressed (.csv.gz)
try:
    patients_df = pd.read_csv(f'{mimic_path}/hosp/diagnoses_icd.csv.gz')

    print(patients_df.info())
    print(patients_df.head(20))

except FileNotFoundError:
    print("Check your file path and ensure the shortcut is correctly named.")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6364488 entries, 0 to 6364487
# Data columns (total 5 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   subject_id   int64
#  1   hadm_id      int64
#  2   seq_num      int64
#  3   icd_code     object
#  4   icd_version  int64
# dtypes: int64(4), object(1)
# memory usage: 242.8+ MB
# None
#     subject_id   hadm_id  seq_num icd_code  icd_version
# 0     10000032  22595853        1     5723            9
# 1     10000032  22595853        2    78959            9
# 2     10000032  22595853        3     5715            9
# 3     10000032  22595853        4    07070            9
# 4     10000032  22595853        5      496            9
# 5     10000032  22595853        6    29680            9
# 6     10000032  22595853        7    30981            9
# 7     10000032  22595853        8    V1582            9
# 8     10000032  22841357        1    07071            9
# ...

# %% [markdown]
# *   chartevents table for timestamps
# *   seq_num, icd_code in diagnoses_icd (choose seq_num = 1 for the most important icd code)
#
#
# choose top *n* most common icd codes by frequency in the dataset for the inclusion cohort for now
