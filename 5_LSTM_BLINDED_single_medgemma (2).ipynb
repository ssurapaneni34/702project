# %% [markdown]
# # 🧠 ICU Clinical Grouping — Single Agent (MedGemma 27B, 4-bit)
#
# The agent reviews the LSTM's top pick and may override it with one of the
# other candidates in the top-K. The agent does NOT see LSTM probabilities or
# ranking — only which candidate was the top pick, plus the other candidates
# as possible alternatives.
#
# **This notebook is paired with the 5-group LSTM** (`TOP5_IMPROVED_LSTM_TRAINING.ipynb`).
# The model classifies among 5 clinical groups:
# `SEPSIS`, `STROKE_NEURO`, `ACUTE_MI`, `CORONARY_ARTERY_DZ`, `HEART_FAILURE`.

# %% [markdown]
# ## 1. Setup & Configuration

# %%
# ── Install dependencies ──────────────────────────────────────────────────
# !pip install -q -U transformers accelerate bitsandbytes scikit-learn joblib tqdm
# !pip install -U bitsandbytes>=0.46.1

from google.colab import drive, userdata
drive.mount('/content/drive')

print('Setup complete ✓')
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.5/10.5 MB 136.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 34.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 106.1 MB/s eta 0:00:00
# Mounted at /content/drive
# Setup complete ✓

# %%
# ══════════════════════════════════════════════════════════════════════════════
# CONFIGURATION
# ══════════════════════════════════════════════════════════════════════════════
import os

# ── File Paths ────────────────────────────────────────────────────────────────
BASE_DIR = '/content/drive/MyDrive/702 project'
LSTM_OUTPUT_DIR = f'{BASE_DIR}/TOP5_lstm_outputs'

CARDS_PATH   = f'{BASE_DIR}/patient_cards_v6_grouped.json'
MODEL_PATH   = f'{LSTM_OUTPUT_DIR}/best_model.pt'
SCALER_PATH  = f'{LSTM_OUTPUT_DIR}/feature_scaler.pkl'
CONFIG_PATH  = f'{LSTM_OUTPUT_DIR}/model_config.json'

AGENT_OUTPUT_DIR = f'{BASE_DIR}/agent_single_medgemma_results'
os.makedirs(AGENT_OUTPUT_DIR, exist_ok=True)

# ── Pilot Configuration ───────────────────────────────────────────────────────
PILOT_N_CASES = 100
TOP_K         = 3
RANDOM_SEED   = 42

# ── LLM Configuration ─────────────────────────────────────────────────────────
# IMPORTANT: use the TEXT-ONLY variant. 'google/medgemma-27b-it' is multimodal
# (Gemma 3 vision+text) and needs AutoModelForImageTextToText — using the
# wrong loader is what caused the empty AttributeError.
MEDGEMMA_MODEL_ID = 'google/medgemma-27b-text-it'

MAX_NEW_TOKENS = 1000
TEMPERATURE    = 0.2
RETRY_ATTEMPTS = 3

FALLBACK_SENTINEL = 'WHITEBOARD JELLYFISH'

print('Configuration:')
print(f'  Cases      : {PILOT_N_CASES}')
print(f'  Top-K      : {TOP_K}')
print(f'  LLM model  : {MEDGEMMA_MODEL_ID}')
print(f'  Output dir : {AGENT_OUTPUT_DIR}')
# Out:
# Configuration:
#   Cases      : 100
#   Top-K      : 3
#   LLM model  : google/medgemma-27b-text-it
#   Output dir : /content/drive/MyDrive/702 project/agent_single_medgemma_results

# %%
# ══════════════════════════════════════════════════════════════════════════════
# LOAD MEDGEMMA (text-only, 4-bit quantized)
# ══════════════════════════════════════════════════════════════════════════════
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig
from google.colab import userdata

try:
    hf_token = userdata.get('HF_TOKEN')
    print('✓ HF_TOKEN loaded from Colab Secrets')
except Exception:
    raise ValueError('Add HF_TOKEN to Colab Secrets (sidebar → 🔑)')

if not torch.cuda.is_available():
    raise RuntimeError('MedGemma 27B requires a GPU. Switch runtime to GPU.')

print(f'GPU : {torch.cuda.get_device_name(0)}')
print(f'VRAM: {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB')

quantization_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_compute_dtype=torch.bfloat16,
    bnb_4bit_quant_type='nf4',
    bnb_4bit_use_double_quant=True,
)

print(f'\nLoading {MEDGEMMA_MODEL_ID} (this takes a few minutes)...')
llm_tokenizer = AutoTokenizer.from_pretrained(MEDGEMMA_MODEL_ID, token=hf_token)
llm_model = AutoModelForCausalLM.from_pretrained(
    MEDGEMMA_MODEL_ID,
    quantization_config=quantization_config,
    device_map='auto',
    token=hf_token,
)
llm_model.eval()

if llm_tokenizer.pad_token_id is None:
    llm_tokenizer.pad_token_id = llm_tokenizer.eos_token_id

print(f'✓ MedGemma loaded ({sum(p.numel() for p in llm_model.parameters()):,} params)')
# Out:
# ✓ HF_TOKEN loaded from Colab Secrets
# GPU : NVIDIA A100-SXM4-80GB
# VRAM: 85.1 GB
#
# Loading google/medgemma-27b-text-it (this takes a few minutes)...
# config.json:   0%|          | 0.00/931 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/33.4M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/35.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/662 [00:00<?, ?B/s]
# chat_template.jinja: 0.00B [00:00, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 11 files:   0%|          | 0/11 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/808 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/173 [00:00<?, ?B/s]
# ✓ MedGemma loaded (14,209,821,440 params)

# %% [markdown]
# ## 2. Load Data & LSTM Model

# %%
# ══════════════════════════════════════════════════════════════════════════════
# LOAD PATIENT CARDS & 5-CLASS LABEL MAP
# ══════════════════════════════════════════════════════════════════════════════
# IMPORTANT: this notebook is paired with the 5-group LSTM
# (TOP5_IMPROVED_LSTM_TRAINING.ipynb). That model classifies among only:
#   SEPSIS, STROKE_NEURO, ACUTE_MI, CORONARY_ARTERY_DZ, HEART_FAILURE
#
# The training notebook filters the patient cards down to those 5 classes
# and remaps labels to 0..4 (by frequency). We replicate that here so the
# label ids the LSTM emits line up with the cards the agent scores against.
#
# NOTE: scaler load is deferred to a later cell so we can refit-from-training-
# split if feature_scaler.pkl is missing (the original top5 run apparently
# didn't save it).
import json
import numpy as np
import random
import torch.nn as nn
import joblib
from collections import defaultdict, Counter

print('Loading patient cards...')
with open(CARDS_PATH) as f:
    data = json.load(f)

all_cards          = data['patients']
raw_label_map      = data['label_map']                 # original 21-class map (name → id)
raw_inv_label_map  = {v: k for k, v in raw_label_map.items()}   # id → name

feature_names  = data['feature_names']
n_features     = data['n_features']
n_timesteps    = data['n_timesteps']

val_idx  = list(range(0, n_features, 2))
mask_idx = list(range(1, n_features, 2))

print(f'  Cards (raw, all 21 classes): {len(all_cards):,}')

# ── Load LSTM config (contains the FINAL 5-class label_map after frequency remap)
with open(CONFIG_PATH) as f:
    config = json.load(f)

label_map     = config['label_map']                    # 5-class name → id (0..4)
inv_label_map = {v: k for k, v in label_map.items()}   # id (0..4) → name
num_classes   = len(label_map)
assert num_classes == 5, f'Expected 5 classes, got {num_classes}'

TOP_5_CLASSES = set(label_map.keys())
print(f'  Top-5 classes from LSTM config: {sorted(TOP_5_CLASSES)}')

# ── Filter all_cards to only the 5 classes the LSTM knows about ──────────────
# Each card's `label` is currently an int into the ORIGINAL 21-class map.
# Translate via raw_inv_label_map → class name → new 0..4 id.
def _remap_card(card):
    name = raw_inv_label_map[card['label']]
    card['label'] = label_map[name]   # 0..4
    return card

filtered = []
for c in all_cards:
    name = raw_inv_label_map.get(c['label'])
    if name in TOP_5_CLASSES:
        filtered.append(_remap_card(c))

all_cards = filtered
print(f'  Cards (filtered to 5 classes, remapped 0..4): {len(all_cards):,}')

# Sanity: every card's label is now a valid 5-class id
assert all(0 <= c['label'] < 5 for c in all_cards), 'Bad remap'

# Class distribution (post-filter, post-remap)
post_counts = Counter(c['label'] for c in all_cards)
print('\n  Class distribution after filter+remap:')
for new_id in range(num_classes):
    print(f'    {new_id} ({inv_label_map[new_id]:<22}): {post_counts[new_id]:,} cards')

print('\n✓ Cards loaded and label_map aligned to 5-group LSTM (scaler loaded later)')
# Out:
# Loading patient cards...
#   Cards (raw, all 21 classes): 28,467
#   Top-5 classes from LSTM config: ['ACUTE_MI', 'CORONARY_ARTERY_DZ', 'HEART_FAILURE', 'SEPSIS', 'STROKE_NEURO']
#   Cards (filtered to 5 classes, remapped 0..4): 16,754
#
#   Class distribution after filter+remap:
#     0 (SEPSIS                ): 5,524 cards
#     1 (STROKE_NEURO          ): 4,740 cards
#     2 (ACUTE_MI              ): 2,361 cards
#     3 (CORONARY_ARTERY_DZ    ): 2,335 cards
#     4 (HEART_FAILURE         ): 1,794 cards
#
# ✓ Cards loaded and label_map aligned to 5-group LSTM (scaler loaded later)

# %%
# ══════════════════════════════════════════════════════════════════════════════
# LOAD LSTM MODEL  (kept as `lstm_model` to avoid collision with `llm_model`)
# ══════════════════════════════════════════════════════════════════════════════
import torch

device = 'cuda' if torch.cuda.is_available() else 'cpu'

class LSTMWithAttention(nn.Module):
    def __init__(self, input_dim, hidden_dim, num_layers, num_classes,
                 dropout=0.3, num_heads=4):
        super().__init__()
        self.hidden_dim = hidden_dim
        self.num_layers = num_layers
        self.lstm = nn.LSTM(
            input_size=input_dim, hidden_size=hidden_dim, num_layers=num_layers,
            batch_first=True, dropout=dropout if num_layers > 1 else 0, bidirectional=True
        )
        self.attention = nn.MultiheadAttention(
            embed_dim=hidden_dim * 2, num_heads=num_heads, dropout=dropout, batch_first=True
        )
        self.layer_norm = nn.LayerNorm(hidden_dim * 2)
        self.dropout = nn.Dropout(dropout)
        self.fc1 = nn.Linear(hidden_dim * 2, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, num_classes)

    def forward(self, x, return_attention=False):
        lstm_out, _ = self.lstm(x)
        attn_out, attn_weights = self.attention(lstm_out, lstm_out, lstm_out, need_weights=True)
        attn_out = self.layer_norm(lstm_out + attn_out)
        pooled = attn_out.mean(dim=1)
        out = self.dropout(pooled)
        out = torch.relu(self.fc1(out))
        out = self.dropout(out)
        logits = self.fc2(out)
        return (logits, attn_weights) if return_attention else logits

lstm_model = LSTMWithAttention(
    input_dim=config['input_dim'], hidden_dim=config['hidden_dim'],
    num_layers=config['num_layers'], num_classes=config['num_classes'],
    dropout=config['dropout'], num_heads=config['num_heads']
).to(device)

lstm_model.load_state_dict(torch.load(MODEL_PATH, map_location=device))
lstm_model.eval()
print(f'✓ LSTM loaded ({sum(p.numel() for p in lstm_model.parameters()):,} params)')
# Out:
# ✓ LSTM loaded (3,568,133 params)

# %%
# # ══════════════════════════════════════════════════════════════════════════════
# # CREATE TEST SPLIT & PILOT SAMPLE
# # ══════════════════════════════════════════════════════════════════════════════
# TRAIN_RATIO, VAL_RATIO = 0.70, 0.15

# random.seed(42)
# np.random.seed(42)

# patient_to_cards = defaultdict(list)
# for i, card in enumerate(all_cards):
#     patient_to_cards[card['patient_id']].append(i)

# patient_ids = list(patient_to_cards.keys())
# random.shuffle(patient_ids)

# n_train = int(len(patient_ids) * TRAIN_RATIO)
# n_val   = int(len(patient_ids) * VAL_RATIO)
# test_pids  = set(patient_ids[n_train + n_val:])
# test_cards = [all_cards[i] for pid in test_pids for i in patient_to_cards[pid]]

# random.seed(RANDOM_SEED)
# label_to_cards = defaultdict(list)
# for card in test_cards:
#     label_to_cards[card['label']].append(card)

# label_counts = Counter(c['label'] for c in test_cards)
# total = sum(label_counts.values())

# pilot_cards = []
# for label, count in sorted(label_counts.items(), key=lambda x: -x[1]):
#     n_sample = max(1, int(PILOT_N_CASES * count / total))
#     n_sample = min(n_sample, len(label_to_cards[label]))
#     pilot_cards.extend(random.sample(label_to_cards[label], n_sample))

# random.shuffle(pilot_cards)
# pilot_cards = pilot_cards[:PILOT_N_CASES]

# print(f'Test set   : {len(test_cards):,} stays')
# print(f'Pilot sample: {len(pilot_cards)} cases')

# %%
# ══════════════════════════════════════════════════════════════════════════════
# RECREATE THE EXACT TRAIN/VAL/TEST SPLIT FROM THE 5-GROUP LSTM TRAINING
# ══════════════════════════════════════════════════════════════════════════════
# The LSTM training notebook (TOP5_IMPROVED_LSTM_TRAINING):
#   - filtered cards to the 5 top groups
#   - sorted by patient_id  ← critical for deterministic shuffle
#   - random.seed(42); np.random.seed(42)
#   - 70/15/15 split by PATIENT (not stay) so the same patient never spans splits
#
# We replicate every step here so `test_cards` is byte-for-byte the same
# cohort the LSTM was evaluated on. We also keep train_cards on hand in case
# the next cell needs to refit the feature scaler.
TRAIN_RATIO, VAL_RATIO = 0.70, 0.15
SPLIT_SEED = 42  # MUST match TOP5_IMPROVED_LSTM_TRAINING.ipynb

random.seed(SPLIT_SEED)
np.random.seed(SPLIT_SEED)

# ── Sort by patient_id BEFORE indexing (mirrors top5 cell 8)
all_cards = sorted(all_cards, key=lambda x: x['patient_id'])

patient_to_cards = defaultdict(list)
for i, card in enumerate(all_cards):
    patient_to_cards[card['patient_id']].append(i)

patient_ids = list(patient_to_cards.keys())
random.shuffle(patient_ids)

n_train = int(len(patient_ids) * TRAIN_RATIO)
n_val   = int(len(patient_ids) * VAL_RATIO)

train_pids        = patient_ids[:n_train]
val_pids          = patient_ids[n_train:n_train + n_val]
test_pids_ordered = patient_ids[n_train + n_val:]

train_cards = [all_cards[i] for pid in train_pids        for i in patient_to_cards[pid]]
val_cards   = [all_cards[i] for pid in val_pids          for i in patient_to_cards[pid]]
test_cards  = [all_cards[i] for pid in test_pids_ordered for i in patient_to_cards[pid]]

print(f'Patients — train: {len(train_pids):,}  val: {len(val_pids):,}  test: {len(test_pids_ordered):,}')
print(f'Stays    — train: {len(train_cards):,}  val: {len(val_cards):,}  test: {len(test_cards):,}')

# ── Now stratified pilot sample from the test set ────────────────────────────
random.seed(RANDOM_SEED)

# Index test cards so we can de-dup deterministically across stratification + top-up
indexed_test = list(enumerate(test_cards))
label_to_indexed = defaultdict(list)
for ix, card in indexed_test:
    label_to_indexed[card['label']].append((ix, card))

label_counts = Counter(c['label'] for c in test_cards)
total = sum(label_counts.values())

pilot_indices = set()
pilot_cards   = []

# 2a. Proportional allocation per class (uses int(), so under-allocates)
for label, count in sorted(label_counts.items(), key=lambda x: -x[1]):
    n_sample = max(1, int(PILOT_N_CASES * count / total))
    n_sample = min(n_sample, len(label_to_indexed[label]))
    for ix, c in random.sample(label_to_indexed[label], n_sample):
        pilot_indices.add(ix)
        pilot_cards.append(c)

# 2b. Top up to PILOT_N_CASES from any unused test cards (rounding-loss correction)
shortfall = PILOT_N_CASES - len(pilot_cards)
if shortfall > 0:
    remaining = [(ix, c) for ix, c in indexed_test if ix not in pilot_indices]
    n_extra = min(shortfall, len(remaining))
    if n_extra > 0:
        for ix, c in random.sample(remaining, n_extra):
            pilot_indices.add(ix)
            pilot_cards.append(c)

print(f'\nPilot sample : {len(pilot_cards)} cases  (stratified by 5-class label)')

# ── Test-cohort signature — should match the one printed by the LSTM notebook
import hashlib
test_signature = hashlib.md5(
    ','.join(str(c['patient_id']) + ':' + str(c.get('stay_id', '')) for c in test_cards).encode()
).hexdigest()
print(f'\nTest cohort signature: {test_signature}')
print('  (must match TOP5_IMPROVED_LSTM_TRAINING test_signature for a fair comparison)')

# Pilot class breakdown
pilot_counts = Counter(c['label'] for c in pilot_cards)
print('\nPilot class breakdown:')
for new_id in range(num_classes):
    if new_id in pilot_counts:
        print(f'  {new_id} ({inv_label_map[new_id]:<22}): {pilot_counts[new_id]} cases')
# Out:
# Patients — train: 9,624  val: 2,062  test: 2,063
# Stays    — train: 11,716  val: 2,554  test: 2,484
#
# Pilot sample : 100 cases  (stratified by 5-class label)
#
# Test cohort signature: cecc29fd0d5283d8b86fb5be8fc250c5
#   (must match TOP5_IMPROVED_LSTM_TRAINING test_signature for a fair comparison)
#
# Pilot class breakdown:
#   0 (SEPSIS                ): 33 cases
#   1 (STROKE_NEURO          ): 30 cases
#   2 (ACUTE_MI              ): 14 cases
#   3 (CORONARY_ARTERY_DZ    ): 13 cases
#   4 (HEART_FAILURE         ): 10 cases

# %%
# ══════════════════════════════════════════════════════════════════════════════
# LOAD-OR-REFIT FEATURE SCALER
# ══════════════════════════════════════════════════════════════════════════════
# The 5-group LSTM was trained on time-series whose VALUE columns (even-indexed)
# were normalized via StandardScaler fitted on the TRAINING SPLIT only. At
# inference, we must apply the IDENTICAL scaler — same per-feature means and
# stds — or the LSTM's input distribution shifts and predictions degrade
# silently.
#
# If feature_scaler.pkl exists from the LSTM training run, load it. Otherwise
# refit on train_cards using the exact same logic as
# TOP5_IMPROVED_LSTM_TRAINING.ipynb cell 11. Because cell 9 above reproduces
# that notebook's split bit-for-bit (same 5-class filter, same patient_id sort,
# same seed=42, same 70/15/15), train_cards here is the same set of stays —
# so the refitted scaler is bit-for-bit identical to what the LSTM saw.
import os
from sklearn.preprocessing import StandardScaler

if os.path.exists(SCALER_PATH):
    print(f'Loading existing scaler from {SCALER_PATH}')
    scaler = joblib.load(SCALER_PATH)
else:
    print(f'⚠ {SCALER_PATH} not found — refitting from training split')
    print('   (this reproduces TOP5_IMPROVED_LSTM_TRAINING cell 11 exactly)')

    # Same logic as top5 cell 11
    X_train_raw = np.array([c['time_series'] for c in train_cards])
    N_tr, T, F  = X_train_raw.shape
    train_vals  = X_train_raw[:, :, val_idx].reshape(-1, len(val_idx))

    scaler = StandardScaler()
    scaler.fit(train_vals)

    os.makedirs(os.path.dirname(SCALER_PATH), exist_ok=True)
    joblib.dump(scaler, SCALER_PATH)
    print(f'   ✓ Scaler fitted on {N_tr:,} training stays and saved to {SCALER_PATH}')

# Sanity: scaler dimensionality matches the LSTM's expected value-column count
expected_n_vals = len(val_idx)
if hasattr(scaler, 'n_features_in_'):
    assert scaler.n_features_in_ == expected_n_vals, (
        f'Scaler expects {scaler.n_features_in_} features, '
        f'but data has {expected_n_vals} value columns'
    )

print(f'\n✓ Scaler ready (mean shape: {scaler.mean_.shape}, '
      f'first 3 means: {scaler.mean_[:3].round(3)})')
# Out:
# Loading existing scaler from /content/drive/MyDrive/702 project/TOP5_lstm_outputs/feature_scaler.pkl
#
# ✓ Scaler ready (mean shape: (68,), first 3 means: [ 82.75   19.408 227.397])
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py:463: InconsistentVersionWarning: Trying to unpickle estimator StandardScaler from version 1.6.1 when using version 1.8.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
import hashlib
pilot_signature = hashlib.md5(
    ','.join(str(c['patient_id']) + ':' + str(c.get('stay_id', '')) for c in pilot_cards).encode()
).hexdigest()
print(f'pilot signature: {pilot_signature}')
print(f'first 5 patient_ids: {[c["patient_id"] for c in pilot_cards[:5]]}')
print(f'last 5 patient_ids:  {[c["patient_id"] for c in pilot_cards[-5:]]}')
# Out:
# pilot signature: 1b4d427efffdd0666a53dd265877243b
# first 5 patient_ids: ['17829884', '19833452', '11693201', '18958916', '13789582']
# last 5 patient_ids:  ['19339132', '13177098', '14428310', '13859166', '15277035']

# %% [markdown]
# ## 3. Define Single Agent System

# %%
# ══════════════════════════════════════════════════════════════════════════════
# PREPROCESSING & LSTM PREDICTION
# ══════════════════════════════════════════════════════════════════════════════

def normalize_time_series(card):
    """Apply scaler to patient time series."""
    X = np.array(card['time_series'], dtype=np.float32)
    X_vals = X[:, val_idx]
    X_vals_scaled = scaler.transform(X_vals)
    X[:, val_idx] = X_vals_scaled.astype(np.float32)
    return X


def get_lstm_predictions(card, top_k=3):
    """Get LSTM top-K predictions."""
    X = normalize_time_series(card)
    X_tensor = torch.from_numpy(X).unsqueeze(0).to(device)

    with torch.no_grad():
        logits = lstm_model(X_tensor)
        probs = torch.softmax(logits, dim=-1).squeeze(0)

    top_k_idx    = probs.argsort(descending=True)[:top_k]
    top_k_groups = [inv_label_map[i.item()] for i in top_k_idx]
    top_k_probs  = [probs[i].item() for i in top_k_idx]

    return {
        'top_k_codes'    : top_k_groups,
        'top_k_probs'    : top_k_probs,
        'lstm_prediction': top_k_groups[0],
        'lstm_confidence': top_k_probs[0],
    }

test_pred = get_lstm_predictions(pilot_cards[0], TOP_K)
print(f'✓ LSTM test: {test_pred["lstm_prediction"]} ({test_pred["lstm_confidence"]:.1%})')
# Out:
# ✓ LSTM test: SEPSIS (49.5%)

# %%
# ══════════════════════════════════════════════════════════════════════════════
# FORMATTERS
# ══════════════════════════════════════════════════════════════════════════════

def format_clinical_summary(summary: dict) -> str:
    """Format clinical summary for prompt."""
    if not summary:
        return "Clinical summary not available"

    lines = []

    if 'vitals' in summary:
        lines.append("VITAL SIGNS (Last 12 Hours):")
        for name, stats in summary['vitals'].items():
            if isinstance(stats, dict) and 'mean' in stats:
                lines.append(
                    f"  {name.replace('_', ' ').title()}: "
                    f"mean={stats['mean']:.1f}, range=[{stats['min']:.1f}–{stats['max']:.1f}], "
                    f"last={stats['last']:.1f} ({stats.get('trend', 'N/A')})"
                )

    if 'labs' in summary:
        lines.append("\nLABORATORY VALUES:")
        for name, stats in summary['labs'].items():
            if isinstance(stats, dict) and 'mean' in stats:
                lines.append(
                    f"  {name.replace('_', ' ').title()}: "
                    f"mean={stats['mean']:.2f}, last={stats['last']:.2f} ({stats.get('trend', 'N/A')})"
                )

    if 'interventions' in summary:
        iv = summary['interventions']
        lines.append("\nINTERVENTIONS:")
        if iv.get('active_drugs'):
            lines.append(f"  Medications: {', '.join(iv['active_drugs'])}")
        if iv.get('active_procedures'):
            lines.append(f"  Procedures: {', '.join(iv['active_procedures'])}")

    return '\n'.join(lines) if lines else "Clinical summary not available"

print('✓ Formatters defined')
# Out:
# ✓ Formatters defined

# %%
# ══════════════════════════════════════════════════════════════════════════════
# BUILD AGENT-SAFE PATIENT CARD
# ══════════════════════════════════════════════════════════════════════════════
# Strip any field that reveals (or temporally leaks) the diagnosis before the
# card is handed to the LLM. Ground truth stays on the ORIGINAL card for
# downstream validation.

LEAKY_CARD_FIELDS = {
    'icd_code',         # raw ICD-10 code
    'clinical_group',   # text answer
    'label',            # integer index into label_map
    'procedures',       # whole-admission ICD-PCS codes (temporal leak)
    'drugs',            # whole-admission prescriptions (temporal leak)
    'conditions',       # may contain dx history
}


def build_clinical_summary_for_agent(card: dict) -> dict:
    """Return a shallow copy of the card with diagnosis-revealing fields removed."""
    safe = {k: v for k, v in card.items() if k not in LEAKY_CARD_FIELDS}

    # Defensive scrub of clinical_summary keys whose names hint at diagnosis.
    cs = safe.get('clinical_summary')
    if isinstance(cs, dict):
        diag_hint_keys = [
            k for k in cs.keys()
            if any(tok in k.lower()
                   for tok in ('diag', 'icd', 'group', 'label', 'condition',
                               'problem', 'impression'))
        ]
        if diag_hint_keys:
            safe['clinical_summary'] = {
                k: v for k, v in cs.items() if k not in diag_hint_keys
            }

    return safe


_probe = build_clinical_summary_for_agent(pilot_cards[0])
_leaks_present = LEAKY_CARD_FIELDS & set(_probe.keys())
assert not _leaks_present, f'Leak check failed: {_leaks_present} still in stripped card'
print('✓ build_clinical_summary_for_agent() defined')
print(f'  Original card keys   : {sorted(pilot_cards[0].keys())}')
print(f'  Agent-safe card keys : {sorted(_probe.keys())}')
print(f'  Stripped             : {sorted(set(pilot_cards[0].keys()) - set(_probe.keys()))}')
# Out:
# ✓ build_clinical_summary_for_agent() defined
#   Original card keys   : ['clinical_group', 'clinical_summary', 'conditions', 'drugs', 'feature_names', 'icd_code', 'label', 'patient_id', 'procedures', 'stay_id', 'time_series', 'visit_id']
#   Agent-safe card keys : ['clinical_summary', 'feature_names', 'patient_id', 'stay_id', 'time_series', 'visit_id']
#   Stripped             : ['clinical_group', 'conditions', 'drugs', 'icd_code', 'label', 'procedures']

# %%
# ══════════════════════════════════════════════════════════════════════════════
# INSPECT AGENT-SAFE CARDS (pre-flight audit)
# ══════════════════════════════════════════════════════════════════════════════
# Nothing here is shown to the LLM — this is for you to sanity-check what the
# agent will and won't see.
import pprint

N_INSPECT = 5
pp = pprint.PrettyPrinter(width=100, depth=4, sort_dicts=False)

for inspect_i, inspect_card in enumerate(pilot_cards[:N_INSPECT]):
    print('\n' + '█' * 78)
    print(f'█ AGENT-SAFE CARD PREVIEW  [{inspect_i + 1}/{N_INSPECT}]')
    print('█' * 78)

    _true = inv_label_map[inspect_card['label']]
    print(f'\n➤ GROUND TRUTH (not shown to agent):  {_true}')
    print(f'  (integer label {inspect_card["label"]}, patient {inspect_card["patient_id"]})')

    safe = build_clinical_summary_for_agent(inspect_card)
    print('\n── 1. AGENT-SAFE CARD (top-level keys) ──')
    print(f'  Keys     : {sorted(safe.keys())}')
    print(f'  Stripped : {sorted(set(inspect_card.keys()) - set(safe.keys()))}')

    print('\n── 2. FULL clinical_summary DICT ──')
    pp.pprint(safe.get('clinical_summary', {}))

    print('\n── 3. FORMATTED CLINICAL SUMMARY (exact text in prompt) ──')
    print(format_clinical_summary(safe.get('clinical_summary', {})))

    _lstm = get_lstm_predictions(safe, TOP_K)
    print('\n── 4. LSTM TOP-K (agent sees top pick + other candidates, no probs) ──')
    print(f'  LSTM top-{TOP_K} with probs (for your reference only):')
    for _rank, (_c, _p) in enumerate(zip(_lstm['top_k_codes'], _lstm['top_k_probs'])):
        _mark = '✓' if _c == _true else ' '
        print(f'    {_rank+1}. {_c:<25} {_p:>6.1%} {_mark}')
    print(f'  What the agent will see:')
    print(f'    LSTM TOP PICK    : {_lstm["top_k_codes"][0]}')
    print(f'    Other candidates :')
    for _c in _lstm['top_k_codes'][1:]:
        print(f'      - {_c}')

print('\n' + '█' * 78)
print(f'█ End of agent-safe card preview ({N_INSPECT} cards)')
print('█' * 78)
# Out:
# ██████████████████████████████████████████████████████████████████████████████
# █ AGENT-SAFE CARD PREVIEW  [1/5]
# ██████████████████████████████████████████████████████████████████████████████
#
# ➤ GROUND TRUTH (not shown to agent):  SEPSIS
#   (integer label 0, patient 17829884)
#
# ── 1. AGENT-SAFE CARD (top-level keys) ──
#   Keys     : ['clinical_summary', 'feature_names', 'patient_id', 'stay_id', 'time_series', 'visit_id']
#   Stripped : ['clinical_group', 'conditions', 'drugs', 'icd_code', 'label', 'procedures']
#
# ── 2. FULL clinical_summary DICT ──
# {'vitals': {'heart_rate': {'mean': 98.5,
#                            'min': 89.0,
#                            'max': 104.0,
#                            'last': 98.0,
#                            'first': 89.0,
#                            'trend': 'worsening',
#                            'n_observations': 12},
#             'respiratory_rate': {'mean': 19.75,
#                                  'min': 17.0,
#                                  'max': 24.0,
#                                  'last': 20.0,
#                                  'first': 18.0,
#                                  'trend': 'worsening',
#                                  'n_observations': 12},
#             'o2_saturation_pulseoxymetry': {'mean': 94.75,
#                                             'min': 92.0,
#                                             'max': 97.0,
#                                             'last': 92.0,
#                                             'first': 95.0,
#                                             'trend': 'stable',
#                                             'n_observations': 12},
#             'non_invasive_blood_pressure_systolic': {'mean': 120.83,
#                                                      'min': 99.0,
#                                                      'max': 134.0,
#                                                      'last': 118.0,
#                                                      'first': 124.0,
#                                                      'trend': 'stable',
#                                                      'n_observations': 12},
#             'non_invasive_blood_pressure_diastolic': {'mean': 62.5,
#                                                       'min': 40.0,
#                                                       'max': 80.0,
#                                                       'last': 65.0,
#                                                       'first': 62.0,
#                                                       'trend': 'stable',
#                                                       'n_observations': 12},
#             'non_invasive_blood_pressure_mean': {'mean': 80.5,
#                                                  'min': 58.0,
#                                                  'max': 97.0,
#                                                  'last': 81.0,
#                                                  'first': 82.0,
#                                                  'trend': 'stable',
#                                                  'n_observations': 12},
#             'temperature_fahrenheit': {'mean': 98.57,
#                                        'min': 98.1,
#                                        'max': 99.0,
#                                        'last': 98.6,
#                                        'first': 98.1,
#                                        'trend': 'stable',
#                                        'n_observations': 3},
#             'glucose_finger_stick': {'mean': 167.0,
#                                      'min': 153.0,
#                                      'max': 181.0,
#                                      'last': 181.0,
#                                      'first': 153.0,
#                                      'trend': 'worsening',
#                                      'n_observations': 2},
#             'heart_rate_alarm_low': {'mean': 40.0,
#                                      'min': 40.0,
#                                      'max': 40.0,
#                                      'last': 40.0,
#                                      'first': 40.0,
#                                      'trend': 'single_observation',
#                                      'n_observations': 1},
#             'heart_rate_alarm_high': {'mean': 130.0,
#                                       'min': 130.0,
#                                       'max': 130.0,
#                                       'last': 130.0,
#                                       'first': 130.0,
#                                       'trend': 'single_observation',
#                                       'n_observations': 1},
#             'o2_saturation_pulseoxymetry_alarm_low': {'mean': 88.0,
#                                                       'min': 88.0,
#                                                       'max': 88.0,
#                                                       'last': 88.0,
#                                                       'first': 88.0,
#                                                       'trend': 'single_observation',
#                                                       'n_observations': 1},
#             'o2_saturation_pulseoxymetry_alarm_high': {'mean': 100.0,
#                                                        'min': 100.0,
#                                                        'max': 100.0,
#                                                        'last': 100.0,
#                                                        'first': 100.0,
#                                                        'trend': 'single_observation',
#                                                        'n_observations': 1},
#             'resp_alarm_high': {'mean': 35.0,
#                                 'min': 35.0,
#                                 'max': 35.0,
#                                 'last': 35.0,
#                                 'first': 35.0,
#                                 'trend': 'single_observation',
#                                 'n_observations': 1},
#             'resp_alarm_low': {'mean': 8.0,
#                                'min': 8.0,
#                                'max': 8.0,
#                                'last': 8.0,
#                                'first': 8.0,
#                                'trend': 'single_observation',
#                                'n_observations': 1},
#             'non_invasive_blood_pressure_alarm_low': {'mean': 90.0,
#                                                       'min': 90.0,
#                                                       'max': 90.0,
#                                                       'last': 90.0,
#                                                       'first': 90.0,
#                                                       'trend': 'single_observation',
#                                                       'n_observations': 1},
#             'non_invasive_blood_pressure_alarm_high': {'mean': 160.0,
#                                                        'min': 160.0,
#                                                        'max': 160.0,
#                                                        'last': 160.0,
#                                                        'first': 160.0,
#                                                        'trend': 'single_observation',
#                                                        'n_observations': 1}},
#  'labs': {},
#  'interventions': {'active_drugs': ['nacl_0_9', 'po_intake'],
#                    'active_procedures': ['20_gauge', '22_gauge'],
#                    'urine_output_total_ml': 3450.0},
#  'observation_hours': 12,
#  'pct_hours_monitored': 1.0}
#
# ── 3. FORMATTED CLINICAL SUMMARY (exact text in prompt) ──
# VITAL SIGNS (Last 12 Hours):
#   Heart Rate: mean=98.5, range=[89.0–104.0], last=98.0 (worsening)
#   Respiratory Rate: mean=19.8, range=[17.0–24.0], last=20.0 (worsening)
#   O2 Saturation Pulseoxymetry: mean=94.8, range=[92.0–97.0], last=92.0 (stable)
#   Non Invasive Blood Pressure Systolic: mean=120.8, range=[99.0–134.0], last=118.0 (stable)
#   Non Invasive Blood Pressure Diastolic: mean=62.5, range=[40.0–80.0], last=65.0 (stable)
#   Non Invasive Blood Pressure Mean: mean=80.5, range=[58.0–97.0], last=81.0 (stable)
#   Temperature Fahrenheit: mean=98.6, range=[98.1–99.0], last=98.6 (stable)
#   Glucose Finger Stick: mean=167.0, range=[153.0–181.0], last=181.0 (worsening)
#   Heart Rate Alarm Low: mean=40.0, range=[40.0–40.0], last=40.0 (single_observation)
#   Heart Rate Alarm High: mean=130.0, range=[130.0–130.0], last=130.0 (single_observation)
#   O2 Saturation Pulseoxymetry Alarm Low: mean=88.0, range=[88.0–88.0], last=88.0 (single_observation)
#   O2 Saturation Pulseoxymetry Alarm High: mean=100.0, range=[100.0–100.0], last=100.0 (single_observation)
#   Resp Alarm High: mean=35.0, range=[35.0–35.0], last=35.0 (single_observation)
#   Resp Alarm Low: mean=8.0, range=[8.0–8.0], last=8.0 (single_observation)
#   Non Invasive Blood Pressure Alarm Low: mean=90.0, range=[90.0–90.0], last=90.0 (single_observation)
#   Non Invasive Blood Pressure Alarm High: mean=160.0, range=[160.0–160.0], last=160.0 (single_observation)
#
# LABORATORY VALUES:
#
# INTERVENTIONS:
#   Medications: nacl_0_9, po_intake
#   Procedures: 20_gauge, 22_gauge
#
# ── 4. LSTM TOP-K (agent sees top pick + other candidates, no probs) ──
#   LSTM top-3 with probs (for your reference only):
#     1. SEPSIS                     49.5% ✓
#     2. HEART_FAILURE              37.4%
#     3. ACUTE_MI                   12.8%
#   What the agent will see:
#     LSTM TOP PICK    : SEPSIS
#     Other candidates :
#       - HEART_FAILURE
#       - ACUTE_MI
#
# ██████████████████████████████████████████████████████████████████████████████
# █ AGENT-SAFE CARD PREVIEW  [2/5]
# ██████████████████████████████████████████████████████████████████████████████
#
# ➤ GROUND TRUTH (not shown to agent):  SEPSIS
#   (integer label 0, patient 19833452)
#
# ── 1. AGENT-SAFE CARD (top-level keys) ──
#   Keys     : ['clinical_summary', 'feature_names', 'patient_id', 'stay_id', 'time_series', 'visit_id']
#   Stripped : ['clinical_group', 'conditions', 'drugs', 'icd_code', 'label', 'procedures']
#
# ── 2. FULL clinical_summary DICT ──
# {'vitals': {'heart_rate': {'mean': 112.67,
#                            'min': 98.0,
#                            'max': 125.0,
#                            'last': 125.0,
#                            'first': 100.0,
#                            'trend': 'worsening',
#                            'n_observations': 12},
#             'respiratory_rate': {'mean': 24.25,
#                                  'min': 19.0,
#                                  'max': 29.0,
#                                  'last': 24.0,
#                                  'first': 29.0,
#                                  'trend': 'improving',
#                                  'n_observations': 12},
#             'o2_saturation_pulseoxymetry': {'mean': 96.42,
#                                             'min': 94.0,
#                                             'max': 98.0,
#                                             'last': 97.0,
#                                             'first': 98.0,
#                                             'trend': 'stable',
#                                             'n_observations': 12},
#             'non_invasive_blood_pressure_systolic': {'mean': 103.18,
#                                                      'min': 88.0,
#                                                      'max': 119.0,
#                                                      'last': 113.0,
#                                                      'first': 97.0,
#                                                      'trend': 'worsening',
#                                                      'n_observations': 11},
#             'non_invasive_blood_pressure_diastolic': {'mean': 51.73,
#                                                       'min': 45.0,
#                                                       'max': 59.0,
#                                                       'last': 53.0,
#                                                       'first': 45.0,
#                                                       'trend': 'worsening',
#                                                       'n_observations': 11},
#             'non_invasive_blood_pressure_mean': {'mean': 62.73,
#                                                  'min': 54.0,
#                                                  'max': 70.0,
#                                                  'last': 68.0,
#                                                  'first': 59.0,
#                                                  'trend': 'worsening',
#                                                  'n_observations': 11},
#             'temperature_fahrenheit': {'mean': 98.62,
#                                        'min': 97.2,
#                                        'max': 99.3,
#                                        'last': 99.0,
#                                        'first': 99.0,
#                                        'trend': 'stable',
#                                        'n_observations': 4},
#             'heart_rate_alarm_low': {'mean': 40.0,
#                                      'min': 40.0,
#                                      'max': 40.0,
#                                      'last': 40.0,
#                                      'first': 40.0,
#                                      'trend': 'single_observation',
#                                      'n_observations': 1},
#             'heart_rate_alarm_high': {'mean': 140.0,
#                                       'min': 140.0,
#                                       'max': 140.0,
#                                       'last': 140.0,
#                                       'first': 140.0,
#                                       'trend': 'single_observation',
#                                       'n_observations': 1},
#             'o2_saturation_pulseoxymetry_alarm_low': {'mean': 92.0,
#                                                       'min': 92.0,
#                                                       'max': 92.0,
#                                                       'last': 92.0,
#                                                       'first': 92.0,
#                                                       'trend': 'single_observation',
#                                                       'n_observations': 1},
#             'o2_saturation_pulseoxymetry_alarm_high': {'mean': 100.0,
#                                                        'min': 100.0,
#                                                        'max': 100.0,
#                                                        'last': 100.0,
#                                                        'first': 100.0,
#                                                        'trend': 'single_observation',
#                                                        'n_observations': 1},
#             'resp_alarm_high': {'mean': 35.0,
#                                 'min': 35.0,
#                                 'max': 35.0,
#                                 'last': 35.0,
#                                 'first': 35.0,
#                                 'trend': 'single_observation',
#                                 'n_observations': 1},
#             'resp_alarm_low': {'mean': 8.0,
#                                'min': 8.0,
#                                'max': 8.0,
#                                'last': 8.0,
#                                'first': 8.0,
#                                'trend': 'single_observation',
#                                'n_observations': 1},
#             'o2_flow': {'mean': 2.5,
#                         'min': 2.0,
#                         'max': 4.0,
#                         'last': 2.0,
#                         'first': 4.0,
#                         'trend': 'improving',
#                         'n_observations': 4},
#             'sodium': {'mean': 146.0,
#                        'min': 146.0,
#                        'max': 146.0,
#                        'last': 146.0,
#                        'first': 146.0,
#                        'trend': 'single_observation',
#                        'n_observations': 1},
#             'hemoglobin': {'mean': 7.8,
#                            'min': 7.8,
#                            'max': 7.8,
#                            'last': 7.8,
#                            'first': 7.8,
#                            'trend': 'single_observation',
#                            'n_observations': 1},
#             'non_invasive_blood_pressure_alarm_low': {'mean': 55.0,
#                                                       'min': 55.0,
#                                                       'max': 55.0,
#                                                       'last': 55.0,
#                                                       'first': 55.0,
#                                                       'trend': 'single_observation',
#                                                       'n_observations': 1},
#             'non_invasive_blood_pressure_alarm_high': {'mean': 120.0,
#                                                        'min': 120.0,
#                                                        'max': 120.0,
#                                                        'last': 120.0,
#                                                        'first': 120.0,
#                                                        'trend': 'single_observation',
#                                                        'n_observations': 1},
#             'chloride': {'mean': 102.0,
#                          'min': 102.0,
#                          'max': 102.0,
#                          'last': 102.0,
#                          'first': 102.0,
#                          'trend': 'single_observation',
#                          'n_observations': 1},
#             'anion_gap': {'mean': 9.0,
#                           'min': 9.0,
#                           'max': 9.0,
#                           'last': 9.0,
#                           'first': 9.0,
#                           'trend': 'single_observation',
#                           'n_observations': 1}},
#  'labs': {'h': {'mean': 7.0,
#                 'min': 7.0,
#                 'max': 7.0,
#                 'last': 7.0,
#                 'first': 7.0,
#                 'trend': 'single_observation',
#                 'n_observations': 1},
#           'l': {'mean': 3.0,
#                 'min': 3.0,
#                 'max': 3.0,
#                 'last': 3.0,
#                 'first': 3.0,
#                 'trend': 'single_observation',
#                 'n_observations': 1},
#           'i': {'mean': 0.0,
#                 'min': 0.0,
#                 'max': 0.0,
#                 'last': 0.0,
#                 'first': 0.0,
#                 'trend': 'single_observation',
#                 'n_observations': 1},
#           'potassium': {'mean': 4.5,
#                         'min': 4.5,
#                         'max': 4.5,
#                         'last': 4.5,
#                         'first': 4.5,
#                         'trend': 'single_observation',
#                         'n_observations': 1},
#           'sodium': {'mean': 146.0,
#                      'min': 146.0,
#                      'max': 146.0,
#                      'last': 146.0,
#                      'first': 146.0,
#                      'trend': 'single_observation',
#                      'n_observations': 1},
#           'chloride': {'mean': 102.0,
#                        'min': 102.0,
#                        'max': 102.0,
#                        'last': 102.0,
#                        'first': 102.0,
#                        'trend': 'single_observation',
#                        'n_observations': 1},
#           'creatinine': {'mean': 1.3,
#                          'min': 1.3,
#                          'max': 1.3,
#                          'last': 1.3,
#                          'first': 1.3,
#                          'trend': 'single_observation',
#                          'n_observations': 1},
#           'urea_nitrogen': {'mean': 34.0,
#                             'min': 34.0,
#                             'max': 34.0,
#                             'last': 34.0,
#                             'first': 34.0,
#                             'trend': 'single_observation',
#                             'n_observations': 1},
#           'bicarbonate': {'mean': 35.0,
#                           'min': 35.0,
#                           'max': 35.0,
#                           'last': 35.0,
#                           'first': 35.0,
#                           'trend': 'single_observation',
#                           'n_observations': 1},
#           'anion_gap': {'mean': 9.0,
#                         'min': 9.0,
#                         'max': 9.0,
#                         'last': 9.0,
#                         'first': 9.0,
#                         'trend': 'single_observation',
#                         'n_observations': 1},
#           'glucose': {'mean': 97.0,
#                       'min': 97.0,
#                       'max': 97.0,
#                       'last': 97.0,
#                       'first': 97.0,
#                       'trend': 'single_observation',
#                       'n_observations': 1},
#           'magnesium': {'mean': 2.0,
#                         'min': 2.0,
#                         'max': 2.0,
#                         'last': 2.0,
#                         'first': 2.0,
#                         'trend': 'single_observation',
#                         'n_observations': 1},
#           'hematocrit': {'mean': 28.1,
#                          'min': 28.1,
#                          'max': 28.1,
#                          'last': 28.1,
#                          'first': 28.1,
#                          'trend': 'single_observation',
#                          'n_observations': 1},
#           'hemoglobin': {'mean': 7.8,
#                          'min': 7.8,
#                          'max': 7.8,
#                          'last': 7.8,
#                          'first': 7.8,
#                          'trend': 'single_observation',
#                          'n_observations': 1},
#           'platelet_count': {'mean': 299.0,
#                              'min': 299.0,
#                              'max': 299.0,
#                              'last': 299.0,
#                              'first': 299.0,
#                              'trend': 'single_observation',
#                              'n_observations': 1},
#           'white_blood_cells': {'mean': 12.5,
#                                 'min': 12.5,
#                                 'max': 12.5,
#                                 'last': 12.5,
#                                 'first': 12.5,
#                                 'trend': 'single_observation',
#                                 'n_observations': 1},
#           'mch': {'mean': 24.6,
#                   'min': 24.6,
#                   'max': 24.6,
#                   'last': 24.6,
#                   'first': 24.6,
#                   'trend': 'single_observation',
#                   'n_observations': 1},
#           'mcv': {'mean': 89.0,
#                   'min': 89.0,
#                   'max': 89.0,
#                   'last': 89.0,
#                   'first': 89.0,
#                   'trend': 'single_observation',
#                   'n_observations': 1},
#           'rdw': {'mean': 18.9,
#                   'min': 18.9,
#                   'max': 18.9,
#                   'last': 18.9,
#                   'first': 18.9,
#                   'trend': 'single_observation',
#                   'n_observations': 1},
#           'mchc': {'mean': 27.8,
#                    'min': 27.8,
#                    'max': 27.8,
#                    'last': 27.8,
#                    'first': 27.8,
#                    'trend': 'single_observation',
#                    'n_observations': 1},
#           'red_blood_cells': {'mean': 3.17,
#                               'min': 3.17,
#                               'max': 3.17,
#                               'last': 3.17,
#                               'first': 3.17,
#                               'trend': 'single_observation',
#                               'n_observations': 1},
#           'rdw_sd': {'mean': 62.0,
#                      'min': 62.0,
#                      'max': 62.0,
#                      'last': 62.0,
#                      'first': 62.0,
#                      'trend': 'single_observation',
#                      'n_observations': 1},
#           'phosphate': {'mean': 4.6,
#                         'min': 4.6,
#                         'max': 4.6,
#                         'last': 4.6,
#                         'first': 4.6,
#                         'trend': 'single_observation',
#                         'n_observations': 1},
#           'calcium_total': {'mean': 8.9,
#                             'min': 8.9,
#                             'max': 8.9,
#                             'last': 8.9,
#                             'first': 8.9,
#                             'trend': 'single_observation',
#                             'n_observations': 1},
#           'ptt': {'mean': 31.3,
#                   'min': 31.3,
#                   'max': 31.3,
#                   'last': 31.3,
#                   'first': 31.3,
#                   'trend': 'single_observation',
#                   'n_observations': 1},
#           'ph': {'mean': 7.33,
#                  'min': 7.28,
#                  'max': 7.37,
#                  'last': 7.37,
#                  'first': 7.28,
#                  'trend': 'stable',
#                  'n_observations': 2},
#           'pt': {'mean': 29.6,
#                  'min': 29.6,
#                  'max': 29.6,
#                  'last': 29.6,
#                  'first': 29.6,
#                  'trend': 'single_observation',
#                  'n_observations': 1},
#           'inr': {'mean': 2.7,
#                   'min': 2.7,
#                   'max': 2.7,
#                   'last': 2.7,
#                   'first': 2.7,
#                   'trend': 'single_observation',
#                   'n_observations': 1},
#           'po2': {'mean': 89.0,
#                   'min': 48.0,
#                   'max': 130.0,
#                   'last': 48.0,
#                   'first': 130.0,
#                   'trend': 'improving',
#                   'n_observations': 2}},
#  'interventions': {'active_drugs': ['nacl_0_9', 'dextrose_5', 'solution', 'po_intake'],
#                    'active_procedures': ['18_gauge', 'foley_catheter'],
#                    'urine_output_total_ml': 645.0},
#  'observation_hours': 12,
#  'pct_hours_monitored': 1.0}
#
# ── 3. FORMATTED CLINICAL SUMMARY (exact text in prompt) ──
# VITAL SIGNS (Last 12 Hours):
#   Heart Rate: mean=112.7, range=[98.0–125.0], last=125.0 (worsening)
#   Respiratory Rate: mean=24.2, range=[19.0–29.0], last=24.0 (improving)
#   O2 Saturation Pulseoxymetry: mean=96.4, range=[94.0–98.0], last=97.0 (stable)
#   Non Invasive Blood Pressure Systolic: mean=103.2, range=[88.0–119.0], last=113.0 (worsening)
#   Non Invasive Blood Pressure Diastolic: mean=51.7, range=[45.0–59.0], last=53.0 (worsening)
#   Non Invasive Blood Pressure Mean: mean=62.7, range=[54.0–70.0], last=68.0 (worsening)
#   Temperature Fahrenheit: mean=98.6, range=[97.2–99.3], last=99.0 (stable)
#   Heart Rate Alarm Low: mean=40.0, range=[40.0–40.0], last=40.0 (single_observation)
#   Heart Rate Alarm High: mean=140.0, range=[140.0–140.0], last=140.0 (single_observation)
#   O2 Saturation Pulseoxymetry Alarm Low: mean=92.0, range=[92.0–92.0], last=92.0 (single_observation)
#   O2 Saturation Pulseoxymetry Alarm High: mean=100.0, range=[100.0–100.0], last=100.0 (single_observation)
#   Resp Alarm High: mean=35.0, range=[35.0–35.0], last=35.0 (single_observation)
#   Resp Alarm Low: mean=8.0, range=[8.0–8.0], last=8.0 (single_observation)
#   O2 Flow: mean=2.5, range=[2.0–4.0], last=2.0 (improving)
#   Sodium: mean=146.0, range=[146.0–146.0], last=146.0 (single_observation)
#   Hemoglobin: mean=7.8, range=[7.8–7.8], last=7.8 (single_observation)
#   Non Invasive Blood Pressure Alarm Low: mean=55.0, range=[55.0–55.0], last=55.0 (single_observation)
#   Non Invasive Blood Pressure Alarm High: mean=120.0, range=[120.0–120.0], last=120.0 (single_observation)
#   Chloride: mean=102.0, range=[102.0–102.0], last=102.0 (single_observation)
#   Anion Gap: mean=9.0, range=[9.0–9.0], last=9.0 (single_observation)
#
# LABORATORY VALUES:
#   H: mean=7.00, last=7.00 (single_observation)
#   L: mean=3.00, last=3.00 (single_observation)
#   I: mean=0.00, last=0.00 (single_observation)
#   Potassium: mean=4.50, last=4.50 (single_observation)
#   Sodium: mean=146.00, last=146.00 (single_observation)
#   Chloride: mean=102.00, last=102.00 (single_observation)
#   Creatinine: mean=1.30, last=1.30 (single_observation)
#   Urea Nitrogen: mean=34.00, last=34.00 (single_observation)
#   Bicarbonate: mean=35.00, last=35.00 (single_observation)
#   Anion Gap: mean=9.00, last=9.00 (single_observation)
#   Glucose: mean=97.00, last=97.00 (single_observation)
#   Magnesium: mean=2.00, last=2.00 (single_observation)
#   Hematocrit: mean=28.10, last=28.10 (single_observation)
#   Hemoglobin: mean=7.80, last=7.80 (single_observation)
#   Platelet Count: mean=299.00, last=299.00 (single_observation)
#   White Blood Cells: mean=12.50, last=12.50 (single_observation)
#   Mch: mean=24.60, last=24.60 (single_observation)
#   Mcv: mean=89.00, last=89.00 (single_observation)
#   Rdw: mean=18.90, last=18.90 (single_observation)
#   Mchc: mean=27.80, last=27.80 (single_observation)
#   Red Blood Cells: mean=3.17, last=3.17 (single_observation)
#   Rdw Sd: mean=62.00, last=62.00 (single_observation)
#   Phosphate: mean=4.60, last=4.60 (single_observation)
#   Calcium Total: mean=8.90, last=8.90 (single_observation)
#   Ptt: mean=31.30, last=31.30 (single_observation)
#   Ph: mean=7.33, last=7.37 (stable)
#   Pt: mean=29.60, last=29.60 (single_observation)
#   Inr: mean=2.70, last=2.70 (single_observation)
#   Po2: mean=89.00, last=48.00 (improving)
#
# INTERVENTIONS:
#   Medications: nacl_0_9, dextrose_5, solution, po_intake
#   Procedures: 18_gauge, foley_catheter
#
# ── 4. LSTM TOP-K (agent sees top pick + other candidates, no probs) ──
#   LSTM top-3 with probs (for your reference only):
#     1. HEART_FAILURE              51.5%
#     2. SEPSIS                     41.5% ✓
#     3. ACUTE_MI                    6.8%
#   What the agent will see:
#     LSTM TOP PICK    : HEART_FAILURE
#     Other candidates :
#       - SEPSIS
#       - ACUTE_MI
#
# ██████████████████████████████████████████████████████████████████████████████
# █ AGENT-SAFE CARD PREVIEW  [3/5]
# ██████████████████████████████████████████████████████████████████████████████
#
# ➤ GROUND TRUTH (not shown to agent):  SEPSIS
#   (integer label 0, patient 11693201)
#
# ── 1. AGENT-SAFE CARD (top-level keys) ──
#   Keys     : ['clinical_summary', 'feature_names', 'patient_id', 'stay_id', 'time_series', 'visit_id']
#   Stripped : ['clinical_group', 'conditions', 'drugs', 'icd_code', 'label', 'procedures']
#
# ── 2. FULL clinical_summary DICT ──
# {'vitals': {'heart_rate': {'mean': 104.95,
#                            'min': 85.0,
#                            'max': 116.0,
#                            'last': 116.0,
#                            'first': 93.0,
#                            'trend': 'worsening',
#                            'n_observations': 12},
#             'respiratory_rate': {'mean': 20.15,
#                                  'min': 14.0,
#                                  'max': 27.0,
#                                  'last': 14.0,
#                                  'first': 16.0,
#                                  'trend': 'improving',
#                                  'n_observations': 12},
#             'o2_saturation_pulseoxymetry': {'mean': 97.35,
#                                             'min': 94.67,
#                                             'max': 99.0,
#                                             'last': 99.0,
#                                             'first': 98.0,
#                                             'trend': 'stable',
#                                             'n_observations': 12},
#             'non_invasive_blood_pressure_systolic': {'mean': 117.09,
#                                                      'min': 94.75,
#                                                      'max': 140.0,
#                                                      'last': 124.0,
#                                                      'first': 126.0,
#                                                      'trend': 'stable',
#                                                      'n_observations': 8},
#             'non_invasive_blood_pressure_diastolic': {'mean': 62.28,
#                                                       'min': 49.0,
#                                                       'max': 86.0,
#                                                       'last': 57.0,
#                                                       'first': 71.0,
#                                                       'trend': 'improving',
#                                                       'n_observations': 8},
#             'non_invasive_blood_pressure_mean': {'mean': 78.44,
#                                                  'min': 66.5,
#                                                  'max': 94.0,
#                                                  'last': 79.0,
#                                                  'first': 89.0,
#                                                  'trend': 'improving',
#                                                  'n_observations': 8},
#             'arterial_blood_pressure_mean': {'mean': 71.4,
#                                              'min': 61.0,
#                                              'max': 78.0,
#                                              'last': 78.0,
#                                              'first': 61.0,
#                                              'trend': 'worsening',
#                                              'n_observations': 5},
#             'arterial_blood_pressure_systolic': {'mean': 110.0,
#                                                  'min': 81.0,
#                                                  'max': 128.0,
#                                                  'last': 117.0,
#                                                  'first': 118.0,
#                                                  'trend': 'stable',
#                                                  'n_observations': 5},
#             'arterial_blood_pressure_diastolic': {'mean': 55.0,
#                                                   'min': 42.0,
#                                                   'max': 73.0,
#                                                   'last': 57.0,
#                                                   'first': 42.0,
#                                                   'trend': 'worsening',
#                                                   'n_observations': 5},
#             'temperature_fahrenheit': {'mean': 98.03,
#                                        'min': 97.6,
#                                        'max': 98.3,
#                                        'last': 98.3,
#                                        'first': 98.2,
#                                        'trend': 'stable',
#                                        'n_observations': 3},
#             'glucose_finger_stick': {'mean': 168.0,
#                                      'min': 136.0,
#                                      'max': 200.0,
#                                      'last': 136.0,
#                                      'first': 200.0,
#                                      'trend': 'improving',
#                                      'n_observations': 2},
#             'heart_rate_alarm_low': {'mean': 40.0,
#                                      'min': 40.0,
#                                      'max': 40.0,
#                                      'last': 40.0,
#                                      'first': 40.0,
#                                      'trend': 'single_observation',
#                                      'n_observations': 1},
#             'heart_rate_alarm_high': {'mean': 130.0,
#                                       'min': 130.0,
#                                       'max': 130.0,
#                                       'last': 130.0,
#                                       'first': 130.0,
#                                       'trend': 'single_observation',
#                                       'n_observations': 1},
#             'o2_saturation_pulseoxymetry_alarm_low': {'mean': 90.0,
#                                                       'min': 90.0,
#                                                       'max': 90.0,
#                                                       'last': 90.0,
#                                                       'first': 90.0,
#                                                       'trend': 'single_observation',
#                                                       'n_observations': 1},
#             'o2_saturation_pulseoxymetry_alarm_high': {'mean': 100.0,
#                                                        'min': 100.0,
#                                                        'max': 100.0,
#                                                        'last': 100.0,
#                                                        'first': 100.0,
#                                                        'trend': 'single_observation',
#                                                        'n_observations': 1},
#             'spo2_desat_limit': {'mean': 85.0,
#                                  'min': 85.0,
#                                  'max': 85.0,
#                                  'last': 85.0,
#                                  'first': 85.0,
#                                  'trend': 'single_observation',
#                                  'n_observations': 1},
#             'resp_alarm_high': {'mean': 35.0,
#                                 'min': 35.0,
#                                 'max': 35.0,
#                                 'last': 35.0,
#                                 'first': 35.0,
#                                 'trend': 'single_observation',
#                                 'n_observations': 1},
#             'resp_alarm_low': {'mean': 8.0,
#                                'min': 8.0,
#                                'max': 8.0,
#                                'last': 8.0,
#                                'first': 8.0,
#                                'trend': 'single_observation',
#                                'n_observations': 1},
#             'sodium': {'mean': 127.0,
#                        'min': 127.0,
#                        'max': 127.0,
#                        'last': 127.0,
#                        'first': 127.0,
#                        'trend': 'single_observation',
#                        'n_observations': 1},
#             'hemoglobin': {'mean': 7.7,
#                            'min': 7.7,
#                            'max': 7.7,
#                            'last': 7.7,
#                            'first': 7.7,
#                            'trend': 'single_observation',
#                            'n_observations': 1},
#             'non_invasive_blood_pressure_alarm_low': {'mean': 60.0,
#                                                       'min': 60.0,
#                                                       'max': 60.0,
#                                                       'last': 60.0,
#                                                       'first': 60.0,
#                                                       'trend': 'single_observation',
#                                                       'n_observations': 1},
#             'non_invasive_blood_pressure_alarm_high': {'mean': 120.0,
#                                                        'min': 120.0,
#                                                        'max': 120.0,
#                                                        'last': 120.0,
#                                                        'first': 120.0,
#                                                        'trend': 'single_observation',
#                                                        'n_observations': 1},
#             'chloride': {'mean': 91.0,
#                          'min': 91.0,
#                          'max': 91.0,
#                          'last': 91.0,
#                          'first': 91.0,
#                          'trend': 'single_observation',
#                          'n_observations': 1},
#             'anion_gap': {'mean': 11.0,
#                           'min': 11.0,
#                           'max': 11.0,
#                           'last': 11.0,
#                           'first': 11.0,
#                           'trend': 'single_observation',
#                           'n_observations': 1}},
#  'labs': {'h': {'mean': 2.0,
#                 'min': 2.0,
#                 'max': 2.0,
#                 'last': 2.0,
#                 'first': 2.0,
#                 'trend': 'single_observation',
#                 'n_observations': 1},
#           'l': {'mean': 19.0,
#                 'min': 19.0,
#                 'max': 19.0,
#                 'last': 19.0,
#                 'first': 19.0,
#                 'trend': 'single_observation',
#                 'n_observations': 1},
#           'i': {'mean': 1.0,
#                 'min': 1.0,
#                 'max': 1.0,
#                 'last': 1.0,
#                 'first': 1.0,
#                 'trend': 'single_observation',
#                 'n_observations': 1},
#           'potassium': {'mean': 4.0,
#                         'min': 4.0,
#                         'max': 4.0,
#                         'last': 4.0,
#                         'first': 4.0,
#                         'trend': 'single_observation',
#                         'n_observations': 1},
#           'sodium': {'mean': 127.0,
#                      'min': 127.0,
#                      'max': 127.0,
#                      'last': 127.0,
#                      'first': 127.0,
#                      'trend': 'single_observation',
#                      'n_observations': 1},
#           'chloride': {'mean': 91.0,
#                        'min': 91.0,
#                        'max': 91.0,
#                        'last': 91.0,
#                        'first': 91.0,
#                        'trend': 'single_observation',
#                        'n_observations': 1},
#           'creatinine': {'mean': 3.4,
#                          'min': 3.4,
#                          'max': 3.4,
#                          'last': 3.4,
#                          'first': 3.4,
#                          'trend': 'single_observation',
#                          'n_observations': 1},
#           'urea_nitrogen': {'mean': 51.0,
#                             'min': 51.0,
#                             'max': 51.0,
#                             'last': 51.0,
#                             'first': 51.0,
#                             'trend': 'single_observation',
#                             'n_observations': 1},
#           'bicarbonate': {'mean': 25.0,
#                           'min': 25.0,
#                           'max': 25.0,
#                           'last': 25.0,
#                           'first': 25.0,
#                           'trend': 'single_observation',
#                           'n_observations': 1},
#           'anion_gap': {'mean': 11.0,
#                         'min': 11.0,
#                         'max': 11.0,
#                         'last': 11.0,
#                         'first': 11.0,
#                         'trend': 'single_observation',
#                         'n_observations': 1},
#           'glucose': {'mean': 181.0,
#                       'min': 181.0,
#                       'max': 181.0,
#                       'last': 181.0,
#                       'first': 181.0,
#                       'trend': 'single_observation',
#                       'n_observations': 1},
#           'magnesium': {'mean': 2.2,
#                         'min': 2.2,
#                         'max': 2.2,
#                         'last': 2.2,
#                         'first': 2.2,
#                         'trend': 'single_observation',
#                         'n_observations': 1},
#           'hematocrit': {'mean': 24.6,
#                          'min': 24.6,
#                          'max': 24.6,
#                          'last': 24.6,
#                          'first': 24.6,
#                          'trend': 'single_observation',
#                          'n_observations': 1},
#           'hemoglobin': {'mean': 7.7,
#                          'min': 7.7,
#                          'max': 7.7,
#                          'last': 7.7,
#                          'first': 7.7,
#                          'trend': 'single_observation',
#                          'n_observations': 1},
#           'platelet_count': {'mean': 200.0,
#                              'min': 200.0,
#                              'max': 200.0,
#                              'last': 200.0,
#                              'first': 200.0,
#                              'trend': 'single_observation',
#                              'n_observations': 1},
#           'white_blood_cells': {'mean': 7.4,
#                                 'min': 7.4,
#                                 'max': 7.4,
#                                 'last': 7.4,
#                                 'first': 7.4,
#                                 'trend': 'single_observation',
#                                 'n_observations': 1},
#           'mch': {'mean': 30.0,
#                   'min': 30.0,
#                   'max': 30.0,
#                   'last': 30.0,
#                   'first': 30.0,
#                   'trend': 'single_observation',
#                   'n_observations': 1},
#           'mcv': {'mean': 96.0,
#                   'min': 96.0,
#                   'max': 96.0,
#                   'last': 96.0,
#                   'first': 96.0,
#                   'trend': 'single_observation',
#                   'n_observations': 1},
#           'rdw': {'mean': 15.7,
#                   'min': 15.7,
#                   'max': 15.7,
#                   'last': 15.7,
#                   'first': 15.7,
#                   'trend': 'single_observation',
#                   'n_observations': 1},
#           'mchc': {'mean': 31.3,
#                    'min': 31.3,
#                    'max': 31.3,
#                    'last': 31.3,
#                    'first': 31.3,
#                    'trend': 'single_observation',
#                    'n_observations': 1},
#           'red_blood_cells': {'mean': 2.57,
#                               'min': 2.57,
#                               'max': 2.57,
#                               'last': 2.57,
#                               'first': 2.57,
#                               'trend': 'single_observation',
#                               'n_observations': 1},
#           'rdw_sd': {'mean': 55.3,
#                      'min': 55.3,
#                      'max': 55.3,
#                      'last': 55.3,
#                      'first': 55.3,
#                      'trend': 'single_observation',
#                      'n_observations': 1},
#           'phosphate': {'mean': 3.3,
#                         'min': 3.3,
#                         'max': 3.3,
#                         'last': 3.3,
#                         'first': 3.3,
#                         'trend': 'single_observation',
#                         'n_observations': 1},
#           'calcium_total': {'mean': 8.4,
#                             'min': 8.4,
#                             'max': 8.4,
#                             'last': 8.4,
#                             'first': 8.4,
#                             'trend': 'single_observation',
#                             'n_observations': 1},
#           'ptt': {'mean': 30.0,
#                   'min': 30.0,
#                   'max': 30.0,
#                   'last': 30.0,
#                   'first': 30.0,
#                   'trend': 'single_observation',
#                   'n_observations': 1},
#           'pt': {'mean': 10.8,
#                  'min': 10.8,
#                  'max': 10.8,
#                  'last': 10.8,
#                  'first': 10.8,
#                  'trend': 'single_observation',
#                  'n_observations': 1},
#           'inr': {'mean': 1.0,
#                   'min': 1.0,
#                   'max': 1.0,
#                   'last': 1.0,
#                   'first': 1.0,
#                   'trend': 'single_observation',
#                   'n_observations': 1}},
#  'interventions': {'active_drugs': [],
#                    'active_procedures': ['arterial_line'],
#                    'urine_output_total_ml': 300.0},
#  'observation_hours': 12,
#  'pct_hours_monitored': 1.0}
#
# ── 3. FORMATTED CLINICAL SUMMARY (exact text in prompt) ──
# VITAL SIGNS (Last 12 Hours):
#   Heart Rate: mean=105.0, range=[85.0–116.0], last=116.0 (worsening)
# ...
#  'observation_hours': 12,
#  'pct_hours_monitored': 0.75}
#
# ── 3. FORMATTED CLINICAL SUMMARY (exact text in prompt) ──
# VITAL SIGNS (Last 12 Hours):
#   Heart Rate: mean=90.4, range=[73.0–108.0], last=108.0 (worsening)
#   Respiratory Rate: mean=20.2, range=[16.0–26.0], last=26.0 (worsening)
#   O2 Saturation Pulseoxymetry: mean=95.8, range=[94.0–97.0], last=96.0 (stable)
#   Non Invasive Blood Pressure Systolic: mean=116.9, range=[97.0–136.0], last=132.0 (stable)
#   Non Invasive Blood Pressure Diastolic: mean=67.0, range=[54.0–81.0], last=68.0 (stable)
#   Non Invasive Blood Pressure Mean: mean=77.8, range=[64.0–91.0], last=81.0 (stable)
#   Temperature Fahrenheit: mean=98.2, range=[98.0–98.3], last=98.3 (stable)
#   Heart Rate Alarm Low: mean=40.0, range=[40.0–40.0], last=40.0 (stable)
#   Heart Rate Alarm High: mean=130.0, range=[130.0–130.0], last=130.0 (stable)
#   O2 Saturation Pulseoxymetry Alarm Low: mean=91.0, range=[90.0–92.0], last=90.0 (stable)
#   O2 Saturation Pulseoxymetry Alarm High: mean=100.0, range=[100.0–100.0], last=100.0 (stable)
#   Spo2 Desat Limit: mean=85.0, range=[85.0–85.0], last=85.0 (stable)
#   Resp Alarm High: mean=35.0, range=[35.0–35.0], last=35.0 (stable)
#   Resp Alarm Low: mean=8.0, range=[8.0–8.0], last=8.0 (stable)
#   O2 Flow: mean=1.0, range=[1.0–1.0], last=1.0 (single_observation)
#   Non Invasive Blood Pressure Alarm Low: mean=125.0, range=[90.0–160.0], last=90.0 (improving)
#   Non Invasive Blood Pressure Alarm High: mean=125.0, range=[90.0–160.0], last=160.0 (worsening)
#
# LABORATORY VALUES:
#   H: mean=8.00, last=8.00 (single_observation)
#   L: mean=10.00, last=10.00 (single_observation)
#   I: mean=1.00, last=1.00 (single_observation)
#
# INTERVENTIONS:
#   Medications: nacl_0_9, dextrose_5, po_intake
#   Procedures: 20_gauge
#
# ── 4. LSTM TOP-K (agent sees top pick + other candidates, no probs) ──
#   LSTM top-3 with probs (for your reference only):
#     1. SEPSIS                     60.9% ✓
#     2. ACUTE_MI                   18.0%
#     3. HEART_FAILURE              17.6%
#   What the agent will see:
#     LSTM TOP PICK    : SEPSIS
#     Other candidates :
#       - ACUTE_MI
#       - HEART_FAILURE
#
# ██████████████████████████████████████████████████████████████████████████████
# █ AGENT-SAFE CARD PREVIEW  [5/5]
# ██████████████████████████████████████████████████████████████████████████████
#
# ➤ GROUND TRUTH (not shown to agent):  SEPSIS
#   (integer label 0, patient 13789582)
#
# ── 1. AGENT-SAFE CARD (top-level keys) ──
#   Keys     : ['clinical_summary', 'feature_names', 'patient_id', 'stay_id', 'time_series', 'visit_id']
#   Stripped : ['clinical_group', 'conditions', 'drugs', 'icd_code', 'label', 'procedures']
#
# ── 2. FULL clinical_summary DICT ──
# {'vitals': {'heart_rate': {'mean': 77.06,
#                            'min': 67.0,
#                            'max': 86.0,
#                            'last': 82.0,
#                            'first': 76.0,
#                            'trend': 'stable',
#                            'n_observations': 11},
#             'respiratory_rate': {'mean': 18.48,
#                                  'min': 15.0,
#                                  'max': 26.0,
#                                  'last': 24.0,
#                                  'first': 16.0,
#                                  'trend': 'worsening',
#                                  'n_observations': 11},
#             'o2_saturation_pulseoxymetry': {'mean': 99.73,
#                                             'min': 98.33,
#                                             'max': 100.0,
#                                             'last': 100.0,
#                                             'first': 99.0,
#                                             'trend': 'stable',
#                                             'n_observations': 10},
#             'non_invasive_blood_pressure_systolic': {'mean': 107.42,
#                                                      'min': 89.0,
#                                                      'max': 119.0,
#                                                      'last': 100.0,
#                                                      'first': 102.0,
#                                                      'trend': 'stable',
#                                                      'n_observations': 11},
#             'non_invasive_blood_pressure_diastolic': {'mean': 66.76,
#                                                       'min': 49.0,
#                                                       'max': 98.0,
#                                                       'last': 60.0,
#                                                       'first': 60.0,
#                                                       'trend': 'stable',
#                                                       'n_observations': 11},
#             'non_invasive_blood_pressure_mean': {'mean': 78.97,
#                                                  'min': 60.0,
#                                                  'max': 106.0,
#                                                  'last': 74.0,
#                                                  'first': 73.0,
#                                                  'trend': 'stable',
#                                                  'n_observations': 11},
#             'temperature_fahrenheit': {'mean': 98.43,
#                                        'min': 98.2,
#                                        'max': 98.8,
#                                        'last': 98.8,
#                                        'first': 98.2,
#                                        'trend': 'stable',
#                                        'n_observations': 3},
#             'glucose_finger_stick': {'mean': 263.0,
#                                      'min': 263.0,
#                                      'max': 263.0,
#                                      'last': 263.0,
#                                      'first': 263.0,
#                                      'trend': 'single_observation',
#                                      'n_observations': 1},
#             'heart_rate_alarm_low': {'mean': 50.0,
#                                      'min': 50.0,
#                                      'max': 50.0,
#                                      'last': 50.0,
#                                      'first': 50.0,
#                                      'trend': 'single_observation',
#                                      'n_observations': 1},
#             'heart_rate_alarm_high': {'mean': 130.0,
#                                       'min': 130.0,
#                                       'max': 130.0,
#                                       'last': 130.0,
#                                       'first': 130.0,
#                                       'trend': 'single_observation',
#                                       'n_observations': 1},
#             'o2_saturation_pulseoxymetry_alarm_low': {'mean': 92.0,
#                                                       'min': 92.0,
#                                                       'max': 92.0,
#                                                       'last': 92.0,
#                                                       'first': 92.0,
#                                                       'trend': 'single_observation',
#                                                       'n_observations': 1},
#             'o2_saturation_pulseoxymetry_alarm_high': {'mean': 100.0,
#                                                        'min': 100.0,
#                                                        'max': 100.0,
#                                                        'last': 100.0,
#                                                        'first': 100.0,
#                                                        'trend': 'single_observation',
#                                                        'n_observations': 1},
#             'spo2_desat_limit': {'mean': 88.0,
#                                  'min': 88.0,
#                                  'max': 88.0,
#                                  'last': 88.0,
#                                  'first': 88.0,
#                                  'trend': 'single_observation',
#                                  'n_observations': 1},
#             'resp_alarm_high': {'mean': 35.0,
#                                 'min': 35.0,
#                                 'max': 35.0,
#                                 'last': 35.0,
#                                 'first': 35.0,
#                                 'trend': 'single_observation',
#                                 'n_observations': 1},
#             'resp_alarm_low': {'mean': 8.0,
#                                'min': 8.0,
#                                'max': 8.0,
#                                'last': 8.0,
#                                'first': 8.0,
#                                'trend': 'single_observation',
#                                'n_observations': 1},
#             'hemoglobin': {'mean': 9.4,
#                            'min': 9.4,
#                            'max': 9.4,
#                            'last': 9.4,
#                            'first': 9.4,
#                            'trend': 'single_observation',
#                            'n_observations': 1},
#             'non_invasive_blood_pressure_alarm_low': {'mean': 90.0,
#                                                       'min': 90.0,
#                                                       'max': 90.0,
#                                                       'last': 90.0,
#                                                       'first': 90.0,
#                                                       'trend': 'single_observation',
#                                                       'n_observations': 1},
#             'non_invasive_blood_pressure_alarm_high': {'mean': 160.0,
#                                                        'min': 160.0,
#                                                        'max': 160.0,
#                                                        'last': 160.0,
#                                                        'first': 160.0,
#                                                        'trend': 'single_observation',
#                                                        'n_observations': 1}},
#  'labs': {'hematocrit': {'mean': 28.3,
#                          'min': 28.3,
#                          'max': 28.3,
#                          'last': 28.3,
#                          'first': 28.3,
#                          'trend': 'single_observation',
#                          'n_observations': 1},
#           'hemoglobin': {'mean': 9.4,
#                          'min': 9.4,
#                          'max': 9.4,
#                          'last': 9.4,
#                          'first': 9.4,
#                          'trend': 'single_observation',
#                          'n_observations': 1},
#           'platelet_count': {'mean': 242.0,
#                              'min': 242.0,
#                              'max': 242.0,
#                              'last': 242.0,
#                              'first': 242.0,
#                              'trend': 'single_observation',
#                              'n_observations': 1},
#           'white_blood_cells': {'mean': 12.3,
#                                 'min': 12.3,
#                                 'max': 12.3,
#                                 'last': 12.3,
#                                 'first': 12.3,
#                                 'trend': 'single_observation',
#                                 'n_observations': 1},
#           'mch': {'mean': 30.7,
#                   'min': 30.7,
#                   'max': 30.7,
#                   'last': 30.7,
#                   'first': 30.7,
#                   'trend': 'single_observation',
#                   'n_observations': 1},
#           'mcv': {'mean': 93.0,
#                   'min': 93.0,
#                   'max': 93.0,
#                   'last': 93.0,
#                   'first': 93.0,
#                   'trend': 'single_observation',
#                   'n_observations': 1},
#           'rdw': {'mean': 16.7,
#                   'min': 16.7,
#                   'max': 16.7,
#                   'last': 16.7,
#                   'first': 16.7,
#                   'trend': 'single_observation',
#                   'n_observations': 1},
#           'mchc': {'mean': 33.2,
#                    'min': 33.2,
#                    'max': 33.2,
#                    'last': 33.2,
#                    'first': 33.2,
#                    'trend': 'single_observation',
#                    'n_observations': 1},
#           'red_blood_cells': {'mean': 3.06,
#                               'min': 3.06,
#                               'max': 3.06,
#                               'last': 3.06,
#                               'first': 3.06,
#                               'trend': 'single_observation',
#                               'n_observations': 1},
#           'rdw_sd': {'mean': 50.5,
#                      'min': 50.5,
#                      'max': 50.5,
#                      'last': 50.5,
#                      'first': 50.5,
#                      'trend': 'single_observation',
#                      'n_observations': 1}},
#  'interventions': {'active_drugs': ['nacl_0_9'],
#                    'active_procedures': [],
#                    'urine_output_total_ml': 1525.0},
#  'observation_hours': 12,
#  'pct_hours_monitored': 0.92}
#
# ── 3. FORMATTED CLINICAL SUMMARY (exact text in prompt) ──
# VITAL SIGNS (Last 12 Hours):
#   Heart Rate: mean=77.1, range=[67.0–86.0], last=82.0 (stable)
#   Respiratory Rate: mean=18.5, range=[15.0–26.0], last=24.0 (worsening)
#   O2 Saturation Pulseoxymetry: mean=99.7, range=[98.3–100.0], last=100.0 (stable)
#   Non Invasive Blood Pressure Systolic: mean=107.4, range=[89.0–119.0], last=100.0 (stable)
#   Non Invasive Blood Pressure Diastolic: mean=66.8, range=[49.0–98.0], last=60.0 (stable)
#   Non Invasive Blood Pressure Mean: mean=79.0, range=[60.0–106.0], last=74.0 (stable)
#   Temperature Fahrenheit: mean=98.4, range=[98.2–98.8], last=98.8 (stable)
#   Glucose Finger Stick: mean=263.0, range=[263.0–263.0], last=263.0 (single_observation)
#   Heart Rate Alarm Low: mean=50.0, range=[50.0–50.0], last=50.0 (single_observation)
#   Heart Rate Alarm High: mean=130.0, range=[130.0–130.0], last=130.0 (single_observation)
#   O2 Saturation Pulseoxymetry Alarm Low: mean=92.0, range=[92.0–92.0], last=92.0 (single_observation)
#   O2 Saturation Pulseoxymetry Alarm High: mean=100.0, range=[100.0–100.0], last=100.0 (single_observation)
#   Spo2 Desat Limit: mean=88.0, range=[88.0–88.0], last=88.0 (single_observation)
#   Resp Alarm High: mean=35.0, range=[35.0–35.0], last=35.0 (single_observation)
#   Resp Alarm Low: mean=8.0, range=[8.0–8.0], last=8.0 (single_observation)
#   Hemoglobin: mean=9.4, range=[9.4–9.4], last=9.4 (single_observation)
#   Non Invasive Blood Pressure Alarm Low: mean=90.0, range=[90.0–90.0], last=90.0 (single_observation)
#   Non Invasive Blood Pressure Alarm High: mean=160.0, range=[160.0–160.0], last=160.0 (single_observation)
#
# LABORATORY VALUES:
#   Hematocrit: mean=28.30, last=28.30 (single_observation)
#   Hemoglobin: mean=9.40, last=9.40 (single_observation)
#   Platelet Count: mean=242.00, last=242.00 (single_observation)
#   White Blood Cells: mean=12.30, last=12.30 (single_observation)
#   Mch: mean=30.70, last=30.70 (single_observation)
#   Mcv: mean=93.00, last=93.00 (single_observation)
#   Rdw: mean=16.70, last=16.70 (single_observation)
#   Mchc: mean=33.20, last=33.20 (single_observation)
#   Red Blood Cells: mean=3.06, last=3.06 (single_observation)
#   Rdw Sd: mean=50.50, last=50.50 (single_observation)
#
# INTERVENTIONS:
#   Medications: nacl_0_9
#
# ── 4. LSTM TOP-K (agent sees top pick + other candidates, no probs) ──
#   LSTM top-3 with probs (for your reference only):
#     1. SEPSIS                     41.5% ✓
#     2. ACUTE_MI                   30.8%
#     3. CORONARY_ARTERY_DZ         18.3%
#   What the agent will see:
#     LSTM TOP PICK    : SEPSIS
#     Other candidates :
#       - ACUTE_MI
#       - CORONARY_ARTERY_DZ
#
# ██████████████████████████████████████████████████████████████████████████████
# █ End of agent-safe card preview (5 cards)
# ██████████████████████████████████████████████████████████████████████████████

# %%
# ══════════════════════════════════════════════════════════════════════════════
# SINGLE AGENT PROMPT — BLINDED to LSTM ranking
# ══════════════════════════════════════════════════════════════════════════════

SINGLE_AGENT_PROMPT = """
You are an expert ICU physician. You are given patient data and {top_k} possible diagnoses to consider. Your task is to determine which diagnosis best fits the clinical picture.

## PATIENT DATA (Last 12 Hours in ICU)
{clinical_summary}

## CANDIDATE DIAGNOSES
Consider these {top_k} possibilities (listed in no particular order):
{candidates_list}


## YOUR TASK
You are working with INCOMPLETE ICU data. Not all clinically relevant labs will be present. Your goal is to find the diagnosis most consistent with available evidence, explicitly accounting for what is and is not measured. A diagnosis should not be dismissed solely because its defining marker was not collected.


Respond with ONLY valid JSON:
{{
  "chosen_diagnosis": "DIAGNOSIS_NAME",
  "reasoning": "2-3 sentence explanation of why this diagnosis fits best",
  "supporting_evidence": ["key finding 1", "key finding 2", "key finding 3"],
  "ruled_out": [
    {{"diagnosis": "OTHER_DIAGNOSIS_1", "reason": "why ruled out"}},
    {{"diagnosis": "OTHER_DIAGNOSIS_2", "reason": "why ruled out"}}
  ]
}}

Your chosen_diagnosis MUST be one of the {top_k} candidates listed above.
"""

print('✓ Blinded single agent prompt defined (agent does NOT see LSTM ranking)')
# Out:
# ✓ Blinded single agent prompt defined (agent does NOT see LSTM ranking)

# %%
# ══════════════════════════════════════════════════════════════════════════════
# LLM WRAPPER (local MedGemma) — robust error handling + full tracebacks
# ══════════════════════════════════════════════════════════════════════════════
import re
import time
import traceback


def _is_oom(exc: BaseException) -> bool:
    """Detect GPU OOM across PyTorch versions.

    torch.cuda.OutOfMemoryError was only added in PyTorch 2.1; on older
    installs we fall back to sniffing the RuntimeError message.
    """
    oom_cls = getattr(torch.cuda, 'OutOfMemoryError', None)
    if oom_cls is not None and isinstance(exc, oom_cls):
        return True
    return isinstance(exc, RuntimeError) and 'out of memory' in str(exc).lower()


def call_llm(prompt: str) -> dict:
    """Call MedGemma 27B (local, 4-bit) and parse JSON from the response."""

    for attempt in range(RETRY_ATTEMPTS):
        try:
            # 1. Render chat template to a plain string, then tokenize explicitly.
            #    This avoids transformers-version differences in what
            #    apply_chat_template(return_tensors='pt') returns (tensor vs
            #    BatchEncoding) that caused the empty AttributeError.
            chat_text = llm_tokenizer.apply_chat_template(
                [{'role': 'user', 'content': prompt}],
                add_generation_prompt=True,
                tokenize=False,
            )
            inputs = llm_tokenizer(
                chat_text,
                return_tensors='pt',
            ).to(llm_model.device)

            # 2. Generate
            with torch.no_grad():
                outputs = llm_model.generate(
                    **inputs,
                    max_new_tokens=MAX_NEW_TOKENS,
                    do_sample=True,
                    temperature=TEMPERATURE,
                    pad_token_id=llm_tokenizer.pad_token_id,
                )

            # 3. Decode only new tokens
            prompt_len = inputs['input_ids'].shape[-1]
            new_tokens = outputs[0][prompt_len:]
            full_text = llm_tokenizer.decode(new_tokens, skip_special_tokens=True)

            if not full_text.strip():
                raise ValueError('Empty response from model')

            # 4. Extract JSON object from response
            json_match = re.search(r'\{[\s\S]*\}', full_text.strip())
            if not json_match:
                raise ValueError(f'No JSON found. First 200 chars: {full_text[:200]!r}')
            return json.loads(json_match.group(0))

        except Exception as e:
            if _is_oom(e):
                print('    ⚠ GPU OOM: clearing cache and retrying...')
                torch.cuda.empty_cache()
                time.sleep(5)
                continue

            # Show the full traceback — this is what we needed to debug the
            # original empty-AttributeError. Truncated str(e) hid everything.
            print(f'    ⚠ {type(e).__name__} on attempt {attempt+1}/{RETRY_ATTEMPTS}:')
            traceback.print_exc()
            if attempt < RETRY_ATTEMPTS - 1:
                time.sleep(2)

    return {'error': 'Failed after retries', 'chosen_diagnosis': None}

print('✓ MedGemma wrapper ready')
# Out:
# ✓ MedGemma wrapper ready

# %%
# ══════════════════════════════════════════════════════════════════════════════
# SINGLE AGENT DIAGNOSIS FUNCTION — BLINDED mode
# ══════════════════════════════════════════════════════════════════════════════
# The agent sees all K candidates in a SHUFFLED order, with no indication of
# which was the LSTM's top pick. 'accept' / 'override' labels are computed
# post-hoc by comparing the agent's choice to the LSTM top-1 — the agent itself
# is never told what the LSTM ranked first.


def diagnose_single_agent(patient_card: dict, verbose: bool = False) -> dict:
    """Run single-agent diagnosis on one patient, blinded to LSTM ranking."""

    def _log(title, body=None):
        if not verbose:
            return
        print(f'\n── {title} ──')
        if body is not None:
            print(body)

    # Build agent-safe view of the card. Everything the LLM sees comes from here.
    clinical_summary_for_agent = build_clinical_summary_for_agent(patient_card)
    _log('STEP A: agent-safe card (top-level keys)',
         f'  keys: {sorted(clinical_summary_for_agent.keys())}')

    # 1. LSTM top-K (uses stripped card — only needs time_series)
    lstm_output = get_lstm_predictions(clinical_summary_for_agent, TOP_K)
    if verbose:
        print('\n── STEP B: LSTM top-K (probs shown for reference — NOT shown to agent) ──')
        for _rank, (_c, _p) in enumerate(zip(lstm_output['top_k_codes'], lstm_output['top_k_probs'])):
            print(f'  {_rank+1}. {_c:<25} {_p:>6.1%}')

    # 2. Record LSTM top-1 for post-hoc agreement analysis (NOT shown to agent)
    lstm_top_pick = lstm_output['top_k_codes'][0]

    # 3. Shuffle the candidates. Seed per-patient so the order is reproducible
    #    across runs but independent of LSTM rank position.
    patient_id_for_seed = patient_card.get('patient_id') or patient_card.get('stay_id') or 0
    shuffle_rng = random.Random(hash(('shuffle', patient_id_for_seed, RANDOM_SEED)))
    shuffled_candidates = list(lstm_output['top_k_codes'])
    shuffle_rng.shuffle(shuffled_candidates)

    _log('STEP C: shuffled candidate order the agent will see (blinded)',
         '  ' + ' | '.join(shuffled_candidates))

    candidates_list = '\n'.join([f'- {code}' for code in shuffled_candidates])

    # 4. Build the prompt
    formatted_summary = format_clinical_summary(
        clinical_summary_for_agent.get('clinical_summary', {})
    )
    _log('STEP D: formatted clinical summary', formatted_summary)

    prompt = SINGLE_AGENT_PROMPT.format(
        top_k=TOP_K,
        clinical_summary=formatted_summary,
        candidates_list=candidates_list,
    )
    _log('STEP E: FULL PROMPT SENT TO LLM', prompt)

    # 5. Call LLM
    agent_output = call_llm(prompt)
    if verbose:
        print('\n── STEP F: RAW LLM RESPONSE (parsed JSON) ──')
        try:
            print(json.dumps(agent_output, indent=2, ensure_ascii=False))
        except (TypeError, ValueError):
            print(repr(agent_output))

    # 6. Extract prediction; normalize against the candidate set
    raw_pred = agent_output.get('chosen_diagnosis') or ''
    norm     = raw_pred.strip().strip('"\'.,').upper()
    lookup   = {c.strip().upper(): c for c in lstm_output['top_k_codes']}
    agent_pred = lookup.get(norm)

    if agent_pred is None:
        if verbose:
            print(f'\n  ⚠ chosen_diagnosis {raw_pred!r} not in top-K candidates; '
                  f'falling back to sentinel: {FALLBACK_SENTINEL}')
        agent_pred = FALLBACK_SENTINEL

    # 7. Compute post-hoc agreement label (agent itself never reported a decision)
    decision = 'accept' if agent_pred == lstm_top_pick else 'override'

    print(f'{agent_pred}  ({decision})')

    if verbose:
        print('\n── STEP G: AGENT REASONING (parsed fields) ──')
        print(f'  decision (post-hoc): {decision}   [agent was blinded; computed from chosen_diagnosis vs LSTM top-1]')
        print(f'  chosen_diagnosis   : {agent_pred}')
        _reasoning = agent_output.get('reasoning')
        if _reasoning:
            print('  reasoning        :')
            for line in str(_reasoning).splitlines() or [str(_reasoning)]:
                print(f'      {line}')
        _support = agent_output.get('supporting_evidence') or []
        if _support:
            print('  supporting_evidence:')
            for item in _support:
                print(f'      • {item}')
        _ruled = agent_output.get('ruled_out') or []
        if _ruled:
            print('  ruled_out:')
            for item in _ruled:
                if isinstance(item, dict):
                    print(f'      • {item.get("diagnosis", "?")}: {item.get("reason", "")}')
                else:
                    print(f'      • {item}')

    # 8. Ground truth from the ORIGINAL card (never sent to LLM)
    true_label = inv_label_map[patient_card['label']]

    return {
        'patient_id'            : patient_card.get('patient_id'),
        'stay_id'               : patient_card.get('stay_id'),
        'true_label'            : true_label,
        'lstm_output'           : lstm_output,
        'lstm_top_pick'         : lstm_top_pick,
        'candidates_shown_order': shuffled_candidates,  # exact order agent saw
        'agent_output'          : agent_output,
        'agent_prediction'      : agent_pred,
        'agent_decision'        : decision,             # post-hoc label
        'agent_disagrees'       : agent_pred != lstm_top_pick,
        'lstm_correct'          : lstm_top_pick == true_label,
        'agent_correct'         : agent_pred == true_label,
    }

print('✓ Blinded single agent system ready')
# Out:
# ✓ Blinded single agent system ready

# %% [markdown]
# ## 4. Run Pilot

# %%
# ══════════════════════════════════════════════════════════════════════════════
# RUN PILOT  (verbose: full per-case logging)
# ══════════════════════════════════════════════════════════════════════════════
from tqdm.notebook import tqdm
import datetime

print(f'Starting single-agent pilot: {len(pilot_cards)} cases')
print(f'LLM calls: {len(pilot_cards)} (1 per case)')
print(f'Model   : {MEDGEMMA_MODEL_ID}')
print(f'Verbose : True  — every step of every case will be printed in full.')
print('=' * 78)

results = []
start_time = datetime.datetime.now()

for i, card in enumerate(tqdm(pilot_cards, desc='Processing')):
    true_label = inv_label_map[card['label']]

    print('\n' + '═' * 78)
    print(f'CASE [{i+1}/{len(pilot_cards)}]  Patient {card["patient_id"]}  |  True: {true_label}')
    print('═' * 78)

    try:
        result = diagnose_single_agent(card, verbose=True)
        results.append(result)

        lstm_mark    = '✓' if result['lstm_correct']  else '✗'
        agent_mark   = '✓' if result['agent_correct'] else '✗'
        decision_tag = f'  ({result["agent_decision"].upper()})'
        print('\n── OUTCOME ──')
        print(f'  LSTM top pick : {result["lstm_top_pick"]} {lstm_mark}')
        print(f'  Agent pick    : {result["agent_prediction"]} {agent_mark}{decision_tag}')

    except Exception as e:
        print(f'\n  ERROR: {type(e).__name__}: {e}')
        results.append({'patient_id': card.get('patient_id'), 'error': str(e)})

elapsed = datetime.datetime.now() - start_time
print('\n' + '=' * 78)
print(f'Pilot complete — elapsed: {elapsed}')
print(f'Valid: {sum(1 for r in results if "error" not in r)}/{len(results)}')
# Out:
# Starting single-agent pilot: 100 cases
# LLM calls: 100 (1 per case)
# Model   : google/medgemma-27b-text-it
# Verbose : True  — every step of every case will be printed in full.
# ==============================================================================
# Processing:   0%|          | 0/100 [00:00<?, ?it/s]
# Streaming output truncated to the last 5000 lines.
# You are working with INCOMPLETE ICU data. Not all clinically relevant labs will be present. Your goal is to find the diagnosis most consistent with available evidence, explicitly accounting for what is and is not measured. A diagnosis should not be dismissed solely because its defining marker was not collected.
#
#
# Respond with ONLY valid JSON:
# {
#   "chosen_diagnosis": "DIAGNOSIS_NAME",
#   "reasoning": "2-3 sentence explanation of why this diagnosis fits best",
#   "supporting_evidence": ["key finding 1", "key finding 2", "key finding 3"],
#   "ruled_out": [
#     {"diagnosis": "OTHER_DIAGNOSIS_1", "reason": "why ruled out"},
#     {"diagnosis": "OTHER_DIAGNOSIS_2", "reason": "why ruled out"}
#   ]
# }
#
# Your chosen_diagnosis MUST be one of the 3 candidates listed above.
#
#
# ── STEP F: RAW LLM RESPONSE (parsed JSON) ──
# {
#   "chosen_diagnosis": "SEPSIS",
#   "reasoning": "The patient presents with worsening vital signs including increasing blood pressure and respiratory rate, despite stable oxygen saturation. While specific infection markers are missing, the overall clinical picture suggests a systemic inflammatory response, potentially sepsis, which requires immediate attention.",
#   "supporting_evidence": [
#     "Worsening systolic, diastolic, and mean blood pressure",
#     "Worsening respiratory rate",
#     "Hyponatremia (Sodium 129.0)"
#   ],
#   "ruled_out": [
#     {
#       "diagnosis": "CORONARY_ARTERY_DZ",
#       "reason": "No specific cardiac enzyme markers (e.g., Troponin) or EKG data are provided to support acute coronary syndrome or underlying coronary artery disease."
#     },
#     {
#       "diagnosis": "ACUTE_MI",
#       "reason": "Lack of specific cardiac markers (e.g., Troponin) or EKG findings makes acute myocardial infarction less likely based on the available data, although it cannot be definitively excluded."
#     }
#   ]
# }
# SEPSIS  (override)
#
# ── STEP G: AGENT REASONING (parsed fields) ──
#   decision (post-hoc): override   [agent was blinded; computed from chosen_diagnosis vs LSTM top-1]
#   chosen_diagnosis   : SEPSIS
#   reasoning        :
#       The patient presents with worsening vital signs including increasing blood pressure and respiratory rate, despite stable oxygen saturation. While specific infection markers are missing, the overall clinical picture suggests a systemic inflammatory response, potentially sepsis, which requires immediate attention.
#   supporting_evidence:
#       • Worsening systolic, diastolic, and mean blood pressure
#       • Worsening respiratory rate
#       • Hyponatremia (Sodium 129.0)
#   ruled_out:
#       • CORONARY_ARTERY_DZ: No specific cardiac enzyme markers (e.g., Troponin) or EKG data are provided to support acute coronary syndrome or underlying coronary artery disease.
#       • ACUTE_MI: Lack of specific cardiac markers (e.g., Troponin) or EKG findings makes acute myocardial infarction less likely based on the available data, although it cannot be definitively excluded.
#
# ── OUTCOME ──
#   LSTM top pick : CORONARY_ARTERY_DZ ✗
#   Agent pick    : SEPSIS ✗  (OVERRIDE)
#
# ══════════════════════════════════════════════════════════════════════════════
# CASE [70/100]  Patient 17864819  |  True: ACUTE_MI
# ══════════════════════════════════════════════════════════════════════════════
#
# ── STEP A: agent-safe card (top-level keys) ──
#   keys: ['clinical_summary', 'feature_names', 'patient_id', 'stay_id', 'time_series', 'visit_id']
#
# ── STEP B: LSTM top-K (probs shown for reference — NOT shown to agent) ──
#   1. HEART_FAILURE              43.3%
#   2. SEPSIS                     30.9%
#   3. ACUTE_MI                   24.5%
#
# ── STEP C: shuffled candidate order the agent will see (blinded) ──
#   ACUTE_MI | SEPSIS | HEART_FAILURE
#
# ── STEP D: formatted clinical summary ──
# VITAL SIGNS (Last 12 Hours):
#   Heart Rate: mean=103.1, range=[94.0–112.0], last=106.0 (stable)
#   Respiratory Rate: mean=26.7, range=[20.0–30.0], last=28.0 (worsening)
#   O2 Saturation Pulseoxymetry: mean=97.2, range=[95.0–99.0], last=97.0 (stable)
#   Non Invasive Blood Pressure Systolic: mean=127.2, range=[104.0–141.0], last=119.0 (improving)
#   Non Invasive Blood Pressure Diastolic: mean=74.2, range=[64.0–81.0], last=70.0 (improving)
#   Non Invasive Blood Pressure Mean: mean=90.6, range=[81.0–99.0], last=86.0 (improving)
#   Temperature Fahrenheit: mean=99.1, range=[98.6–99.7], last=98.8 (stable)
#   Glucose Finger Stick: mean=246.0, range=[241.0–251.0], last=241.0 (stable)
#   Heart Rate Alarm Low: mean=50.0, range=[50.0–50.0], last=50.0 (single_observation)
#   Heart Rate Alarm High: mean=130.0, range=[130.0–130.0], last=130.0 (single_observation)
#   O2 Saturation Pulseoxymetry Alarm Low: mean=92.0, range=[92.0–92.0], last=92.0 (single_observation)
#   O2 Saturation Pulseoxymetry Alarm High: mean=100.0, range=[100.0–100.0], last=100.0 (single_observation)
#   Spo2 Desat Limit: mean=85.0, range=[85.0–85.0], last=85.0 (single_observation)
#   Resp Alarm High: mean=35.0, range=[35.0–35.0], last=35.0 (single_observation)
#   Resp Alarm Low: mean=8.0, range=[8.0–8.0], last=8.0 (single_observation)
#   Non Invasive Blood Pressure Alarm Low: mean=90.0, range=[90.0–90.0], last=90.0 (single_observation)
#   Non Invasive Blood Pressure Alarm High: mean=160.0, range=[160.0–160.0], last=160.0 (single_observation)
#
# LABORATORY VALUES:
#   Ptt: mean=95.80, last=95.80 (single_observation)
#
# INTERVENTIONS:
#   Medications: dextrose_5, heparin_sodium
#   Procedures: 20_gauge, foley_catheter
#
# ── STEP E: FULL PROMPT SENT TO LLM ──
#
# You are an expert ICU physician. You are given patient data and 3 possible diagnoses to consider. Your task is to determine which diagnosis best fits the clinical picture.
#
# ## PATIENT DATA (Last 12 Hours in ICU)
# VITAL SIGNS (Last 12 Hours):
#   Heart Rate: mean=103.1, range=[94.0–112.0], last=106.0 (stable)
#   Respiratory Rate: mean=26.7, range=[20.0–30.0], last=28.0 (worsening)
#   O2 Saturation Pulseoxymetry: mean=97.2, range=[95.0–99.0], last=97.0 (stable)
#   Non Invasive Blood Pressure Systolic: mean=127.2, range=[104.0–141.0], last=119.0 (improving)
#   Non Invasive Blood Pressure Diastolic: mean=74.2, range=[64.0–81.0], last=70.0 (improving)
#   Non Invasive Blood Pressure Mean: mean=90.6, range=[81.0–99.0], last=86.0 (improving)
#   Temperature Fahrenheit: mean=99.1, range=[98.6–99.7], last=98.8 (stable)
#   Glucose Finger Stick: mean=246.0, range=[241.0–251.0], last=241.0 (stable)
#   Heart Rate Alarm Low: mean=50.0, range=[50.0–50.0], last=50.0 (single_observation)
#   Heart Rate Alarm High: mean=130.0, range=[130.0–130.0], last=130.0 (single_observation)
#   O2 Saturation Pulseoxymetry Alarm Low: mean=92.0, range=[92.0–92.0], last=92.0 (single_observation)
#   O2 Saturation Pulseoxymetry Alarm High: mean=100.0, range=[100.0–100.0], last=100.0 (single_observation)
#   Spo2 Desat Limit: mean=85.0, range=[85.0–85.0], last=85.0 (single_observation)
#   Resp Alarm High: mean=35.0, range=[35.0–35.0], last=35.0 (single_observation)
#   Resp Alarm Low: mean=8.0, range=[8.0–8.0], last=8.0 (single_observation)
#   Non Invasive Blood Pressure Alarm Low: mean=90.0, range=[90.0–90.0], last=90.0 (single_observation)
#   Non Invasive Blood Pressure Alarm High: mean=160.0, range=[160.0–160.0], last=160.0 (single_observation)
#
# LABORATORY VALUES:
#   Ptt: mean=95.80, last=95.80 (single_observation)
#
# INTERVENTIONS:
#   Medications: dextrose_5, heparin_sodium
#   Procedures: 20_gauge, foley_catheter
#
# ## CANDIDATE DIAGNOSES
# Consider these 3 possibilities (listed in no particular order):
# - ACUTE_MI
# - SEPSIS
# - HEART_FAILURE
#
#
# ## YOUR TASK
# You are working with INCOMPLETE ICU data. Not all clinically relevant labs will be present. Your goal is to find the diagnosis most consistent with available evidence, explicitly accounting for what is and is not measured. A diagnosis should not be dismissed solely because its defining marker was not collected.
#
#
# Respond with ONLY valid JSON:
# {
#   "chosen_diagnosis": "DIAGNOSIS_NAME",
#   "reasoning": "2-3 sentence explanation of why this diagnosis fits best",
#   "supporting_evidence": ["key finding 1", "key finding 2", "key finding 3"],
#   "ruled_out": [
#     {"diagnosis": "OTHER_DIAGNOSIS_1", "reason": "why ruled out"},
#     {"diagnosis": "OTHER_DIAGNOSIS_2", "reason": "why ruled out"}
#   ]
# }
#
# Your chosen_diagnosis MUST be one of the 3 candidates listed above.
#
#
# ── STEP F: RAW LLM RESPONSE (parsed JSON) ──
# {
#   "chosen_diagnosis": "SEPSIS",
#   "reasoning": "The patient presents with tachycardia (mean HR 103.1) and tachypnea (mean RR 26.7, worsening), which are common signs of sepsis. While blood pressure is currently stable/improving, the initial presentation and persistent elevated heart rate and respiratory rate are highly suggestive of a systemic inflammatory response. The lack of specific sepsis markers (like lactate or WBC count) doesn't rule it out, as these are often collected later or may not be immediately available.",
#   "supporting_evidence": [
#     "Tachycardia (mean HR 103.1)",
#     "Tachypnea (mean RR 26.7, worsening)",
#     "Elevated temperature (mean 99.1)"
#   ],
#   "ruled_out": [
#     {
#       "diagnosis": "ACUTE_MI",
#       "reason": "No specific ECG or cardiac enzyme data is provided, but the vital signs (stable BP, stable O2 sat) are less typical for an acute MI presentation, although not definitive."
#     },
#     {
#       "diagnosis": "HEART_FAILURE",
#       "reason": "While tachycardia and tachypnea can occur in heart failure, the improving blood pressure and stable oxygen saturation make acute decompensated heart failure less likely as the primary driver compared to sepsis, especially without other signs like edema or specific imaging."
#     }
#   ]
# }
# SEPSIS  (override)
#
# ── STEP G: AGENT REASONING (parsed fields) ──
#   decision (post-hoc): override   [agent was blinded; computed from chosen_diagnosis vs LSTM top-1]
#   chosen_diagnosis   : SEPSIS
#   reasoning        :
#       The patient presents with tachycardia (mean HR 103.1) and tachypnea (mean RR 26.7, worsening), which are common signs of sepsis. While blood pressure is currently stable/improving, the initial presentation and persistent elevated heart rate and respiratory rate are highly suggestive of a systemic inflammatory response. The lack of specific sepsis markers (like lactate or WBC count) doesn't rule it out, as these are often collected later or may not be immediately available.
#   supporting_evidence:
#       • Tachycardia (mean HR 103.1)
#       • Tachypnea (mean RR 26.7, worsening)
#       • Elevated temperature (mean 99.1)
#   ruled_out:
#       • ACUTE_MI: No specific ECG or cardiac enzyme data is provided, but the vital signs (stable BP, stable O2 sat) are less typical for an acute MI presentation, although not definitive.
#       • HEART_FAILURE: While tachycardia and tachypnea can occur in heart failure, the improving blood pressure and stable oxygen saturation make acute decompensated heart failure less likely as the primary driver compared to sepsis, especially without other signs like edema or specific imaging.
#
# ── OUTCOME ──
#   LSTM top pick : HEART_FAILURE ✗
#   Agent pick    : SEPSIS ✗  (OVERRIDE)
#
# ══════════════════════════════════════════════════════════════════════════════
# CASE [71/100]  Patient 18255949  |  True: ACUTE_MI
# ══════════════════════════════════════════════════════════════════════════════
#
# ── STEP A: agent-safe card (top-level keys) ──
#   keys: ['clinical_summary', 'feature_names', 'patient_id', 'stay_id', 'time_series', 'visit_id']
#
# ── STEP B: LSTM top-K (probs shown for reference — NOT shown to agent) ──
#   1. HEART_FAILURE              46.4%
#   2. ACUTE_MI                   31.5%
#   3. SEPSIS                     17.7%
#
# ── STEP C: shuffled candidate order the agent will see (blinded) ──
#   ACUTE_MI | SEPSIS | HEART_FAILURE
#
# ── STEP D: formatted clinical summary ──
# VITAL SIGNS (Last 12 Hours):
#   Heart Rate: mean=88.4, range=[83.0–96.0], last=96.0 (worsening)
#   Respiratory Rate: mean=17.4, range=[13.0–21.0], last=16.0 (worsening)
#   O2 Saturation Pulseoxymetry: mean=96.0, range=[92.0–100.0], last=96.0 (stable)
#   Non Invasive Blood Pressure Systolic: mean=105.5, range=[98.0–109.0], last=109.0 (stable)
#   Non Invasive Blood Pressure Diastolic: mean=69.9, range=[66.0–77.0], last=66.0 (improving)
#   Non Invasive Blood Pressure Mean: mean=80.8, range=[77.0–85.0], last=80.0 (stable)
#   Temperature Fahrenheit: mean=98.4, range=[98.0–99.4], last=99.4 (stable)
#   Heart Rate Alarm Low: mean=50.0, range=[50.0–50.0], last=50.0 (single_observation)
#   Heart Rate Alarm High: mean=130.0, range=[130.0–130.0], last=130.0 (single_observation)
#   O2 Saturation Pulseoxymetry Alarm Low: mean=90.0, range=[90.0–90.0], last=90.0 (single_observation)
#   O2 Saturation Pulseoxymetry Alarm High: mean=100.0, range=[100.0–100.0], last=100.0 (single_observation)
#   Spo2 Desat Limit: mean=85.0, range=[85.0–85.0], last=85.0 (single_observation)
#   Resp Alarm High: mean=35.0, range=[35.0–35.0], last=35.0 (single_observation)
#   Resp Alarm Low: mean=8.0, range=[8.0–8.0], last=8.0 (single_observation)
#   O2 Flow: mean=2.7, range=[2.0–4.0], last=2.0 (improving)
#   Non Invasive Blood Pressure Alarm Low: mean=90.0, range=[90.0–90.0], last=90.0 (single_observation)
#   Non Invasive Blood Pressure Alarm High: mean=160.0, range=[160.0–160.0], last=160.0 (single_observation)
#
# LABORATORY VALUES:
#   Ptt: mean=45.60, last=45.60 (single_observation)
#
# INTERVENTIONS:
#   Medications: dextrose_5, po_intake, heparin_sodium
#   Procedures: 20_gauge, 18_gauge
#
# ── STEP E: FULL PROMPT SENT TO LLM ──
#
# You are an expert ICU physician. You are given patient data and 3 possible diagnoses to consider. Your task is to determine which diagnosis best fits the clinical picture.
#
# ## PATIENT DATA (Last 12 Hours in ICU)
# VITAL SIGNS (Last 12 Hours):
#   Heart Rate: mean=88.4, range=[83.0–96.0], last=96.0 (worsening)
#   Respiratory Rate: mean=17.4, range=[13.0–21.0], last=16.0 (worsening)
#   O2 Saturation Pulseoxymetry: mean=96.0, range=[92.0–100.0], last=96.0 (stable)
#   Non Invasive Blood Pressure Systolic: mean=105.5, range=[98.0–109.0], last=109.0 (stable)
#   Non Invasive Blood Pressure Diastolic: mean=69.9, range=[66.0–77.0], last=66.0 (improving)
#   Non Invasive Blood Pressure Mean: mean=80.8, range=[77.0–85.0], last=80.0 (stable)
#   Temperature Fahrenheit: mean=98.4, range=[98.0–99.4], last=99.4 (stable)
#   Heart Rate Alarm Low: mean=50.0, range=[50.0–50.0], last=50.0 (single_observation)
#   Heart Rate Alarm High: mean=130.0, range=[130.0–130.0], last=130.0 (single_observation)
#   O2 Saturation Pulseoxymetry Alarm Low: mean=90.0, range=[90.0–90.0], last=90.0 (single_observation)
#   O2 Saturation Pulseoxymetry Alarm High: mean=100.0, range=[100.0–100.0], last=100.0 (single_observation)
#   Spo2 Desat Limit: mean=85.0, range=[85.0–85.0], last=85.0 (single_observation)
#   Resp Alarm High: mean=35.0, range=[35.0–35.0], last=35.0 (single_observation)
#   Resp Alarm Low: mean=8.0, range=[8.0–8.0], last=8.0 (single_observation)
#   O2 Flow: mean=2.7, range=[2.0–4.0], last=2.0 (improving)
#   Non Invasive Blood Pressure Alarm Low: mean=90.0, range=[90.0–90.0], last=90.0 (single_observation)
#   Non Invasive Blood Pressure Alarm High: mean=160.0, range=[160.0–160.0], last=160.0 (single_observation)
#
# LABORATORY VALUES:
#   Ptt: mean=45.60, last=45.60 (single_observation)
#
# INTERVENTIONS:
#   Medications: dextrose_5, po_intake, heparin_sodium
#   Procedures: 20_gauge, 18_gauge
#
# ## CANDIDATE DIAGNOSES
# Consider these 3 possibilities (listed in no particular order):
# - ACUTE_MI
# - SEPSIS
# - HEART_FAILURE
#
#
# ## YOUR TASK
# You are working with INCOMPLETE ICU data. Not all clinically relevant labs will be present. Your goal is to find the diagnosis most consistent with available evidence, explicitly accounting for what is and is not measured. A diagnosis should not be dismissed solely because its defining marker was not collected.
#
#
# Respond with ONLY valid JSON:
# {
#   "chosen_diagnosis": "DIAGNOSIS_NAME",
#   "reasoning": "2-3 sentence explanation of why this diagnosis fits best",
#   "supporting_evidence": ["key finding 1", "key finding 2", "key finding 3"],
#   "ruled_out": [
#     {"diagnosis": "OTHER_DIAGNOSIS_1", "reason": "why ruled out"},
#     {"diagnosis": "OTHER_DIAGNOSIS_2", "reason": "why ruled out"}
#   ]
# }
#
# Your chosen_diagnosis MUST be one of the 3 candidates listed above.
#
#
# ── STEP F: RAW LLM RESPONSE (parsed JSON) ──
# {
#   "chosen_diagnosis": "SEPSIS",
#   "reasoning": "The patient exhibits worsening vital signs, specifically increasing heart rate and respiratory rate, which are common early indicators of sepsis. While oxygen saturation is stable, the overall trend suggests a systemic inflammatory response. The lack of specific sepsis markers (like lactate or WBC count) doesn't rule it out, as these are often not immediately available or may not be present yet.",
#   "supporting_evidence": [
#     "Worsening heart rate (mean 88.4, last 96.0)",
#     "Worsening respiratory rate (mean 17.4, last 16.0)",
#     "Presence of heparin (suggests potential underlying condition like DVT/PE or prophylaxis for sepsis risk)"
#   ],
#   "ruled_out": [
#     {
#       "diagnosis": "ACUTE_MI",
#       "reason": "No specific ECG or cardiac enzyme data is provided to support acute myocardial infarction. While tachycardia is present, it's not specific to MI."
#     },
#     {
#       "diagnosis": "HEART_FAILURE",
#       "reason": "While tachycardia and tachypnea can occur in heart failure, the stable oxygen saturation and lack of other typical signs (like significant hypotension or specific imaging/biomarker data) make it less likely than sepsis given the available information."
#     }
#   ]
# }
# SEPSIS  (override)
#
# ── STEP G: AGENT REASONING (parsed fields) ──
#   decision (post-hoc): override   [agent was blinded; computed from chosen_diagnosis vs LSTM top-1]
#   chosen_diagnosis   : SEPSIS
#   reasoning        :
#       The patient exhibits worsening vital signs, specifically increasing heart rate and respiratory rate, which are common early indicators of sepsis. While oxygen saturation is stable, the overall trend suggests a systemic inflammatory response. The lack of specific sepsis markers (like lactate or WBC count) doesn't rule it out, as these are often not immediately available or may not be present yet.
#   supporting_evidence:
#       • Worsening heart rate (mean 88.4, last 96.0)
#       • Worsening respiratory rate (mean 17.4, last 16.0)
#       • Presence of heparin (suggests potential underlying condition like DVT/PE or prophylaxis for sepsis risk)
#   ruled_out:
#       • ACUTE_MI: No specific ECG or cardiac enzyme data is provided to support acute myocardial infarction. While tachycardia is present, it's not specific to MI.
#       • HEART_FAILURE: While tachycardia and tachypnea can occur in heart failure, the stable oxygen saturation and lack of other typical signs (like significant hypotension or specific imaging/biomarker data) make it less likely than sepsis given the available information.
#
# ── OUTCOME ──
#   LSTM top pick : HEART_FAILURE ✗
#   Agent pick    : SEPSIS ✗  (OVERRIDE)
#
# ══════════════════════════════════════════════════════════════════════════════
# CASE [72/100]  Patient 14947978  |  True: ACUTE_MI
# ══════════════════════════════════════════════════════════════════════════════
#
# ── STEP A: agent-safe card (top-level keys) ──
#   keys: ['clinical_summary', 'feature_names', 'patient_id', 'stay_id', 'time_series', 'visit_id']
#
# ── STEP B: LSTM top-K (probs shown for reference — NOT shown to agent) ──
#   1. ACUTE_MI                   29.4%
#   2. CORONARY_ARTERY_DZ         29.2%
#   3. SEPSIS                     26.0%
#
# ── STEP C: shuffled candidate order the agent will see (blinded) ──
#   ACUTE_MI | SEPSIS | CORONARY_ARTERY_DZ
#
# ── STEP D: formatted clinical summary ──
# VITAL SIGNS (Last 12 Hours):
#   Heart Rate: mean=84.4, range=[71.0–97.0], last=75.0 (improving)
#   Respiratory Rate: mean=17.0, range=[12.0–21.0], last=17.0 (worsening)
#   O2 Saturation Pulseoxymetry: mean=95.5, range=[92.0–99.0], last=92.0 (stable)
#   Non Invasive Blood Pressure Systolic: mean=107.8, range=[93.0–128.0], last=93.0 (improving)
#   Non Invasive Blood Pressure Diastolic: mean=59.2, range=[54.0–63.0], last=60.0 (stable)
#   Non Invasive Blood Pressure Mean: mean=73.9, range=[67.0–80.0], last=71.0 (improving)
#   Temperature Fahrenheit: mean=99.4, range=[98.9–99.6], last=98.9 (stable)
#   Glucose Finger Stick: mean=90.3, range=[90.0–91.0], last=90.0 (stable)
#   Heart Rate Alarm Low: mean=60.0, range=[60.0–60.0], last=60.0 (single_observation)
#   Heart Rate Alarm High: mean=120.0, range=[120.0–120.0], last=120.0 (single_observation)
#   O2 Saturation Pulseoxymetry Alarm Low: mean=90.0, range=[90.0–90.0], last=90.0 (single_observation)
#   O2 Saturation Pulseoxymetry Alarm High: mean=100.0, range=[100.0–100.0], last=100.0 (single_observation)
#   Spo2 Desat Limit: mean=85.0, range=[85.0–85.0], last=85.0 (single_observation)
#   Resp Alarm High: mean=35.0, range=[35.0–35.0], last=35.0 (single_observation)
#   Resp Alarm Low: mean=8.0, range=[8.0–8.0], last=8.0 (single_observation)
#   O2 Flow: mean=2.0, range=[2.0–2.0], last=2.0 (single_observation)
#   Non Invasive Blood Pressure Alarm Low: mean=90.0, range=[90.0–90.0], last=90.0 (single_observation)
#   Non Invasive Blood Pressure Alarm High: mean=150.0, range=[150.0–150.0], last=150.0 (single_observation)
#
# LABORATORY VALUES:
#
# INTERVENTIONS:
#   Medications: po_intake
#   Procedures: 18_gauge
#
# ── STEP E: FULL PROMPT SENT TO LLM ──
#
# You are an expert ICU physician. You are given patient data and 3 possible diagnoses to consider. Your task is to determine which diagnosis best fits the clinical picture.
#
# ## PATIENT DATA (Last 12 Hours in ICU)
# VITAL SIGNS (Last 12 Hours):
#   Heart Rate: mean=84.4, range=[71.0–97.0], last=75.0 (improving)
#   Respiratory Rate: mean=17.0, range=[12.0–21.0], last=17.0 (worsening)
#   O2 Saturation Pulseoxymetry: mean=95.5, range=[92.0–99.0], last=92.0 (stable)
#   Non Invasive Blood Pressure Systolic: mean=107.8, range=[93.0–128.0], last=93.0 (improving)
#   Non Invasive Blood Pressure Diastolic: mean=59.2, range=[54.0–63.0], last=60.0 (stable)
#   Non Invasive Blood Pressure Mean: mean=73.9, range=[67.0–80.0], last=71.0 (improving)
#   Temperature Fahrenheit: mean=99.4, range=[98.9–99.6], last=98.9 (stable)
#   Glucose Finger Stick: mean=90.3, range=[90.0–91.0], last=90.0 (stable)
#   Heart Rate Alarm Low: mean=60.0, range=[60.0–60.0], last=60.0 (single_observation)
#   Heart Rate Alarm High: mean=120.0, range=[120.0–120.0], last=120.0 (single_observation)
#   O2 Saturation Pulseoxymetry Alarm Low: mean=90.0, range=[90.0–90.0], last=90.0 (single_observation)
#   O2 Saturation Pulseoxymetry Alarm High: mean=100.0, range=[100.0–100.0], last=100.0 (single_observation)
#   Spo2 Desat Limit: mean=85.0, range=[85.0–85.0], last=85.0 (single_observation)
#   Resp Alarm High: mean=35.0, range=[35.0–35.0], last=35.0 (single_observation)
#   Resp Alarm Low: mean=8.0, range=[8.0–8.0], last=8.0 (single_observation)
#   O2 Flow: mean=2.0, range=[2.0–2.0], last=2.0 (single_observation)
#   Non Invasive Blood Pressure Alarm Low: mean=90.0, range=[90.0–90.0], last=90.0 (single_observation)
#   Non Invasive Blood Pressure Alarm High: mean=150.0, range=[150.0–150.0], last=150.0 (single_observation)
#
# LABORATORY VALUES:
#
# INTERVENTIONS:
#   Medications: po_intake
#   Procedures: 18_gauge
#
# ## CANDIDATE DIAGNOSES
# Consider these 3 possibilities (listed in no particular order):
# - ACUTE_MI
# - SEPSIS
# - CORONARY_ARTERY_DZ
#
#
# ## YOUR TASK
# You are working with INCOMPLETE ICU data. Not all clinically relevant labs will be present. Your goal is to find the diagnosis most consistent with available evidence, explicitly accounting for what is and is not measured. A diagnosis should not be dismissed solely because its defining marker was not collected.
#
#
# Respond with ONLY valid JSON:
# {
#   "chosen_diagnosis": "DIAGNOSIS_NAME",
#   "reasoning": "2-3 sentence explanation of why this diagnosis fits best",
#   "supporting_evidence": ["key finding 1", "key finding 2", "key finding 3"],
#   "ruled_out": [
#     {"diagnosis": "OTHER_DIAGNOSIS_1", "reason": "why ruled out"},
#     {"diagnosis": "OTHER_DIAGNOSIS_2", "reason": "why ruled out"}
#   ]
# }
#
# Your chosen_diagnosis MUST be one of the 3 candidates listed above.
#
#
# ── STEP F: RAW LLM RESPONSE (parsed JSON) ──
# {
#   "chosen_diagnosis": "SEPSIS",
#   "reasoning": "The patient presents with a worsening respiratory rate despite relatively stable oxygen saturation and improving hemodynamics, which can be an early sign of sepsis. While specific sepsis markers like lactate or white blood cell count are missing, the overall clinical picture warrants high suspicion for sepsis, especially given the potential for subtle presentations in the ICU.",
#   "supporting_evidence": [
#     "Worsening respiratory rate (mean 17.0, range 12.0-21.0)",
#     "Stable but low-normal O2 saturation (mean 95.5, range 92.0-99.0)",
#     "Improving hemodynamics (mean BP improving, HR improving)"
#   ],
#   "ruled_out": [
#     {
#       "diagnosis": "ACUTE_MI",
#       "reason": "No specific ECG changes, troponin levels, or chest pain reported to suggest acute myocardial infarction."
#     },
#     {
#       "diagnosis": "CORONARY_ARTERY_DZ",
#       "reason": "This is a chronic condition, and while it could be present, the acute presentation doesn't strongly point to it as the primary driver of the current clinical changes. The data lacks information to confirm or deny underlying CAD, but the acute picture is more suggestive of sepsis."
#     }
#   ]
# }
# SEPSIS  (override)
#
# ── STEP G: AGENT REASONING (parsed fields) ──
#   decision (post-hoc): override   [agent was blinded; computed from chosen_diagnosis vs LSTM top-1]
#   chosen_diagnosis   : SEPSIS
#   reasoning        :
#       The patient presents with a worsening respiratory rate despite relatively stable oxygen saturation and improving hemodynamics, which can be an early sign of sepsis. While specific sepsis markers like lactate or white blood cell count are missing, the overall clinical picture warrants high suspicion for sepsis, especially given the potential for subtle presentations in the ICU.
#   supporting_evidence:
#       • Worsening respiratory rate (mean 17.0, range 12.0-21.0)
#       • Stable but low-normal O2 saturation (mean 95.5, range 92.0-99.0)
#       • Improving hemodynamics (mean BP improving, HR improving)
#   ruled_out:
#       • ACUTE_MI: No specific ECG changes, troponin levels, or chest pain reported to suggest acute myocardial infarction.
#       • CORONARY_ARTERY_DZ: This is a chronic condition, and while it could be present, the acute presentation doesn't strongly point to it as the primary driver of the current clinical changes. The data lacks information to confirm or deny underlying CAD, but the acute picture is more suggestive of sepsis.
#
# ── OUTCOME ──
#   LSTM top pick : ACUTE_MI ✓
#   Agent pick    : SEPSIS ✗  (OVERRIDE)
#
# ══════════════════════════════════════════════════════════════════════════════
# CASE [73/100]  Patient 19341048  |  True: ACUTE_MI
# ══════════════════════════════════════════════════════════════════════════════
#
# ── STEP A: agent-safe card (top-level keys) ──
#   keys: ['clinical_summary', 'feature_names', 'patient_id', 'stay_id', 'time_series', 'visit_id']
#
# ── STEP B: LSTM top-K (probs shown for reference — NOT shown to agent) ──
#   1. SEPSIS                     57.3%
#   2. CORONARY_ARTERY_DZ         18.8%
#   3. ACUTE_MI                   16.7%
#
# ── STEP C: shuffled candidate order the agent will see (blinded) ──
#   CORONARY_ARTERY_DZ | SEPSIS | ACUTE_MI
#
# ── STEP D: formatted clinical summary ──
# VITAL SIGNS (Last 12 Hours):
#   Heart Rate: mean=115.4, range=[102.0–139.0], last=109.0 (improving)
#   Respiratory Rate: mean=13.2, range=[10.0–19.0], last=13.0 (stable)
#   O2 Saturation Pulseoxymetry: mean=95.5, range=[93.0–98.0], last=96.0 (stable)
#   Non Invasive Blood Pressure Systolic: mean=118.4, range=[97.0–145.0], last=100.0 (stable)
#   Non Invasive Blood Pressure Diastolic: mean=81.9, range=[70.0–99.0], last=83.0 (stable)
#   Non Invasive Blood Pressure Mean: mean=92.6, range=[76.0–107.0], last=91.0 (stable)
#   Temperature Fahrenheit: mean=98.3, range=[97.9–98.7], last=97.9 (stable)
#   Glucose Finger Stick: mean=111.0, range=[111.0–111.0], last=111.0 (single_observation)
#   Heart Rate Alarm Low: mean=55.0, range=[55.0–55.0], last=55.0 (single_observation)
#   Heart Rate Alarm High: mean=160.0, range=[160.0–160.0], last=160.0 (single_observation)
#   O2 Saturation Pulseoxymetry Alarm Low: mean=92.0, range=[92.0–92.0], last=92.0 (single_observation)
#   O2 Saturation Pulseoxymetry Alarm High: mean=100.0, range=[100.0–100.0], last=100.0 (single_observation)
#   Spo2 Desat Limit: mean=85.0, range=[85.0–85.0], last=85.0 (single_observation)
#   Resp Alarm High: mean=35.0, range=[35.0–35.0], last=35.0 (single_observation)
#   Resp Alarm Low: mean=8.0, range=[8.0–8.0], last=8.0 (single_observation)
#   Sodium: mean=139.0, range=[139.0–139.0], last=139.0 (single_observation)
#   Hemoglobin: mean=9.2, range=[9.2–9.2], last=9.2 (single_observation)
#   Non Invasive Blood Pressure Alarm Low: mean=90.0, range=[90.0–90.0], last=90.0 (single_observation)
#   Non Invasive Blood Pressure Alarm High: mean=160.0, range=[160.0–160.0], last=160.0 (single_observation)
#   Chloride: mean=102.0, range=[102.0–102.0], last=102.0 (single_observation)
#   Anion Gap: mean=12.0, range=[12.0–12.0], last=12.0 (single_observation)
#
# LABORATORY VALUES:
#   H: mean=0.00, last=0.00 (single_observation)
#   L: mean=10.00, last=10.00 (single_observation)
#   I: mean=1.00, last=1.00 (single_observation)
#   Potassium: mean=5.00, last=5.00 (single_observation)
#   Sodium: mean=139.00, last=139.00 (single_observation)
#   Chloride: mean=102.00, last=102.00 (single_observation)
#   Creatinine: mean=1.70, last=1.70 (single_observation)
#   Urea Nitrogen: mean=37.00, last=37.00 (single_observation)
#   Bicarbonate: mean=25.00, last=25.00 (single_observation)
#   Anion Gap: mean=12.00, last=12.00 (single_observation)
#   Glucose: mean=106.00, last=106.00 (single_observation)
#   Magnesium: mean=2.20, last=2.20 (single_observation)
#   Hematocrit: mean=29.90, last=29.90 (single_observation)
#   Hemoglobin: mean=9.20, last=9.20 (single_observation)
#   Platelet Count: mean=296.00, last=296.00 (single_observation)
#   White Blood Cells: mean=14.00, last=14.00 (single_observation)
#   Mch: mean=29.60, last=29.60 (single_observation)
#   Mcv: mean=96.00, last=96.00 (single_observation)
#   Rdw: mean=16.10, last=16.10 (single_observation)
#   Mchc: mean=30.80, last=30.80 (single_observation)
#   Red Blood Cells: mean=3.11, last=3.11 (single_observation)
#   Rdw Sd: mean=55.50, last=55.50 (single_observation)
#   Phosphate: mean=3.70, last=3.70 (single_observation)
#   Calcium Total: mean=8.70, last=8.70 (single_observation)
#   Ptt: mean=24.50, last=24.50 (single_observation)
#   Pt: mean=15.90, last=15.90 (single_observation)
#   Inr: mean=1.50, last=1.50 (single_observation)
#
# INTERVENTIONS:
#   Medications: po_intake
#   Procedures: multi_lumen
#
# ── STEP E: FULL PROMPT SENT TO LLM ──
#
# You are an expert ICU physician. You are given patient data and 3 possible diagnoses to consider. Your task is to determine which diagnosis best fits the clinical picture.
#
# ## PATIENT DATA (Last 12 Hours in ICU)
# VITAL SIGNS (Last 12 Hours):
#   Heart Rate: mean=115.4, range=[102.0–139.0], last=109.0 (improving)
#   Respiratory Rate: mean=13.2, range=[10.0–19.0], last=13.0 (stable)
#   O2 Saturation Pulseoxymetry: mean=95.5, range=[93.0–98.0], last=96.0 (stable)
#   Non Invasive Blood Pressure Systolic: mean=118.4, range=[97.0–145.0], last=100.0 (stable)
#   Non Invasive Blood Pressure Diastolic: mean=81.9, range=[70.0–99.0], last=83.0 (stable)
#   Non Invasive Blood Pressure Mean: mean=92.6, range=[76.0–107.0], last=91.0 (stable)
#   Temperature Fahrenheit: mean=98.3, range=[97.9–98.7], last=97.9 (stable)
#   Glucose Finger Stick: mean=111.0, range=[111.0–111.0], last=111.0 (single_observation)
#   Heart Rate Alarm Low: mean=55.0, range=[55.0–55.0], last=55.0 (single_observation)
#   Heart Rate Alarm High: mean=160.0, range=[160.0–160.0], last=160.0 (single_observation)
#   O2 Saturation Pulseoxymetry Alarm Low: mean=92.0, range=[92.0–92.0], last=92.0 (single_observation)
#   O2 Saturation Pulseoxymetry Alarm High: mean=100.0, range=[100.0–100.0], last=100.0 (single_observation)
#   Spo2 Desat Limit: mean=85.0, range=[85.0–85.0], last=85.0 (single_observation)
#   Resp Alarm High: mean=35.0, range=[35.0–35.0], last=35.0 (single_observation)
#   Resp Alarm Low: mean=8.0, range=[8.0–8.0], last=8.0 (single_observation)
#   Sodium: mean=139.0, range=[139.0–139.0], last=139.0 (single_observation)
#   Hemoglobin: mean=9.2, range=[9.2–9.2], last=9.2 (single_observation)
#   Non Invasive Blood Pressure Alarm Low: mean=90.0, range=[90.0–90.0], last=90.0 (single_observation)
#   Non Invasive Blood Pressure Alarm High: mean=160.0, range=[160.0–160.0], last=160.0 (single_observation)
#   Chloride: mean=102.0, range=[102.0–102.0], last=102.0 (single_observation)
#   Anion Gap: mean=12.0, range=[12.0–12.0], last=12.0 (single_observation)
#
# LABORATORY VALUES:
#   H: mean=0.00, last=0.00 (single_observation)
#   L: mean=10.00, last=10.00 (single_observation)
#   I: mean=1.00, last=1.00 (single_observation)
#   Potassium: mean=5.00, last=5.00 (single_observation)
#   Sodium: mean=139.00, last=139.00 (single_observation)
#   Chloride: mean=102.00, last=102.00 (single_observation)
#   Creatinine: mean=1.70, last=1.70 (single_observation)
#   Urea Nitrogen: mean=37.00, last=37.00 (single_observation)
#   Bicarbonate: mean=25.00, last=25.00 (single_observation)
#   Anion Gap: mean=12.00, last=12.00 (single_observation)
#   Glucose: mean=106.00, last=106.00 (single_observation)
#   Magnesium: mean=2.20, last=2.20 (single_observation)
#   Hematocrit: mean=29.90, last=29.90 (single_observation)
#   Hemoglobin: mean=9.20, last=9.20 (single_observation)
#   Platelet Count: mean=296.00, last=296.00 (single_observation)
#   White Blood Cells: mean=14.00, last=14.00 (single_observation)
#   Mch: mean=29.60, last=29.60 (single_observation)
#   Mcv: mean=96.00, last=96.00 (single_observation)
#   Rdw: mean=16.10, last=16.10 (single_observation)
#   Mchc: mean=30.80, last=30.80 (single_observation)
#   Red Blood Cells: mean=3.11, last=3.11 (single_observation)
#   Rdw Sd: mean=55.50, last=55.50 (single_observation)
#   Phosphate: mean=3.70, last=3.70 (single_observation)
#   Calcium Total: mean=8.70, last=8.70 (single_observation)
#   Ptt: mean=24.50, last=24.50 (single_observation)
#   Pt: mean=15.90, last=15.90 (single_observation)
#   Inr: mean=1.50, last=1.50 (single_observation)
#
# INTERVENTIONS:
#   Medications: po_intake
#   Procedures: multi_lumen
#
# ## CANDIDATE DIAGNOSES
# Consider these 3 possibilities (listed in no particular order):
# - CORONARY_ARTERY_DZ
# - SEPSIS
# - ACUTE_MI
#
#
# ## YOUR TASK
# You are working with INCOMPLETE ICU data. Not all clinically relevant labs will be present. Your goal is to find the diagnosis most consistent with available evidence, explicitly accounting for what is and is not measured. A diagnosis should not be dismissed solely because its defining marker was not collected.
#
#
# Respond with ONLY valid JSON:
# {
#   "chosen_diagnosis": "DIAGNOSIS_NAME",
#   "reasoning": "2-3 sentence explanation of why this diagnosis fits best",
#   "supporting_evidence": ["key finding 1", "key finding 2", "key finding 3"],
#   "ruled_out": [
#     {"diagnosis": "OTHER_DIAGNOSIS_1", "reason": "why ruled out"},
#     {"diagnosis": "OTHER_DIAGNOSIS_2", "reason": "why ruled out"}
#   ]
# }
#
# Your chosen_diagnosis MUST be one of the 3 candidates listed above.
#
#
# ── STEP F: RAW LLM RESPONSE (parsed JSON) ──
# {
#   "chosen_diagnosis": "SEPSIS",
#   "reasoning": "The patient presents with tachycardia (mean HR 115.4) and leukocytosis (WBC 14.000), which are common signs of sepsis. While specific infection source or inflammatory markers like lactate or CRP are missing, the overall clinical picture is most suggestive of sepsis among the given options.",
#   "supporting_evidence": [
#     "Tachycardia (mean HR 115.4)",
#     "Leukocytosis (WBC 14.000)",
#     "Elevated Creatinine (1.70)"
#   ],
#   "ruled_out": [
#     {
#       "diagnosis": "CORONARY_ARTERY_DZ",
#       "reason": "No specific cardiac markers (e.g., Troponin) or ECG data are provided to support acute coronary syndrome, although tachycardia could be present."
#     },
#     {
#       "diagnosis": "ACUTE_MI",
#       "reason": "Similar to CAD, crucial data like ECG changes or cardiac enzyme elevation (Troponin) are missing, making acute MI less likely based solely on the provided data."
#     }
#   ]
# }
# SEPSIS  (accept)
#
# ── STEP G: AGENT REASONING (parsed fields) ──
#   decision (post-hoc): accept   [agent was blinded; computed from chosen_diagnosis vs LSTM top-1]
#   chosen_diagnosis   : SEPSIS
#   reasoning        :
#       The patient presents with tachycardia (mean HR 115.4) and leukocytosis (WBC 14.000), which are common signs of sepsis. While specific infection source or inflammatory markers like lactate or CRP are missing, the overall clinical picture is most suggestive of sepsis among the given options.
#   supporting_evidence:
#       • Tachycardia (mean HR 115.4)
#       • Leukocytosis (WBC 14.000)
#       • Elevated Creatinine (1.70)
#   ruled_out:
#       • CORONARY_ARTERY_DZ: No specific cardiac markers (e.g., Troponin) or ECG data are provided to support acute coronary syndrome, although tachycardia could be present.
#       • ACUTE_MI: Similar to CAD, crucial data like ECG changes or cardiac enzyme elevation (Troponin) are missing, making acute MI less likely based solely on the provided data.
#
# ── OUTCOME ──
#   LSTM top pick : SEPSIS ✗
#   Agent pick    : SEPSIS ✗  (ACCEPT)
#
# ══════════════════════════════════════════════════════════════════════════════
# CASE [74/100]  Patient 11838076  |  True: ACUTE_MI
# ══════════════════════════════════════════════════════════════════════════════
#
# ── STEP A: agent-safe card (top-level keys) ──
#   keys: ['clinical_summary', 'feature_names', 'patient_id', 'stay_id', 'time_series', 'visit_id']
#
# ── STEP B: LSTM top-K (probs shown for reference — NOT shown to agent) ──
#   1. HEART_FAILURE              56.1%
#   2. SEPSIS                     37.5%
#   3. ACUTE_MI                    5.8%
#
# ── STEP C: shuffled candidate order the agent will see (blinded) ──
#   HEART_FAILURE | ACUTE_MI | SEPSIS
#
# ── STEP D: formatted clinical summary ──
# VITAL SIGNS (Last 12 Hours):
#   Heart Rate: mean=62.3, range=[47.0–71.0], last=70.0 (worsening)
#   Respiratory Rate: mean=24.1, range=[20.0–27.0], last=20.0 (improving)
#   O2 Saturation Pulseoxymetry: mean=99.0, range=[97.0–100.0], last=100.0 (stable)
#   Non Invasive Blood Pressure Systolic: mean=163.2, range=[135.0–181.0], last=165.0 (stable)
#   Non Invasive Blood Pressure Diastolic: mean=79.9, range=[55.0–152.0], last=68.0 (worsening)
#   Non Invasive Blood Pressure Mean: mean=111.1, range=[78.0–194.0], last=194.0 (worsening)
#   Temperature Fahrenheit: mean=97.8, range=[97.6–98.0], last=97.7 (stable)
#   Heart Rate Alarm Low: mean=40.0, range=[40.0–40.0], last=40.0 (single_observation)
#   Heart Rate Alarm High: mean=130.0, range=[130.0–130.0], last=130.0 (single_observation)
#   O2 Saturation Pulseoxymetry Alarm Low: mean=90.0, range=[90.0–90.0], last=90.0 (single_observation)
#   O2 Saturation Pulseoxymetry Alarm High: mean=100.0, range=[100.0–100.0], last=100.0 (single_observation)
#   Spo2 Desat Limit: mean=85.0, range=[85.0–85.0], last=85.0 (single_observation)
#   Resp Alarm High: mean=35.0, range=[35.0–35.0], last=35.0 (single_observation)
#   Resp Alarm Low: mean=8.0, range=[8.0–8.0], last=8.0 (single_observation)
#   O2 Flow: mean=2.0, range=[2.0–2.0], last=2.0 (stable)
#   Non Invasive Blood Pressure Alarm Low: mean=90.0, range=[90.0–90.0], last=90.0 (single_observation)
#   Non Invasive Blood Pressure Alarm High: mean=160.0, range=[160.0–160.0], last=160.0 (single_observation)
#
# LABORATORY VALUES:
#   H: mean=20.00, last=20.00 (single_observation)
#   L: mean=4.00, last=4.00 (single_observation)
#   I: mean=2.00, last=2.00 (single_observation)
#   Potassium: mean=3.90, last=3.90 (single_observation)
#   Sodium: mean=149.00, last=149.00 (single_observation)
#   Chloride: mean=104.00, last=104.00 (single_observation)
#   Creatinine: mean=1.20, last=1.20 (single_observation)
#   Urea Nitrogen: mean=28.00, last=28.00 (single_observation)
#   Bicarbonate: mean=38.00, last=38.00 (single_observation)
#   Anion Gap: mean=7.00, last=7.00 (single_observation)
#   Glucose: mean=168.00, last=168.00 (single_observation)
#   Magnesium: mean=2.10, last=2.10 (single_observation)
#   Phosphate: mean=3.70, last=3.70 (single_observation)
#   Calcium Total: mean=8.30, last=8.30 (single_observation)
#
# INTERVENTIONS:
#   Medications: nacl_0_9, po_intake
#   Procedures: 20_gauge
#
# ── STEP E: FULL PROMPT SENT TO LLM ──
#
# You are an expert ICU physician. You are given patient data and 3 possible diagnoses to consider. Your task is to determine which diagnosis best fits the clinical picture.
#
# ## PATIENT DATA (Last 12 Hours in ICU)
# VITAL SIGNS (Last 12 Hours):
#   Heart Rate: mean=62.3, range=[47.0–71.0], last=70.0 (worsening)
#   Respiratory Rate: mean=24.1, range=[20.0–27.0], last=20.0 (improving)
#   O2 Saturation Pulseoxymetry: mean=99.0, range=[97.0–100.0], last=100.0 (stable)
#   Non Invasive Blood Pressure Systolic: mean=163.2, range=[135.0–181.0], last=165.0 (stable)
#   Non Invasive Blood Pressure Diastolic: mean=79.9, range=[55.0–152.0], last=68.0 (worsening)
#   Non Invasive Blood Pressure Mean: mean=111.1, range=[78.0–194.0], last=194.0 (worsening)
#   Temperature Fahrenheit: mean=97.8, range=[97.6–98.0], last=97.7 (stable)
#   Heart Rate Alarm Low: mean=40.0, range=[40.0–40.0], last=40.0 (single_observation)
#   Heart Rate Alarm High: mean=130.0, range=[130.0–130.0], last=130.0 (single_observation)
#   O2 Saturation Pulseoxymetry Alarm Low: mean=90.0, range=[90.0–90.0], last=90.0 (single_observation)
#   O2 Saturation Pulseoxymetry Alarm High: mean=100.0, range=[100.0–100.0], last=100.0 (single_observation)
#   Spo2 Desat Limit: mean=85.0, range=[85.0–85.0], last=85.0 (single_observation)
#   Resp Alarm High: mean=35.0, range=[35.0–35.0], last=35.0 (single_observation)
#   Resp Alarm Low: mean=8.0, range=[8.0–8.0], last=8.0 (single_observation)
#   O2 Flow: mean=2.0, range=[2.0–2.0], last=2.0 (stable)
#   Non Invasive Blood Pressure Alarm Low: mean=90.0, range=[90.0–90.0], last=90.0 (single_observation)
#   Non Invasive Blood Pressure Alarm High: mean=160.0, range=[160.0–160.0], last=160.0 (single_observation)
#
# LABORATORY VALUES:
#   H: mean=20.00, last=20.00 (single_observation)
#   L: mean=4.00, last=4.00 (single_observation)
#   I: mean=2.00, last=2.00 (single_observation)
#   Potassium: mean=3.90, last=3.90 (single_observation)
#   Sodium: mean=149.00, last=149.00 (single_observation)
#   Chloride: mean=104.00, last=104.00 (single_observation)
#   Creatinine: mean=1.20, last=1.20 (single_observation)
#   Urea Nitrogen: mean=28.00, last=28.00 (single_observation)
#   Bicarbonate: mean=38.00, last=38.00 (single_observation)
#   Anion Gap: mean=7.00, last=7.00 (single_observation)
#   Glucose: mean=168.00, last=168.00 (single_observation)
#   Magnesium: mean=2.10, last=2.10 (single_observation)
#   Phosphate: mean=3.70, last=3.70 (single_observation)
#   Calcium Total: mean=8.30, last=8.30 (single_observation)
#
# INTERVENTIONS:
#   Medications: nacl_0_9, po_intake
#   Procedures: 20_gauge
#
# ## CANDIDATE DIAGNOSES
# Consider these 3 possibilities (listed in no particular order):
# - HEART_FAILURE
# - ACUTE_MI
# - SEPSIS
#
#
# ## YOUR TASK
# You are working with INCOMPLETE ICU data. Not all clinically relevant labs will be present. Your goal is to find the diagnosis most consistent with available evidence, explicitly accounting for what is and is not measured. A diagnosis should not be dismissed solely because its defining marker was not collected.
#
#
# Respond with ONLY valid JSON:
# {
#   "chosen_diagnosis": "DIAGNOSIS_NAME",
#   "reasoning": "2-3 sentence explanation of why this diagnosis fits best",
#   "supporting_evidence": ["key finding 1", "key finding 2", "key finding 3"],
#   "ruled_out": [
#     {"diagnosis": "OTHER_DIAGNOSIS_1", "reason": "why ruled out"},
#     {"diagnosis": "OTHER_DIAGNOSIS_2", "reason": "why ruled out"}
#   ]
# }
#
# Your chosen_diagnosis MUST be one of the 3 candidates listed above.
#
#
# ── STEP F: RAW LLM RESPONSE (parsed JSON) ──
# {
#   "chosen_diagnosis": "SEPSIS",
#   "reasoning": "The patient presents with worsening diastolic blood pressure and mean arterial pressure, alongside a high respiratory rate, which are concerning signs potentially indicative of sepsis. While other markers are missing, the overall trend suggests a systemic inflammatory response or distributive shock, making sepsis a strong possibility.",
#   "supporting_evidence": [
#     "Worsening diastolic blood pressure (last=68.0)",
#     "Worsening mean arterial pressure (last=194.0)",
#     "Elevated respiratory rate (mean=24.1)"
#   ],
#   "ruled_out": [
#     {
#       "diagnosis": "HEART_FAILURE",
#       "reason": "No specific cardiac markers (e.g., BNP, troponin) or echocardiogram data are available to confirm heart failure, although the blood pressure changes could be consistent."
#     },
#     {
#       "diagnosis": "ACUTE_MI",
#       "reason": "No ECG or cardiac enzyme data (e.g., troponin) are provided, making it impossible to confirm or rule out an acute myocardial infarction based on the available information."
#     }
#   ]
# }
# SEPSIS  (override)
#
# ── STEP G: AGENT REASONING (parsed fields) ──
#   decision (post-hoc): override   [agent was blinded; computed from chosen_diagnosis vs LSTM top-1]
#   chosen_diagnosis   : SEPSIS
#   reasoning        :
#       The patient presents with worsening diastolic blood pressure and mean arterial pressure, alongside a high respiratory rate, which are concerning signs potentially indicative of sepsis. While other markers are missing, the overall trend suggests a systemic inflammatory response or distributive shock, making sepsis a strong possibility.
#   supporting_evidence:
#       • Worsening diastolic blood pressure (last=68.0)
#       • Worsening mean arterial pressure (last=194.0)
#       • Elevated respiratory rate (mean=24.1)
#   ruled_out:
#       • HEART_FAILURE: No specific cardiac markers (e.g., BNP, troponin) or echocardiogram data are available to confirm heart failure, although the blood pressure changes could be consistent.
#       • ACUTE_MI: No ECG or cardiac enzyme data (e.g., troponin) are provided, making it impossible to confirm or rule out an acute myocardial infarction based on the available information.
#
# ── OUTCOME ──
#   LSTM top pick : HEART_FAILURE ✗
#   Agent pick    : SEPSIS ✗  (OVERRIDE)
#
# ══════════════════════════════════════════════════════════════════════════════
# CASE [75/100]  Patient 15334501  |  True: ACUTE_MI
# ══════════════════════════════════════════════════════════════════════════════
#
# ── STEP A: agent-safe card (top-level keys) ──
#   keys: ['clinical_summary', 'feature_names', 'patient_id', 'stay_id', 'time_series', 'visit_id']
#
# ── STEP B: LSTM top-K (probs shown for reference — NOT shown to agent) ──
#   1. SEPSIS                     56.4%
#   2. HEART_FAILURE              31.0%
#   3. ACUTE_MI                   11.5%
#
# ── STEP C: shuffled candidate order the agent will see (blinded) ──
#   SEPSIS | HEART_FAILURE | ACUTE_MI
#
# ── STEP D: formatted clinical summary ──
# VITAL SIGNS (Last 12 Hours):
#   Heart Rate: mean=88.3, range=[79.0–110.0], last=82.0 (stable)
#   Respiratory Rate: mean=18.3, range=[13.0–24.0], last=21.0 (worsening)
#   O2 Saturation Pulseoxymetry: mean=95.4, range=[91.0–100.0], last=95.0 (stable)
#   Non Invasive Blood Pressure Systolic: mean=118.5, range=[92.0–145.0], last=118.0 (stable)
#   Non Invasive Blood Pressure Diastolic: mean=54.0, range=[48.0–60.0], last=60.0 (worsening)
#   Non Invasive Blood Pressure Mean: mean=71.8, range=[56.0–84.0], last=76.0 (worsening)
#   Temperature Fahrenheit: mean=98.3, range=[98.1–98.7], last=98.7 (stable)
#   Heart Rate Alarm Low: mean=40.0, range=[40.0–40.0], last=40.0 (single_observation)
#   Heart Rate Alarm High: mean=150.0, range=[150.0–150.0], last=150.0 (single_observation)
# ...
#   Glucose Finger Stick: mean=89.0, range=[84.0–94.0], last=84.0 (improving)
#   Heart Rate Alarm Low: mean=40.0, range=[40.0–40.0], last=40.0 (stable)
#   Heart Rate Alarm High: mean=130.0, range=[130.0–130.0], last=130.0 (stable)
#   O2 Saturation Pulseoxymetry Alarm Low: mean=88.0, range=[88.0–88.0], last=88.0 (stable)
#   O2 Saturation Pulseoxymetry Alarm High: mean=100.0, range=[100.0–100.0], last=100.0 (stable)
#   Spo2 Desat Limit: mean=87.0, range=[87.0–87.0], last=87.0 (stable)
#   Resp Alarm High: mean=22.0, range=[22.0–22.0], last=22.0 (stable)
#   Resp Alarm Low: mean=7.0, range=[7.0–7.0], last=7.0 (stable)
#   Non Invasive Blood Pressure Alarm Low: mean=100.0, range=[100.0–100.0], last=100.0 (stable)
#   Non Invasive Blood Pressure Alarm High: mean=220.0, range=[220.0–220.0], last=220.0 (stable)
#
# LABORATORY VALUES:
#
# INTERVENTIONS:
#   Medications: po_intake
#   Procedures: 20_gauge
#
# ── STEP E: FULL PROMPT SENT TO LLM ──
#
# You are an expert ICU physician. You are given patient data and 3 possible diagnoses to consider. Your task is to determine which diagnosis best fits the clinical picture.
#
# ## PATIENT DATA (Last 12 Hours in ICU)
# VITAL SIGNS (Last 12 Hours):
#   Heart Rate: mean=79.3, range=[68.0–93.0], last=85.0 (stable)
#   O2 Saturation Pulseoxymetry: mean=92.9, range=[91.0–94.0], last=94.0 (stable)
#   Non Invasive Blood Pressure Systolic: mean=158.2, range=[154.0–163.0], last=163.0 (stable)
#   Non Invasive Blood Pressure Diastolic: mean=95.1, range=[78.0–111.0], last=105.0 (worsening)
#   Non Invasive Blood Pressure Mean: mean=112.3, range=[104.0–125.0], last=114.0 (stable)
#   Temperature Fahrenheit: mean=98.0, range=[97.9–98.2], last=97.9 (stable)
#   Glucose Finger Stick: mean=89.0, range=[84.0–94.0], last=84.0 (improving)
#   Heart Rate Alarm Low: mean=40.0, range=[40.0–40.0], last=40.0 (stable)
#   Heart Rate Alarm High: mean=130.0, range=[130.0–130.0], last=130.0 (stable)
#   O2 Saturation Pulseoxymetry Alarm Low: mean=88.0, range=[88.0–88.0], last=88.0 (stable)
#   O2 Saturation Pulseoxymetry Alarm High: mean=100.0, range=[100.0–100.0], last=100.0 (stable)
#   Spo2 Desat Limit: mean=87.0, range=[87.0–87.0], last=87.0 (stable)
#   Resp Alarm High: mean=22.0, range=[22.0–22.0], last=22.0 (stable)
#   Resp Alarm Low: mean=7.0, range=[7.0–7.0], last=7.0 (stable)
#   Non Invasive Blood Pressure Alarm Low: mean=100.0, range=[100.0–100.0], last=100.0 (stable)
#   Non Invasive Blood Pressure Alarm High: mean=220.0, range=[220.0–220.0], last=220.0 (stable)
#
# LABORATORY VALUES:
#
# INTERVENTIONS:
#   Medications: po_intake
#   Procedures: 20_gauge
#
# ## CANDIDATE DIAGNOSES
# Consider these 3 possibilities (listed in no particular order):
# - SEPSIS
# - STROKE_NEURO
# - ACUTE_MI
#
#
# ## YOUR TASK
# You are working with INCOMPLETE ICU data. Not all clinically relevant labs will be present. Your goal is to find the diagnosis most consistent with available evidence, explicitly accounting for what is and is not measured. A diagnosis should not be dismissed solely because its defining marker was not collected.
#
#
# Respond with ONLY valid JSON:
# {
#   "chosen_diagnosis": "DIAGNOSIS_NAME",
#   "reasoning": "2-3 sentence explanation of why this diagnosis fits best",
#   "supporting_evidence": ["key finding 1", "key finding 2", "key finding 3"],
#   "ruled_out": [
#     {"diagnosis": "OTHER_DIAGNOSIS_1", "reason": "why ruled out"},
#     {"diagnosis": "OTHER_DIAGNOSIS_2", "reason": "why ruled out"}
#   ]
# }
#
# Your chosen_diagnosis MUST be one of the 3 candidates listed above.
#
#
# ── STEP F: RAW LLM RESPONSE (parsed JSON) ──
# {
#   "chosen_diagnosis": "SEPSIS",
#   "reasoning": "The patient presents with stable heart rate and oxygen saturation, but has significantly elevated blood pressure (mean 112.3, systolic 158.2) and a worsening diastolic pressure (range 78-111, last 105). While not definitive, these hemodynamic changes, especially the hypertension and widening pulse pressure, could be early signs of sepsis, particularly septic shock, which often presents with relative bradycardia or normal heart rate initially. The lack of fever or leukocytosis doesn't rule out sepsis, as immunosuppressed or elderly patients may not mount a typical response.",
#   "supporting_evidence": [
#     "Elevated systolic blood pressure (mean 158.2)",
#     "Worsening diastolic blood pressure (range 78.0–111.0)",
#     "Stable heart rate (mean 79.3)"
#   ],
#   "ruled_out": [
#     {
#       "diagnosis": "STROKE_NEURO",
#       "reason": "No focal neurological deficits or specific stroke risk factors are mentioned; vital signs are not typical for acute stroke presentation."
#     },
#     {
#       "diagnosis": "ACUTE_MI",
#       "reason": "Stable heart rate and oxygen saturation, along with lack of reported chest pain or ECG data, make acute MI less likely as the primary driver of the current presentation."
#     }
#   ]
# }
# SEPSIS  (override)
#
# ── STEP G: AGENT REASONING (parsed fields) ──
#   decision (post-hoc): override   [agent was blinded; computed from chosen_diagnosis vs LSTM top-1]
#   chosen_diagnosis   : SEPSIS
#   reasoning        :
#       The patient presents with stable heart rate and oxygen saturation, but has significantly elevated blood pressure (mean 112.3, systolic 158.2) and a worsening diastolic pressure (range 78-111, last 105). While not definitive, these hemodynamic changes, especially the hypertension and widening pulse pressure, could be early signs of sepsis, particularly septic shock, which often presents with relative bradycardia or normal heart rate initially. The lack of fever or leukocytosis doesn't rule out sepsis, as immunosuppressed or elderly patients may not mount a typical response.
#   supporting_evidence:
#       • Elevated systolic blood pressure (mean 158.2)
#       • Worsening diastolic blood pressure (range 78.0–111.0)
#       • Stable heart rate (mean 79.3)
#   ruled_out:
#       • STROKE_NEURO: No focal neurological deficits or specific stroke risk factors are mentioned; vital signs are not typical for acute stroke presentation.
#       • ACUTE_MI: Stable heart rate and oxygen saturation, along with lack of reported chest pain or ECG data, make acute MI less likely as the primary driver of the current presentation.
#
# ── OUTCOME ──
#   LSTM top pick : STROKE_NEURO ✓
#   Agent pick    : SEPSIS ✗  (OVERRIDE)
#
# ══════════════════════════════════════════════════════════════════════════════
# CASE [100/100]  Patient 15277035  |  True: CORONARY_ARTERY_DZ
# ══════════════════════════════════════════════════════════════════════════════
#
# ── STEP A: agent-safe card (top-level keys) ──
#   keys: ['clinical_summary', 'feature_names', 'patient_id', 'stay_id', 'time_series', 'visit_id']
#
# ── STEP B: LSTM top-K (probs shown for reference — NOT shown to agent) ──
#   1. CORONARY_ARTERY_DZ         49.6%
#   2. ACUTE_MI                   49.4%
#   3. SEPSIS                      0.6%
#
# ── STEP C: shuffled candidate order the agent will see (blinded) ──
#   ACUTE_MI | CORONARY_ARTERY_DZ | SEPSIS
#
# ── STEP D: formatted clinical summary ──
# VITAL SIGNS (Last 12 Hours):
#   Heart Rate: mean=78.9, range=[75.0–83.0], last=81.0 (stable)
#   Respiratory Rate: mean=20.8, range=[17.0–28.0], last=17.0 (improving)
#   O2 Saturation Pulseoxymetry: mean=99.5, range=[98.0–100.0], last=98.0 (stable)
#   Non Invasive Blood Pressure Systolic: mean=132.0, range=[118.0–153.0], last=129.0 (stable)
#   Non Invasive Blood Pressure Diastolic: mean=65.7, range=[56.5–77.0], last=67.0 (worsening)
#   Non Invasive Blood Pressure Mean: mean=82.0, range=[70.0–93.0], last=83.0 (worsening)
#   Arterial Blood Pressure Mean: mean=84.0, range=[83.0–85.0], last=85.0 (stable)
#   Arterial Blood Pressure Systolic: mean=138.0, range=[137.0–139.0], last=139.0 (stable)
#   Arterial Blood Pressure Diastolic: mean=58.0, range=[57.0–59.0], last=59.0 (stable)
#   Temperature Fahrenheit: mean=98.5, range=[98.4–98.7], last=98.7 (stable)
#   Heart Rate Alarm Low: mean=60.0, range=[60.0–60.0], last=60.0 (single_observation)
#   Heart Rate Alarm High: mean=120.0, range=[120.0–120.0], last=120.0 (single_observation)
#   O2 Saturation Pulseoxymetry Alarm Low: mean=92.0, range=[92.0–92.0], last=92.0 (single_observation)
#   O2 Saturation Pulseoxymetry Alarm High: mean=100.0, range=[100.0–100.0], last=100.0 (single_observation)
#   Spo2 Desat Limit: mean=85.0, range=[85.0–85.0], last=85.0 (single_observation)
#   Resp Alarm High: mean=35.0, range=[35.0–35.0], last=35.0 (single_observation)
#   Resp Alarm Low: mean=8.0, range=[8.0–8.0], last=8.0 (single_observation)
#   Sodium: mean=131.7, range=[129.0–134.0], last=132.0 (stable)
#   Non Invasive Blood Pressure Alarm Low: mean=90.0, range=[90.0–90.0], last=90.0 (single_observation)
#   Non Invasive Blood Pressure Alarm High: mean=160.0, range=[160.0–160.0], last=160.0 (single_observation)
#   Chloride: mean=101.0, range=[99.0–104.0], last=100.0 (stable)
#   Anion Gap: mean=12.0, range=[12.0–12.0], last=12.0 (single_observation)
#
# LABORATORY VALUES:
#   Potassium: mean=5.53, last=4.90 (stable)
#   Sodium: mean=131.67, last=132.00 (stable)
#   Chloride: mean=101.00, last=100.00 (stable)
#   Creatinine: mean=0.83, last=0.80 (stable)
#   Urea Nitrogen: mean=15.75, last=16.00 (stable)
#   Bicarbonate: mean=25.00, last=25.00 (single_observation)
#   Anion Gap: mean=12.00, last=12.00 (single_observation)
#   Glucose: mean=171.50, last=189.00 (worsening)
#   Magnesium: mean=2.00, last=1.90 (stable)
#   Hematocrit: mean=28.50, last=28.10 (stable)
#   Phosphate: mean=4.60, last=4.60 (single_observation)
#   Calcium Total: mean=8.50, last=8.50 (single_observation)
#
# INTERVENTIONS:
#   Medications: dextrose_5, po_intake
#   Procedures: 20_gauge, 18_gauge, foley_catheter, arterial_line, multi_lumen
#
# ── STEP E: FULL PROMPT SENT TO LLM ──
#
# You are an expert ICU physician. You are given patient data and 3 possible diagnoses to consider. Your task is to determine which diagnosis best fits the clinical picture.
#
# ## PATIENT DATA (Last 12 Hours in ICU)
# VITAL SIGNS (Last 12 Hours):
#   Heart Rate: mean=78.9, range=[75.0–83.0], last=81.0 (stable)
#   Respiratory Rate: mean=20.8, range=[17.0–28.0], last=17.0 (improving)
#   O2 Saturation Pulseoxymetry: mean=99.5, range=[98.0–100.0], last=98.0 (stable)
#   Non Invasive Blood Pressure Systolic: mean=132.0, range=[118.0–153.0], last=129.0 (stable)
#   Non Invasive Blood Pressure Diastolic: mean=65.7, range=[56.5–77.0], last=67.0 (worsening)
#   Non Invasive Blood Pressure Mean: mean=82.0, range=[70.0–93.0], last=83.0 (worsening)
#   Arterial Blood Pressure Mean: mean=84.0, range=[83.0–85.0], last=85.0 (stable)
#   Arterial Blood Pressure Systolic: mean=138.0, range=[137.0–139.0], last=139.0 (stable)
#   Arterial Blood Pressure Diastolic: mean=58.0, range=[57.0–59.0], last=59.0 (stable)
#   Temperature Fahrenheit: mean=98.5, range=[98.4–98.7], last=98.7 (stable)
#   Heart Rate Alarm Low: mean=60.0, range=[60.0–60.0], last=60.0 (single_observation)
#   Heart Rate Alarm High: mean=120.0, range=[120.0–120.0], last=120.0 (single_observation)
#   O2 Saturation Pulseoxymetry Alarm Low: mean=92.0, range=[92.0–92.0], last=92.0 (single_observation)
#   O2 Saturation Pulseoxymetry Alarm High: mean=100.0, range=[100.0–100.0], last=100.0 (single_observation)
#   Spo2 Desat Limit: mean=85.0, range=[85.0–85.0], last=85.0 (single_observation)
#   Resp Alarm High: mean=35.0, range=[35.0–35.0], last=35.0 (single_observation)
#   Resp Alarm Low: mean=8.0, range=[8.0–8.0], last=8.0 (single_observation)
#   Sodium: mean=131.7, range=[129.0–134.0], last=132.0 (stable)
#   Non Invasive Blood Pressure Alarm Low: mean=90.0, range=[90.0–90.0], last=90.0 (single_observation)
#   Non Invasive Blood Pressure Alarm High: mean=160.0, range=[160.0–160.0], last=160.0 (single_observation)
#   Chloride: mean=101.0, range=[99.0–104.0], last=100.0 (stable)
#   Anion Gap: mean=12.0, range=[12.0–12.0], last=12.0 (single_observation)
#
# LABORATORY VALUES:
#   Potassium: mean=5.53, last=4.90 (stable)
#   Sodium: mean=131.67, last=132.00 (stable)
#   Chloride: mean=101.00, last=100.00 (stable)
#   Creatinine: mean=0.83, last=0.80 (stable)
#   Urea Nitrogen: mean=15.75, last=16.00 (stable)
#   Bicarbonate: mean=25.00, last=25.00 (single_observation)
#   Anion Gap: mean=12.00, last=12.00 (single_observation)
#   Glucose: mean=171.50, last=189.00 (worsening)
#   Magnesium: mean=2.00, last=1.90 (stable)
#   Hematocrit: mean=28.50, last=28.10 (stable)
#   Phosphate: mean=4.60, last=4.60 (single_observation)
#   Calcium Total: mean=8.50, last=8.50 (single_observation)
#
# INTERVENTIONS:
#   Medications: dextrose_5, po_intake
#   Procedures: 20_gauge, 18_gauge, foley_catheter, arterial_line, multi_lumen
#
# ## CANDIDATE DIAGNOSES
# Consider these 3 possibilities (listed in no particular order):
# - ACUTE_MI
# - CORONARY_ARTERY_DZ
# - SEPSIS
#
#
# ## YOUR TASK
# You are working with INCOMPLETE ICU data. Not all clinically relevant labs will be present. Your goal is to find the diagnosis most consistent with available evidence, explicitly accounting for what is and is not measured. A diagnosis should not be dismissed solely because its defining marker was not collected.
#
#
# Respond with ONLY valid JSON:
# {
#   "chosen_diagnosis": "DIAGNOSIS_NAME",
#   "reasoning": "2-3 sentence explanation of why this diagnosis fits best",
#   "supporting_evidence": ["key finding 1", "key finding 2", "key finding 3"],
#   "ruled_out": [
#     {"diagnosis": "OTHER_DIAGNOSIS_1", "reason": "why ruled out"},
#     {"diagnosis": "OTHER_DIAGNOSIS_2", "reason": "why ruled out"}
#   ]
# }
#
# Your chosen_diagnosis MUST be one of the 3 candidates listed above.
#
#
# ── STEP F: RAW LLM RESPONSE (parsed JSON) ──
# {
#   "chosen_diagnosis": "SEPSIS",
#   "reasoning": "The patient presents with worsening diastolic and mean blood pressure despite relatively stable heart rate and oxygen saturation, suggesting potential distributive shock. The elevated glucose and stable but slightly low sodium could be consistent with stress hyperglycemia and fluid shifts seen in sepsis. While cardiac markers are missing, the overall picture is more suggestive of a systemic inflammatory response than an acute cardiac event.",
#   "supporting_evidence": [
#     "Worsening diastolic and mean blood pressure",
#     "Elevated glucose (189.00)",
#     "Slightly low sodium (132.00)"
#   ],
#   "ruled_out": [
#     {
#       "diagnosis": "ACUTE_MI",
#       "reason": "No specific cardiac markers (e.g., troponin, ECG) are provided to confirm myocardial injury, and vital signs are relatively stable without clear signs of cardiogenic shock."
#     },
#     {
#       "diagnosis": "CORONARY_ARTERY_DZ",
#       "reason": "This is a chronic condition, not an acute diagnosis explaining the current presentation. While the patient may have underlying CAD, the acute changes point towards sepsis."
#     }
#   ]
# }
# SEPSIS  (override)
#
# ── STEP G: AGENT REASONING (parsed fields) ──
#   decision (post-hoc): override   [agent was blinded; computed from chosen_diagnosis vs LSTM top-1]
#   chosen_diagnosis   : SEPSIS
#   reasoning        :
#       The patient presents with worsening diastolic and mean blood pressure despite relatively stable heart rate and oxygen saturation, suggesting potential distributive shock. The elevated glucose and stable but slightly low sodium could be consistent with stress hyperglycemia and fluid shifts seen in sepsis. While cardiac markers are missing, the overall picture is more suggestive of a systemic inflammatory response than an acute cardiac event.
#   supporting_evidence:
#       • Worsening diastolic and mean blood pressure
#       • Elevated glucose (189.00)
#       • Slightly low sodium (132.00)
#   ruled_out:
#       • ACUTE_MI: No specific cardiac markers (e.g., troponin, ECG) are provided to confirm myocardial injury, and vital signs are relatively stable without clear signs of cardiogenic shock.
#       • CORONARY_ARTERY_DZ: This is a chronic condition, not an acute diagnosis explaining the current presentation. While the patient may have underlying CAD, the acute changes point towards sepsis.
#
# ── OUTCOME ──
#   LSTM top pick : CORONARY_ARTERY_DZ ✓
#   Agent pick    : SEPSIS ✗  (OVERRIDE)
#
# ==============================================================================
# Pilot complete — elapsed: 1:33:30.297735
# Valid: 100/100

# %%
# ══════════════════════════════════════════════════════════════════════════════
# COMPUTE METRICS
# ══════════════════════════════════════════════════════════════════════════════

valid_results = [r for r in results if 'error' not in r]
print(f'Valid results: {len(valid_results)}/{len(results)}')

disagree_cases = []
if valid_results:
    n = len(valid_results)

    lstm_correct  = sum(r['lstm_correct']  for r in valid_results)
    agent_correct = sum(r['agent_correct'] for r in valid_results)

    both_correct   = sum(r['lstm_correct']     and r['agent_correct']     for r in valid_results)
    agent_improved = sum(not r['lstm_correct'] and r['agent_correct']     for r in valid_results)
    agent_hurt     = sum(r['lstm_correct']     and not r['agent_correct'] for r in valid_results)
    both_wrong     = sum(not r['lstm_correct'] and not r['agent_correct'] for r in valid_results)

    disagreements = sum(r['agent_disagrees'] for r in valid_results)
    true_in_topk  = sum(r['true_label'] in r['lstm_output']['top_k_codes'] for r in valid_results)

    print(f'\n{"═" * 60}')
    print(f'SINGLE AGENT RESULTS ({n} cases, top-{TOP_K})')
    print(f'{"═" * 60}')
    print(f'\nAccuracy:')
    print(f'  LSTM Top-1  : {lstm_correct}/{n} ({lstm_correct/n*100:.1f}%)')
    print(f'  Agent       : {agent_correct}/{n} ({agent_correct/n*100:.1f}%)')
    print(f'  Improvement : {(agent_correct - lstm_correct)/n*100:+.1f}%')
    print(f'\nTrue in top-{TOP_K}: {true_in_topk}/{n} ({true_in_topk/n*100:.1f}%)')
    print(f'Agent disagreed: {disagreements}/{n} ({disagreements/n*100:.1f}%)')
    print(f'\nCase Breakdown:')
    print(f'  Both correct    : {both_correct} ({both_correct/n*100:.1f}%)')
    print(f'  Agent improved  : {agent_improved} ({agent_improved/n*100:.1f}%) 🎉')
    print(f'  Agent hurt      : {agent_hurt} ({agent_hurt/n*100:.1f}%) ⚠️')
    print(f'  Both wrong      : {both_wrong} ({both_wrong/n*100:.1f}%)')
    print(f'\nNet: {agent_improved - agent_hurt:+d} cases')

    disagree_cases = [r for r in valid_results if r['agent_disagrees']]
# Out:
# Valid results: 100/100
#
# ════════════════════════════════════════════════════════════
# SINGLE AGENT RESULTS (100 cases, top-3)
# ════════════════════════════════════════════════════════════
#
# Accuracy:
#   LSTM Top-1  : 65/100 (65.0%)
#   Agent       : 39/100 (39.0%)
#   Improvement : -26.0%
#
# True in top-3: 96/100 (96.0%)
# Agent disagreed: 61/100 (61.0%)
#
# Case Breakdown:
#   Both correct    : 28 (28.0%)
#   Agent improved  : 11 (11.0%) 🎉
#   Agent hurt      : 37 (37.0%) ⚠️
#   Both wrong      : 24 (24.0%)
#
# Net: -26 cases

# %%
import pandas as pd

# Ensure valid_results is defined, in case the previous cell was not executed
valid_results = [r for r in results if 'error' not in r]

table_data = []
for r in valid_results:
    lstm_top_pick = r['lstm_top_pick']
    true_label = r['true_label']
    lstm_confidence = f"{r['lstm_output']['top_k_probs'][0]:.1%}"
    agent_pick = r['agent_prediction']

    # Map agent_decision to 'Accept' or 'Reject'
    decision_text = 'Accept' if r['agent_decision'] == 'accept' else 'Reject'

    # Map agent_correct to 'Correct' or 'Wrong'
    agent_result_text = 'Correct' if r['agent_correct'] else 'Wrong'

    table_data.append({
        'True Label': true_label,
        'LSTM Top-1': lstm_top_pick,
        'LSTM Confidence (%)': lstm_confidence,
        'Agent Pick': agent_pick,
        'Decision (Accept/Reject)': decision_text,
        'Result (Correct/Wrong)': agent_result_text
    })

df_results = pd.DataFrame(table_data)

print("\nSummary of all 100 cases:")
df_results
# Out:
# Summary of all 100 cases:
#             True Label          LSTM Top-1 LSTM Confidence (%) Agent Pick  \
# 0               SEPSIS              SEPSIS               49.5%     SEPSIS
# 1               SEPSIS       HEART_FAILURE               51.5%     SEPSIS
# 2               SEPSIS              SEPSIS               34.4%     SEPSIS
# 3               SEPSIS              SEPSIS               60.9%     SEPSIS
# 4               SEPSIS              SEPSIS               41.5%     SEPSIS
# ..                 ...                 ...                 ...        ...
# 95       HEART_FAILURE       HEART_FAILURE               54.1%     SEPSIS
# 96       HEART_FAILURE       HEART_FAILURE               64.5%     SEPSIS
# 97       HEART_FAILURE            ACUTE_MI               32.6%     SEPSIS
# 98        STROKE_NEURO        STROKE_NEURO               94.1%     SEPSIS
# 99  CORONARY_ARTERY_DZ  CORONARY_ARTERY_DZ               49.6%     SEPSIS
#
#    Decision (Accept/Reject) Result (Correct/Wrong)
# 0                    Accept                Correct
# 1                    Reject                Correct
# 2                    Accept                Correct
# 3                    Accept                Correct
# 4                    Accept                Correct
# ..                      ...                    ...
# 95                   Reject                  Wrong
# 96                   Reject                  Wrong
# 97                   Reject                  Wrong
# 98                   Reject                  Wrong
# 99                   Reject                  Wrong
#
# [100 rows x 6 columns]
#             True Label          LSTM Top-1 LSTM Confidence (%) Agent Pick  \
# 0               SEPSIS              SEPSIS               49.5%     SEPSIS
# 1               SEPSIS       HEART_FAILURE               51.5%     SEPSIS
# 2               SEPSIS              SEPSIS               34.4%     SEPSIS
# 3               SEPSIS              SEPSIS               60.9%     SEPSIS
# 4               SEPSIS              SEPSIS               41.5%     SEPSIS
# ..                 ...                 ...                 ...        ...
# 95       HEART_FAILURE       HEART_FAILURE               54.1%     SEPSIS
# 96       HEART_FAILURE       HEART_FAILURE               64.5%     SEPSIS
# 97       HEART_FAILURE            ACUTE_MI               32.6%     SEPSIS
# 98        STROKE_NEURO        STROKE_NEURO               94.1%     SEPSIS
# 99  CORONARY_ARTERY_DZ  CORONARY_ARTERY_DZ               49.6%     SEPSIS
#
#    Decision (Accept/Reject) Result (Correct/Wrong)
# 0                    Accept                Correct
# 1                    Reject                Correct
# 2                    Accept                Correct
# 3                    Accept                Correct
# 4                    Accept                Correct
# ..                      ...                    ...
# 95                   Reject                  Wrong
# 96                   Reject                  Wrong
# 97                   Reject                  Wrong
# 98                   Reject                  Wrong
# 99                   Reject                  Wrong
#
# [100 rows x 6 columns]

# %%
# ══════════════════════════════════════════════════════════════════════════════
# INSPECT A CASE
# ══════════════════════════════════════════════════════════════════════════════

def inspect_case(result):
    print('═' * 70)
    print(f"PATIENT: {result['patient_id']}")
    print('═' * 70)
    print(f"\n🎯 TRUE: {result['true_label']}")

    print(f"\n📊 LSTM TOP-{TOP_K} (probs not shown to agent):")
    for i, (code, prob) in enumerate(zip(
        result['lstm_output']['top_k_codes'],
        result['lstm_output']['top_k_probs']
    )):
        mark = '✓' if code == result['true_label'] else ' '
        tag  = '  ← LSTM top pick' if i == 0 else ''
        print(f"   {i+1}. {code:<25} {prob:>6.1%} {mark}{tag}")

    print(f"\n   What the agent saw (no probs):")
    print(f"     LSTM top pick   : {result.get('lstm_top_pick')}")
    for c in result.get('other_candidates_shown', []):
        print(f"     other candidate : {c}")

    print(f"\n🤖 AGENT DECISION:")
    print(f"   Decision: {result.get('agent_decision', '?').upper()}")
    print(f"   Chose   : {result['agent_prediction']}")

    ao = result['agent_output']
    if 'lstm_top_pick_assessment' in ao:
        print(f"\n   LSTM top-pick assessment: {ao['lstm_top_pick_assessment']}")
    if 'reasoning' in ao:
        print(f"\n   Reasoning: {ao['reasoning']}")
    if 'supporting_evidence' in ao:
        print(f"\n   Supporting evidence:")
        for ev in ao['supporting_evidence'][:3]:
            print(f"     • {ev}")
    if 'ruled_out' in ao:
        print(f"\n   Ruled out:")
        for ro in ao['ruled_out']:
            print(f"     • {ro.get('diagnosis', '?')}: {ro.get('reason', 'N/A')}")

    print(f"\n{'─' * 70}")
    if result['lstm_correct'] and result['agent_correct']:
        print('✅ BOTH CORRECT')
    elif not result['lstm_correct'] and result['agent_correct']:
        print('🎉 AGENT IMPROVED (override was right)' if result['agent_decision'] == 'override'
              else '🎉 AGENT CORRECT (accepted correct LSTM pick)')
    elif result['lstm_correct'] and not result['agent_correct']:
        print('⚠️ AGENT HURT (overrode a correct LSTM pick)')
    else:
        print('❌ BOTH WRONG')

if valid_results:
    inspect_case(valid_results[0])

# %%
import pandas as pd

# Ensure valid_results is defined, in case the previous cell was not executed
valid_results = [r for r in results if 'error' not in r]

table_data = []
for r in valid_results:
    lstm_top_pick = r['lstm_top_pick']
    true_label = r['true_label']
    lstm_confidence = f"{r['lstm_output']['top_k_probs'][0]:.1%}"
    agent_pick = r['agent_prediction']
    decision = r['agent_decision'].upper()

    agent_result = 'CORRECT' if r['agent_correct'] else 'INCORRECT'

    table_data.append({
        'Patient ID': r['patient_id'],
        'LSTM Top-1': lstm_top_pick,
        'True Label': true_label,
        'LSTM Confidence': lstm_confidence,
        'Agent Pick': agent_pick,
        'Decision': decision,
        'Agent Result': agent_result
    })

df_results = pd.DataFrame(table_data)

print("\nSummary of all 100 cases:")
display(df_results)

# %%
# ══════════════════════════════════════════════════════════════════════════════
# DISAGREEMENTS WHERE TRUE IS IN LSTM TOP-K
# ══════════════════════════════════════════════════════════════════════════════
print('\n' + '═' * 60)
print('DISAGREEMENTS WHERE TRUE IS IN LSTM TOP-K')
print('═' * 60)

true_in_topk_disagreements = [
    r for r in disagree_cases
    if r['true_label'] in r['lstm_output']['top_k_codes']
]

if true_in_topk_disagreements:
    for r in true_in_topk_disagreements:
        print(f'\n  Patient {r["patient_id"]}')
        print(f'    True: {r["true_label"]}')
        print(f'    LSTM Top-{TOP_K}: {r["lstm_output"]["top_k_codes"]}')
        print(f'    Agent: {r["agent_prediction"]}')
    for result_item in true_in_topk_disagreements:
        inspect_case(result_item)
else:
    print('  No cases where agent disagreed and true label was in LSTM top-K.')
